# %%
import pandas as pd
import json
from openai import OpenAI
from typing import List, Tuple
import tiktoken  # Tokenizer library

with open('input/secret.json', 'r', encoding='UTF-8') as file:
    secret_json = json.load(file)
api_key = secret_json['OPENAI_API_KEY']
client = OpenAI(api_key=api_key)

# %%
# Load the DataFrame from CSV
df_train = pd.read_csv('output/pii_detected_trf_train.csv')

# Define the category dictionary
category_dict = {
    'PERSON': "student's name",
    'EMAIL_ADDRESS': "personal email address",
    'URL': "personal URL",
    'PHONE_NUMBER': "personal phone number"
}

# Prepare the JSONL data for fine-tuning
jsonl_data = []

for index, row in df_train.iterrows():
    entity_text = row['entity_text']
    entity_type = row['type']
    # sentence = row['sentence']
    context = row['context']
    true_label = row['true_label']
    
    # Generate the structured message
    message = {
        "messages": [
            {"role": "system", "content": "You are an expert in verifying Personally Identifiable Information."},
            {"role": "user", "content": f"Determine if '{entity_text}' is a {category_dict[entity_type]} in this context: '{context}'? Output only 'T' for True or 'F' for False without additional output. Be very careful of outputting F due to PII leakage."},
            {"role": "assistant", "content": true_label}
        ]
    }
    
    # Append to the JSONL data list
    jsonl_data.append(message)

# Write to a JSONL file
output_file = 'output/pii_detected_train.jsonl'
with open(output_file, 'w') as f:
    for entry in jsonl_data:
        f.write(json.dumps(entry) + '\n')

# %%
client = OpenAI(api_key="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")

# Load your CSV file
df_test = pd.read_csv('output/pii_detected_trf_test.csv')
# df_test_sample = df_test[df_test['file_idx'].isin([5,7,8,11,16,19,23,31,39,42])]

# Prepare the results list
results = []

# Define the category dictionary
category_dict = {
    'PERSON': "student's name",
    'EMAIL_ADDRESS': "personal email address",
    'URL': "personal URL",
    'PHONE_NUMBER': "personal phone number"
}

total_len = len(df_test)

for index, row in df_test.iterrows():
    print(f"Processing row {index}/{total_len}:")
    entity_text = row['entity_text']
    entity_type = row['type']
    context = row['context']
    true_label = row['true_label']
    
    try:
        response = client.chat.completions.create(
            model="ft:gpt-4o-mini-2024-07-18:personal::A86tyITx",
            messages=[
                {"role": "system", "content": "You are an expert in verifying Personally Identifiable Information."},
                {"role": "user", "content": f"Determine if '{entity_text}' is a {category_dict[entity_type]} in this context: '{context}'? Output only 'T' for True or 'F' for False without additional output. Be very careful of outputting F due to PII leakage."}
            ],
            temperature = 0
        )
        gpt_output = response.choices[0].message.content.strip().upper()

        print(f"Text: {entity_text}, Type: {entity_type}, True: {true_label}, Pred: {gpt_output}")
        
        # Determine if entity should be kept
        if gpt_output == 'T':
            results.append({
                'file_idx': row['file_idx'],
                'entity_text': entity_text,
                'type': entity_type,
                'positions': row['positions']
            })
        elif gpt_output == 'F':
            continue
        else:
            print(f"Unexpected response for row {index}: {gpt_output}")

    except Exception as e:
        print(f"Error processing row {index}: {e}")

# Convert results to DataFrame
filtered_df = pd.DataFrame(results)

# Save the results to a new CSV file
filtered_df.to_csv('output/pii_pre+ft_detected.csv', index=False)

print("Processing complete. Results saved to 'output/pii_pre+ft_detected.csv'.")
# Out:
# Processing row 0/12197:
# Text: https://www.santander.com/content/dam/santander-com/es/documentos/informe-anual-de-sostenibilidad/2019/ias-2019-informe-de-, Type: URL, True: F, Pred: F
# Processing row 1/12197:
# Text: https://www.greatplacetowork.com/resources/blog/why-is-diversity-inclusion-in-the-workplace-important, Type: URL, True: F, Pred: F
# Processing row 2/12197:
# Text: Nathalie Sylla, Type: PERSON, True: T, Pred: T
# Processing row 3/12197:
# Text: Buzan T., Type: PERSON, True: F, Pred: F
# Processing row 4/12197:
# Text: Buzan B., Type: PERSON, True: F, Pred: F
# Processing row 5/12197:
# Text: Nathalie Sylla, Type: PERSON, True: T, Pred: T
# Processing row 6/12197:
# Text: Nathalie Sylla, Type: PERSON, True: T, Pred: T
# Processing row 7/12197:
# Text: Vanesa Chan, Type: PERSON, True: T, Pred: T
# Processing row 8/12197:
# Text: Aristotle, Type: PERSON, True: F, Pred: F
# Processing row 9/12197:
# Text: James Cook, Type: PERSON, True: T, Pred: T
# Processing row 10/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 11/12197:
# Text: Gilberto Gamboa, Type: PERSON, True: T, Pred: T
# Processing row 12/12197:
# Text: Alessandro, Type: PERSON, True: T, Pred: T
# Processing row 13/12197:
# Text: Alessandro, Type: PERSON, True: T, Pred: T
# Processing row 14/12197:
# Text: Gianni, Type: PERSON, True: T, Pred: F
# Processing row 15/12197:
# Text: Don Norman, Type: PERSON, True: F, Pred: F
# Processing row 16/12197:
# Text: Don Norman, Type: PERSON, True: F, Pred: F
# Processing row 17/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 18/12197:
# Text: Janet Galdamez, Type: PERSON, True: F, Pred: F
# Processing row 19/12197:
# Text: Personas, Type: PERSON, True: F, Pred: F
# Processing row 20/12197:
# Text: David  Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 21/12197:
# Text: David Gray's, Type: PERSON, True: F, Pred: F
# Processing row 22/12197:
# Text: Socrates, Type: PERSON, True: F, Pred: F
# Processing row 23/12197:
# Text: Peg Neuhauser, Type: PERSON, True: F, Pred: F
# Processing row 24/12197:
# Text: Jerome Bruner, Type: PERSON, True: F, Pred: F
# Processing row 25/12197:
# Text: Lopez, Type: PERSON, True: F, Pred: F
# Processing row 26/12197:
# Text: Jennifer, Type: PERSON, True: F, Pred: F
# Processing row 27/12197:
# Text: Stefan Thomke, Type: PERSON, True: F, Pred: F
# Processing row 28/12197:
# Text: Umm Gabriel, Type: PERSON, True: F, Pred: F
# Processing row 29/12197:
# Text: Ali Kraft’s, Type: PERSON, True: F, Pred: F
# Processing row 30/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 31/12197:
# Text: booking.com, Type: URL, True: F, Pred: F
# Processing row 32/12197:
# Text: Karol Ferreira, Type: PERSON, True: T, Pred: T
# Processing row 33/12197:
# Text: Karol Ferreira, Type: PERSON, True: T, Pred: T
# Processing row 34/12197:
# Text: Carlos Flores, Type: PERSON, True: F, Pred: F
# Processing row 35/12197:
# Text: sathya meva jayathe’s, Type: PERSON, True: F, Pred: F
# Processing row 36/12197:
# Text: Rakesh Singh, Type: PERSON, True: T, Pred: T
# Processing row 37/12197:
# Text: Yoni Solis, Type: PERSON, True: F, Pred: F
# Processing row 38/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 39/12197:
# Text: Yoni Solis, Type: PERSON, True: F, Pred: F
# Processing row 40/12197:
# Text: Laura Moshkela, Type: PERSON, True: F, Pred: F
# Processing row 41/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 42/12197:
# Text: Sami, Type: PERSON, True: F, Pred: F
# Processing row 43/12197:
# Text: Sami, Type: PERSON, True: F, Pred: T
# Processing row 44/12197:
# Text: Sami, Type: PERSON, True: F, Pred: F
# Processing row 45/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 46/12197:
# Text: Sami, Type: PERSON, True: F, Pred: F
# Processing row 47/12197:
# Text: Sami, Type: PERSON, True: F, Pred: F
# Processing row 48/12197:
# Text: Sami, Type: PERSON, True: F, Pred: F
# Processing row 49/12197:
# Text: Sami, Type: PERSON, True: F, Pred: F
# Processing row 50/12197:
# Text: Silvia Villalobos, Type: PERSON, True: T, Pred: T
# Processing row 51/12197:
# Text: Francisco Ferreira, Type: PERSON, True: T, Pred: T
# Processing row 52/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 53/12197:
# Text: Diogenes, Type: PERSON, True: F, Pred: F
# Processing row 54/12197:
# Text: Sinope, Type: PERSON, True: F, Pred: F
# Processing row 55/12197:
# Text: Diogenes, Type: PERSON, True: F, Pred: F
# Processing row 56/12197:
# Text: Diogenes, Type: PERSON, True: F, Pred: F
# Processing row 57/12197:
# Text: Stefano Lovato, Type: PERSON, True: T, Pred: T
# Processing row 58/12197:
# Text: Sathyabama, Type: PERSON, True: F, Pred: T
# Processing row 59/12197:
# Text: Adam Smith’s, Type: PERSON, True: F, Pred: F
# Processing row 60/12197:
# Text: John Stuart  Mill, Type: PERSON, True: F, Pred: F
# Processing row 61/12197:
# Text: Gerashchenko Igor, Type: PERSON, True: F, Pred: F
# Processing row 62/12197:
# Text: Alexander Shmakov, Type: PERSON, True: F, Pred: F
# Processing row 63/12197:
# Text: A, Type: PERSON, True: F, Pred: F
# Processing row 64/12197:
# Text: B, Type: PERSON, True: F, Pred: F
# Processing row 65/12197:
# Text: B, Type: PERSON, True: F, Pred: F
# Processing row 66/12197:
# Text: Ernst Fehr, Type: PERSON, True: F, Pred: F
# Processing row 67/12197:
# Text: Urs Fischbacher, Type: PERSON, True: F, Pred: F
# Processing row 68/12197:
# Text: S., Type: PERSON, True: F, Pred: F
# Processing row 69/12197:
# Text: Kolm, Type: PERSON, True: F, Pred: F
# Processing row 70/12197:
# Text: J. Ythier, Type: PERSON, True: F, Pred: F
# Processing row 71/12197:
# Text: Fehr, Type: PERSON, True: F, Pred: F
# Processing row 72/12197:
# Text: Schmidt, Type: PERSON, True: F, Pred: F
# Processing row 73/12197:
# Text: https://en.wikipedia.org/wiki/Homo_economicus, Type: URL, True: F, Pred: F
# Processing row 74/12197:
# Text: https://cyberleninka.ru/article/n/stremlenie-, Type: URL, True: F, Pred: F
# Processing row 75/12197:
# Text: http://www.intelros.ru/readroom/credo_new/k3-2018/36398-eticheskoe-, Type: URL, True: F, Pred: F
# Processing row 76/12197:
# Text: https://cyberleninka.ru/article/n/14398333, Type: URL, True: F, Pred: F
# Processing row 77/12197:
# Text: https://cyberleninka.ru/article/n/stremlenie-k-spravedlivomu-sotrudnichestvu-kak-, Type: URL, True: F, Pred: F
# Processing row 78/12197:
# Text: https://econweb.ucsd.edu/~jandreon/WorkingPapers/Philanthropy.pdf, Type: URL, True: F, Pred: F
# Processing row 79/12197:
# Text: https://www.me, Type: URL, True: F, Pred: F
# Processing row 80/12197:
# Text: shiv khera, Type: PERSON, True: F, Pred: F
# Processing row 81/12197:
# Text: K.Kamarajar, Type: PERSON, True: F, Pred: F
# Processing row 82/12197:
# Text: shiv khera, Type: PERSON, True: F, Pred: F
# Processing row 83/12197:
# Text: Corrector, Type: PERSON, True: F, Pred: F
# Processing row 84/12197:
# Text: Al, Type: PERSON, True: T, Pred: T
# Processing row 85/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/lsFRa/, Type: URL, True: F, Pred: F
# Processing row 86/12197:
# Text: Approach, Type: PERSON, True: F, Pred: F
# Processing row 87/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/xju53/, Type: URL, True: F, Pred: F
# Processing row 88/12197:
# Text: Chalenge, Type: PERSON, True: F, Pred: F
# Processing row 89/12197:
# Text: Dan Roam, Type: PERSON, True: F, Pred: F
# Processing row 90/12197:
# Text: Jameson, Type: PERSON, True: F, Pred: F
# Processing row 91/12197:
# Text: Pepa Medrano, Type: PERSON, True: T, Pred: T
# Processing row 92/12197:
# Text: Mind Mapping, Type: PERSON, True: F, Pred: F
# Processing row 93/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 94/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 95/12197:
# Text: Chris Sims, Type: PERSON, True: F, Pred: F
# Processing row 96/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 97/12197:
# Text: https://en.wikipedia.org/wiki/Storytelling, Type: URL, True: F, Pred: F
# Processing row 98/12197:
# Text: Leonardo Da Vinci, Type: PERSON, True: F, Pred: F
# Processing row 99/12197:
# Text: Grace Akello, Type: PERSON, True: F, Pred: F
# Processing row 100/12197:
# Text: Grace, Type: PERSON, True: F, Pred: F
# Processing row 101/12197:
# Text: Grace, Type: PERSON, True: F, Pred: F
# Processing row 102/12197:
# Text: http://www.fao.org/kenya/fao-in-kenya/kenya-at-a-glance/en/, Type: URL, True: F, Pred: F
# Processing row 103/12197:
# Text: https://en.wikipedia.org/wiki/M-Pesa, Type: URL, True: F, Pred: F
# Processing row 104/12197:
# Text: Danny Long, Type: PERSON, True: T, Pred: T
# Processing row 105/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 106/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 107/12197:
# Text: Manuel Alvarez, Type: PERSON, True: T, Pred: T
# Processing row 108/12197:
# Text: John Walsh, Type: PERSON, True: F, Pred: F
# Processing row 109/12197:
# Text: Rama, Type: PERSON, True: F, Pred: F
# Processing row 110/12197:
# Text: Rizan Rizvi, Type: PERSON, True: F, Pred: T
# Processing row 111/12197:
# Text: https://www.linkedin.com/pulse/importance-visualisation-design-thinking-rizan-rizvi/, Type: URL, True: F, Pred: T
# Processing row 112/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 113/12197:
# Text: Moskowitz, Type: PERSON, True: F, Pred: F
# Processing row 114/12197:
# Text: Saguy, Type: PERSON, True: F, Pred: F
# Processing row 115/12197:
# Text: ISIGHTS, Type: PERSON, True: F, Pred: F
# Processing row 116/12197:
# Text: Covey, Type: PERSON, True: F, Pred: F
# Processing row 117/12197:
# Text: David, Type: PERSON, True: F, Pred: F
# Processing row 118/12197:
# Text: Steffen Aziz, Type: PERSON, True: F, Pred: F
# Processing row 119/12197:
# Text: Claudia Sarria., Type: PERSON, True: F, Pred: T
# Processing row 120/12197:
# Text: Mohammad Samer, Type: PERSON, True: T, Pred: T
# Processing row 121/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 122/12197:
# Text: Ana Gomez, Type: PERSON, True: F, Pred: F
# Processing row 123/12197:
# Text: Ed Hasse, Type: PERSON, True: F, Pred: F
# Processing row 124/12197:
# Text: Rajinder Santos, Type: PERSON, True: T, Pred: T
# Processing row 125/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 126/12197:
# Text: Juan Magnani, Type: PERSON, True: T, Pred: T
# Processing row 127/12197:
# Text: Juan Magnani, Type: PERSON, True: T, Pred: T
# Processing row 128/12197:
# Text: Tom, Type: PERSON, True: F, Pred: F
# Processing row 129/12197:
# Text: Cristina Shani, Type: PERSON, True: T, Pred: T
# Processing row 130/12197:
# Text: https://www.jackson.com/list/explorehomepage.htm, Type: URL, True: T, Pred: T
# Processing row 131/12197:
# Text: David Grey’, Type: PERSON, True: F, Pred: F
# Processing row 132/12197:
# Text: Cris, Type: PERSON, True: F, Pred: F
# Processing row 133/12197:
# Text: Cris, Type: PERSON, True: F, Pred: F
# Processing row 134/12197:
# Text: Coursera, Type: PERSON, True: F, Pred: F
# Processing row 135/12197:
# Text: Applicaiton, Type: PERSON, True: F, Pred: F
# Processing row 136/12197:
# Text: Davide Carletti, Type: PERSON, True: T, Pred: T
# Processing row 137/12197:
# Text: Yeimy Molina, Type: PERSON, True: T, Pred: T
# Processing row 138/12197:
# Text: Karan Patel, Type: PERSON, True: T, Pred: T
# Processing row 139/12197:
# Text: Andres Diaz, Type: PERSON, True: T, Pred: T
# Processing row 140/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 141/12197:
# Text: Andres Diaz, Type: PERSON, True: T, Pred: T
# Processing row 142/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 143/12197:
# Text: Milton Desai, Type: PERSON, True: T, Pred: T
# Processing row 144/12197:
# Text: Sundar Pichai, Type: PERSON, True: F, Pred: F
# Processing row 145/12197:
# Text: Luis Ramadan, Type: PERSON, True: T, Pred: T
# Processing row 146/12197:
# Text: Barry Buzan, Type: PERSON, True: F, Pred: F
# Processing row 147/12197:
# Text: Tony Buzan, Type: PERSON, True: F, Pred: F
# Processing row 148/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 149/12197:
# Text: Shahzad Johnson, Type: PERSON, True: T, Pred: T
# Processing row 150/12197:
# Text: https://www.mdpi.com/2078-2489/9/3/65/pdf, Type: URL, True: F, Pred: F
# Processing row 151/12197:
# Text: Cesar Rivera, Type: PERSON, True: T, Pred: T
# Processing row 152/12197:
# Text: Juan Hernandez, Type: PERSON, True: T, Pred: T
# Processing row 153/12197:
# Text: Deans, Type: PERSON, True: F, Pred: F
# Processing row 154/12197:
# Text: Carl Jung, Type: PERSON, True: F, Pred: F
# Processing row 155/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 156/12197:
# Text: Angel Aguilar, Type: PERSON, True: T, Pred: T
# Processing row 157/12197:
# Text: Jeoff, Type: PERSON, True: F, Pred: F
# Processing row 158/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 159/12197:
# Text: geoff, Type: PERSON, True: F, Pred: F
# Processing row 160/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 161/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 162/12197:
# Text: Rose Morales, Type: PERSON, True: F, Pred: F
# Processing row 163/12197:
# Text: david Kelly, Type: PERSON, True: F, Pred: F
# Processing row 164/12197:
# Text: Marlene Carrasquillo, Type: PERSON, True: F, Pred: F
# Processing row 165/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 166/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 167/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 168/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 169/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/F04r6/learning-launch-, Type: URL, True: F, Pred: F
# Processing row 170/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 171/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 172/12197:
# Text: Olivia Nelson, Type: PERSON, True: F, Pred: F
# Processing row 173/12197:
# Text: Lauren Burnett, Type: PERSON, True: F, Pred: F
# Processing row 174/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 175/12197:
# Text: JT, Type: PERSON, True: F, Pred: T
# Processing row 176/12197:
# Text: Daniel, Type: PERSON, True: T, Pred: T
# Processing row 177/12197:
# Text: Suhag Shah, Type: PERSON, True: T, Pred: T
# Processing row 178/12197:
# Text: https://youtu.be/rFD2lJuvace, Type: URL, True: T, Pred: F
# Processing row 179/12197:
# Text: Henk Van Der Heijden, Type: PERSON, True: T, Pred: T
# Processing row 180/12197:
# Text: Mind Mapping Tool, Type: PERSON, True: F, Pred: F
# Processing row 181/12197:
# Text: Ed Hesse, Type: PERSON, True: F, Pred: F
# Processing row 182/12197:
# Text: Jeff Bezos’s, Type: PERSON, True: F, Pred: F
# Processing row 183/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 184/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 185/12197:
# Text: Lucas Martin  Zapata, Type: PERSON, True: F, Pred: T
# Processing row 186/12197:
# Text: Salah Ammar, Type: PERSON, True: F, Pred: T
# Processing row 187/12197:
# Text: Angela Mayer, Type: PERSON, True: F, Pred: F
# Processing row 188/12197:
# Text: Peter Theil, Type: PERSON, True: F, Pred: F
# Processing row 189/12197:
# Text: Eric Ries, Type: PERSON, True: F, Pred: F
# Processing row 190/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 191/12197:
# Text: Peter, Type: PERSON, True: F, Pred: F
# Processing row 192/12197:
# Text: Peter, Type: PERSON, True: F, Pred: F
# Processing row 193/12197:
# Text: Peter, Type: PERSON, True: F, Pred: F
# Processing row 194/12197:
# Text: Gisela Parissenti, Type: PERSON, True: F, Pred: T
# Processing row 195/12197:
# Text: - Adesh M. Jadhav, Type: PERSON, True: F, Pred: F
# Processing row 196/12197:
# Text: Barnett, Type: PERSON, True: F, Pred: F
# Processing row 197/12197:
# Text: S. de Castro, Type: PERSON, True: F, Pred: F
# Processing row 198/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 199/12197:
# Text: Isaac Newton, Type: PERSON, True: F, Pred: F
# Processing row 200/12197:
# Text: Marian   , Type: PERSON, True: F, Pred: F
# Processing row 201/12197:
# Text: Moore, Type: PERSON, True: F, Pred: F
# Processing row 202/12197:
# Text: Jeanne, Type: PERSON, True: F, Pred: F
# Processing row 203/12197:
# Text: Fishbone, Type: PERSON, True: F, Pred: F
# Processing row 204/12197:
# Text: abhishekkumarbrahma@gmail.com, Type: EMAIL_ADDRESS, True: F, Pred: T
# Processing row 205/12197:
# Text: Abhishek Kumar Brahma, Type: PERSON, True: F, Pred: T
# Processing row 206/12197:
# Text: Hazel Wagner, Type: PERSON, True: F, Pred: F
# Processing row 207/12197:
# Text: Jeanne Liedtka, Type: PERSON, True: F, Pred: F
# Processing row 208/12197:
# Text: Tim Ogilvie, Type: PERSON, True: F, Pred: F
# Processing row 209/12197:
# Text: Martine Davies, Type: PERSON, True: F, Pred: F
# Processing row 210/12197:
# Text: Radheyshyam Pal, Type: PERSON, True: F, Pred: T
# Processing row 211/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 212/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 213/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 214/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 215/12197:
# Text: Alexander Osterwalder, Type: PERSON, True: F, Pred: F
# Processing row 216/12197:
# Text: https://www.youtube.com/watch?v=QoAOzMTLP5s, Type: URL, True: F, Pred: F
# Processing row 217/12197:
# Text: https://www.wagner.net/categoriesmain.jsp, Type: URL, True: T, Pred: T
# Processing row 218/12197:
# Text: Eina Nazim, Type: PERSON, True: T, Pred: T
# Processing row 219/12197:
# Text: Cesar Rodriguez, Type: PERSON, True: T, Pred: T
# Processing row 220/12197:
# Text: CHALLENGE, Type: PERSON, True: F, Pred: F
# Processing row 221/12197:
# Text: Joseph Campbell’s, Type: PERSON, True: F, Pred: F
# Processing row 222/12197:
# Text: George Lucas’, Type: PERSON, True: F, Pred: F
# Processing row 223/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 224/12197:
# Text: Mauro Pacheco, Type: PERSON, True: T, Pred: T
# Processing row 225/12197:
# Text: -
#
# Iftikhar Ansari, Type: PERSON, True: F, Pred: T
# Processing row 226/12197:
# Text: SELECTION, Type: PERSON, True: F, Pred: F
# Processing row 227/12197:
# Text: Mohd Asim, Type: PERSON, True: T, Pred: T
# Processing row 228/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 229/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 230/12197:
# Text: Darton, Type: PERSON, True: F, Pred: F
# Processing row 231/12197:
# Text: Theresa Escobar, Type: PERSON, True: F, Pred: T
# Processing row 232/12197:
# Text: https://miro.com/app/board/o9J_koq3hdU=/,, Type: URL, True: F, Pred: F
# Processing row 233/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 234/12197:
# Text: Kevin Lopez, Type: PERSON, True: T, Pred: T
# Processing row 235/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 236/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 237/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 238/12197:
# Text: Simon Welch, Type: PERSON, True: F, Pred: F
# Processing row 239/12197:
# Text: Lucia Tapia, Type: PERSON, True: F, Pred: F
# Processing row 240/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 241/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 242/12197:
# Text: May Kook, Type: PERSON, True: T, Pred: T
# Processing row 243/12197:
# Text: Raaz Gupta, Type: PERSON, True: F, Pred: F
# Processing row 244/12197:
# Text: Mairan, Type: PERSON, True: F, Pred: F
# Processing row 245/12197:
# Text: Raaz Gupta, Type: PERSON, True: F, Pred: F
# Processing row 246/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 247/12197:
# Text: Jeff, Type: PERSON, True: F, Pred: F
# Processing row 248/12197:
# Text: Chris, Type: PERSON, True: F, Pred: F
# Processing row 249/12197:
# Text: Princess, Type: PERSON, True: F, Pred: F
# Processing row 250/12197:
# Text: Miriam Durango, Type: PERSON, True: T, Pred: T
# Processing row 251/12197:
# Text: soving metho ds typicaly, Type: PERSON, True: F, Pred: F
# Processing row 252/12197:
# Text: David Gray's, Type: PERSON, True: F, Pred: F
# Processing row 253/12197:
# Text: Application, Type: PERSON, True: F, Pred: F
# Processing row 254/12197:
# Text: Nomfundo, Type: PERSON, True: T, Pred: T
# Processing row 255/12197:
# Text: Nomfundo, Type: PERSON, True: T, Pred: T
# Processing row 256/12197:
# Text: Carlos, Type: PERSON, True: T, Pred: T
# Processing row 257/12197:
# Text: Carlos, Type: PERSON, True: T, Pred: T
# Processing row 258/12197:
# Text: Akash Thakur, Type: PERSON, True: T, Pred: T
# Processing row 259/12197:
# Text: Approach, Type: PERSON, True: F, Pred: F
# Processing row 260/12197:
# Text: Rick, Type: PERSON, True: F, Pred: F
# Processing row 261/12197:
# Text: Edgar Lara, Type: PERSON, True: T, Pred: T
# Processing row 262/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 263/12197:
# Text: Danny Rose, Type: PERSON, True: T, Pred: T
# Processing row 264/12197:
# Text: Paul, Type: PERSON, True: F, Pred: F
# Processing row 265/12197:
# Text: Ahmed Saeed, Type: PERSON, True: T, Pred: T
# Processing row 266/12197:
# Text: Ahmed Saeed, Type: PERSON, True: T, Pred: T
# Processing row 267/12197:
# Text: Ahmed Saeed, Type: PERSON, True: T, Pred: T
# Processing row 268/12197:
# Text: CHALLENGE, Type: PERSON, True: F, Pred: F
# Processing row 269/12197:
# Text: Nestor Puerta, Type: PERSON, True: T, Pred: T
# Processing row 270/12197:
# Text: Joao Courtois, Type: PERSON, True: T, Pred: T
# Processing row 271/12197:
# Text: Itai   Ben-Jacob, Type: PERSON, True: F, Pred: F
# Processing row 272/12197:
# Text: Itai   Ben, Type: PERSON, True: F, Pred: F
# Processing row 273/12197:
# Text: Christian   , Type: PERSON, True: F, Pred: F
# Processing row 274/12197:
# Text: Itai   Ben, Type: PERSON, True: F, Pred: F
# Processing row 275/12197:
# Text: Pavel   , Type: PERSON, True: F, Pred: F
# Processing row 276/12197:
# Text: Roman, Type: PERSON, True: F, Pred: F
# Processing row 277/12197:
# Text: Njoud Kumar, Type: PERSON, True: T, Pred: T
# Processing row 278/12197:
# Text: Njoud Kumar, Type: PERSON, True: T, Pred: T
# Processing row 279/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 280/12197:
# Text: Manuel Vazquez, Type: PERSON, True: T, Pred: T
# Processing row 281/12197:
# Text: https://www.youtube.com/watch?v=Kx0SXy87bVZ, Type: URL, True: T, Pred: F
# Processing row 282/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 283/12197:
# Text: https://www.youtube.com/watch?v=zFBa7URT654, Type: URL, True: F, Pred: F
# Processing row 284/12197:
# Text: http://bit.ly/1QObSRy, Type: URL, True: F, Pred: F
# Processing row 285/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 286/12197:
# Text: Anna, Type: PERSON, True: F, Pred: F
# Processing row 287/12197:
# Text: Anna, Type: PERSON, True: F, Pred: F
# Processing row 288/12197:
# Text: Anna, Type: PERSON, True: F, Pred: F
# Processing row 289/12197:
# Text: Anna, Type: PERSON, True: F, Pred: F
# Processing row 290/12197:
# Text: Anna, Type: PERSON, True: F, Pred: F
# Processing row 291/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 292/12197:
# Text: Richa Arora, Type: PERSON, True: F, Pred: T
# Processing row 293/12197:
# Text: Richa Arora, Type: PERSON, True: F, Pred: T
# Processing row 294/12197:
# Text: AUTHOR
#
# HELBERT, Type: PERSON, True: F, Pred: F
# Processing row 295/12197:
# Text: AUTHOR
#
# HELBERT RODRIGUEZ AGUDELO, Type: PERSON, True: F, Pred: F
# Processing row 296/12197:
# Text: Ed Hesse, Type: PERSON, True: F, Pred: F
# Processing row 297/12197:
# Text: Javier Barragán, Type: PERSON, True: F, Pred: T
# Processing row 298/12197:
# Text: Ulrich, Type: PERSON, True: F, Pred: F
# Processing row 299/12197:
# Text: Eppinger, Type: PERSON, True: F, Pred: F
# Processing row 300/12197:
# Text: Ulrich, Type: PERSON, True: F, Pred: F
# Processing row 301/12197:
# Text: Eppinger, Type: PERSON, True: F, Pred: F
# Processing row 302/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 303/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 304/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 305/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 306/12197:
# Text: https://www.coursera.org/learn/design-thinking-innovation/lecture/PAXCd/storytelling-tool, Type: URL, True: F, Pred: F
# Processing row 307/12197:
# Text: https://www.coursera.org/learn/design-thinking-innovation/lecture/W6oQ4/the-story-of-george-geoff, Type: URL, True: F, Pred: F
# Processing row 308/12197:
# Text: Fermín Torroba, Type: PERSON, True: F, Pred: T
# Processing row 309/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 310/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 311/12197:
# Text: Myer, Type: PERSON, True: F, Pred: F
# Processing row 312/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-, Type: URL, True: F, Pred: F
# Processing row 313/12197:
# Text: https://www.versionone.com/pdf/state-of-agile-development-survey-ninth.pdf, Type: URL, True: F, Pred: F
# Processing row 314/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 315/12197:
# Text: Marian Moore, Type: PERSON, True: F, Pred: F
# Processing row 316/12197:
# Text: Aristotle, Type: PERSON, True: F, Pred: F
# Processing row 317/12197:
# Text: Rick, Type: PERSON, True: F, Pred: F
# Processing row 318/12197:
# Text: Rick, Type: PERSON, True: F, Pred: F
# Processing row 319/12197:
# Text: Rick, Type: PERSON, True: F, Pred: F
# Processing row 320/12197:
# Text: Rick, Type: PERSON, True: F, Pred: F
# Processing row 321/12197:
# Text: Rick, Type: PERSON, True: F, Pred: F
# Processing row 322/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 323/12197:
# Text: harley davidson, Type: PERSON, True: F, Pred: F
# Processing row 324/12197:
# Text: DeMorgan, Type: PERSON, True: F, Pred: F
# Processing row 325/12197:
# Text: Eric BERNE, Type: PERSON, True: F, Pred: F
# Processing row 326/12197:
# Text: John Kotter, Type: PERSON, True: F, Pred: F
# Processing row 327/12197:
# Text: Eliyahu M.  GOLDRATT, Type: PERSON, True: F, Pred: F
# Processing row 328/12197:
# Text: John Kotter, Type: PERSON, True: F, Pred: F
# Processing row 329/12197:
# Text: Eric BERNE, Type: PERSON, True: F, Pred: F
# Processing row 330/12197:
# Text: Eliyahu M.  GOLDRATT, Type: PERSON, True: F, Pred: F
# Processing row 331/12197:
# Text: Mihály  Csíkszentmihályi, Type: PERSON, True: F, Pred: F
# Processing row 332/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 333/12197:
# Text: Mlungisi Msibi, Type: PERSON, True: T, Pred: T
# Processing row 334/12197:
# Text: 05.02.2021, Type: PHONE_NUMBER, True: F, Pred: F
# Processing row 335/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 336/12197:
# Text: Yago Pena, Type: PERSON, True: F, Pred: T
# Processing row 337/12197:
# Text: João Miranda, Type: PERSON, True: F, Pred: T
# Processing row 338/12197:
# Text: Ed Hesse’s, Type: PERSON, True: F, Pred: F
# Processing row 339/12197:
# Text: Alonso Antón Rodríguez
#
# Challenge, Type: PERSON, True: F, Pred: F
# Processing row 340/12197:
# Text: Alexandra	Cherali, Type: PERSON, True: F, Pred: T
# Processing row 341/12197:
# Text: Alexandra, Type: PERSON, True: F, Pred: T
# Processing row 342/12197:
# Text: Tony  Buzan, Type: PERSON, True: F, Pred: F
# Processing row 343/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 344/12197:
# Text: J. Liedtka, Type: PERSON, True: F, Pred: F
# Processing row 345/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 346/12197:
# Text: Geff, Type: PERSON, True: F, Pred: F
# Processing row 347/12197:
# Text: Reflection, Type: PERSON, True: F, Pred: F
# Processing row 348/12197:
# Text: Christos SIDIROPOULOS, Type: PERSON, True: F, Pred: T
# Processing row 349/12197:
# Text: Christos Sidiropoulos, Type: PERSON, True: F, Pred: T
# Processing row 350/12197:
# Text: https://youtu.be/lkniTyQ3RBQ, Type: URL, True: F, Pred: T
# Processing row 351/12197:
# Text: D. G. Kulkarni- India, Type: PERSON, True: F, Pred: F
# Processing row 352/12197:
# Text: Princess, Type: PERSON, True: F, Pred: F
# Processing row 353/12197:
# Text: Ed Hess, Type: PERSON, True: F, Pred: F
# Processing row 354/12197:
# Text: Darshan Deepak Ruhtiya, Type: PERSON, True: F, Pred: T
# Processing row 355/12197:
# Text: Marian Moore, Type: PERSON, True: F, Pred: F
# Processing row 356/12197:
# Text: Jeanne Liedtka, Type: PERSON, True: F, Pred: F
# Processing row 357/12197:
# Text: Tim Ogilvie, Type: PERSON, True: F, Pred: F
# Processing row 358/12197:
# Text: Steven D. Rubin, Type: PERSON, True: F, Pred: F
# Processing row 359/12197:
# Text: Krishna, Type: PERSON, True: F, Pred: F
# Processing row 360/12197:
# Text: Krishna, Type: PERSON, True: F, Pred: F
# Processing row 361/12197:
# Text: Ibrahim Lodi, Type: PERSON, True: F, Pred: F
# Processing row 362/12197:
# Text: R Akhil karthik, Type: PERSON, True: F, Pred: T
# Processing row 363/12197:
# Text: vasanth
#
# 18, Type: PERSON, True: F, Pred: F
# Processing row 364/12197:
# Text: Tharun
#
# 18, Type: PERSON, True: F, Pred: F
# Processing row 365/12197:
# Text: Kamal, Type: PERSON, True: F, Pred: T
# Processing row 366/12197:
# Text: Arnob Saha, Type: PERSON, True: F, Pred: T
# Processing row 367/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 368/12197:
# Text: David Gray's, Type: PERSON, True: F, Pred: F
# Processing row 369/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 370/12197:
# Text: l, Type: PERSON, True: F, Pred: F
# Processing row 371/12197:
# Text: Gabriela, Type: PERSON, True: F, Pred: F
# Processing row 372/12197:
# Text: Matheus Baumgart, Type: PERSON, True: F, Pred: T
# Processing row 373/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 374/12197:
# Text: Approach, Type: PERSON, True: F, Pred: F
# Processing row 375/12197:
# Text: David  Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 376/12197:
# Text: Lukas Knecht, Type: PERSON, True: F, Pred: T
# Processing row 377/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 378/12197:
# Text: Ashley Johnston, Type: PERSON, True: F, Pred: T
# Processing row 379/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 380/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 381/12197:
# Text: Colbert, Type: PERSON, True: F, Pred: T
# Processing row 382/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 383/12197:
# Text: Jeanne Liedtka, Type: PERSON, True: F, Pred: F
# Processing row 384/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 385/12197:
# Text: https://www.texasgateway.org/resource/interpreting-scatterplots, Type: URL, True: F, Pred: F
# Processing row 386/12197:
# Text: https://www.sas.com/en_us/insights/big-data/data-visualization.html, Type: URL, True: F, Pred: F
# Processing row 387/12197:
# Text: David Dark's, Type: PERSON, True: F, Pred: F
# Processing row 388/12197:
# Text: https://coursera.org/share/b1c94445935e19fd9e7ffe6921b721e5, Type: URL, True: F, Pred: F
# Processing row 389/12197:
# Text: CHALLENGE, Type: PERSON, True: F, Pred: F
# Processing row 390/12197:
# Text: David Kelley, Type: PERSON, True: F, Pred: F
# Processing row 391/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-, Type: URL, True: F, Pred: F
# Processing row 392/12197:
# Text: the Jacqueline Novogratz, Type: PERSON, True: F, Pred: F
# Processing row 393/12197:
# Text: Ed Hesse, Type: PERSON, True: F, Pred: F
# Processing row 394/12197:
# Text: Rebecca Huynh, Type: PERSON, True: F, Pred: F
# Processing row 395/12197:
# Text: Rebecca Huynh, Type: PERSON, True: F, Pred: F
# Processing row 396/12197:
# Text: Jeanne, Type: PERSON, True: F, Pred: F
# Processing row 397/12197:
# Text: Luis Henrique, Type: PERSON, True: T, Pred: T
# Processing row 398/12197:
# Text: Paul Iles, Type: PERSON, True: F, Pred: F
# Processing row 399/12197:
# Text: Shakespeare, Type: PERSON, True: F, Pred: F
# Processing row 400/12197:
# Text: Alfredo RBH, Type: PERSON, True: F, Pred: F
# Processing row 401/12197:
# Text: John Dewey, Type: PERSON, True: F, Pred: F
# Processing row 402/12197:
# Text: Inspiration, Type: PERSON, True: F, Pred: F
# Processing row 403/12197:
# Text: way.An, Type: URL, True: F, Pred: F
# Processing row 404/12197:
# Text: Jakob Nielsen, Type: PERSON, True: F, Pred: F
# Processing row 405/12197:
# Text: Nielsen, Type: PERSON, True: F, Pred: F
# Processing row 406/12197:
# Text: Nielsen, Type: PERSON, True: F, Pred: F
# Processing row 407/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 408/12197:
# Text: Amina, Type: PERSON, True: F, Pred: F
# Processing row 409/12197:
# Text: Amina, Type: PERSON, True: F, Pred: F
# Processing row 410/12197:
# Text: Amina, Type: PERSON, True: F, Pred: F
# Processing row 411/12197:
# Text: Amina, Type: PERSON, True: F, Pred: F
# Processing row 412/12197:
# Text: Amina, Type: PERSON, True: F, Pred: F
# Processing row 413/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 414/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 415/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 416/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 417/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 418/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 419/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 420/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 421/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 422/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 423/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 424/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 425/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 426/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 427/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 428/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 429/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 430/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 431/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 432/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 433/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 434/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 435/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 436/12197:
# Text: Jane, Type: PERSON, True: F, Pred: F
# Processing row 437/12197:
# Text: Robert, Type: PERSON, True: F, Pred: F
# Processing row 438/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 439/12197:
# Text: Reflection, Type: PERSON, True: F, Pred: F
# Processing row 440/12197:
# Text: Kim Frank, Type: PERSON, True: F, Pred: F
# Processing row 441/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 442/12197:
# Text: Michelle, Type: PERSON, True: F, Pred: F
# Processing row 443/12197:
# Text: Michelle, Type: PERSON, True: F, Pred: F
# Processing row 444/12197:
# Text: Fatima Molina, Type: PERSON, True: T, Pred: T
# Processing row 445/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: T
# Processing row 446/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: T
# Processing row 447/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: F
# Processing row 448/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: T
# Processing row 449/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: T
# Processing row 450/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: T
# Processing row 451/12197:
# Text: Fatima, Type: PERSON, True: T, Pred: F
# Processing row 452/12197:
# Text: fresher, Type: PERSON, True: F, Pred: F
# Processing row 453/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 454/12197:
# Text: Makhoul, Type: PERSON, True: F, Pred: F
# Processing row 455/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 456/12197:
# Text: Christian Schmidt, Type: PERSON, True: T, Pred: T
# Processing row 457/12197:
# Text: Christian Schmidt, Type: PERSON, True: T, Pred: T
# Processing row 458/12197:
# Text: Narayan Majid, Type: PERSON, True: T, Pred: T
# Processing row 459/12197:
# Text: Pamela Cruz, Type: PERSON, True: F, Pred: F
# Processing row 460/12197:
# Text: https://www.youtube.com/watch?v=j6Ro7TPzRoo, Type: URL, True: F, Pred: F
# Processing row 461/12197:
# Text: https://www.youtube.com/watch?v=34EuT2KH2Lw, Type: URL, True: F, Pred: T
# Processing row 462/12197:
# Text: G. Zaltman, Type: PERSON, True: F, Pred: F
# Processing row 463/12197:
# Text: G Zaltman, Type: PERSON, True: F, Pred: F
# Processing row 464/12197:
# Text: Jim Simons, Type: PERSON, True: F, Pred: F
# Processing row 465/12197:
# Text: Jim Simons, Type: PERSON, True: F, Pred: F
# Processing row 466/12197:
# Text: Jim Simons, Type: PERSON, True: F, Pred: F
# Processing row 467/12197:
# Text: Jim Simons, Type: PERSON, True: F, Pred: F
# Processing row 468/12197:
# Text: G. Zuckerman, Type: PERSON, True: F, Pred: F
# Processing row 469/12197:
# Text: Jim Simons, Type: PERSON, True: F, Pred: F
# Processing row 470/12197:
# Text: Romaric Ngambo, Type: PERSON, True: F, Pred: T
# Processing row 471/12197:
# Text: Romaric Ngambo
#
# Insight, Type: PERSON, True: F, Pred: F
# Processing row 472/12197:
# Text: Marian Moore, Type: PERSON, True: F, Pred: F
# Processing row 473/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 474/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 475/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 476/12197:
# Text: wat wovs, Type: PERSON, True: F, Pred: F
# Processing row 477/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 478/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 479/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 480/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 481/12197:
# Text: Mariam Moore, Type: PERSON, True: F, Pred: F
# Processing row 482/12197:
# Text: Alfredo Caballero Diaz, Type: PERSON, True: F, Pred: T
# Processing row 483/12197:
# Text: Anders Wikstrom, Type: PERSON, True: F, Pred: F
# Processing row 484/12197:
# Text: Valeria Godofredo Osorio, Type: PERSON, True: F, Pred: T
# Processing row 485/12197:
# Text: Olga Malysheva, Type: PERSON, True: T, Pred: T
# Processing row 486/12197:
# Text: Jose Torres, Type: PERSON, True: T, Pred: T
# Processing row 487/12197:
# Text: Samsul Khan, Type: PERSON, True: T, Pred: T
# Processing row 488/12197:
# Text: Florian Richter, Type: PERSON, True: T, Pred: T
# Processing row 489/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 490/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 491/12197:
# Text: Centurion, Type: PERSON, True: F, Pred: F
# Processing row 492/12197:
# Text: Centurion, Type: PERSON, True: F, Pred: F
# Processing row 493/12197:
# Text: Centurion, Type: PERSON, True: F, Pred: F
# Processing row 494/12197:
# Text: Centurion, Type: PERSON, True: F, Pred: F
# Processing row 495/12197:
# Text: Jesus, Type: PERSON, True: F, Pred: F
# Processing row 496/12197:
# Text: Pilate, Type: PERSON, True: F, Pred: F
# Processing row 497/12197:
# Text: Pontius Pilate, Type: PERSON, True: F, Pred: F
# Processing row 498/12197:
# Text: Jesus Christ, Type: PERSON, True: F, Pred: F
# Processing row 499/12197:
# Text: Mary, Type: PERSON, True: F, Pred: F
# Processing row 500/12197:
# Text: Joseph, Type: PERSON, True: F, Pred: F
# Processing row 501/12197:
# Text: Jesus, Type: PERSON, True: F, Pred: F
# Processing row 502/12197:
# Text: Pontius Pilate, Type: PERSON, True: F, Pred: F
# Processing row 503/12197:
# Text: Pontius Pilate, Type: PERSON, True: F, Pred: F
# Processing row 504/12197:
# Text: Jesus Christ, Type: PERSON, True: F, Pred: F
# Processing row 505/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 506/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 507/12197:
# Text: Tanvi Shah, Type: PERSON, True: F, Pred: T
# Processing row 508/12197:
# Text: Simon Nkabinde, Type: PERSON, True: T, Pred: T
# Processing row 509/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 510/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 511/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 512/12197:
# Text: Jose Suarez, Type: PERSON, True: T, Pred: T
# Processing row 513/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 514/12197:
# Text: Antonio Torres, Type: PERSON, True: F, Pred: F
# Processing row 515/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 516/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 517/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 518/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 519/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 520/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 521/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 522/12197:
# Text: Tony, Type: PERSON, True: F, Pred: F
# Processing row 523/12197:
# Text: Henrik Kniberg, Type: PERSON, True: F, Pred: F
# Processing row 524/12197:
# Text: https://www.youtube.com/watch?v=n7wH2XdOWpM,, Type: URL, True: F, Pred: F
# Processing row 525/12197:
# Text: Michael Richter, Type: PERSON, True: F, Pred: F
# Processing row 526/12197:
# Text: Sandra Valencia, Type: PERSON, True: T, Pred: T
# Processing row 527/12197:
# Text: Nathan Curtis, Type: PERSON, True: F, Pred: F
# Processing row 528/12197:
# Text: Kamban, Type: PERSON, True: F, Pred: F
# Processing row 529/12197:
# Text: Nathan Curtis, Type: PERSON, True: F, Pred: F
# Processing row 530/12197:
# Text: Jina Anne, Type: PERSON, True: F, Pred: F
# Processing row 531/12197:
# Text: Nathan Curtis’, Type: PERSON, True: F, Pred: F
# Processing row 532/12197:
# Text: Yuli Thomas, Type: PERSON, True: F, Pred: F
# Processing row 533/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 534/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 535/12197:
# Text: Jack, Type: PERSON, True: F, Pred: F
# Processing row 536/12197:
# Text: Jack, Type: PERSON, True: F, Pred: F
# Processing row 537/12197:
# Text: Angela Maier, Type: PERSON, True: F, Pred: F
# Processing row 538/12197:
# Text: Marian  , Type: PERSON, True: F, Pred: F
# Processing row 539/12197:
# Text: Moor, Type: PERSON, True: F, Pred: F
# Processing row 540/12197:
# Text: Vicki Mahi, Type: PERSON, True: T, Pred: T
# Processing row 541/12197:
# Text: Vicki Mahi, Type: PERSON, True: T, Pred: T
# Processing row 542/12197:
# Text: Hamada, Type: PERSON, True: F, Pred: F
# Processing row 543/12197:
# Text: Nompilo Mthembu, Type: PERSON, True: T, Pred: T
# Processing row 544/12197:
# Text: CHALLENGE, Type: PERSON, True: F, Pred: F
# Processing row 545/12197:
# Text: David  Gray's, Type: PERSON, True: F, Pred: F
# Processing row 546/12197:
# Text: Mohd Javed, Type: PERSON, True: T, Pred: T
# Processing row 547/12197:
# Text: Ray, Type: PERSON, True: T, Pred: T
# Processing row 548/12197:
# Text: Ishikawa, Type: PERSON, True: F, Pred: F
# Processing row 549/12197:
# Text: Tony Buzan, Type: PERSON, True: F, Pred: F
# Processing row 550/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 551/12197:
# Text: Meadows, Type: PERSON, True: F, Pred: F
# Processing row 552/12197:
# Text: Moore, Type: PERSON, True: F, Pred: F
# Processing row 553/12197:
# Text: Jose, Type: PERSON, True: F, Pred: F
# Processing row 554/12197:
# Text: Ana, Type: PERSON, True: F, Pred: F
# Processing row 555/12197:
# Text: Carlos, Type: PERSON, True: F, Pred: F
# Processing row 556/12197:
# Text: Andrea, Type: PERSON, True: F, Pred: F
# Processing row 557/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 558/12197:
# Text: David  Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 559/12197:
# Text: SELECTION, Type: PERSON, True: F, Pred: F
# Processing row 560/12197:
# Text: Chuck Frey, Type: PERSON, True: F, Pred: F
# Processing row 561/12197:
# Text: Darwin, Type: PERSON, True: F, Pred: F
# Processing row 562/12197:
# Text: Medo Uddin, Type: PERSON, True: T, Pred: T
# Processing row 563/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 564/12197:
# Text: Meenakshi Mathur, Type: PERSON, True: F, Pred: T
# Processing row 565/12197:
# Text: Darden, Type: PERSON, True: F, Pred: F
# Processing row 566/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-innovation, Type: URL, True: F, Pred: F
# Processing row 567/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-, Type: URL, True: F, Pred: F
# Processing row 568/12197:
# Text: Rekha Nambiar, Type: PERSON, True: F, Pred: T
# Processing row 569/12197:
# Text: Rekha Nambiar, Type: PERSON, True: F, Pred: T
# Processing row 570/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 571/12197:
# Text: Fernando Lima, Type: PERSON, True: F, Pred: T
# Processing row 572/12197:
# Text: Samaa Abdelghany, Type: PERSON, True: F, Pred: T
# Processing row 573/12197:
# Text: David Gray's, Type: PERSON, True: F, Pred: F
# Processing row 574/12197:
# Text: https://commons.wikimedia.org/wiki/File:Benefits_and_Challenges_of_Distance_Education.jpg, Type: URL, True: F, Pred: F
# Processing row 575/12197:
# Text: Isaac David Quirós Romero, Type: PERSON, True: F, Pred: T
# Processing row 576/12197:
# Text: Sathvika, Type: PERSON, True: F, Pred: T
# Processing row 577/12197:
# Text: Bharath, Type: PERSON, True: F, Pred: T
# Processing row 578/12197:
# Text: 222010404041, Type: PERSON, True: F, Pred: F
# Processing row 579/12197:
# Text: Johanna Cabrera, Type: PERSON, True: F, Pred: T
# Processing row 580/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 581/12197:
# Text: Jean Jones, Type: PERSON, True: F, Pred: F
# Processing row 582/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 583/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 584/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 585/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 586/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 587/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 588/12197:
# Text: Jean, Type: PERSON, True: F, Pred: F
# Processing row 589/12197:
# Text: Michelle McIntyre, Type: PERSON, True: F, Pred: T
# Processing row 590/12197:
# Text: Michelle, Type: PERSON, True: F, Pred: F
# Processing row 591/12197:
# Text: Michelle, Type: PERSON, True: F, Pred: F
# Processing row 592/12197:
# Text: Michelle, Type: PERSON, True: F, Pred: F
# Processing row 593/12197:
# Text: Jay Singh, Type: PERSON, True: F, Pred: T
# Processing row 594/12197:
# Text: Jay, Type: PERSON, True: F, Pred: F
# Processing row 595/12197:
# Text: https://www.designthinking.services/herramdamientos-design-thinking/storytelli, Type: URL, True: F, Pred: F
# Processing row 596/12197:
# Text: https://www.youtube.com/watch?v=I0qsOs1Y4Do, Type: URL, True: F, Pred: T
# Processing row 597/12197:
# Text: Andre  Martin, Type: PERSON, True: F, Pred: F
# Processing row 598/12197:
# Text: Baymax, Type: PERSON, True: F, Pred: F
# Processing row 599/12197:
# Text: Germán Márquez, Type: PERSON, True: F, Pred: T
# Processing row 600/12197:
# Text: DOLAPO ALADE, Type: PERSON, True: F, Pred: T
# Processing row 601/12197:
# Text: David, Type: PERSON, True: F, Pred: F
# Processing row 602/12197:
# Text: Goliath, Type: PERSON, True: F, Pred: F
# Processing row 603/12197:
# Text: Goliath, Type: PERSON, True: F, Pred: F
# Processing row 604/12197:
# Text: David, Type: PERSON, True: F, Pred: F
# Processing row 605/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 606/12197:
# Text: Geoth, Type: PERSON, True: F, Pred: F
# Processing row 607/12197:
# Text: Approach, Type: PERSON, True: F, Pred: F
# Processing row 608/12197:
# Text: Moses, Type: PERSON, True: F, Pred: F
# Processing row 609/12197:
# Text: Mahatma Gandhi, Type: PERSON, True: F, Pred: F
# Processing row 610/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 611/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 612/12197:
# Text: Steve Jobs, Type: PERSON, True: F, Pred: F
# Processing row 613/12197:
# Text: Sims, Type: PERSON, True: F, Pred: F
# Processing row 614/12197:
# Text: Robert Sims, Type: PERSON, True: F, Pred: F
# Processing row 615/12197:
# Text: Ashraf, Type: PERSON, True: F, Pred: F
# Processing row 616/12197:
# Text: Al Mkhonza, Type: PERSON, True: T, Pred: T
# Processing row 617/12197:
# ...
# Text: Ryan Johnson, Type: PERSON, True: T, Pred: F
# Processing row 11999/12197:
# Text: Ryan Johnson, Type: PERSON, True: T, Pred: T
# Processing row 12000/12197:
# Text: Daniel Rayan, Type: PERSON, True: F, Pred: T
# Processing row 12001/12197:
# Text: Deepak Thakur, Type: PERSON, True: T, Pred: T
# Processing row 12002/12197:
# Text: https://www.designthinkingformobility.org/wp-, Type: URL, True: F, Pred: F
# Processing row 12003/12197:
# Text: Francesca Hussain’s, Type: PERSON, True: F, Pred: F
# Processing row 12004/12197:
# Text: Melanie   Pinola, Type: PERSON, True: F, Pred: F
# Processing row 12005/12197:
# Text: http://lifehacker.com/how-to-use-mind-maps-to-unleash-your-, Type: URL, True: F, Pred: F
# Processing row 12006/12197:
# Text: 1348869811, Type: PHONE_NUMBER, True: F, Pred: F
# Processing row 12007/12197:
# Text: Giovanni De Maio, Type: PERSON, True: T, Pred: T
# Processing row 12008/12197:
# Text: Auwal De Maio, Type: PERSON, True: T, Pred: T
# Processing row 12009/12197:
# Text: George, Type: PERSON, True: F, Pred: F
# Processing row 12010/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 12011/12197:
# Text: Odysseus, Type: PERSON, True: F, Pred: F
# Processing row 12012/12197:
# Text: Portman, Type: PERSON, True: F, Pred: F
# Processing row 12013/12197:
# Text: Natalie   Portman, Type: PERSON, True: F, Pred: F
# Processing row 12014/12197:
# Text: Madelon, Type: PERSON, True: F, Pred: T
# Processing row 12015/12197:
# Text: René, Type: PERSON, True: F, Pred: T
# Processing row 12016/12197:
# Text: Madelon, Type: PERSON, True: F, Pred: T
# Processing row 12017/12197:
# Text: Madelon, Type: PERSON, True: F, Pred: T
# Processing row 12018/12197:
# Text: Madelon, Type: PERSON, True: F, Pred: F
# Processing row 12019/12197:
# Text: Madelon, Type: PERSON, True: F, Pred: T
# Processing row 12020/12197:
# Text: René, Type: PERSON, True: F, Pred: F
# Processing row 12021/12197:
# Text: https://www.nngroup.com/articles/storyboards-visualize-ideas/, Type: URL, True: F, Pred: F
# Processing row 12022/12197:
# Text: Stephen Chan, Type: PERSON, True: T, Pred: T
# Processing row 12023/12197:
# Text: JK Rowling, Type: PERSON, True: F, Pred: F
# Processing row 12024/12197:
# Text: JK Rowling, Type: PERSON, True: F, Pred: F
# Processing row 12025/12197:
# Text: JK Rowling, Type: PERSON, True: F, Pred: F
# Processing row 12026/12197:
# Text: Amelia Earhart, Type: PERSON, True: F, Pred: F
# Processing row 12027/12197:
# Text: Jose Luis Gaudenzi, Type: PERSON, True: T, Pred: T
# Processing row 12028/12197:
# Text: katherinebrady@gmail.com, Type: EMAIL_ADDRESS, True: T, Pred: T
# Processing row 12029/12197:
# Text: Arvind Vikash Kumar, Type: PERSON, True: T, Pred: T
# Processing row 12030/12197:
# Text: Rodolfo Jimenez, Type: PERSON, True: T, Pred: T
# Processing row 12031/12197:
# Text: Tony Busan, Type: PERSON, True: F, Pred: F
# Processing row 12032/12197:
# Text: Norma Alvarado, Type: PERSON, True: T, Pred: T
# Processing row 12033/12197:
# Text: Ted, Type: PERSON, True: F, Pred: F
# Processing row 12034/12197:
# Text: Alice, Type: PERSON, True: F, Pred: F
# Processing row 12035/12197:
# Text: Alice, Type: PERSON, True: F, Pred: F
# Processing row 12036/12197:
# Text: Alice, Type: PERSON, True: F, Pred: F
# Processing row 12037/12197:
# Text: http://www.silverdialogue.co.uk/word_clouds.html, Type: URL, True: F, Pred: T
# Processing row 12038/12197:
# Text: Jimmy, Type: PERSON, True: F, Pred: F
# Processing row 12039/12197:
# Text: Jimmy, Type: PERSON, True: F, Pred: F
# Processing row 12040/12197:
# Text: Jimmy, Type: PERSON, True: F, Pred: F
# Processing row 12041/12197:
# Text: Messi, Type: PERSON, True: F, Pred: F
# Processing row 12042/12197:
# Text: Gretel, Type: PERSON, True: F, Pred: F
# Processing row 12043/12197:
# Text: Steve, Type: PERSON, True: F, Pred: F
# Processing row 12044/12197:
# Text: John Ortiz, Type: PERSON, True: F, Pred: F
# Processing row 12045/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 12046/12197:
# Text: Ed Hess, Type: PERSON, True: F, Pred: F
# Processing row 12047/12197:
# Text: Leonardo da Vinci's, Type: PERSON, True: F, Pred: F
# Processing row 12048/12197:
# Text: ANS1, Type: PERSON, True: F, Pred: F
# Processing row 12049/12197:
# Text: Shultz, Type: PERSON, True: F, Pred: F
# Processing row 12050/12197:
# Text: Shultz, Type: PERSON, True: F, Pred: F
# Processing row 12051/12197:
# Text: Geoff, Type: PERSON, True: F, Pred: F
# Processing row 12052/12197:
# Text: hon tere  i0the, Type: PERSON, True: F, Pred: F
# Processing row 12053/12197:
# Text: Gathe  auyYe, Type: PERSON, True: F, Pred: F
# Processing row 12054/12197:
# Text: matk  , Type: PERSON, True: F, Pred: F
# Processing row 12055/12197:
# Text: hetha au ve
#
# CatcaorRg, Type: PERSON, True: F, Pred: F
# Processing row 12056/12197:
# Text: een Conne, Type: PERSON, True: F, Pred: F
# Processing row 12057/12197:
# Text: wrie the Subieck, Type: PERSON, True: F, Pred: F
# Processing row 12058/12197:
# Text: dra A  enclong9, Type: PERSON, True: F, Pred: F
# Processing row 12059/12197:
# Text: Reflection, Type: PERSON, True: F, Pred: F
# Processing row 12060/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12061/12197:
# Text: Ana Melton, Type: PERSON, True: F, Pred: F
# Processing row 12062/12197:
# Text: Ed Hess, Type: PERSON, True: F, Pred: F
# Processing row 12063/12197:
# Text: https://www.mindmeister.com, Type: URL, True: F, Pred: F
# Processing row 12064/12197:
# Text: Akash Pandit, Type: PERSON, True: T, Pred: T
# Processing row 12065/12197:
# Text: Coursera
#
# Meh, Type: PERSON, True: F, Pred: F
# Processing row 12066/12197:
# Text: Coursera
#
# Meh, Type: PERSON, True: F, Pred: F
# Processing row 12067/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 12068/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 12069/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12070/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 12071/12197:
# Text: Jackson, Type: PERSON, True: F, Pred: F
# Processing row 12072/12197:
# Text: Simi, Type: PERSON, True: F, Pred: T
# Processing row 12073/12197:
# Text: http://www.designkit.org/methods, Type: URL, True: F, Pred: F
# Processing row 12074/12197:
# Text: Roger Martin, Type: PERSON, True: F, Pred: F
# Processing row 12075/12197:
# Text: Raj    Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12076/12197:
# Text: Awang Chai, Type: PERSON, True: T, Pred: T
# Processing row 12077/12197:
# Text: Awang Chai, Type: PERSON, True: T, Pred: T
# Processing row 12078/12197:
# Text: Marion Moore, Type: PERSON, True: F, Pred: F
# Processing row 12079/12197:
# Text: Chris Carter, Type: PERSON, True: F, Pred: F
# Processing row 12080/12197:
# Text: Kobe Bryant’s, Type: PERSON, True: F, Pred: F
# Processing row 12081/12197:
# Text: Magic Johnson, Type: PERSON, True: F, Pred: F
# Processing row 12082/12197:
# Text: Bryant, Type: PERSON, True: F, Pred: F
# Processing row 12083/12197:
# Text: Kobeeeeee Bryyyyyyyyyant, Type: PERSON, True: F, Pred: F
# Processing row 12084/12197:
# Text: Kobe, Type: PERSON, True: F, Pred: F
# Processing row 12085/12197:
# Text: Kobe Bryant, Type: PERSON, True: F, Pred: F
# Processing row 12086/12197:
# Text: Gianna, Type: PERSON, True: F, Pred: F
# Processing row 12087/12197:
# Text: Kobe, Type: PERSON, True: F, Pred: F
# Processing row 12088/12197:
# Text: Bryant, Type: PERSON, True: F, Pred: F
# Processing row 12089/12197:
# Text: James Harden, Type: PERSON, True: F, Pred: F
# Processing row 12090/12197:
# Text: Michael Jordan, Type: PERSON, True: F, Pred: F
# Processing row 12091/12197:
# Text: Kobe, Type: PERSON, True: F, Pred: F
# Processing row 12092/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-, Type: URL, True: F, Pred: F
# Processing row 12093/12197:
# Text: Justin George, Type: PERSON, True: F, Pred: F
# Processing row 12094/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-, Type: URL, True: F, Pred: F
# Processing row 12095/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/xju53/visualization-, Type: URL, True: F, Pred: F
# Processing row 12096/12197:
# Text: Angela  , Type: PERSON, True: F, Pred: F
# Processing row 12097/12197:
# Text: https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/, Type: URL, True: F, Pred: F
# Processing row 12098/12197:
# Text: Andreas Schmitz, Type: PERSON, True: F, Pred: F
# Processing row 12099/12197:
# Text: Ernest Shackleton, Type: PERSON, True: F, Pred: F
# Processing row 12100/12197:
# Text: Carlo Serra, Type: PERSON, True: T, Pred: T
# Processing row 12101/12197:
# Text: The Insight & Approach, Type: PERSON, True: F, Pred: F
# Processing row 12102/12197:
# Text: Taboo, Type: PERSON, True: F, Pred: F
# Processing row 12103/12197:
# Text: Ed  , Type: PERSON, True: F, Pred: F
# Processing row 12104/12197:
# Text: Hess, Type: PERSON, True: F, Pred: F
# Processing row 12105/12197:
# Text: Ed  Hess, Type: PERSON, True: F, Pred: F
# Processing row 12106/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 12107/12197:
# Text: https://www.coursera.org/learn/design-thinking-, Type: URL, True: F, Pred: F
# Processing row 12108/12197:
# Text: http://designresearchtechniques.com/casestudies/storytelling/, Type: URL, True: F, Pred: F
# Processing row 12109/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 12110/12197:
# Text: https://trello.com/, Type: URL, True: F, Pred: F
# Processing row 12111/12197:
# Text: https://www.draw.io, Type: URL, True: F, Pred: F
# Processing row 12112/12197:
# Text: Andy Wilson, Type: PERSON, True: T, Pred: T
# Processing row 12113/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12114/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12115/12197:
# Text: Angela Meyer, Type: PERSON, True: F, Pred: F
# Processing row 12116/12197:
# Text: Insight, Type: PERSON, True: F, Pred: F
# Processing row 12117/12197:
# Text: Angela Mayer, Type: PERSON, True: F, Pred: F
# Processing row 12118/12197:
# Text: Tim  O’Brien, Type: PERSON, True: F, Pred: F
# Processing row 12119/12197:
# Text: sheela, Type: PERSON, True: F, Pred: F
# Processing row 12120/12197:
# Text: Gwilym, Type: PERSON, True: F, Pred: F
# Processing row 12121/12197:
# Text: Gerth, Type: PERSON, True: F, Pred: F
# Processing row 12122/12197:
# Text: Gerth, Type: PERSON, True: F, Pred: F
# Processing row 12123/12197:
# Text: God, Type: PERSON, True: F, Pred: F
# Processing row 12124/12197:
# Text: Beatriz Bron, Type: PERSON, True: F, Pred: F
# Processing row 12125/12197:
# Text: Aesop, Type: PERSON, True: F, Pred: F
# Processing row 12126/12197:
# Text: Justin Sotelo, Type: PERSON, True: F, Pred: F
# Processing row 12127/12197:
# Text: Omprakash Maurya, Type: PERSON, True: T, Pred: T
# Processing row 12128/12197:
# Text: https://www.youtube.com/watch?v=DCUcrfBKyeL, Type: URL, True: T, Pred: T
# Processing row 12129/12197:
# Text: Kublai Khaidir, Type: PERSON, True: T, Pred: T
# Processing row 12130/12197:
# Text: Ghandy, Type: PERSON, True: F, Pred: F
# Processing row 12131/12197:
# Text: qoute, Type: PERSON, True: F, Pred: F
# Processing row 12132/12197:
# Text: Aryan, Type: PERSON, True: F, Pred: F
# Processing row 12133/12197:
# Text: Furthur, Type: PERSON, True: F, Pred: F
# Processing row 12134/12197:
# Text: Maria Martinez, Type: PERSON, True: F, Pred: F
# Processing row 12135/12197:
# Text: Leidteka, Type: PERSON, True: F, Pred: F
# Processing row 12136/12197:
# Text: Ogilvie, Type: PERSON, True: F, Pred: F
# Processing row 12137/12197:
# Text: Knight, Type: PERSON, True: F, Pred: F
# Processing row 12138/12197:
# Text: Sankey, Type: PERSON, True: F, Pred: F
# Processing row 12139/12197:
# Text: HMW, Type: PERSON, True: F, Pred: F
# Processing row 12140/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 12141/12197:
# Text: Goldie Locks, Type: PERSON, True: F, Pred: F
# Processing row 12142/12197:
# Text: Goldie Locks, Type: PERSON, True: F, Pred: F
# Processing row 12143/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12144/12197:
# Text: Leonardo da Vinci's, Type: PERSON, True: F, Pred: F
# Processing row 12145/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 12146/12197:
# Text: Md Abdulla, Type: PERSON, True: T, Pred: T
# Processing row 12147/12197:
# Text: Manuel Lima, Type: PERSON, True: F, Pred: F
# Processing row 12148/12197:
# Text: http://www.ted.com/talks/manuel_lima_a_visual_history_of_human_knowledge/transcript?language=, Type: URL, True: F, Pred: F
# Processing row 12149/12197:
# Text: Daniela Mora, Type: PERSON, True: T, Pred: T
# Processing row 12150/12197:
# Text: Miguel Torres, Type: PERSON, True: T, Pred: T
# Processing row 12151/12197:
# Text: Angela Myer, Type: PERSON, True: F, Pred: F
# Processing row 12152/12197:
# Text: IIE. Diego Castro, Type: PERSON, True: F, Pred: F
# Processing row 12153/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12154/12197:
# Text: Bob, Type: PERSON, True: F, Pred: F
# Processing row 12155/12197:
# Text: Mark, Type: PERSON, True: F, Pred: F
# Processing row 12156/12197:
# Text: Jeff Bezos, Type: PERSON, True: F, Pred: F
# Processing row 12157/12197:
# Text: Tom Walton, Type: PERSON, True: F, Pred: F
# Processing row 12158/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12159/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12160/12197:
# Text: Michael Schumacher, Type: PERSON, True: F, Pred: F
# Processing row 12161/12197:
# Text: Wolf, Type: PERSON, True: F, Pred: F
# Processing row 12162/12197:
# Text: Little Red Riding Hood, Type: PERSON, True: F, Pred: F
# Processing row 12163/12197:
# Text: Little Red Riding Hood, Type: PERSON, True: F, Pred: F
# Processing row 12164/12197:
# Text: Wolf, Type: PERSON, True: F, Pred: F
# Processing row 12165/12197:
# Text: Woodsman, Type: PERSON, True: F, Pred: F
# Processing row 12166/12197:
# Text: Red Riding Hood, Type: PERSON, True: F, Pred: F
# Processing row 12167/12197:
# Text: Wolf, Type: PERSON, True: F, Pred: F
# Processing row 12168/12197:
# Text: Jeff Dean, Type: PERSON, True: F, Pred: F
# Processing row 12169/12197:
# Text: Sanjay Ghemawat, Type: PERSON, True: F, Pred: F
# Processing row 12170/12197:
# Text: Dean, Type: PERSON, True: F, Pred: F
# Processing row 12171/12197:
# Text: Ghemawat, Type: PERSON, True: F, Pred: F
# Processing row 12172/12197:
# Text: Kohlhammer, Type: PERSON, True: F, Pred: F
# Processing row 12173/12197:
# Text: David Gray’s, Type: PERSON, True: F, Pred: F
# Processing row 12174/12197:
# Text: Dave, Type: PERSON, True: F, Pred: F
# Processing row 12175/12197:
# Text: Jim, Type: PERSON, True: F, Pred: F
# Processing row 12176/12197:
# Text: Zig Ziglar’s, Type: PERSON, True: F, Pred: F
# Processing row 12177/12197:
# Text: Dave, Type: PERSON, True: F, Pred: F
# Processing row 12178/12197:
# Text: Jim, Type: PERSON, True: F, Pred: F
# Processing row 12179/12197:
# Text: Mahatma  , Type: PERSON, True: F, Pred: F
# Processing row 12180/12197:
# Text: Anthony Abubakar, Type: PERSON, True: T, Pred: T
# Processing row 12181/12197:
# Text: Marilyn Garzon, Type: PERSON, True: F, Pred: F
# Processing row 12182/12197:
# Text: Jeanne, Type: PERSON, True: F, Pred: F
# Processing row 12183/12197:
# Text: Gaudi, Type: PERSON, True: F, Pred: F
# Processing row 12184/12197:
# Text: CHALLENGE, Type: PERSON, True: F, Pred: F
# Processing row 12185/12197:
# Text: Storytelling, Type: PERSON, True: F, Pred: F
# Processing row 12186/12197:
# Text: eatery.By, Type: URL, True: F, Pred: F
# Processing row 12187/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12188/12197:
# Text: Amina Koko, Type: PERSON, True: T, Pred: T
# Processing row 12189/12197:
# Text: Challenge, Type: PERSON, True: F, Pred: F
# Processing row 12190/12197:
# Text: Amina Koko, Type: PERSON, True: F, Pred: F
# Processing row 12191/12197:
# Text: Amina Koko, Type: PERSON, True: T, Pred: T
# Processing row 12192/12197:
# Text: Jake Knapp, Type: PERSON, True: F, Pred: F
# Processing row 12193/12197:
# Text: Andre Martin, Type: PERSON, True: F, Pred: F
# Processing row 12194/12197:
# Text: Carmen Garcia, Type: PERSON, True: T, Pred: T
# Processing row 12195/12197:
# Text: JOURNEY MAP, Type: PERSON, True: F, Pred: F
# Processing row 12196/12197:
# Text: Venkat, Type: PERSON, True: F, Pred: F
# Processing complete. Results saved to 'output/pii_pre+ft_detected.csv'.

# %%
df_test = pd.read_csv('output/pii_detected_trf_test.csv')
filtered_df = pd.read_csv('output/pii_pre+ft_detected.csv')
# Filter the rows where the true label is True in the original test dataset
true_labels = df_test[df_test['true_label'] == 'T']

# Perform a left join to find rows that exist in the true_labels but not in the GPT 4o detected dataset
false_negatives = pd.merge(
    true_labels,
    filtered_df,
    on=['file_idx', 'entity_text', 'positions'],
    how='left',
    indicator=True
)

# Filter rows where GPT 4o failed to detect the True entities (i.e., these are False Negatives)
false_negatives = false_negatives[false_negatives['_merge'] == 'left_only']

# Display the results
# import ace_tools as tools; tools.display_dataframe_to_user(name="False Negatives (PII Leakage)", dataframe=false_negatives)

false_negatives
# Out:
#       file_idx                                  entity_text        type_x  \
# 8           22                                       Gianni        PERSON
# 38         472                 https://youtu.be/rFD2lJuvace           URL
# 63         761  https://www.youtube.com/watch?v=Kx0SXy87bVZ           URL
# 69        1105                                       Fatima        PERSON
# 73        1105                                       Fatima        PERSON
# ...        ...                                          ...           ...
# 2965     20869  https://www.youtube.com/watch?v=Cl-pzEZu1xK           URL
# 2967     20903                                         Bang        PERSON
# 2994     21228                         001-204-337-0177x663  PHONE_NUMBER
# 3012     21512                                  Grazia Doni        PERSON
# 3039     22127                                 Ryan Johnson        PERSON
#
#          positions true_label  \
# 8       (934, 940)          T
# 38    (4886, 4914)          T
# 63    (1186, 1229)          T
# 69      (810, 816)          T
# 73    (2815, 2821)          T
# ...            ...        ...
# 2965  (2117, 2160)          T
# 2967  (3110, 3114)          T
# 2994      (20, 40)          T
# 3012      (79, 90)          T
# 3039  (3318, 3330)          T
#
#                                                sentence  \
# 8     Application\n\nAs I describe the challenge “Mo...
# 38    Check out here – https://youtu.be/rFD2lJuvace ...
# 63    The visualization process we used can be seen ...
# 69    Fatima  took upon herself to be the home tutor...
# 73    Approach    With the above mind mapping tool, ...
# ...                                                 ...
# 2965  I\n\nrecommend  the  Youtube  Video: The  magi...
# 2967  A new person named Bang was  introduced at tha...
# 2994  Kimberly Alina\n\nTEL 001-204-337-0177x663\n\n...
# 3012  STORYTELLING - CHALLENGE\n\nREDUCING THE RATE ...
# 3039  The graphics  pasted across the wall helped pe...
#
#                                                 context type_y     _merge
# 8     3. Application\n\nAs I describe the challenge ...    NaN  left_only
# 38    Also, use social media to present your stories...    NaN  left_only
# 63    The second day, after 6 teams of 3-7 people ea...    NaN  left_only
# 69    Schools in India forces students to spend an i...    NaN  left_only
# 73    She felt her role  of training drivers helped ...    NaN  left_only
# ...                                                 ...    ...        ...
# 2965  His  way  of  using  storytelling  and  how  t...    NaN  left_only
# 2967  So, he made this decision and started planning...    NaN  left_only
# 2994  Kimberly Alina\n\nTEL 001-204-337-0177x663\n\n...    NaN  left_only
# 3012  STORYTELLING - CHALLENGE\n\nREDUCING THE RATE ...    NaN  left_only
# 3039  The pain points were discussed in detail and v...    NaN  left_only
#
# [413 rows x 9 columns]
