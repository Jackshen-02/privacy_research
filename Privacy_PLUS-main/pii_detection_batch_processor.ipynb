# %% [markdown]
# ### Introduction
# This notebook demonstrates how to process a batch of documents for Personally Identifiable Information (PII) detection using Azure's Cognitive Services. It adheres to the rate limits specified for the S / Multi-service tier and processes a single batch of 5 documents to ensure the pipeline works correctly.

# %% [markdown]
# ### Setup
# First, we need to import the necessary libraries.

# %%
import os
import time
import pandas as pd
import ast
import requests
import json

# %% [markdown]
# ### Load the Data
# Load the JSON data and the list of test indices.

# %%
def read_json(path='data/obfuscated_data_06.json'):
    """
    Reads a JSON file into a pandas DataFrame.
    
    Parameters:
        path (str): Path to the JSON file.
        
    Returns:
        pd.DataFrame: DataFrame containing the JSON data.
    """
    df = pd.read_json(path, orient="records", encoding='utf-8')
    return df

def load_test_indices(path='data/test_indices_2.txt'):
    """
    Loads test indices from a text file.
    
    Parameters:
        path (str): Path to the text file containing test indices.
        
    Returns:
        list: List of test indices.
    """
    with open(path, 'r') as file:
        test_indices = ast.literal_eval(file.read().strip())
    return test_indices

# Load Data
df = read_json()
test_indices_2 = load_test_indices()

print(f"Total Documents Loaded: {len(df)}")
print(f"Total Test Indices: {len(test_indices_2)}")
# Out:
# Total Documents Loaded: 22688
# Total Test Indices: 13613

# %% [markdown]
# ### Send the PII Detection Request
# Construct the JSON payload and send a POST request to Azure's PII Detection API.

# %%
# Configuration Parameters
with open('input/secret.json', 'r', encoding='UTF-8') as file:
    secret_json = json.load(file)
API_KEY = secret_json['LANGUAGE_KEY']
API_ENDPOINT = secret_json['LANGUAGE_ENDPOINT'] + 'language/analyze-text/jobs'

API_VERSION = "2023-04-15-preview"
SHOW_STATS = "True"

def send_pii_detection_request(batch, df, batch_number):
    """
    Sends a PII detection request for a batch of documents.
    
    Parameters:
        batch (list): List of document indices.
        df (pd.DataFrame): DataFrame containing the documents.
        batch_number (int): The current batch number.
        
    Returns:
        str: Operation location URL if the request is accepted.
    """
    documents = []
    for doc_idx in batch:
        document_id = str(doc_idx)  # Ensure it's a string
        text_content = df.iloc[doc_idx]['full_text']
        
        documents.append({
            "id": document_id,
            "language": "en",
            "text": text_content
        })
    
    # Construct the payload
    payload = {
        "displayName": f"Document PII Detection Task Batch {batch_number}",
        "analysisInput": {
            "documents": documents
        },
        "tasks": [
            {
                "kind": "PiiEntityRecognition",
                "taskName": f"Document PII Detection Task {batch_number}",
                "parameters": {
                    "model-version": "latest",
                    "piiCategories": ["Person", "URL", "Email", "PhoneNumber"]
                }
            }
        ]
    }
    
    headers = {
        "Content-Type": "application/json",
        "Ocp-Apim-Subscription-Key": API_KEY
    }
    
    try:
        response = requests.post(
            f"{API_ENDPOINT}?api-version={API_VERSION}&showStats={SHOW_STATS}",
            headers=headers,
            data=json.dumps(payload)
        )
        
        if response.status_code == 202:
            operation_location = response.headers.get("operation-location")
            print(f"Batch {batch_number}: Request accepted.")
            print(f"Operation Location: {operation_location}")
            return operation_location
        else:
            print(f"Batch {batch_number}: Failed with status code {response.status_code}.")
            print(f"Response: {response.text}")
            return None
    except Exception as e:
        print(f"Batch {batch_number}: Exception occurred - {str(e)}")
        return None

# %%
send_error_log = []
receive_error_log = []
job_ids = []
batch_ids = []

# %%
from torch.utils.data import Dataset, DataLoader 

class doc_dataset(Dataset): 
    def __init__(self,indices):
        self.indices = indices 
    def __len__(self):
        return len(self.indices)
    def __getitem__(self,idx): 
        return self.indices[idx]

datas = doc_dataset(test_indices_2)
loader = DataLoader(datas, batch_size = 5)

for i, batch in enumerate(loader):
    batch_ids.append(batch)
    if i % 50 == 0 and (i != 0): 
        time.sleep(3)
        if i % 250 == 0 and (i != 0): 
            time.sleep(90)
    print(batch.tolist())
    batch = batch.tolist()
    operation_location = send_pii_detection_request(batch, df, batch_number=i)
    if operation_location == None:
        send_error_log.append(batch)
        job_ids.append('NONE')
        print(f"batch with file indices {batch}, failed to load")
    else: 
        with open('output/operation_locations.txt','a') as file: 
            file.write(f'{operation_location}\n')
        job_ids.append(operation_location)

# runtime: 33m 35.3s
# Out:
# [2, 5, 6, 7, 9]
# Batch 0: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1eb6f2f1-5f5d-49d2-8cad-9ef5a0bf7116?api-version=2023-04-15-preview
# [10, 11, 12, 13, 14]
# Batch 1: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1151c083-5ed7-4677-af3c-21f8754c5524?api-version=2023-04-15-preview
# [16, 17, 18, 19, 21]
# Batch 2: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5bfbd9e8-a5b4-481b-bc29-b4910bb3b505?api-version=2023-04-15-preview
# [22, 24, 25, 26, 27]
# Batch 3: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/66ad6d9e-a9ee-421a-8375-5f0f9b26dbb3?api-version=2023-04-15-preview
# [28, 30, 31, 32, 35]
# Batch 4: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/46897465-4a32-47fc-9ceb-2eca7e5fdb77?api-version=2023-04-15-preview
# [37, 41, 42, 43, 45]
# Batch 5: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a62ce48d-1160-4c90-a9be-128219c23a8e?api-version=2023-04-15-preview
# [47, 52, 53, 56, 57]
# Batch 6: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/92f64840-c0f9-432a-8c8f-e1e25d4e2eb0?api-version=2023-04-15-preview
# [58, 62, 65, 66, 67]
# Batch 7: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7026f59f-5231-4b1c-b948-9e74726cc158?api-version=2023-04-15-preview
# [68, 69, 71, 73, 75]
# Batch 8: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a5e368f0-f184-494e-b7e1-1fd6a71fa775?api-version=2023-04-15-preview
# [78, 79, 80, 83, 84]
# Batch 9: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/01dce88a-202e-41ab-968f-c6318aab261c?api-version=2023-04-15-preview
# [85, 88, 89, 90, 91]
# Batch 10: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b5b401b2-d164-4460-bb41-3829de77998d?api-version=2023-04-15-preview
# [94, 96, 97, 99, 103]
# Batch 11: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/986ced80-7d1d-4613-9edc-ede95db7992d?api-version=2023-04-15-preview
# [105, 106, 107, 111, 112]
# Batch 12: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f5ddf1e6-e816-40bc-b3c6-34b087d528e7?api-version=2023-04-15-preview
# [113, 114, 119, 120, 122]
# Batch 13: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f5ba6f8f-0cf6-464b-bf2f-0fd5e8cc0605?api-version=2023-04-15-preview
# [124, 125, 126, 128, 130]
# Batch 14: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/11e40f9e-6c6d-48f1-9523-0548e02a796a?api-version=2023-04-15-preview
# [131, 132, 138, 142, 143]
# Batch 15: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ef6dcdaf-12f2-4cb2-af13-86040bd9f49c?api-version=2023-04-15-preview
# [145, 147, 148, 149, 150]
# Batch 16: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5daad505-6634-47b5-96dd-56279213eb05?api-version=2023-04-15-preview
# [154, 156, 157, 158, 159]
# Batch 17: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c0a304f5-e62a-4420-99bc-6fe991da8a04?api-version=2023-04-15-preview
# [160, 163, 164, 166, 167]
# Batch 18: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a7fca043-2c6f-4b09-9f01-e2471fd9e7c3?api-version=2023-04-15-preview
# [168, 171, 172, 173, 175]
# Batch 19: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/39a69547-eadb-436d-8f23-ee1cbe9a6a6e?api-version=2023-04-15-preview
# [176, 177, 179, 180, 183]
# Batch 20: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4f1dddb5-a0d7-4dec-a045-1608b51fbfdd?api-version=2023-04-15-preview
# [185, 186, 187, 188, 189]
# Batch 21: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/54b76a06-4620-49aa-8a11-d5fd376e24f8?api-version=2023-04-15-preview
# [190, 191, 192, 193, 194]
# Batch 22: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8243e39c-8028-4ce5-ac2c-69f97c1518b7?api-version=2023-04-15-preview
# [195, 196, 197, 198, 199]
# Batch 23: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/af4c632c-6f5b-48b9-9fcc-21366ff645a3?api-version=2023-04-15-preview
# [200, 201, 202, 203, 204]
# Batch 24: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/db3f7396-b6e7-4acb-8d9e-45062d935a2a?api-version=2023-04-15-preview
# [207, 208, 209, 210, 211]
# Batch 25: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/af52bef8-b314-4b98-9d29-0c3b440bdb0e?api-version=2023-04-15-preview
# [212, 213, 214, 216, 217]
# Batch 26: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ebb6e5e9-3ab7-49bc-8b94-49c57716c7da?api-version=2023-04-15-preview
# [218, 220, 221, 223, 224]
# Batch 27: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5d6fe7d9-6b45-4e8f-b587-3fb3cf2b7c89?api-version=2023-04-15-preview
# [225, 226, 227, 228, 232]
# Batch 28: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/89f13298-1c9c-468b-8beb-e5428e7a4b6a?api-version=2023-04-15-preview
# [233, 237, 238, 239, 241]
# Batch 29: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/24148143-9e00-4f07-a123-1df74a8a9e18?api-version=2023-04-15-preview
# [242, 243, 245, 247, 250]
# Batch 30: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/32c07a9c-08a7-4167-a89c-ffa811506c30?api-version=2023-04-15-preview
# [251, 254, 255, 257, 258]
# Batch 31: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/15803673-f71f-4f65-b92e-6c65677e7c71?api-version=2023-04-15-preview
# [260, 261, 262, 264, 266]
# Batch 32: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/423a71cb-f2b0-4efa-8d9c-ad000e20f901?api-version=2023-04-15-preview
# [268, 270, 271, 273, 274]
# Batch 33: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/90f54ea0-b5ac-4841-ab0f-c5c098254ab3?api-version=2023-04-15-preview
# [275, 276, 278, 279, 280]
# Batch 34: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7fe65769-fee6-4cef-aa2a-5b850699dc1a?api-version=2023-04-15-preview
# [282, 285, 287, 289, 290]
# Batch 35: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5d1b177b-71a5-4e39-987d-a5755acad23a?api-version=2023-04-15-preview
# [291, 293, 295, 297, 298]
# Batch 36: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/33435242-f646-4823-80c4-ac4825395f3e?api-version=2023-04-15-preview
# [299, 302, 303, 304, 305]
# Batch 37: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d93188b9-6abe-490c-b911-f2c76ce698f5?api-version=2023-04-15-preview
# [307, 311, 313, 314, 315]
# Batch 38: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0e3ce240-aec1-4513-98ef-658723ade356?api-version=2023-04-15-preview
# [317, 318, 320, 321, 322]
# Batch 39: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/fc7a652e-23df-496d-8dbd-3bf682383569?api-version=2023-04-15-preview
# [325, 326, 327, 328, 329]
# Batch 40: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/30e634f2-fb3b-47aa-b34f-6833ed9817d7?api-version=2023-04-15-preview
# [330, 331, 332, 334, 336]
# Batch 41: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ff8d1384-7084-4581-a48c-519de5338a49?api-version=2023-04-15-preview
# [337, 339, 341, 342, 343]
# Batch 42: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c9eacb3f-09dc-43dc-8f24-65e27a0d875e?api-version=2023-04-15-preview
# [344, 345, 346, 348, 350]
# Batch 43: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/358c188e-0a06-4a30-b208-871aecb2448a?api-version=2023-04-15-preview
# [352, 356, 357, 360, 361]
# Batch 44: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ee3b8801-c7b6-4dcf-9bdc-a4b71f3e5184?api-version=2023-04-15-preview
# [362, 363, 364, 365, 367]
# Batch 45: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/39dbd031-91d4-4123-814f-f309de62877f?api-version=2023-04-15-preview
# [369, 370, 377, 378, 382]
# Batch 46: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/139ea189-8f78-4e70-955a-c5d384b81f8d?api-version=2023-04-15-preview
# [383, 385, 386, 388, 390]
# Batch 47: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/3624ab95-7ecd-4b19-ac78-ce5c72c4f0de?api-version=2023-04-15-preview
# [391, 392, 393, 394, 397]
# Batch 48: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8601240f-56ca-4a7a-94f8-7945a4a3a6df?api-version=2023-04-15-preview
# [398, 399, 400, 403, 404]
# Batch 49: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a2c62fef-9848-4528-a7b5-9861d2710760?api-version=2023-04-15-preview
# [405, 406, 408, 409, 410]
# Batch 50: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/30f56725-9865-455f-814f-f237e6db84c0?api-version=2023-04-15-preview
# [411, 412, 414, 416, 417]
# Batch 51: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/310bf5aa-9c59-456c-8a81-4e2d0016f4b9?api-version=2023-04-15-preview
# [419, 421, 422, 425, 427]
# Batch 52: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6e15f076-bfa6-4659-a0f8-721021e306b6?api-version=2023-04-15-preview
# [429, 431, 432, 433, 434]
# Batch 53: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/149967f0-c39f-473a-9494-12f5db1b09dc?api-version=2023-04-15-preview
# [435, 437, 438, 441, 442]
# Batch 54: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b856809b-b225-49ce-a7cf-bc6485f0bacd?api-version=2023-04-15-preview
# [443, 444, 445, 447, 448]
# Batch 55: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bbada450-1b10-4b3f-b921-6d2c6a06fbc2?api-version=2023-04-15-preview
# [449, 451, 453, 454, 455]
# Batch 56: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ca5fa942-421c-4c66-84ea-f0a90fb4fdc7?api-version=2023-04-15-preview
# [456, 458, 461, 463, 464]
# Batch 57: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ab0a54cc-1083-4122-a797-fa6f844dfdaf?api-version=2023-04-15-preview
# [465, 468, 472, 475, 477]
# Batch 58: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/68f46acc-6f96-4583-958a-a3ef7d892c80?api-version=2023-04-15-preview
# [478, 479, 481, 483, 485]
# Batch 59: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/691b2471-0e4d-433d-8e79-6488479221c8?api-version=2023-04-15-preview
# [486, 489, 491, 492, 493]
# Batch 60: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/432631bb-4e21-44ee-8066-79efef2222d6?api-version=2023-04-15-preview
# [495, 496, 497, 498, 500]
# Batch 61: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1c38f7c3-cf79-49b8-acf6-75aca5425912?api-version=2023-04-15-preview
# [501, 505, 506, 508, 509]
# Batch 62: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/9cd0f717-4cf5-4628-b3ff-e3e1064c7b9d?api-version=2023-04-15-preview
# [510, 511, 513, 515, 517]
# Batch 63: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7163edc8-4ffe-497b-9ab3-180c03e213a3?api-version=2023-04-15-preview
# [519, 520, 523, 525, 527]
# Batch 64: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/18ec001d-5afe-4aa0-aaf6-2852a4ee4b49?api-version=2023-04-15-preview
# [534, 536, 538, 539, 541]
# Batch 65: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ff29eed8-aa59-4e5b-a146-d495a3149518?api-version=2023-04-15-preview
# [542, 544, 545, 546, 547]
# Batch 66: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/164e4540-655d-4a3e-bd44-99af32fd5604?api-version=2023-04-15-preview
# [548, 549, 551, 552, 553]
# Batch 67: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/47c51123-4df2-4f99-bc88-fc660b6cc944?api-version=2023-04-15-preview
# [554, 556, 557, 560, 562]
# Batch 68: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e2b5daa0-5439-4aeb-9fa6-2d06a42fbeaa?api-version=2023-04-15-preview
# [564, 565, 566, 568, 572]
# Batch 69: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f03ec866-b39a-4caa-a82f-c932cea43dc9?api-version=2023-04-15-preview
# [573, 574, 575, 576, 577]
# Batch 70: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/daf670bc-efa5-46ad-9048-cf4edb3b0689?api-version=2023-04-15-preview
# [578, 579, 580, 582, 585]
# Batch 71: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ac771256-0482-4a98-8973-1e41ed533286?api-version=2023-04-15-preview
# [586, 587, 588, 589, 590]
# Batch 72: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/292b0b58-00d3-4525-8544-daa3caee4a74?api-version=2023-04-15-preview
# [591, 592, 595, 596, 597]
# Batch 73: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/49691a1c-a562-435b-b9e1-a134bb286cf7?api-version=2023-04-15-preview
# [599, 604, 605, 606, 607]
# Batch 74: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/2eab7bfd-f740-459e-99d8-932b01e8a41a?api-version=2023-04-15-preview
# [612, 616, 617, 620, 621]
# Batch 75: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1f4db064-ad93-49cd-95cd-0f0a1564f70e?api-version=2023-04-15-preview
# [622, 623, 625, 628, 629]
# Batch 76: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d6d3b9b0-d0d5-46cb-b69a-16d7737a48ba?api-version=2023-04-15-preview
# [630, 631, 633, 634, 635]
# Batch 77: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0dffc447-1eaf-4dc0-ac5f-742a6381517c?api-version=2023-04-15-preview
# [637, 639, 641, 642, 643]
# Batch 78: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/2cec0296-bbf4-4f66-ba6a-8bf3e967caef?api-version=2023-04-15-preview
# [646, 647, 650, 652, 653]
# Batch 79: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/67ad2af2-77d9-43c2-a911-f22dafb3f90f?api-version=2023-04-15-preview
# [654, 655, 657, 659, 660]
# Batch 80: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8bd87037-19f1-4594-be1f-ec4d7ed6c5c4?api-version=2023-04-15-preview
# [661, 662, 663, 664, 666]
# Batch 81: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5b0fb546-c3de-4662-b143-678aec368c0e?api-version=2023-04-15-preview
# [667, 670, 672, 673, 675]
# Batch 82: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/96ae87a9-35bb-43a8-9ed1-9860b6d9e511?api-version=2023-04-15-preview
# [676, 677, 678, 680, 681]
# Batch 83: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/780e4ace-fab3-465e-8720-ef84bb7322c1?api-version=2023-04-15-preview
# [682, 687, 689, 692, 694]
# Batch 84: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8190fd27-b148-4ca6-9eee-be17f3f9c535?api-version=2023-04-15-preview
# [695, 696, 698, 700, 703]
# Batch 85: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0c41b300-ffae-4007-8490-aff99c3465a9?api-version=2023-04-15-preview
# [708, 710, 711, 713, 714]
# Batch 86: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/687b6116-a99a-4a00-9c1d-8c7f9fa8f4d9?api-version=2023-04-15-preview
# [715, 716, 717, 719, 720]
# Batch 87: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bb4fd30e-d3f9-4ad7-a9ee-bfa36fe518e0?api-version=2023-04-15-preview
# [721, 725, 726, 729, 730]
# Batch 88: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ecfff6bd-82c1-48ae-97e5-2675899ce4a9?api-version=2023-04-15-preview
# [731, 733, 734, 735, 736]
# Batch 89: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6f0f6c8d-934c-42e8-9d9d-b43f91a3aff4?api-version=2023-04-15-preview
# [737, 738, 739, 740, 742]
# Batch 90: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/3923d947-371f-4201-8093-7154894212f5?api-version=2023-04-15-preview
# [743, 744, 747, 748, 749]
# Batch 91: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a5f592b5-6fb9-48c7-a43f-17bd7bbb009e?api-version=2023-04-15-preview
# [751, 752, 754, 755, 756]
# Batch 92: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/412f67d3-5a0b-4c5e-9407-31b5b22f36fa?api-version=2023-04-15-preview
# [757, 760, 761, 763, 764]
# Batch 93: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/249fd192-22ca-43d7-9845-214c9e727378?api-version=2023-04-15-preview
# [769, 772, 773, 774, 775]
# Batch 94: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e0721a62-e7a3-4edb-8422-155a2816d158?api-version=2023-04-15-preview
# [776, 777, 778, 779, 780]
# Batch 95: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7a1a8fd5-f9b5-46e1-851c-65a5de2f4ad9?api-version=2023-04-15-preview
# [781, 782, 783, 786, 787]
# Batch 96: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/90850b60-261f-46cf-b789-d29d2fc33bfe?api-version=2023-04-15-preview
# [788, 789, 790, 792, 797]
# Batch 97: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/fcdd54b9-af7a-4674-8ce7-cb33b94873cd?api-version=2023-04-15-preview
# [798, 800, 801, 803, 804]
# Batch 98: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a065dd3f-dcb9-446c-a9e1-2046857ca41e?api-version=2023-04-15-preview
# [805, 806, 807, 808, 811]
# Batch 99: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/53f97ccc-7cc9-4cfd-913f-e43165acefa3?api-version=2023-04-15-preview
# [813, 814, 816, 819, 820]
# Batch 100: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/9fca1485-6bb8-43ea-a1fa-337135a321ef?api-version=2023-04-15-preview
# [823, 824, 825, 826, 827]
# Batch 101: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/3f692c09-0932-412c-bd68-77ba16869c4f?api-version=2023-04-15-preview
# [828, 829, 831, 832, 833]
# Batch 102: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f8e9cb5d-a80b-4a61-a3be-6f46f30c488e?api-version=2023-04-15-preview
# [837, 838, 840, 841, 842]
# Batch 103: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/69895df3-80b0-471a-b061-d405688e2329?api-version=2023-04-15-preview
# [844, 845, 847, 848, 849]
# Batch 104: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6b75fb7e-ccfe-4d09-92be-504c7e17947e?api-version=2023-04-15-preview
# [850, 851, 852, 853, 858]
# Batch 105: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/63fc36c3-e293-4906-ad47-1267018e6c31?api-version=2023-04-15-preview
# [859, 860, 864, 865, 868]
# Batch 106: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bee61813-b60c-45ea-b53c-21cd4c0a9344?api-version=2023-04-15-preview
# [871, 873, 874, 877, 878]
# Batch 107: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/02160057-fd03-4198-ac10-e50a95aa300f?api-version=2023-04-15-preview
# [879, 881, 882, 883, 884]
# Batch 108: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/87b0bd81-065f-4115-b493-351b5eca7aa5?api-version=2023-04-15-preview
# [890, 891, 893, 894, 896]
# Batch 109: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c5f8f30b-9fe9-47d3-a78b-105d261222e9?api-version=2023-04-15-preview
# [897, 899, 900, 902, 904]
# Batch 110: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/62210715-856d-4663-8d17-2e42a710d041?api-version=2023-04-15-preview
# [906, 908, 910, 911, 912]
# Batch 111: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/fd404cda-6e3c-477e-ac65-64e38dbf1bca?api-version=2023-04-15-preview
# [914, 915, 916, 919, 920]
# Batch 112: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6fae432f-c0e2-4b27-a6c8-eed4c02d2cbd?api-version=2023-04-15-preview
# [921, 923, 925, 928, 929]
# Batch 113: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/3056c5a5-f5a8-4a59-b970-6ea6adb6130b?api-version=2023-04-15-preview
# [930, 931, 936, 937, 940]
# Batch 114: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5d47b7d0-15dd-4136-a3ea-ae6bd5d04dce?api-version=2023-04-15-preview
# [941, 942, 944, 945, 948]
# Batch 115: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/26d43d4d-8e54-4b47-808a-9114ac3a28af?api-version=2023-04-15-preview
# [949, 952, 955, 956, 959]
# Batch 116: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d6837720-2274-46f3-90e6-f243cdc32ed8?api-version=2023-04-15-preview
# [960, 963, 965, 966, 967]
# Batch 117: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b756a1cf-bcde-4792-bb56-166c445ab2e5?api-version=2023-04-15-preview
# [969, 970, 971, 972, 973]
# Batch 118: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7957b1b8-c491-4dca-bbd6-bae75e2ea0b2?api-version=2023-04-15-preview
# [976, 980, 981, 982, 984]
# Batch 119: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/01bf3d7a-844d-4124-95db-c104a2cd49c5?api-version=2023-04-15-preview
# [985, 987, 988, 989, 990]
# Batch 120: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bdef2566-6c6a-4d98-aed2-d72287d2a4aa?api-version=2023-04-15-preview
# [991, 992, 993, 994, 997]
# Batch 121: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/91bc741d-44f7-4f7a-baf0-d2e7534ce4ee?api-version=2023-04-15-preview
# [998, 999, 1000, 1003, 1006]
# Batch 122: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/68135dc5-37e5-4d20-bb0b-3ff2f3ffb184?api-version=2023-04-15-preview
# [1007, 1009, 1010, 1012, 1013]
# Batch 123: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e45e4103-5344-49a3-a45a-d094484a3c8f?api-version=2023-04-15-preview
# [1014, 1015, 1017, 1023, 1024]
# Batch 124: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ad68eaf4-7b7c-4e68-bd47-73f0ed82f7cf?api-version=2023-04-15-preview
# [1025, 1028, 1030, 1031, 1032]
# Batch 125: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/40271694-9b1d-464f-aca3-63bd8511e7ae?api-version=2023-04-15-preview
# [1035, 1037, 1038, 1041, 1042]
# Batch 126: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d2157dff-13ed-43b6-a148-1be6c25c02c6?api-version=2023-04-15-preview
# [1043, 1044, 1046, 1047, 1048]
# Batch 127: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0f222876-6e45-4757-bfd2-6db05ca2ba79?api-version=2023-04-15-preview
# [1050, 1051, 1053, 1055, 1056]
# Batch 128: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8e56b95a-f791-4959-8d57-abe5827087df?api-version=2023-04-15-preview
# [1058, 1059, 1060, 1061, 1063]
# Batch 129: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/751926d4-c254-4f2a-8874-e50cdd6d6555?api-version=2023-04-15-preview
# [1066, 1067, 1069, 1070, 1074]
# Batch 130: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ca596796-951b-4d5b-85e6-5932c0bec2ac?api-version=2023-04-15-preview
# [1076, 1077, 1078, 1079, 1081]
# Batch 131: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4ebde93f-d5f4-415d-9266-36c4454b54a7?api-version=2023-04-15-preview
# [1082, 1084, 1085, 1087, 1089]
# Batch 132: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/78076abd-ac50-45f5-870f-db268019a740?api-version=2023-04-15-preview
# [1090, 1091, 1092, 1094, 1096]
# Batch 133: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/671563d5-c86a-4d3a-9902-49f299c395d7?api-version=2023-04-15-preview
# [1098, 1099, 1101, 1103, 1105]
# Batch 134: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7f674e6a-271d-42d9-ab74-b0441e8c3a40?api-version=2023-04-15-preview
# [1107, 1108, 1109, 1110, 1111]
# Batch 135: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c3575cb1-8b74-4387-a25c-98978f6aad06?api-version=2023-04-15-preview
# [1112, 1114, 1120, 1121, 1123]
# Batch 136: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/37cef42a-51a0-409a-8837-469fbfe23a69?api-version=2023-04-15-preview
# [1124, 1125, 1126, 1133, 1134]
# Batch 137: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/882cc55b-674e-44b8-9991-76818f29ebbf?api-version=2023-04-15-preview
# [1136, 1137, 1138, 1139, 1142]
# Batch 138: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/47991d90-9f86-45f6-ab5d-39725b3a4c1c?api-version=2023-04-15-preview
# [1144, 1146, 1147, 1151, 1153]
# Batch 139: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e4211508-9066-4750-b5ef-30bd78615701?api-version=2023-04-15-preview
# [1154, 1157, 1158, 1159, 1161]
# Batch 140: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bb80286b-3607-4694-bd7b-6ec24376c430?api-version=2023-04-15-preview
# [1162, 1164, 1165, 1166, 1168]
# Batch 141: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/dc4e1efa-2b85-4980-bd1a-de94c32d318a?api-version=2023-04-15-preview
# [1170, 1171, 1173, 1175, 1178]
# Batch 142: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bfd840e4-b647-4c3d-ab0a-3906fd010118?api-version=2023-04-15-preview
# [1181, 1182, 1184, 1185, 1188]
# Batch 143: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/47c5541a-d169-42b7-8e08-969c8d710c14?api-version=2023-04-15-preview
# [1189, 1190, 1191, 1196, 1197]
# Batch 144: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8e810d0f-8ce3-4134-9803-86e371c65b4b?api-version=2023-04-15-preview
# [1198, 1200, 1203, 1205, 1209]
# Batch 145: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/38d9eff0-d5cf-4174-bfb4-f2bd41fc7fdc?api-version=2023-04-15-preview
# [1213, 1214, 1215, 1220, 1221]
# Batch 146: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7d42e205-f28a-49af-b48c-e89718dc41fc?api-version=2023-04-15-preview
# [1222, 1224, 1228, 1229, 1232]
# Batch 147: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ab25f89f-6e6e-49e7-98e2-4aeef0039c6b?api-version=2023-04-15-preview
# [1233, 1235, 1236, 1240, 1242]
# Batch 148: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4010d329-e206-4d93-bea0-197b7f3d89a1?api-version=2023-04-15-preview
# [1244, 1245, 1246, 1249, 1250]
# Batch 149: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/41950396-8b88-467e-8c8d-0e525ca54fd4?api-version=2023-04-15-preview
# [1253, 1254, 1255, 1262, 1263]
# Batch 150: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0069a800-1dca-41cd-83a8-013d4287e0bc?api-version=2023-04-15-preview
# [1264, 1265, 1266, 1267, 1271]
# Batch 151: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/3c857537-c11c-4644-86e8-5ecc7c137882?api-version=2023-04-15-preview
# [1272, 1273, 1274, 1275, 1276]
# Batch 152: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/67ed6f7d-04b8-4d3d-b264-13973bf728e1?api-version=2023-04-15-preview
# [1279, 1280, 1281, 1284, 1285]
# Batch 153: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4f3c3b26-9e8e-4f70-a09e-15b82f6d1452?api-version=2023-04-15-preview
# [1286, 1288, 1289, 1291, 1292]
# Batch 154: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c9bedbf0-999a-46b1-93bd-97ed41b2fd4d?api-version=2023-04-15-preview
# [1293, 1294, 1296, 1297, 1298]
# Batch 155: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/85a44d50-6153-411e-8413-ce001b93fba3?api-version=2023-04-15-preview
# [1299, 1300, 1302, 1303, 1306]
# Batch 156: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c1d9b134-3eba-4edf-b670-d242bdb505ee?api-version=2023-04-15-preview
# [1308, 1310, 1311, 1315, 1316]
# Batch 157: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4fa08bdb-6325-4886-a431-037784b7971f?api-version=2023-04-15-preview
# [1317, 1318, 1319, 1321, 1323]
# Batch 158: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/687c4f6a-0f20-442c-83ab-8f540b363c72?api-version=2023-04-15-preview
# [1324, 1326, 1330, 1331, 1332]
# Batch 159: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e51834f9-965d-4370-b805-82832992ac34?api-version=2023-04-15-preview
# [1333, 1334, 1335, 1336, 1337]
# Batch 160: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ebff5cbd-2973-4d06-aaa4-a9aad3c12e2b?api-version=2023-04-15-preview
# [1344, 1345, 1346, 1348, 1353]
# Batch 161: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d40ab178-c1ee-4b99-81d5-203b5bf12d9e?api-version=2023-04-15-preview
# [1355, 1358, 1359, 1360, 1363]
# Batch 162: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1e92c927-c1bf-413b-b000-35dd6f25d5ad?api-version=2023-04-15-preview
# [1364, 1365, 1366, 1367, 1368]
# Batch 163: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1eecb821-0697-44ef-9f72-b5b13ab23527?api-version=2023-04-15-preview
# [1369, 1371, 1373, 1375, 1376]
# Batch 164: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/31d15809-9f13-43c8-8f5a-460dacc7ee45?api-version=2023-04-15-preview
# [1377, 1378, 1379, 1380, 1382]
# Batch 165: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ec7d4480-dd09-4d87-9292-684eac1b22f5?api-version=2023-04-15-preview
# [1383, 1384, 1385, 1386, 1387]
# Batch 166: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4e8b111d-7e69-4aa1-be24-145d47e3dd88?api-version=2023-04-15-preview
# [1388, 1389, 1391, 1392, 1393]
# Batch 167: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/675b4b35-003b-44c5-8262-9055f1192120?api-version=2023-04-15-preview
# [1394, 1396, 1398, 1399, 1401]
# Batch 168: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/225d353d-03fe-4fbe-aeb3-2807edfad71d?api-version=2023-04-15-preview
# [1402, 1403, 1405, 1408, 1409]
# Batch 169: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/16531f08-3b94-4914-8e17-53bb5f14d212?api-version=2023-04-15-preview
# [1410, 1411, 1412, 1413, 1415]
# Batch 170: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/15c8044f-8f18-42dc-b55b-979490597d9d?api-version=2023-04-15-preview
# [1416, 1418, 1420, 1421, 1422]
# Batch 171: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/2c65d735-f27e-4404-b61f-0d328cd57485?api-version=2023-04-15-preview
# [1424, 1425, 1427, 1431, 1433]
# Batch 172: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e5a46eb2-5325-422c-864c-c099e34f06ce?api-version=2023-04-15-preview
# [1434, 1435, 1438, 1439, 1440]
# Batch 173: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c2c7c1de-7cbf-45d3-9d57-a768e2f40ded?api-version=2023-04-15-preview
# [1441, 1442, 1443, 1445, 1450]
# Batch 174: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/3bab80f1-a873-4c39-9a85-87ac5432cc19?api-version=2023-04-15-preview
# [1451, 1452, 1453, 1454, 1455]
# Batch 175: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/34e4f6e3-949f-470d-bbad-654908d53877?api-version=2023-04-15-preview
# [1456, 1457, 1458, 1459, 1461]
# Batch 176: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/aaefdac4-c1c7-46e4-aabc-95648f099a9d?api-version=2023-04-15-preview
# [1462, 1463, 1465, 1467, 1468]
# Batch 177: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b2b1b4ce-f647-41ee-836e-c5ac85598147?api-version=2023-04-15-preview
# [1470, 1471, 1472, 1474, 1475]
# Batch 178: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d3f31235-2ac8-4630-8032-efe406237856?api-version=2023-04-15-preview
# [1477, 1482, 1484, 1485, 1486]
# Batch 179: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e344f777-4ca3-4f49-aa9f-a75463674069?api-version=2023-04-15-preview
# [1487, 1488, 1489, 1490, 1492]
# Batch 180: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/cc75075d-9b80-42e8-ac97-8cbd32a16749?api-version=2023-04-15-preview
# [1495, 1497, 1500, 1502, 1504]
# Batch 181: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/2c504526-4899-48ba-b103-a95806232b70?api-version=2023-04-15-preview
# [1507, 1508, 1512, 1513, 1515]
# Batch 182: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6b83f2cc-f836-41f4-9224-f2672a48282e?api-version=2023-04-15-preview
# [1516, 1517, 1518, 1519, 1520]
# Batch 183: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/40f7c8eb-dd13-4bec-a95d-8bc72864299c?api-version=2023-04-15-preview
# [1521, 1523, 1525, 1527, 1528]
# Batch 184: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8f8ca818-101d-4575-b36e-1e5fce615dc8?api-version=2023-04-15-preview
# [1531, 1532, 1535, 1536, 1540]
# Batch 185: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ee7bd710-a7c3-41fe-9059-9c5628a202ad?api-version=2023-04-15-preview
# [1541, 1542, 1543, 1545, 1546]
# Batch 186: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/093b008a-7224-427c-8e08-8a4b28b3edb4?api-version=2023-04-15-preview
# [1552, 1554, 1556, 1558, 1561]
# Batch 187: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bcef7e01-8f66-4221-a472-9f0274d6d4cc?api-version=2023-04-15-preview
# [1563, 1564, 1565, 1567, 1568]
# Batch 188: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/06104ab0-575c-4743-92e7-be00f5a411b7?api-version=2023-04-15-preview
# [1570, 1571, 1580, 1581, 1582]
# Batch 189: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c17a70e3-032e-4f04-9edf-179481c0da26?api-version=2023-04-15-preview
# [1583, 1585, 1590, 1591, 1595]
# Batch 190: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/4793e2bc-a898-498c-9940-7a121d085c99?api-version=2023-04-15-preview
# [1597, 1600, 1601, 1602, 1604]
# Batch 191: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/11e73bd0-a260-4c26-bc5a-6aff13001dc2?api-version=2023-04-15-preview
# [1605, 1606, 1607, 1609, 1611]
# Batch 192: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f1aef5d7-620c-4d39-9367-a71604f4abc0?api-version=2023-04-15-preview
# [1612, 1614, 1615, 1617, 1618]
# Batch 193: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/afa1a79d-4b82-4988-a875-947a1ae5fd6a?api-version=2023-04-15-preview
# [1619, 1620, 1621, 1623, 1624]
# Batch 194: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a7328d35-4b42-4749-b39c-7aa32e203ebc?api-version=2023-04-15-preview
# [1626, 1627, 1628, 1631, 1632]
# Batch 195: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bff0a063-25f7-4c67-935f-a214036a39f2?api-version=2023-04-15-preview
# [1635, 1640, 1641, 1642, 1643]
# Batch 196: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/2f7c6490-06d2-451c-b592-a2cc11142c9e?api-version=2023-04-15-preview
# [1649, 1650, 1651, 1652, 1654]
# Batch 197: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/fd93ea58-d9c9-4b49-87f4-cb8f6fea769c?api-version=2023-04-15-preview
# [1655, 1656, 1657, 1660, 1662]
# Batch 198: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1949f54b-b89a-4971-80e8-f76f32c77804?api-version=2023-04-15-preview
# [1663, 1664, 1669, 1670, 1671]
# Batch 199: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/edfa6e49-779d-4dff-aa6d-3d7d73a2d2dc?api-version=2023-04-15-preview
# [1673, 1674, 1676, 1677, 1682]
# Batch 200: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bc35c98a-b0e4-4684-99a9-6b02b555aa41?api-version=2023-04-15-preview
# [1683, 1687, 1688, 1690, 1692]
# Batch 201: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/02ae188d-7af9-4af2-ba5b-a0d88c9bcc0a?api-version=2023-04-15-preview
# [1694, 1696, 1698, 1701, 1703]
# Batch 202: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bb047330-ed70-4f4d-81a8-8cb7155f1ee8?api-version=2023-04-15-preview
# [1704, 1706, 1707, 1709, 1711]
# Batch 203: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/40cc661b-9c59-4237-a9df-9eccf0aeb0b4?api-version=2023-04-15-preview
# [1713, 1717, 1719, 1720, 1722]
# Batch 204: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e4564164-c77c-4fd4-9153-dd8e704b0e07?api-version=2023-04-15-preview
# [1723, 1724, 1726, 1728, 1729]
# Batch 205: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f82da328-10b9-44dc-9dce-c6803f5283dc?api-version=2023-04-15-preview
# [1730, 1734, 1737, 1738, 1739]
# Batch 206: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/62732041-23e6-4a13-a5c9-c689acaf7e3b?api-version=2023-04-15-preview
# [1740, 1741, 1743, 1745, 1746]
# Batch 207: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/665efe50-8ee9-4690-8b9d-03b815519818?api-version=2023-04-15-preview
# [1748, 1749, 1750, 1751, 1752]
# Batch 208: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6bea86bf-9074-4568-8bd8-c2e8dfb2ef38?api-version=2023-04-15-preview
# [1754, 1755, 1757, 1758, 1759]
# Batch 209: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/32b80ebd-6a2d-4709-98c1-3a1feb4fbfe8?api-version=2023-04-15-preview
# [1760, 1761, 1763, 1764, 1765]
# Batch 210: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/80cd184d-36fc-46b4-8e88-f2e92d0e68f3?api-version=2023-04-15-preview
# [1766, 1768, 1770, 1772, 1773]
# ...
# [22137, 22138, 22139, 22140, 22143]
# Batch 2656: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/32182c50-d436-42ad-bd35-242f39a1b035?api-version=2023-04-15-preview
# [22146, 22148, 22149, 22151, 22152]
# Batch 2657: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1d4a3526-c8a9-48f3-a2a8-b0b50b76c563?api-version=2023-04-15-preview
# [22155, 22159, 22161, 22162, 22163]
# Batch 2658: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d87240dd-308f-4af9-a486-7db393d8355d?api-version=2023-04-15-preview
# [22164, 22166, 22170, 22171, 22176]
# Batch 2659: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ec3470d7-7008-46e3-a9b9-a0c8e490e23f?api-version=2023-04-15-preview
# [22177, 22179, 22180, 22181, 22182]
# Batch 2660: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e5a19bc5-28d2-4385-ab9e-63731a757fda?api-version=2023-04-15-preview
# [22184, 22185, 22186, 22188, 22189]
# Batch 2661: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/41e2b719-498a-45cd-b6d3-34652a38b75a?api-version=2023-04-15-preview
# [22191, 22192, 22193, 22194, 22196]
# Batch 2662: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c0ff282e-5e12-4531-a231-804516e5cae9?api-version=2023-04-15-preview
# [22198, 22200, 22201, 22205, 22207]
# Batch 2663: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/774dba6c-36e3-42e9-939e-c01a7a661032?api-version=2023-04-15-preview
# [22208, 22209, 22214, 22218, 22219]
# Batch 2664: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/76f941e4-70e0-4f5d-a541-5f36d1523705?api-version=2023-04-15-preview
# [22220, 22221, 22222, 22223, 22224]
# Batch 2665: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/05ad659d-d6b2-4bca-9ca8-5afc7eb21741?api-version=2023-04-15-preview
# [22225, 22226, 22229, 22231, 22232]
# Batch 2666: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ad372e8d-08e2-4f24-9a9b-5c51cef5727f?api-version=2023-04-15-preview
# [22233, 22236, 22237, 22240, 22241]
# Batch 2667: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/de6bcb1d-5434-441f-8443-d32a155c8636?api-version=2023-04-15-preview
# [22243, 22244, 22246, 22247, 22248]
# Batch 2668: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/12741074-23d8-4d17-bccd-6727284780c5?api-version=2023-04-15-preview
# [22249, 22250, 22251, 22252, 22254]
# Batch 2669: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0c426f4c-f275-4947-9c5e-7c5cb4c94275?api-version=2023-04-15-preview
# [22255, 22256, 22257, 22259, 22260]
# Batch 2670: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b093bf38-5d72-4b4f-83eb-054723795812?api-version=2023-04-15-preview
# [22261, 22262, 22264, 22265, 22266]
# Batch 2671: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/e1f4ecfb-5306-4e92-8a89-44f0fcda7eb4?api-version=2023-04-15-preview
# [22269, 22272, 22273, 22277, 22278]
# Batch 2672: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/9936a76e-dcf1-4ff7-a999-99dcff5ce5bc?api-version=2023-04-15-preview
# [22281, 22284, 22287, 22288, 22291]
# Batch 2673: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f049dc9b-cf8d-43a1-af6d-6e08b67eb338?api-version=2023-04-15-preview
# [22292, 22294, 22295, 22296, 22297]
# Batch 2674: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f4daa944-5238-4acc-adef-5e3136b2c3e1?api-version=2023-04-15-preview
# [22299, 22300, 22301, 22302, 22303]
# Batch 2675: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5d1df8db-c81d-4dfa-afb2-e544c8501241?api-version=2023-04-15-preview
# [22305, 22307, 22310, 22311, 22312]
# Batch 2676: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8dbb57f9-b369-431c-8479-4763805b3444?api-version=2023-04-15-preview
# [22313, 22314, 22315, 22316, 22318]
# Batch 2677: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d6dbce74-7847-4eac-b407-83088421e37e?api-version=2023-04-15-preview
# [22319, 22320, 22321, 22323, 22324]
# Batch 2678: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c5f4456e-703d-4833-a869-b6bcc542499a?api-version=2023-04-15-preview
# [22327, 22328, 22329, 22330, 22332]
# Batch 2679: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/248804d0-f845-4fa5-9965-0691aebb3db8?api-version=2023-04-15-preview
# [22333, 22334, 22335, 22336, 22337]
# Batch 2680: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/bb8d4080-7cb7-48a3-be0d-179764172b0c?api-version=2023-04-15-preview
# [22339, 22340, 22341, 22342, 22343]
# Batch 2681: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/aa083ff5-8ace-400b-8f13-6532a3dacda3?api-version=2023-04-15-preview
# [22345, 22348, 22350, 22351, 22355]
# Batch 2682: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d8097f5a-0f44-49c9-9d2b-354bbef3d9dd?api-version=2023-04-15-preview
# [22356, 22357, 22359, 22360, 22363]
# Batch 2683: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/516fb0a4-aeec-4070-9d9d-df9a9f30f774?api-version=2023-04-15-preview
# [22365, 22368, 22369, 22370, 22371]
# Batch 2684: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c5f2b4ef-2e54-4d46-847f-86bb370bd430?api-version=2023-04-15-preview
# [22372, 22373, 22374, 22375, 22378]
# Batch 2685: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/528c691c-e711-4a12-addf-3bfab0a22fc5?api-version=2023-04-15-preview
# [22379, 22380, 22381, 22382, 22384]
# Batch 2686: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/fd81c119-6edc-4485-98d7-e4aece8a76d0?api-version=2023-04-15-preview
# [22386, 22387, 22388, 22389, 22391]
# Batch 2687: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/04083679-d839-47e8-9820-8f7ed2f6559e?api-version=2023-04-15-preview
# [22392, 22398, 22401, 22402, 22403]
# Batch 2688: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/0386691b-1429-474f-8cc9-fb65ad7a93ea?api-version=2023-04-15-preview
# [22405, 22407, 22408, 22409, 22410]
# Batch 2689: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/49338283-e711-475a-ba55-1aabb4f5a754?api-version=2023-04-15-preview
# [22412, 22413, 22415, 22416, 22417]
# Batch 2690: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/6337677b-f1aa-4124-8118-7fadd800e10c?api-version=2023-04-15-preview
# [22418, 22419, 22422, 22423, 22425]
# Batch 2691: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b9c4511e-9c38-47c3-b551-27d06302c304?api-version=2023-04-15-preview
# [22426, 22427, 22428, 22430, 22434]
# Batch 2692: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/69ad1fd2-e489-4918-9fdd-671cdefcd500?api-version=2023-04-15-preview
# [22435, 22437, 22438, 22440, 22441]
# Batch 2693: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/9a1af474-945a-4631-9761-4f080f76cd41?api-version=2023-04-15-preview
# [22444, 22445, 22446, 22451, 22453]
# Batch 2694: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/acf7be5d-a3f9-48e8-9a22-aa1a511c6884?api-version=2023-04-15-preview
# [22458, 22460, 22461, 22463, 22464]
# Batch 2695: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/dc91db39-9856-4370-a8a6-503ceb1f47a5?api-version=2023-04-15-preview
# [22465, 22466, 22467, 22468, 22469]
# Batch 2696: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5baa9b52-9d86-49e9-a35f-9243fb4b9ffa?api-version=2023-04-15-preview
# [22471, 22473, 22475, 22476, 22477]
# Batch 2697: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8d48a5a1-0ed7-473d-b806-370682da655a?api-version=2023-04-15-preview
# [22478, 22479, 22480, 22483, 22484]
# Batch 2698: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7dc39a3a-47ac-4de3-a353-0a7d113fbcbd?api-version=2023-04-15-preview
# [22486, 22487, 22488, 22489, 22491]
# Batch 2699: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/9fbd629e-cb04-4288-b55e-f2fe351b587c?api-version=2023-04-15-preview
# [22492, 22493, 22494, 22495, 22497]
# Batch 2700: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/a6315d15-29a5-4376-90c3-e6ca32de9573?api-version=2023-04-15-preview
# [22501, 22503, 22506, 22507, 22508]
# Batch 2701: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/1ded8687-6a18-410b-b081-e7c8cfcba437?api-version=2023-04-15-preview
# [22509, 22510, 22512, 22514, 22518]
# Batch 2702: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8c9b954f-dbf6-43ab-8a16-c1bcaddbe1da?api-version=2023-04-15-preview
# [22519, 22520, 22522, 22523, 22524]
# Batch 2703: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/120e0d55-e045-4b5e-9517-c9c12389f41b?api-version=2023-04-15-preview
# [22526, 22528, 22532, 22533, 22536]
# Batch 2704: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/b0f9fff7-d231-4e29-949b-8f01f619d514?api-version=2023-04-15-preview
# [22537, 22538, 22541, 22542, 22543]
# Batch 2705: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/ebb67689-d448-4d7f-99cc-8eb6a94b5a36?api-version=2023-04-15-preview
# [22544, 22546, 22548, 22550, 22551]
# Batch 2706: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/72257892-cc29-47cc-87a3-e9b4a88a333c?api-version=2023-04-15-preview
# [22552, 22553, 22554, 22555, 22559]
# Batch 2707: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/77962e05-3232-4a97-82bd-6e5446139d52?api-version=2023-04-15-preview
# [22560, 22562, 22564, 22566, 22568]
# Batch 2708: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/7cbba30a-0b8e-4fe6-ae7d-b48f33313c72?api-version=2023-04-15-preview
# [22572, 22574, 22578, 22579, 22581]
# Batch 2709: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/c6470145-1bb6-42a0-a5b3-0b7684e0eac1?api-version=2023-04-15-preview
# [22584, 22585, 22587, 22589, 22590]
# Batch 2710: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/9a104a04-cfce-44dd-8ffd-f6014c5135bb?api-version=2023-04-15-preview
# [22592, 22593, 22594, 22596, 22597]
# Batch 2711: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5e2c5067-0511-4513-8411-4ec9dd5f7810?api-version=2023-04-15-preview
# [22599, 22600, 22602, 22603, 22604]
# Batch 2712: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/59d8e536-4b9a-4ec7-baa2-776608c5f4cb?api-version=2023-04-15-preview
# [22606, 22608, 22611, 22613, 22615]
# Batch 2713: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/f2a81c7f-ca29-40ab-a6da-327fee982d6b?api-version=2023-04-15-preview
# [22616, 22617, 22620, 22621, 22622]
# Batch 2714: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d1b52561-60b1-4e85-be0d-650d07b4452f?api-version=2023-04-15-preview
# [22624, 22626, 22629, 22633, 22634]
# Batch 2715: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/49881112-107f-43ee-b73b-499c4a18e277?api-version=2023-04-15-preview
# [22636, 22637, 22638, 22639, 22640]
# Batch 2716: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/23be4ad7-cb3f-4d8d-adf9-af1b56dee697?api-version=2023-04-15-preview
# [22643, 22645, 22646, 22649, 22650]
# Batch 2717: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/8a5210f9-d943-4345-a468-3f3c7ced2699?api-version=2023-04-15-preview
# [22651, 22653, 22654, 22655, 22657]
# Batch 2718: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/32459f41-ac3b-40f8-b88f-2bc1c2ee97e2?api-version=2023-04-15-preview
# [22658, 22659, 22660, 22661, 22662]
# Batch 2719: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/48a7b6c9-934e-46a4-98bb-12c241b7dc03?api-version=2023-04-15-preview
# [22663, 22664, 22665, 22666, 22669]
# Batch 2720: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/5d36859e-86bd-4e8f-967d-001c2bdb5e3c?api-version=2023-04-15-preview
# [22673, 22675, 22678, 22679, 22681]
# Batch 2721: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/d9574847-f184-482c-aa80-9e1dcf6b7f90?api-version=2023-04-15-preview
# [22682, 22683, 22687]
# Batch 2722: Request accepted.
# Operation Location: https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs/18cf6df3-2365-4c37-9d00-fb7c6e27451d?api-version=2023-04-15-preview

# %%
print(send_error_log)
print(receive_error_log)
print(len(job_ids))
print(len(batch_ids))
# Out:
# []
# []
# 2723
# 2723

# %% [markdown]
# ### Monitor Job Status
# Poll the operation location until the job status is succeeded.

# %%
def check_job_status(operation_location, api_key, poll_interval=10, timeout=300):
    """
    Polls the job status until it succeeds or fails.
    
    Parameters:
        operation_location (str): The operation location URL.
        api_key (str): Azure subscription key.
        poll_interval (int): Time to wait between polls (in seconds).
        timeout (int): Maximum time to wait (in seconds).
        
    Returns:
        dict: JSON response of the job status.
    """
    headers = {
        "Ocp-Apim-Subscription-Key": api_key
    }
    
    start_time = time.time()
    
    while True:
        try:
            response = requests.get(operation_location, headers=headers)
            if response.status_code == 200:
                job_status = response.json().get("status")
                print(f"Job Status: {job_status}")
                
                if job_status == "succeeded":
                    # print("Job succeeded.")
                    return response.json()
                elif job_status == "failed":
                    print("Job failed.")
                    return response.json()
                else:
                    print(f"Job is still in progress. Waiting for {poll_interval} seconds before next check.")
            else:
                print(f"Failed to get job status. Status Code: {response.status_code}")
                print(f"Response: {response.text}")
                return None
        except Exception as e:
            print(f"Exception occurred while checking job status: {str(e)}")
            return None
        
        # Check for timeout
        elapsed_time = time.time() - start_time
        if elapsed_time > timeout:
            print("Polling timed out.")
            return None
        
        time.sleep(poll_interval)

# %%
'NONE' in job_ids
# Out:
# False

# %%
# Process all test files
for idx, operation_location in enumerate(job_ids):
    if idx % 100 == 0:
        print(f"Processing {idx} ----------")
    if operation_location != 'NONE':
        job_response = check_job_status(operation_location, API_KEY)
        job_status = job_response["status"]
        if (job_status == "failed"): 
            receive_error_log.append(operation_location)
# Out:
# Processing 0 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 100 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 200 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 300 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 400 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 500 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 600 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 700 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 800 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 900 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1000 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1100 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1200 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1300 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1400 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1500 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1600 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1700 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1800 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 1900 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2000 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2100 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2200 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2300 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2400 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2500 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2600 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Processing 2700 ----------
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded
# Job Status: succeeded

# %%
print(receive_error_log)
# Out:
# []

# %% [markdown]
# ### Retrieve and Process Results
# Once the job succeeds, retrieve the results and process them into a structured format.

# %%
def retrieve_job_results(operation_location, api_key):
    """
    Retrieves the results of a PII detection job.
    
    Parameters:
        operation_location (str): The operation location URL.
        api_key (str): Azure subscription key.
        
    Returns:
        dict: JSON response containing the job results.
    """
    headers = {
        "Ocp-Apim-Subscription-Key": api_key
    }
    
    try:
        response = requests.get(operation_location, headers=headers)
        if response.status_code == 200:
            print("Successfully retrieved job results.")
            return response.json()
        else:
            print(f"Failed to retrieve job results. Status Code: {response.status_code}")
            print(f"Response: {response.text}")
            return None
    except Exception as e:
        print(f"Exception occurred while retrieving job results: {str(e)}")
        return None

def process_results(job_results):
    """
    Processes the job results and structures them into a DataFrame.
    
    Parameters:
        job_results (dict): JSON response from the job results.
        df (pd.DataFrame): DataFrame containing the documents.
        test_indices_batch (list): List of document indices in the batch.
        
    Returns:
        pd.DataFrame: DataFrame with columns [file_idx, entity_text, type, positions].
    """
    processed_data = []
    
    tasks = job_results.get("tasks", {})
    items = tasks.get("items", [])
    
    for task in items:
        results = task.get("results", {})
        documents = results.get("documents", [])
        
        for doc in documents:
            doc_id = int(doc.get("id"))
            entities = doc.get("entities", [])
            
            # Find the original file index from the test_indices_batch
            # Assuming 'id' corresponds to df.iloc[idx]['id']
            # original_idx = df[df['id'].astype(str) == doc_id].index.tolist()
            # if original_idx:
            #     file_idx = original_idx[0]
            # else:
            #     file_idx = None  # Or handle as needed
            
            for entity in entities:
                entity_text = entity.get("text")
                entity_type = entity.get("category")
                offset = entity.get("offset")
                length = entity.get("length")
                positions = (offset, offset + length)
                # positions = f"{offset}-{offset + length}"
                
                processed_data.append({
                    "file_idx": doc_id,
                    "entity_text": entity_text,
                    "type": entity_type,
                    "positions": positions
                })
    
    result_df = pd.DataFrame(processed_data)
    return result_df

# %%
for idx, operation_location in enumerate(job_ids):
    if idx % 100 == 0:
        print(f"Processing {idx} ----------")
    if operation_location != 'NONE':
        job_response = retrieve_job_results(operation_location, API_KEY)
        if job_response == None:
            print('job_response error')

        batch = batch_ids[idx]
        res_df = process_results(job_response)
        if not os.path.exists('output/pii_azure_detected.csv'):
            res_df.to_csv('output/pii_azure_detected.csv', index=False)
            continue
        existing_df = pd.read_csv('output/pii_azure_detected.csv')
        combined_df = pd.concat([existing_df, res_df], axis=0)
        combined_df.to_csv('output/pii_azure_detected.csv', index=False)
# Out:
# Processing 0 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 100 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 200 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 300 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 400 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 500 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 600 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 700 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 800 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 900 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 1000 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 1100 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 1200 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 1300 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# ...
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 2300 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 2400 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 2500 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 2600 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Processing 2700 ----------
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.
# Successfully retrieved job results.

# %% [markdown]
# ### Save Results to CSV
# Export the processed PII entities to a CSV file.

# %%
# # Define output CSV path
# output_csv_path = 'output/pii_azure_detected_sample.csv'

# # Save to CSV
# pii_df.to_csv(output_csv_path, index=False)

# print(f"PII detection results saved to '{output_csv_path}'.")
# Out:
# PII detection results saved to 'output/pii_azure_detected_sample.csv'.

# %%
# # Configuration Parameters
# with open('input/secret.json', 'r', encoding='UTF-8') as file:
#     secret_json = json.load(file)
# API_KEY = secret_json['LANGUAGE_KEY']
# API_ENDPOINT = secret_json['LANGUAGE_ENDPOINT'] + 'language/analyze-text/jobs'
# # ?api-version=2023-04-15-preview'

# # API_ENDPOINT = "https://azure-pii-detection.cognitiveservices.azure.com/language/analyze-text/jobs"
# API_VERSION = "2023-04-15-preview"
# SHOW_STATS = "True"

# # Rate Limits for S0/F0 Tier
# MAX_REQUESTS_PER_MINUTE = 300
# MAX_REQUESTS_PER_SECOND = 100  # Note: For S0/F0, primary limit is per minute

# # Documents per Request
# DOCS_PER_REQUEST = 5

# # Delay Parameters
# SECONDS_PER_MINUTE = 60
# REQUESTS_PER_BATCH = 5  # Number of requests to send per batch to stay within rate limits
# DELAY_BETWEEN_BATCHES = SECONDS_PER_MINUTE / (MAX_REQUESTS_PER_MINUTE / REQUESTS_PER_BATCH)  # e.g., 60 / (300/5) = 1 second

# %%
# def read_json(path='data/obfuscated_data_06.json'):
#     df = pd.read_json(path, orient="records", encoding='utf-8')
#     return df

# def load_test_indices(path='data/test_indices_2.txt'):
#     with open(path, 'r') as file:
#         test_indices = ast.literal_eval(file.read().strip())
#     return test_indices

# # Load Data
# df = read_json()
# test_indices_2 = load_test_indices()

# %%
# # Group the documents into batches of 5, as per the API's maximum documents per request.
# def create_batches(test_indices, batch_size=DOCS_PER_REQUEST):
#     """Yield successive batches of test indices."""
#     for i in range(0, len(test_indices), batch_size):
#         yield test_indices[i:i + batch_size]

# %%
# def send_pii_detection_request(batch, df, batch_number):
#     """Send a PII detection request for a batch of documents."""
#     documents = []
#     for doc_idx in batch:
#         # Assuming 'id' is a unique identifier in your DataFrame
#         document_id = str(df.iloc[doc_idx]['id'])  # Ensure it's a string
#         text_content = df.iloc[doc_idx]['full_text']
        
#         documents.append({
#             "id": document_id,
#             "language": "en",
#             "text": text_content
#         })
    
#     # Construct the payload
#     payload = {
#         "displayName": f"Document PII Detection Task Batch {batch_number}",
#         "analysisInput": {
#             "documents": documents
#         },
#         "tasks": [
#             {
#                 "kind": "PiiEntityRecognition",
#                 "taskName": f"Document PII Detection Task {batch_number}",
#                 "parameters": {
#                     "model-version": "latest",
#                     "piiCategories": ["Person", "URL", "Email", "PhoneNumber"]
#                 }
#             }
#         ]
#     }
    
#     headers = {
#         "Content-Type": "application/json",
#         "Ocp-Apim-Subscription-Key": API_KEY
#     }
    
#     try:
#         response = requests.post(
#             f"{API_ENDPOINT}?api-version={API_VERSION}&showStats={SHOW_STATS}",
#             headers=headers,
#             data=json.dumps(payload)
#         )
        
#         if response.status_code == 202:
#             operation_location = response.headers.get("operation-location")
#             print(f"Batch {batch_number}: Request accepted. Operation Location: {operation_location}")
#             return operation_location
#         else:
#             print(f"Batch {batch_number}: Failed with status code {response.status_code}. Response: {response.text}")
#             return None
#     except Exception as e:
#         print(f"Batch {batch_number}: Exception occurred - {str(e)}")
#         return None
