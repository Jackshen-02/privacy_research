# %%
import re
import os
import pandas as pd
import json
from collections import defaultdict
from openai import OpenAI
import tiktoken  # Tokenizer library

# %%
with open('../input/secret.json', 'r', encoding='UTF-8') as file:
    secret_json = json.load(file)
api_key = secret_json['OPENAI_API_KEY']
client = OpenAI(api_key=api_key)

# %%
def count_placeholder_occurrences(input_folder):
    placeholder_counts = defaultdict(int)
    placeholder_files = defaultdict(list)
    
    # Get and sort all TSV files in the input folder
    file_names = sorted(
        [f for f in os.listdir(input_folder) if f.startswith('teacherstudentchat') and f.endswith('.tsv')],
        key=lambda x: int(re.search(r'\d+', x).group())
    )
    
    # Process the files in the sorted order
    for file_name in file_names:
        file_path = os.path.join(input_folder, file_name)
        
        # Read the TSV file
        df = pd.read_csv(file_path, sep='\t')
        
        # Combine the 'role' and 'edited' columns into a single transcript
        transcript = "\n".join(f"{row['role']}: {row['edited']}" for _, row in df.iterrows())
        
        # Find all placeholders in the transcript
        placeholders = re.findall(r'<([^>]+)>', transcript)
        
        # Count occurrences of each placeholder and track the files they appear in
        for placeholder in placeholders:
            placeholder_counts[placeholder] += 1
            if file_name not in placeholder_files[placeholder]:
                placeholder_files[placeholder].append(file_name)
    
    return dict(placeholder_counts), dict(placeholder_files)

# Example usage
input_folder = '../../public'
placeholder_counts, placeholder_files = count_placeholder_occurrences(input_folder)

# Print the counts of each placeholder category
for category, count in placeholder_counts.items():
    print(f"{category.lower()}: {count}")
# Out:
# student: 874
# teacher: 197
# another student: 41
# student's short name: 2
# student's full name: 1
# student's username: 1
# teacher's short name: 1
# teacher's name: 3
# student's name: 2
# name of the band: 1
# name: 2
# another teacher: 6
# cat's name: 10
# cat's name1: 3
# cat's name2: 1
# teacher's son's full name: 1
# teacher's son's short name: 1
# teacher's son's middle name: 1
# student's cousin's full name: 1
# student's cousin's short name1: 1
# student's cousin's short name2: 2
# student's cousin's short name3: 1
# dog's name: 2
# lizard's name: 7
# lizard's name's: 1
# student's cousin: 1
# language school: 48
# time: 9
# student's friend: 36
# teacher's child: 95
# age: 7
# student's child: 172
# teacher's husband: 50
# student's husband's: 1
# yoga instructor: 1
# student's husband: 66
# student's classmate: 4
# student's classmate1: 2
# student's classmate2: 1
# teacher1: 5
# teacher2: 2
# teacher's son: 4
# student's friend1: 7
# teacher's sister: 6
# dob: 2
# students: 1
# year: 1
# instagram account: 1
# student's : 1
# student's email address: 1
# student's company: 7
# student's student: 1
# student's child_misspelt: 2
# student's partner: 3
# student's colleague: 3
# student's sister: 1
# student's niece: 9
# number: 2
# date: 3
# student's son: 1
# student's birthday: 1
# student's friend's child: 6
# student's daughter: 1
# student's daugther: 1
# student's friend2: 1
# student's sister-in-law: 11
# student's brother: 5
# student's employee: 1
# student's child_misspelled: 4
# teacher's name_misspelled: 1
# student's name_misspelled: 2
# student husband: 1
# studen'ts child: 1
# student's friend's husband: 1
# researcher: 2
# resort: 2

# %%
# Print the files where a specific placeholder category appears
specific_category = 'lizard\'s name'.upper()
if specific_category in placeholder_files:
    print(f"\nFiles containing the placeholder '{specific_category}':")
    for file_name in placeholder_files[specific_category]:
        print(file_name)
else:
    print(f"No occurrences of the placeholder '{specific_category}' found.")
# Out:
# Files containing the placeholder 'LIZARD'S NAME':
# teacherstudentchat00092.tsv
# teacherstudentchat00093.tsv
# teacherstudentchat00095.tsv

# %%
# Set your OpenAI API key
openai.api_key = 'your-api-key'

# Function to generate prompts dynamically
def get_prompt(category):
    name_keywords = ["name", "teacher", "student", "friend", "husband", "child", "son", "daughter", "cousin", "sister", "brother", 
                     "instructor", "colleague", "partner", "employee", "researcher", "school", "account", "resort"]
    for keyword in name_keywords:
        if keyword in category.lower():
            # return f"Generate a realistic {category.lower()}. Just give me one name with no additional output."
            # TODO: Look at this. Generate the name simulated to a ASR process.
            return f"Generate a {category.lower()}. Just give me one name with no additional output."
    
    # Default prompt for non-name categories
    return f"Generate a realistic {category.lower()}. Just give me one result with no additional output."

# Function to generate synthetic data
def generate_synthetic_data(category):
    prompt = get_prompt(category)
    
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message['content'].strip()

# Function to replace placeholders and record locations
def replace_placeholders(text):
    pattern = re.compile(r'<([^>]+)>')
    placeholder_locations = []
    synthetic_data = {}
    
    for match in pattern.finditer(text):
        placeholder = match.group(1)
        placeholder_locations.append((match.start(), match.end(), placeholder))
        if placeholder not in synthetic_data:
            synthetic_data[placeholder] = generate_synthetic_data(placeholder)
    
    for placeholder, synthetic in synthetic_data.items():
        text = text.replace(f"<{placeholder}>", synthetic)
    
    return text, placeholder_locations

# %%
# Main replacement function, take ~9 minutes to run on local machine (Apple M3 Pro Chip)
# Paths
input_folder = '../../public'

# Lists to store transcripts and placeholder locations
original_transcripts = []
processed_transcripts = []
placeholder_locations_list = []

# Get and sort all TSV files in the input folder
file_names = sorted(
    [f for f in os.listdir(input_folder) if f.startswith('teacherstudentchat') and f.endswith('.tsv')],
    key=lambda x: int(re.search(r'\d+', x).group())
)

# Process the files in the sorted order
for i, file_name in enumerate(file_names):
    print(f"Iteration {i}: {file_name}")
    file_path = os.path.join(input_folder, file_name)
    
    # Read the TSV file
    df = pd.read_csv(file_path, sep='\t')
    
    # Combine the 'role' and 'edited' columns into a single transcript
    transcript = "\n".join(f"{row['role']}: {row['edited']}" for _, row in df.iterrows())
    
    # Store the original transcript
    original_transcripts.append(transcript)
    
    # Process the transcript and record placeholder locations
    processed_transcript, placeholder_locations = replace_placeholders(transcript)
    
    # Store the processed transcript and placeholder locations
    processed_transcripts.append(processed_transcript)
    placeholder_locations_list.append(placeholder_locations)

# Save the original transcripts to a text file
with open('original_transcripts.txt', 'w') as f:
    f.write(json.dumps(original_transcripts, indent=4))

# Save the processed transcripts to a text file
with open('processed_transcripts.txt', 'w') as f:
    f.write(json.dumps(processed_transcripts, indent=4))

# Save the placeholder locations to a text file
with open('placeholder_locations.txt', 'w') as f:
    f.write(json.dumps(placeholder_locations_list, indent=4))
# Out:
# Iteration 0: teacherstudentchat00002.tsv
# Iteration 1: teacherstudentchat00003.tsv
# Iteration 2: teacherstudentchat00004.tsv
# Iteration 3: teacherstudentchat00005.tsv
# Iteration 4: teacherstudentchat00006.tsv
# Iteration 5: teacherstudentchat00007.tsv
# Iteration 6: teacherstudentchat00008.tsv
# Iteration 7: teacherstudentchat00009.tsv
# Iteration 8: teacherstudentchat00010.tsv
# Iteration 9: teacherstudentchat00011.tsv
# Iteration 10: teacherstudentchat00012.tsv
# Iteration 11: teacherstudentchat00013.tsv
# Iteration 12: teacherstudentchat00014.tsv
# Iteration 13: teacherstudentchat00015.tsv
# Iteration 14: teacherstudentchat00016.tsv
# Iteration 15: teacherstudentchat00017.tsv
# Iteration 16: teacherstudentchat00018.tsv
# Iteration 17: teacherstudentchat00019.tsv
# Iteration 18: teacherstudentchat00020.tsv
# Iteration 19: teacherstudentchat00021.tsv
# Iteration 20: teacherstudentchat00022.tsv
# Iteration 21: teacherstudentchat00023.tsv
# Iteration 22: teacherstudentchat00024.tsv
# Iteration 23: teacherstudentchat00025.tsv
# Iteration 24: teacherstudentchat00026.tsv
# Iteration 25: teacherstudentchat00027.tsv
# Iteration 26: teacherstudentchat00028.tsv
# Iteration 27: teacherstudentchat00029.tsv
# Iteration 28: teacherstudentchat00030.tsv
# Iteration 29: teacherstudentchat00031.tsv
# Iteration 30: teacherstudentchat00032.tsv
# Iteration 31: teacherstudentchat00033.tsv
# Iteration 32: teacherstudentchat00034.tsv
# Iteration 33: teacherstudentchat00035.tsv
# Iteration 34: teacherstudentchat00036.tsv
# Iteration 35: teacherstudentchat00037.tsv
# Iteration 36: teacherstudentchat00038.tsv
# Iteration 37: teacherstudentchat00039.tsv
# Iteration 38: teacherstudentchat00040.tsv
# Iteration 39: teacherstudentchat00041.tsv
# Iteration 40: teacherstudentchat00042.tsv
# Iteration 41: teacherstudentchat00043.tsv
# Iteration 42: teacherstudentchat00044.tsv
# Iteration 43: teacherstudentchat00045.tsv
# Iteration 44: teacherstudentchat00046.tsv
# Iteration 45: teacherstudentchat00047.tsv
# Iteration 46: teacherstudentchat00048.tsv
# Iteration 47: teacherstudentchat00049.tsv
# Iteration 48: teacherstudentchat00050.tsv
# Iteration 49: teacherstudentchat00051.tsv
# Iteration 50: teacherstudentchat00052.tsv
# Iteration 51: teacherstudentchat00053.tsv
# Iteration 52: teacherstudentchat00054.tsv
# Iteration 53: teacherstudentchat00055.tsv
# Iteration 54: teacherstudentchat00056.tsv
# Iteration 55: teacherstudentchat00057.tsv
# Iteration 56: teacherstudentchat00058.tsv
# Iteration 57: teacherstudentchat00059.tsv
# Iteration 58: teacherstudentchat00060.tsv
# Iteration 59: teacherstudentchat00061.tsv
# Iteration 60: teacherstudentchat00062.tsv
# Iteration 61: teacherstudentchat00063.tsv
# Iteration 62: teacherstudentchat00064.tsv
# Iteration 63: teacherstudentchat00065.tsv
# Iteration 64: teacherstudentchat00066.tsv
# Iteration 65: teacherstudentchat00067.tsv
# Iteration 66: teacherstudentchat00068.tsv
# Iteration 67: teacherstudentchat00069.tsv
# Iteration 68: teacherstudentchat00070.tsv
# Iteration 69: teacherstudentchat00071.tsv
# Iteration 70: teacherstudentchat00072.tsv
# Iteration 71: teacherstudentchat00073.tsv
# Iteration 72: teacherstudentchat00074.tsv
# Iteration 73: teacherstudentchat00075.tsv
# Iteration 74: teacherstudentchat00076.tsv
# Iteration 75: teacherstudentchat00077.tsv
# Iteration 76: teacherstudentchat00078.tsv
# Iteration 77: teacherstudentchat00079.tsv
# Iteration 78: teacherstudentchat00080.tsv
# Iteration 79: teacherstudentchat00081.tsv
# Iteration 80: teacherstudentchat00082.tsv
# Iteration 81: teacherstudentchat00083.tsv
# Iteration 82: teacherstudentchat00084.tsv
# Iteration 83: teacherstudentchat00085.tsv
# Iteration 84: teacherstudentchat00086.tsv
# Iteration 85: teacherstudentchat00087.tsv
# Iteration 86: teacherstudentchat00088.tsv
# Iteration 87: teacherstudentchat00089.tsv
# Iteration 88: teacherstudentchat00090.tsv
# Iteration 89: teacherstudentchat00091.tsv
# Iteration 90: teacherstudentchat00092.tsv
# Iteration 91: teacherstudentchat00093.tsv
# Iteration 92: teacherstudentchat00094.tsv
# Iteration 93: teacherstudentchat00095.tsv
# Iteration 94: teacherstudentchat00096.tsv
# Iteration 95: teacherstudentchat00097.tsv
# Iteration 96: teacherstudentchat00098.tsv
# Iteration 97: teacherstudentchat00099.tsv
# Iteration 98: teacherstudentchat00100.tsv
# Iteration 99: teacherstudentchat00101.tsv
# Iteration 100: teacherstudentchat00102.tsv
# Iteration 101: teacherstudentchat00103.tsv
# Iteration 102: teacherstudentchat00104.tsv
# Iteration 103: teacherstudentchat00105.tsv
# Iteration 104: teacherstudentchat00106.tsv
# Iteration 105: teacherstudentchat00107.tsv
# Iteration 106: teacherstudentchat00108.tsv
# Iteration 107: teacherstudentchat00109.tsv
# Iteration 108: teacherstudentchat00110.tsv
# Iteration 109: teacherstudentchat00111.tsv
# Iteration 110: teacherstudentchat00112.tsv
# Iteration 111: teacherstudentchat00113.tsv
# Iteration 112: teacherstudentchat00114.tsv
# Iteration 113: teacherstudentchat00115.tsv
# Iteration 114: teacherstudentchat00116.tsv
# Iteration 115: teacherstudentchat00117.tsv
# Iteration 116: teacherstudentchat00118.tsv
# Iteration 117: teacherstudentchat00119.tsv
# Iteration 118: teacherstudentchat00120.tsv
# Iteration 119: teacherstudentchat00121.tsv
# Iteration 120: teacherstudentchat00122.tsv
# Iteration 121: teacherstudentchat00123.tsv
# Iteration 122: teacherstudentchat00124.tsv
# Iteration 123: teacherstudentchat00125.tsv
# Iteration 124: teacherstudentchat00126.tsv
# Iteration 125: teacherstudentchat00127.tsv
# Iteration 126: teacherstudentchat00128.tsv
# Iteration 127: teacherstudentchat00129.tsv
# Iteration 128: teacherstudentchat00130.tsv
# Iteration 129: teacherstudentchat00131.tsv
# Iteration 130: teacherstudentchat00132.tsv
# Iteration 131: teacherstudentchat00133.tsv
# Iteration 132: teacherstudentchat00134.tsv
# Iteration 133: teacherstudentchat00135.tsv
# Iteration 134: teacherstudentchat00136.tsv
# Iteration 135: teacherstudentchat00137.tsv
# Iteration 136: teacherstudentchat00138.tsv
# Iteration 137: teacherstudentchat00139.tsv
# Iteration 138: teacherstudentchat00140.tsv
# Iteration 139: teacherstudentchat00141.tsv
# Iteration 140: teacherstudentchat00142.tsv
# Iteration 141: teacherstudentchat00143.tsv
# Iteration 142: teacherstudentchat00144.tsv
# Iteration 143: teacherstudentchat00145.tsv
# Iteration 144: teacherstudentchat00146.tsv
# Iteration 145: teacherstudentchat00147.tsv
# Iteration 146: teacherstudentchat00148.tsv
# Iteration 147: teacherstudentchat00149.tsv
# Iteration 148: teacherstudentchat00150.tsv
# Iteration 149: teacherstudentchat00151.tsv
# Iteration 150: teacherstudentchat00152.tsv
# Iteration 151: teacherstudentchat00153.tsv
# Iteration 152: teacherstudentchat00154.tsv
# Iteration 153: teacherstudentchat00155.tsv
# Iteration 154: teacherstudentchat00156.tsv
# Iteration 155: teacherstudentchat00157.tsv
# Iteration 156: teacherstudentchat00158.tsv
# Iteration 157: teacherstudentchat00159.tsv
# Iteration 158: teacherstudentchat00160.tsv
# Iteration 159: teacherstudentchat00161.tsv
# Iteration 160: teacherstudentchat00162.tsv
# Iteration 161: teacherstudentchat00163.tsv
# Iteration 162: teacherstudentchat00164.tsv
# Iteration 163: teacherstudentchat00165.tsv
# Iteration 164: teacherstudentchat00166.tsv
# Iteration 165: teacherstudentchat00167.tsv
# Iteration 166: teacherstudentchat00168.tsv
# Iteration 167: teacherstudentchat00169.tsv
# Iteration 168: teacherstudentchat00170.tsv
# Iteration 169: teacherstudentchat00171.tsv
# Iteration 170: teacherstudentchat00172.tsv
# Iteration 171: teacherstudentchat00173.tsv
# Iteration 172: teacherstudentchat00174.tsv
# Iteration 173: teacherstudentchat00175.tsv
# Iteration 174: teacherstudentchat00176.tsv
# Iteration 175: teacherstudentchat00177.tsv
# Iteration 176: teacherstudentchat00178.tsv
# Iteration 177: teacherstudentchat00179.tsv
# Iteration 178: teacherstudentchat00180.tsv
# Iteration 179: teacherstudentchat00181.tsv
# Iteration 180: teacherstudentchat00182.tsv
# Iteration 181: teacherstudentchat00183.tsv
# Iteration 182: teacherstudentchat00184.tsv
# Iteration 183: teacherstudentchat00185.tsv
# Iteration 184: teacherstudentchat00186.tsv
# Iteration 185: teacherstudentchat00187.tsv
# Iteration 186: teacherstudentchat00188.tsv
# Iteration 187: teacherstudentchat00189.tsv
# Iteration 188: teacherstudentchat00190.tsv
# Iteration 189: teacherstudentchat00191.tsv
# Iteration 190: teacherstudentchat00192.tsv
# Iteration 191: teacherstudentchat00193.tsv
# Iteration 192: teacherstudentchat00194.tsv
# Iteration 193: teacherstudentchat00195.tsv
# Iteration 194: teacherstudentchat00196.tsv
# Iteration 195: teacherstudentchat00197.tsv
# Iteration 196: teacherstudentchat00198.tsv
# Iteration 197: teacherstudentchat00199.tsv
# Iteration 198: teacherstudentchat00200.tsv
# Iteration 199: teacherstudentchat00201.tsv
# Iteration 200: teacherstudentchat00202.tsv
# Iteration 201: teacherstudentchat00203.tsv
# Iteration 202: teacherstudentchat00204.tsv
# Iteration 203: teacherstudentchat00205.tsv
# Iteration 204: teacherstudentchat00206.tsv
# Iteration 205: teacherstudentchat00207.tsv
# Iteration 206: teacherstudentchat00208.tsv
# Iteration 207: teacherstudentchat00209.tsv
# Iteration 208: teacherstudentchat00210.tsv
# Iteration 209: teacherstudentchat00211.tsv
# Iteration 210: teacherstudentchat00212.tsv
# Iteration 211: teacherstudentchat00213.tsv
# Iteration 212: teacherstudentchat00214.tsv
# Iteration 213: teacherstudentchat00215.tsv
# Iteration 214: teacherstudentchat00216.tsv
# Iteration 215: teacherstudentchat00217.tsv
# Iteration 216: teacherstudentchat00218.tsv
# Iteration 217: teacherstudentchat00219.tsv
# Iteration 218: teacherstudentchat00220.tsv
# Iteration 219: teacherstudentchat00221.tsv
# Iteration 220: teacherstudentchat00222.tsv
# Iteration 221: teacherstudentchat00223.tsv
# Iteration 222: teacherstudentchat00224.tsv
# Iteration 223: teacherstudentchat00225.tsv
# Iteration 224: teacherstudentchat00226.tsv
# Iteration 225: teacherstudentchat00227.tsv
# Iteration 226: teacherstudentchat00228.tsv
# Iteration 227: teacherstudentchat00229.tsv
# Iteration 228: teacherstudentchat00230.tsv
# Iteration 229: teacherstudentchat00231.tsv
# Iteration 230: teacherstudentchat00232.tsv
# Iteration 231: teacherstudentchat00233.tsv
# Iteration 232: teacherstudentchat00234.tsv
# Iteration 233: teacherstudentchat00235.tsv
# Iteration 234: teacherstudentchat00236.tsv
# Iteration 235: teacherstudentchat00237.tsv
# Iteration 236: teacherstudentchat00238.tsv
# Iteration 237: teacherstudentchat00239.tsv
# Iteration 238: teacherstudentchat00240.tsv
# Iteration 239: teacherstudentchat00241.tsv
# Iteration 240: teacherstudentchat00242.tsv
# Iteration 241: teacherstudentchat00243.tsv
# Iteration 242: teacherstudentchat00244.tsv
# Iteration 243: teacherstudentchat00245.tsv
# Iteration 244: teacherstudentchat00246.tsv
# Iteration 245: teacherstudentchat00247.tsv
# Iteration 246: teacherstudentchat00248.tsv
# Iteration 247: teacherstudentchat00249.tsv
# Iteration 248: teacherstudentchat00250.tsv
# Iteration 249: teacherstudentchat00251.tsv
# Iteration 250: teacherstudentchat00252.tsv
# Iteration 251: teacherstudentchat00253.tsv
# Iteration 252: teacherstudentchat00254.tsv
# Iteration 253: teacherstudentchat00255.tsv
# Iteration 254: teacherstudentchat00256.tsv
# Iteration 255: teacherstudentchat00257.tsv
# Iteration 256: teacherstudentchat00258.tsv
# Iteration 257: teacherstudentchat00259.tsv
# Iteration 258: teacherstudentchat00260.tsv
# Iteration 259: teacherstudentchat00261.tsv

# %%
import openai
import os
import pandas as pd
import re

# Set your OpenAI API key
# openai.api_key = 'your-api-key'

# Function to generate prompts dynamically
def get_prompt(category):
    name_keywords = ["name", "teacher", "student", "friend", "husband", "child", "son", "daughter", "cousin", "sister", "brother", 
                     "instructor", "colleague", "partner", "employee", "researcher", "school", "account", "resort"]
    for keyword in name_keywords:
        if keyword in category.lower():
            return f"Generate a {category.lower()}. Just give me one name with no additional output."
    
    # Default prompt for non-name categories
    return f"Generate a realistic {category.lower()}. Just give me one result with no additional output."

# Function to generate synthetic data
def generate_synthetic_data(category):
    prompt = get_prompt(category)

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        temperature = 0)
    return response.choices[0].message.content

# Function to replace placeholders and record locations
def replace_placeholders(text):
    pattern = re.compile(r'<([^>]+)>')
    placeholder_locations = []
    offset = 0  # This will track the changing index due to replacements
    
    # Iterate through all placeholders in the text
    for match in pattern.finditer(text):
        placeholder = match.group(1)
        start_pos = match.start() + offset
        end_pos = match.end() + offset

        # Generate synthetic data for each placeholder
        synthetic_data = generate_synthetic_data(placeholder)
        
        # Calculate the new positions based on the length of the synthetic data
        replacement_length = len(synthetic_data)
        original_length = end_pos - start_pos
        offset += replacement_length - original_length  # Adjust offset for the length difference
        
        # Record the replacement info with updated positions
        placeholder_locations.append({
            "start": start_pos,
            "end": start_pos + replacement_length,
            "placeholder": placeholder,
            "replacement": synthetic_data
        })

        # Replace the placeholder in the text
        text = text[:start_pos] + synthetic_data + text[end_pos:]

    return text, placeholder_locations

# Main processing function
def process_transcripts(input_folder):
    # Lists to store transcripts and placeholder information
    processed_transcripts = []
    placeholder_info = []

    # Get and sort all TSV files in the input folder
    file_names = sorted(
        [f for f in os.listdir(input_folder) if f.startswith('teacherstudentchat0000') and f.endswith('.tsv')],
        key=lambda x: int(re.search(r'\d+', x).group())
    )
    print(file_names)

    # Process each file
    for i, file_name in enumerate(file_names, start=2):  # file_idx starts from 2
        print(f"Processing file {i}: {file_name}")
        file_path = os.path.join(input_folder, file_name)
        
        # Read the TSV file
        df = pd.read_csv(file_path, sep='\t')
        
        # Combine the 'role' and 'edited' columns into a single transcript
        transcript = "\n".join(f"{row['role']}: {row['edited']}" for _, row in df.iterrows())
        
        # Process the transcript and record placeholder locations
        processed_transcript, placeholder_locations = replace_placeholders(transcript)
        
        # Store the processed transcript
        processed_transcripts.append(processed_transcript)

        # Save placeholder info to the list
        for entry in placeholder_locations:
            placeholder_info.append({
                "file_idx": i,
                "entity_text": entry['replacement'],
                "type": entry['placeholder'],
                "positions": f"({entry['start']}, {entry['end']})"
            })

    # Save the placeholder information to a DataFrame
    df_placeholder_info = pd.DataFrame(placeholder_info, columns=["file_idx", "entity_text", "type", "positions"])

    # Save the DataFrame to a CSV file
    df_placeholder_info.to_csv('synthetic_data_positions.csv', index=False)

    print("Processing completed. Data saved to synthetic_data_positions.csv.")

# Example usage
input_folder = '../../public'  # Define the correct input folder path
process_transcripts(input_folder)
# Out:
# ['teacherstudentchat00002.tsv', 'teacherstudentchat00003.tsv', 'teacherstudentchat00004.tsv', 'teacherstudentchat00005.tsv', 'teacherstudentchat00006.tsv', 'teacherstudentchat00007.tsv', 'teacherstudentchat00008.tsv', 'teacherstudentchat00009.tsv']
# Processing file 2: teacherstudentchat00002.tsv
# Processing file 3: teacherstudentchat00003.tsv
# Processing file 4: teacherstudentchat00004.tsv
# Processing file 5: teacherstudentchat00005.tsv
# Processing file 6: teacherstudentchat00006.tsv
# Processing file 7: teacherstudentchat00007.tsv
# Processing file 8: teacherstudentchat00008.tsv
# Processing file 9: teacherstudentchat00009.tsv
# Processing completed. Data saved to synthetic_data_positions.csv.
