# %%
import ast
from collections import Counter

name_set_true = set()
url_set_true = set()
email_set_true = set()
phoneNum_set_true = set()

# processing true categories
true_categories = Counter()
with open('data/pii_entities.txt', 'r') as file:
    for line in file:
        line = line.strip()
        
        # convert the string to a tuple
        tup = ast.literal_eval(line)
        
        # Only process the first 500 docs
        doc_idx = tup[0]
        # if doc_idx < 15000:
        # increment this category's count in dictionary
        category = tup[2]
        true_categories[category] += 1
        
        new_tup = (tup[0],tup[1],tup[3])
        if category == 'NAME_STUDENT':
            name_set_true.add(new_tup)
        elif category == 'URL_PERSONAL':
            url_set_true.add(new_tup)
        elif category == 'EMAIL':
            email_set_true.add(new_tup)
        elif category == 'PHONE_NUM':
            phoneNum_set_true.add(new_tup)
        
# print categories
print("All true entites summary:")
for key, count in true_categories.items():
    print(f"{key}: {count}")
# Out:
# All true entites summary:
# NAME_STUDENT: 4394
# URL_PERSONAL: 352
# EMAIL: 111
# PHONE_NUM: 14

# %%
def calculate_metrics(synthetic_set, analyzed_set):
    # Exclude the entity type from the comparison
    true_set = set((i, start, end) for i, _, (start, end) in synthetic_set)
    detected_set = set((i, start, end) for i, _, (start, end) in analyzed_set)

    tp = true_set & detected_set
    fp = detected_set - true_set
    fn = true_set - detected_set

    tp_count = len(tp)
    fp_count = len(fp)
    fn_count = len(fn)
    
    return tp_count, fp_count, fn_count

def compute_precision_recall_f1_f5(tp, fp, fn):
    precision = tp / (tp + fp) if tp + fp > 0 else 0
    recall = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0
    f5 = (1 + 5**2) * (precision * recall) / ((5**2 * precision) + recall) if (precision + recall) > 0 else 0
    return precision, recall, f1, f5

# %%
def evaluate_detected_entities(input_detected_entities):
    global name_set_detected
    global url_set_detected
    global email_set_detected
    global phoneNum_set_detected

    name_set_detected = set()
    url_set_detected = set()
    email_set_detected = set()
    phoneNum_set_detected = set()

    # processing detected categories
    detected_categories = Counter()
    with open(input_detected_entities, 'r') as file:
        for line in file:
            line = line.strip()
            
            # convert the string to a tuple
            tup = ast.literal_eval(line)
            
            # increment this category's count in dictionary
            category = tup[2]
            detected_categories[category] += 1
            
            new_tup = (tup[0],tup[1],tup[3])
            if category == 'PERSON':
                name_set_detected.add(new_tup)
            elif category == 'URL':
                url_set_detected.add(new_tup)
            elif category == 'EMAIL_ADDRESS':
                email_set_detected.add(new_tup)
            elif category == 'PHONE_NUMBER':
                phoneNum_set_detected.add(new_tup)

    print("All detected entites summary:")
    # print categories
    for key, count in detected_categories.items():
        print(f"{key}: {count}")
    
    tp_n, fp_n, fn_n = calculate_metrics(name_set_true, name_set_detected)
    tp_u, fp_u, fn_u = calculate_metrics(url_set_true, url_set_detected)
    tp_e, fp_e, fn_e = calculate_metrics(email_set_true, email_set_detected)
    tp_p, fp_p, fn_p = calculate_metrics(phoneNum_set_true, phoneNum_set_detected)

    # Compute Precision, Recall, and F1 Score
    precision_n, recall_n, f1_n, f5_n = compute_precision_recall_f1_f5(tp_n, fp_n, fn_n)
    precision_u, recall_u, f1_u, f5_u = compute_precision_recall_f1_f5(tp_u, fp_u, fn_u)
    precision_e, recall_e, f1_e, f5_e = compute_precision_recall_f1_f5(tp_e, fp_e, fn_e)
    precision_p, recall_p, f1_p, f5_p = compute_precision_recall_f1_f5(tp_p, fp_p, fn_p)
    
    print("\nSummary of Precision, Recall, F1 Score, and F5 Score")
    print(f"NAME_STUDENT    -- Precision: {precision_n:.4f}, Recall: {recall_n:.4f}, F1 Score: {f1_n:.4f}, F5 Score: {f5_n:.4f}, TP: {tp_n}, FP: {fp_n}, FN: {fn_n}")
    print(f"URL_PERSONAL    -- Precision: {precision_u:.4f}, Recall: {recall_u:.4f}, F1 Score: {f1_u:.4f}, F5 Score: {f5_u:.4f}, TP: {tp_u}, FP: {fp_u}, FN: {fn_u}")
    print(f"EMAIL           -- Precision: {precision_e:.4f}, Recall: {recall_e:.4f}, F1 Score: {f1_e:.4f}, F5 Score: {f5_e:.4f}, TP: {tp_e}, FP: {fp_e}, FN: {fn_e}")
    print(f"PHONE_NUM       -- Precision: {precision_p:.4f}, Recall: {recall_p:.4f}, F1 Score: {f1_p:.4f}, F5 Score: {f5_p:.4f}, TP: {tp_p}, FP: {fp_p}, FN: {fn_p}")

# %%
evaluate_detected_entities('output/pii_detected_lg.txt')
# Out:
# All detected entites summary:
# PERSON: 18623
# URL: 4254
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.1623, Recall: 0.6878, F1 Score: 0.2626, F5 Score: 0.6116, TP: 3022, FP: 15601, FN: 1372
# URL_PERSONAL    -- Precision: 0.0691, Recall: 0.8352, F1 Score: 0.1277, F5 Score: 0.5856, TP: 294, FP: 3960, FN: 58
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828, F5 Score: 0.8368, TP: 14, FP: 71, FN: 0

# %%
evaluate_detected_entities('output/pii_detected_trf.txt')
# Out:
# All detected entites summary:
# PERSON: 15330
# URL: 4254
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.2367, Recall: 0.8257, F1 Score: 0.3679, F5 Score: 0.7535, TP: 3628, FP: 11702, FN: 766
# URL_PERSONAL    -- Precision: 0.0686, Recall: 0.8295, F1 Score: 0.1268, F5 Score: 0.5816, TP: 292, FP: 3962, FN: 60
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828, F5 Score: 0.8368, TP: 14, FP: 71, FN: 0

# %%
evaluate_detected_entities('others/pii_detected_trf_threshold.txt')
# Out:
# All detected entites summary:
# PERSON: 15330
# URL: 1122
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 9
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.2367, Recall: 0.8257, F1 Score: 0.3679, F5 Score: 0.7535, TP: 3628, FP: 11702, FN: 766
# URL_PERSONAL    -- Precision: 0.2602, Recall: 0.8295, F1 Score: 0.3962, F5 Score: 0.7652, TP: 292, FP: 830, FN: 60
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.4444, Recall: 0.2857, F1 Score: 0.3478, F5 Score: 0.2897, TP: 4, FP: 5, FN: 10

# %%
evaluate_detected_entities('output/pii_detected_trf_filtered.txt')
# Out:
# All detected entites summary:
# PERSON: 15330
# URL: 1126
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.2367, Recall: 0.8257, F1 Score: 0.3679, F5 Score: 0.7535, TP: 3628, FP: 11702, FN: 766
# URL_PERSONAL    -- Precision: 0.2593, Recall: 0.8295, F1 Score: 0.3951, F5 Score: 0.7649, TP: 292, FP: 834, FN: 60
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828, F5 Score: 0.8368, TP: 14, FP: 71, FN: 0

# %%
# TODO: Run previous and this code chunk. No need to run following code chunks.
evaluate_detected_entities('output/pii_detected_gpt.txt')

# %%
def print_likely_successful_entities(true_set, detected_set, category):
    output_list = []
    count = 0

    for entity_true in true_set:
        if entity_true not in detected_set:
            idx, entity_text, (start, end) = entity_true
            match_found = False  # Initialize a flag to track if a match is found

            for entity_detected in detected_set:
                idx_d, entity_text_d, (start_d, end_d) = entity_detected
                if idx == idx_d:
                    if (start == start_d and end < end_d) or (end == end_d and start > start_d):
                        count += 1
                        output_list.append(f"{entity_true} ---- {entity_detected}")
                        match_found = True  # Set the flag to True when a match is found
                        break  # No need to check further once a match is found

            if not match_found:  # Only add the original entity if no match was found
                output_list.append(str(entity_true))
    
    # Sort the output list by document index (idx)
    sorted_output = sorted(output_list, key=lambda x: int(x.split(",")[0][1:]))

    # Print the sorted output
    print(f"Out of {len(sorted_output)} FN entities for {category} category, {count} entities might have likely been successfully detected by Presidio.")
    for line in sorted_output:
        print(line)

# %%
print_likely_successful_entities(name_set_true, name_set_detected, 'NAME_STUDENT')
# Out:
# Out of 1372 FN entities for NAME_STUDENT category, 901 entities might have likely been successfully detected by Presidio.
# (7, 'Nathalie Sylla', (52, 66)) ---- (7, 'Nathalie Sylla\n\n', (52, 68))
# (80, 'Karol Ferreira', (2, 16)) ---- (80, 'Karol Ferreira\n\nREFLECTION - VISUALIZATION\n\nChallenge\n\nWorking', (2, 64))
# (88, 'Rakesh Singh', (61, 73)) ---- (88, 'Rakesh Singh\n\nChallenge', (61, 84))
# (99, 'Francesco Boscolo', (38, 55)) ---- (99, 'Francesco Boscolo\n\nChallenge', (38, 66))
# (109, 'Michael', (3336, 3343)) ---- (109, 'Michael  -', (3336, 3346))
# (109, 'Michael', (1300, 1307)) ---- (109, 'Michael  -', (1300, 1310))
# (109, 'Michael', (71, 78)) ---- (109, 'Michael  -', (71, 81))
# (112, 'Francisco Ferreira', (30, 48))
# (113, 'Rita', (0, 4))
# (123, 'Stefano Lovato', (156, 170)) ---- (123, 'Stefano Lovato\n\nMDI-191', (156, 179))
# (161, 'Juan Farid', (3758, 3768)) ---- (161, 'Juan Farid  ', (3758, 3770))
# (202, 'Danny Long', (0, 10)) ---- (202, 'Danny Long Reflection', (0, 21))
# (204, 'Deiby', (29, 34))
# (205, 'Azeez Olaide', (0, 12)) ---- (205, 'Azeez Olaide - Design Thinking for Innovation - 01.04.2020', (0, 58))
# (205, 'Azeez Olaide', (3225, 3237)) ---- (205, 'Azeez Olaide - Design Thinking for Innovation - 01.04.2020', (3225, 3283))
# (214, 'Fareed Ponce', (28, 40)) ---- (214, 'Fareed Ponce\n\nChallenge', (28, 51))
# (288, 'Rajinder Santos', (0, 15))
# (324, 'Zia', (79, 82))
# (331, 'Yeimy Molina', (0, 12)) ---- (331, 'Yeimy Molina  ', (0, 14))
# (334, 'Andres Diaz', (0, 11)) ---- (334, 'Andres Diaz\n\nReflection', (0, 23))
# (377, 'Juan Hernandez', (17, 31))
# (470, 'Daniel', (0, 6))
# (609, 'Alex Swetha', (409, 420)) ---- (609, 'Alex Swetha  ', (409, 422))
# (609, 'Tino Swetha', (290, 301)) ---- (609, 'Tino Swetha  ', (290, 303))
# (609, 'Alex Bravo', (438, 448))
# (609, 'Gabriel Bravo', (112, 125))
# (669, 'Miriam Durango', (0, 14)) ---- (669, 'Miriam Durango\n\nDesign Thinking', (0, 31))
# (671, 'Amparo', (65, 71))
# (689, 'Carlos', (53, 59)) ---- (689, 'Carlos Interviewee Name', (53, 76))
# (714, 'Edgar Lara', (18, 28)) ---- (714, 'Edgar Lara\n\n', (18, 30))
# (730, 'Ahmed Saeed', (32, 43))
# (730, 'Ahmed Saeed', (19, 30)) ---- (730, 'Ahmed Saeed\n\nAhmed Saeed\n\nDESIGN', (19, 51))
# (733, 'Nestor Puerta', (0, 13)) ---- (733, 'Nestor Puerta\n\nReflection', (0, 25))
# (736, 'Joao Courtois', (97, 110)) ---- (736, 'Joao Courtois\n\nElements', (97, 120))
# (1125, 'Christian Schmidt', (3397, 3414))
# (1125, 'Christian Schmidt', (13, 30))
# (1185, 'Florian Richter', (36, 51)) ---- (1185, 'Florian Richter\n\nDate', (36, 57))
# (1201, 'Hannah Ali', (48, 58)) ---- (1201, 'Hannah Ali\t\r \xa0\t\r \xa0 Brazilian', (48, 76))
# (1226, 'Jose Suarez', (40, 51)) ---- (1226, 'Jose Suarez                    ', (40, 71))
# (1290, 'Olivier Collet', (3182, 3196)) ---- (1290, 'Olivier Collet 2/2', (3182, 3200))
# (1293, 'Mohd Javed', (64, 74)) ---- (1293, 'Mohd Javed\n\nChallenge', (64, 85))
# (1352, 'Katy Rivera', (31, 42))
# (1445, 'Doaa', (323, 327))
# (1445, 'Doaa', (937, 941))
# (1445, 'Doaa', (0, 4))
# (1445, 'Doaa', (2530, 2534))
# (1546, 'Aline Lima', (3338, 3348)) ---- (1546, 'Aline Lima\n\nAssignment Reflection –', (3338, 3373))
# (1546, 'Aline Lima', (40, 50)) ---- (1546, 'Aline Lima\n\nAssignment Reflection –', (40, 75))
# (1551, 'Puja', (0, 4))
# (1607, 'German Franco', (35, 48))
# (1658, 'Rakesh Rajput', (65, 78)) ---- (1658, 'Rakesh Rajput\n\nChallenge', (65, 89))
# (1764, 'Anrudh Clifton', (19, 33))
# (1790, 'Shirley Medina', (51, 65)) ---- (1790, 'Shirley Medina\n\nCompany', (51, 74))
# (1792, 'Jan Moradi', (49, 59))
# (1802, 'Ilir Ahmed', (3698, 3708)) ---- (1802, 'Ilir Ahmed  Profesor de Lengua', (3698, 3728))
# (1802, 'Ilir Ahmed', (0, 10)) ---- (1802, 'Ilir Ahmed  Profesor de Lengua', (0, 30))
# (1802, 'Ilir Ahmed', (6371, 6381)) ---- (1802, 'Ilir Ahmed  Profesor de Lengua', (6371, 6401))
# (1810, 'Shailesh Jain', (73, 86)) ---- (1810, 'Shailesh Jain\n\n1', (73, 89))
# (1814, 'Waliur Aslam', (35, 47))
# (2058, 'Ravneet Williams', (60, 76)) ---- (2058, 'Ravneet Williams  ', (60, 78))
# (2061, 'Pushpalatha Bisht', (52, 69))
# (2337, 'Mahmoud Callejas', (3362, 3378)) ---- (2337, 'Mahmoud Callejas  ', (3362, 3380))
# (2672, 'Asif Khan', (50, 59)) ---- (2672, 'Asif Khan\n\nDesign Thinking', (50, 76))
# (2707, 'Muhammed', (12, 20))
# (2714, 'Edgar Munoz', (28, 39)) ---- (2714, 'Edgar Munoz\n\nChallenge & Selection', (28, 62))
# (2722, 'Saman', (1111, 1116)) ---- (2722, 'Saman Jaramillo', (1111, 1126))
# (2722, 'Adam Filip', (38, 48)) ---- (2722, 'Adam Filip  Project', (38, 57))
# (2722, 'Adam Filip', (3510, 3520)) ---- (2722, 'Adam Filip  Project', (3510, 3529))
# (2727, 'Carter Garcia', (11, 24)) ---- (2727, 'Carter Garcia am', (11, 27))
# (2734, 'Junior Diaz', (30, 41))
# (2769, 'Ruben Soria', (101, 112)) ---- (2769, 'Ruben Soria  matthew72@hotmail.com\n\nCourse Assignment - Mind', (101, 161))
# (2793, 'Md Aktar', (0, 8)) ---- (2793, 'Md Aktar | DESIGN THINKING', (0, 26))
# (2814, 'Ricardo Brito', (16, 29)) ---- (2814, 'Ricardo Brito\n\nChallenge', (16, 40))
# (2830, 'Jorge Oliva', (33, 44)) ---- (2830, 'Jorge Oliva\n\nDesign', (33, 52))
# (2842, 'Md Hamid', (2857, 2865)) ---- (2842, 'Md Hamid\n\n', (2857, 2867))
# (2915, 'Carolina Finetti', (154, 170))
# (3003, 'Guddu Singh', (0, 11)) ---- (3003, 'Guddu Singh Reflection of Design Tool Application\n\nChallenge', (0, 60))
# (3202, 'Ahmed Salem', (259, 270))
# (3211, 'Fabio Sameh', (56, 67)) ---- (3211, 'Fabio Sameh\n\nChallenge', (56, 78))
# (3214, 'Ashley', (1756, 1762))
# (3214, 'Ashley', (1524, 1530))
# (3236, 'Carmen Falchi', (0, 13)) ---- (3236, 'Carmen Falchi\n\nChallenge & Selection\n\nDescription', (0, 49))
# (3285, 'Francisca Rojas', (0, 15)) ---- (3285, 'Francisca Rojas’s', (0, 17))
# (3328, 'Karim Elnazer', (33, 46)) ---- (3328, 'Karim Elnazer\n\nChallenge', (33, 57))
# (3411, 'Mduduzi Dladla', (0, 14)) ---- (3411, 'Mduduzi Dladla\n\nMy Reflection – Visualisation\n\nIntroduction', (0, 59))
# (3427, 'Rhiannon Karim', (129, 143)) ---- (3427, 'Rhiannon Karim\n\nChallenge', (129, 154))
# (3427, 'Rhiannon Karim', (37, 51)) ---- (3427, 'Rhiannon Karim\n\nKatia Rania\n\nDesign Thinking', (37, 81))
# (3446, 'Shivam Giri', (42, 53)) ---- (3446, 'Shivam Giri\n\nChallenge', (42, 64))
# (3518, 'Enrique Olaya', (47, 60)) ---- (3518, 'Enrique Olaya\n\nID', (47, 64))
# (3559, 'Esteban Sanhueza', (2394, 2410)) ---- (3559, 'Esteban Sanhueza - Scrum', (2394, 2418))
# (3559, 'Esteban Sanhueza', (0, 16)) ---- (3559, 'Esteban Sanhueza - Scrum', (0, 24))
# (3572, 'Guillaume', (0, 9)) ---- (3572, 'Guillaume -Visualization\n\n', (0, 26))
# (3579, 'Desiree Mazza', (19, 32)) ---- (3579, 'Desiree Mazza Newtown', (19, 40))
# (3585, 'Angel Paternostro', (0, 17))
# (3585, 'Angel Paternostro', (4276, 4293))
# (3589, 'Maria Ferreira', (19, 33)) ---- (3589, 'Maria Ferreira\n\nLearning Launch Tool\n\nChallenge', (19, 66))
# (3603, 'Esraa Han', (40, 49))
# (3652, 'Bekim Campanelli', (13, 29)) ---- (3652, 'Bekim Campanelli - Mind Mapping\n\nChallenge & Selection', (13, 67))
# (3664, 'Blanca Villa', (37, 49))
# (3686, 'Hussain Mohammed', (7741, 7757)) ---- (3686, 'Hussain Mohammed\n\n', (7741, 7759))
# (3701, 'Newton', (24, 30))
# (3701, 'Newton', (2536, 2542))
# (3736, 'Firoz Khan Pandey', (0, 17)) ---- (3736, 'Firoz Khan Pandey Reflection', (0, 28))
# (3742, 'Hector Prada', (0, 12))
# (3745, 'Jessica', (86, 93))
# (3760, 'Muhmmad Sher', (67, 79)) ---- (3760, 'Muhmmad Sher  ', (67, 81))
# (3786, 'Jakeline Lunardi', (0, 16)) ---- (3786, 'Jakeline Lunardi\n\nDESIGN', (0, 24))
# (3885, 'Luca', (1816, 1820))
# (3896, 'Hector Lopez', (0, 12))
# (3900, 'Carmen Perez', (42, 54)) ---- (3900, 'Carmen Perez\n\nChallenge', (42, 65))
# (3911, 'Ganesh Kumar', (0, 12))
# (3911, 'Ganesh Kumar', (2447, 2459))
# (3911, 'Ganesh Kumar', (3612, 3624))
# (3915, 'Maria Laitinen', (0, 14)) ---- (3915, 'Maria Laitinen  ', (0, 16))
# (3915, 'Maria Laitinen', (2815, 2829)) ---- (3915, 'Maria Laitinen  Design', (2815, 2837))
# (3915, 'Maria Laitinen', (5982, 5996)) ---- (3915, 'Maria Laitinen  Design', (5982, 6004))
# (3915, 'Maria Laitinen', (6041, 6055)) ---- (3915, 'Maria Laitinen  Design', (6041, 6063))
# (3917, 'Jose Rocha', (0, 10)) ---- (3917, 'Jose Rocha\n\n', (0, 12))
# (3921, 'Juan Flores', (47, 58)) ---- (3921, 'Juan Flores\n\nChallenge', (47, 69))
# (3935, 'Ismael Garcia', (95, 108)) ---- (3935, 'Ismael Garcia\n\nReflection', (95, 120))
# (3938, 'Ghala Alzhrani', (60, 74)) ---- (3938, 'Ghala Alzhrani\n\n', (60, 76))
# (3964, 'Thabani Ayo', (0, 11)) ---- (3964, 'Thabani Ayo  Design Thinking', (0, 28))
# (3964, 'Thabani Ayo', (3569, 3580)) ---- (3964, 'Thabani Ayo  Design Thinking', (3569, 3597))
# (3968, 'Mohammed Salah', (16, 30)) ---- (3968, 'Mohammed Salah\n\nChallenge &', (16, 43))
# (3987, 'Tara Limbu', (5917, 5927)) ---- (3987, 'Tara Limbu\n\nPros', (5917, 5933))
# (4003, 'Ruma Ali', (37, 45)) ---- (4003, 'Ruma Ali\n\nChallenge', (37, 56))
# (4004, 'Robin Duffy', (2463, 2474)) ---- (4004, 'Robin Duffy Reﬂection', (2463, 2484))
# (4004, 'Robin Duffy', (0, 11)) ---- (4004, 'Robin Duffy Reﬂection', (0, 21))
# (4026, 'Naty Fernandez', (0, 14)) ---- (4026, 'Naty Fernandez - Homework', (0, 25))
# (4040, 'Manuela Lucas', (0, 13)) ---- (4040, 'Manuela Lucas\n\nReflection', (0, 25))
# (4050, 'Aurore Parmentier', (97, 114))
# (4061, 'Vero Reyes', (67, 77)) ---- (4061, 'Vero Reyes\n\nChallenge', (67, 88))
# (4090, 'Aakash Kumar Aakash Kumar', (0, 25))
# (4091, 'Ahmed Goda', (81, 91))
# (4109, 'Taty', (53, 57))
# (4123, 'Federica', (30, 38))
# (4161, 'Ashley', (1412, 1418))
# (4165, 'Aries Wee', (17, 26))
# (4179, 'Avi Rachel', (15, 25)) ---- (4179, 'Avi Rachel\n\nChallenge', (15, 36))
# (4185, 'Anne Marie Sanquer', (0, 18)) ---- (4185, 'Anne Marie Sanquer   Final Assignment  ', (0, 39))
# (4185, 'Anne Marie Sanquer', (3025, 3043)) ---- (4185, 'Anne Marie Sanquer   Final Assignment  ', (3025, 3064))
# (4191, 'Francesco Rizzi', (41, 56)) ---- (4191, 'Francesco Rizzi      ', (41, 62))
# (4212, 'Carmen Martinez', (0, 15)) ---- (4212, 'Carmen Martinez\n\nTool', (0, 21))
# (4214, 'Alvaro Moreno', (0, 13)) ---- (4214, 'Alvaro Moreno  ', (0, 15))
# (4218, 'Kevin Chai', (59, 69)) ---- (4218, 'Kevin Chai\n\nReflection', (59, 81))
# (4220, 'Ali Costa', (80, 89))
# (4241, 'Richard Young', (0, 13)) ---- (4241, 'Richard Young\n\nExample Reflection – Visualization\n\nChallenge & Selection', (0, 72))
# (4263, 'Zakir', (44, 49))
# (4276, 'Jean Pierre Jouanne', (35, 54)) ---- (4276, 'Jean Pierre Jouanne\n\n', (35, 56))
# (4291, 'Cristian Tapia', (82, 96)) ---- (4291, 'Cristian Tapia\n\nChallenge\n\nReaching', (82, 117))
# (4296, 'Everardo Ayala', (0, 14)) ---- (4296, 'Everardo Ayala  Reflection', (0, 26))
# (4328, 'Ajay Preet', (0, 10))
# (4336, 'Michael Kl', (0, 10)) ---- (4336, 'Michael Kl Reflection:', (0, 22))
# (4339, 'Joe Rana', (0, 8)) ---- (4339, 'Joe Rana\n\nReflection', (0, 20))
# (4351, 'Liz Okey', (359, 367)) ---- (4351, 'Liz Okey Visual Artist', (359, 381))
# (4351, 'Tyler Okey', (35, 45))
# (4351, 'Ivan Marta', (290, 300)) ---- (4351, 'Ivan Marta-Conceptual Artist', (290, 318))
# (4394, 'Manuel Medina', (39, 52)) ---- (4394, 'Manuel Medina\n\nChallenge', (39, 63))
# (4400, 'Esteban Ojeda', (4417, 4430)) ---- (4400, 'Esteban Ojeda -', (4417, 4432))
# (4403, 'Zakaria Hassan', (0, 14)) ---- (4403, 'Zakaria Hassan\n\nChallenge', (0, 25))
# (4443, 'Thyago Miguel', (70, 83)) ---- (4443, 'Thyago Miguel\n\nChallenge', (70, 94))
# (4465, 'Mithilesh Gupta', (4496, 4511))
# (4469, 'Sarah Matthew', (0, 13)) ---- (4469, 'Sarah Matthew\n\nReflection', (0, 25))
# (4495, 'Nicolas Charles', (41, 56)) ---- (4495, 'Nicolas Charles\n\nChallenge', (41, 67))
# (4501, 'Aman Baloch', (256, 267)) ---- (4501, 'Aman Baloch\n\n', (256, 269))
# (4506, 'Wesley Rodrigues', (16, 32)) ---- (4506, 'Wesley Rodrigues\n\n', (16, 34))
# (4521, 'Gabriel Lara', (0, 12)) ---- (4521, 'Gabriel Lara\n\nReflection', (0, 24))
# (4547, 'Mohammad Rayan', (0, 14)) ---- (4547, 'Mohammad Rayan  Final Assignment:', (0, 33))
# (4547, 'Mohammad Rayan', (3090, 3104)) ---- (4547, 'Mohammad Rayan  Final Assignment:', (3090, 3123))
# (4553, 'Jessie Belal https://www.kramer.info/wp-content/category/bloghome.php', (119, 188))
# (4569, 'Carmen Taylor', (19, 32)) ---- (4569, 'Carmen Taylor\n\n', (19, 34))
# (4579, 'Samshad Dercole', (2810, 2825)) ---- (4579, 'Samshad Dercole - 12/22/2016 - Sao Paulo', (2810, 2850))
# (4600, 'Isabel Yomna', (30, 42)) ---- (4600, 'Isabel Yomna I  ', (30, 46))
# (4623, 'Stella Sk', (10, 19)) ---- (4623, 'Stella Sk  Assignment:\u200b', (10, 33))
# (4634, 'Md Rashid', (99, 108)) ---- (4634, 'Md Rashid\n\nChallenge', (99, 119))
# (4650, 'Reshma', (1016, 1022))
# (4698, 'Willian Sanches', (2010, 2025)) ---- (4698, 'Willian Sanches V', (2010, 2027))
# (4698, 'Willian Sanches', (0, 15)) ---- (4698, 'Willian Sanches V', (0, 17))
# (4698, 'Willian Sanches', (3848, 3863)) ---- (4698, 'Willian Sanches V', (3848, 3865))
# (4717, 'Qais', (46, 50))
# (4744, 'Busisiwe Msimanga', (6452, 6469))
# (4749, 'Andrew Hawkins', (32, 46)) ---- (4749, 'Andrew Hawkins  ', (32, 48))
# (4765, 'Joy Cooper', (128, 138)) ---- (4765, 'Joy Cooper\n\nSabah', (128, 145))
# (4777, 'Eslam Abo Fatma', (2168, 2183)) ---- (4777, 'Eslam Abo Fatma\n\nRwanda-', (2168, 2192))
# (4796, 'Samuel Luna', (16, 27)) ---- (4796, 'Samuel Luna\n\nChallenge', (16, 38))
# (4808, 'Rasha', (1511, 1516))
# (4808, 'Rasha', (35, 40))
# (4808, 'Rasha', (525, 530))
# (4811, 'Christian Fuentes', (89, 106))
# (4820, 'Moin Ch', (2024, 2031))
# (4842, 'Jan Peters', (29, 39))
# (4878, 'Juan Jose Diaz', (22, 36)) ---- (4878, 'Juan Jose Diaz - 8/12/2020', (22, 48))
# (4913, 'Nizam Ahmed', (39, 50)) ---- (4913, 'Nizam Ahmed                             Pin', (39, 82))
# (4933, 'Blanca Torres', (48, 61))
# (4948, 'Ganesh Mankar', (65, 78))
# (4954, 'Brian Ho', (82, 90)) ---- (4954, 'Brian Ho\n\nChallenge', (82, 101))
# (4957, 'Mia Villanueva', (73, 87)) ---- (4957, 'Mia Villanueva      ', (73, 93))
# (4968, 'Mdjakir Puerta', (45, 59))
# (4971, 'Sajid Khan', (2780, 2790)) ---- (4971, 'Sajid Khan  167695383458', (2780, 2804))
# (4971, 'Sajid Khan', (2556, 2566)) ---- (4971, 'Sajid Khan  792389774673', (2556, 2580))
# (4972, 'Noor Noor', (14, 23)) ---- (4972, 'Noor Noor\n\nReflection', (14, 35))
# (4998, 'Ernesto Young', (33, 46)) ---- (4998, 'Ernesto Young                    ', (33, 66))
# (5013, 'Santosh Kumar Prajapati', (3420, 3443))
# (5042, 'Hasan Rostami', (1298, 1311)) ---- (5042, 'Hasan Rostami\n\nApplication', (1298, 1324))
# (5060, 'Nor Fitri', (38, 47))
# (5085, 'Kashi Papa', (0, 10)) ---- (5085, 'Kashi Papa\n\nExample Reflection', (0, 30))
# (5155, 'Daniel Mohamed', (0, 14)) ---- (5155, 'Daniel Mohamed Group - Confidential\n\nExample Reflection', (0, 55))
# (5155, 'Daniel Mohamed', (3225, 3239)) ---- (5155, 'Daniel Mohamed Group - Confidential\n\n', (3225, 3262))
# (5167, 'Cherry Dantas', (27, 40))
# (5171, 'Azad Ali', (6, 14)) ---- (5171, 'Azad Ali\n\nTitle: Using', (6, 28))
# (5192, 'Isabelle Laurent', (0, 16)) ---- (5192, 'Isabelle Laurent\n\nDesign Thinking', (0, 33))
# (5203, 'Xavier Xuan', (20, 31)) ---- (5203, 'Xavier Xuan\n\nDesign Thinking for Innovation', (20, 63))
# (5203, 'Xavier Xuan', (3029, 3040)) ---- (5203, 'Xavier Xuan\n\nDesign Thinking for Innovation', (3029, 3072))
# (5212, 'Fernando Aguirre', (3921, 3937)) ---- (5212, 'Fernando Aguirre\n\n', (3921, 3939))
# (5215, 'Matheus Kumari', (1200, 1214)) ---- (5215, "Matheus Kumari's", (1200, 1216))
# (5215, 'Matheus Kumari', (2212, 2226)) ---- (5215, "Matheus Kumari's", (2212, 2228))
# (5225, 'Al Kain', (30, 37)) ---- (5225, 'Al Kain\n\nDesign Thinking Tools', (30, 60))
# (5257, 'Sherif Mackie', (45, 58))
# (5290, 'Thomas Meyer', (0, 12)) ---- (5290, 'Thomas Meyer Reflection', (0, 23))
# (5372, 'Aline Ferreira', (28, 42)) ---- (5372, 'Aline Ferreira\n\nChallenge', (28, 53))
# (5452, 'Daniel Chen', (0, 11)) ---- (5452, 'Daniel Chen  Design Thinking', (0, 28))
# (5471, 'Francisco Brown', (0, 15)) ---- (5471, 'Francisco Brown\n\nDesign Thinking', (0, 32))
# (5480, 'Mustafa Majid', (0, 13)) ---- (5480, 'Mustafa Majid  Design Thinking - Assignment  Learning', (0, 53))
# (5526, 'Andrea Rios', (1183, 1194)) ---- (5526, 'Andrea Rios\n\n', (1183, 1196))
# (5529, 'Raffaella Perillo', (73, 90)) ---- (5529, 'Raffaella Perillo\n\nChallenge', (73, 101))
# (5549, 'Moustapha Santi', (0, 15)) ---- (5549, 'Moustapha Santi\t\r \xa0 \t\r \xa0 Challenge', (0, 34))
# (5554, 'Daniele Ameh', (0, 12)) ---- (5554, 'Daniele Ameh Reflection', (0, 23))
# (5588, 'Janet Rios', (0, 10)) ---- (5588, 'Janet Rios  July 10', (0, 19))
# (5588, 'Janet Rios', (3088, 3098)) ---- (5588, 'Janet Rios  July 10', (3088, 3107))
# (5593, 'Jairo Khan', (0, 10)) ---- (5593, 'Jairo Khan  Design Thinking', (0, 27))
# (5593, 'Jairo Khan', (3102, 3112)) ---- (5593, 'Jairo Khan  Design Thinking', (3102, 3129))
# (5608, 'Nirmal Hossain', (31, 45)) ---- (5608, 'Nirmal Hossain\n\nChallenge', (31, 56))
# (5620, 'Edgar Martinez', (0, 14)) ---- (5620, 'Edgar Martinez  -', (0, 17))
# (5634, 'Talaat Mohmmed', (28, 42))
# (5662, 'Philippe Elle', (60, 73)) ---- (5662, 'Philippe Elle OUSSOU', (60, 80))
# (5670, 'Altaf Manish Kumar', (33, 51))
# (5736, 'Pietro Gabrielli', (27, 43)) ---- (5736, 'Pietro Gabrielli\n\n', (27, 45))
# (5737, 'Crystal Campbell', (35, 51))
# (5742, 'Angel Roy', (0, 9)) ---- (5742, 'Angel Roy      ', (0, 15))
# (5742, 'Angel Roy', (2738, 2747)) ---- (5742, 'Angel Roy\n\n', (2738, 2749))
# (5748, 'Mohamed Kamal', (0, 13)) ---- (5748, 'Mohamed Kamal  ', (0, 15))
# (5748, 'Mohamed Kamal', (2858, 2871)) ---- (5748, 'Mohamed Kamal  ', (2858, 2873))
# (5776, 'Ayman', (14, 19))
# (5813, 'Luz', (1896, 1899))
# (5813, 'Luz', (1751, 1754))
# (5825, 'Ricardo Hernandez', (34, 51))
# (5840, 'Yaser Mostafa', (33, 46)) ---- (5840, 'Yaser Mostafa      Challenge', (33, 61))
# (5855, 'May Sutton', (83, 93))
# (5861, 'Masahiro Takahashi', (54, 72)) ---- (5861, 'Masahiro Takahashi      ', (54, 78))
# (5896, 'Donya Donya', (38, 49)) ---- (5896, 'Donya Donya\n\nChallenge', (38, 60))
# (5902, 'Karen', (10, 15)) ---- (5902, 'Karen - Reflection on Mind Mapping Tool\n\nChallenge & Selection', (10, 72))
# (5905, 'Gianpaolo Poli', (3170, 3184))
# (5905, 'Gianpaolo Poli', (0, 14))
# (5907, 'Anna Pirrotta', (0, 13)) ---- (5907, 'Anna Pirrotta\n\nReflection', (0, 25))
# (5910, 'Sara Garcia', (15, 26)) ---- (5910, 'Sara Garcia\n\nChallenge', (15, 37))
# (5922, 'Leonardo Giles', (18, 32)) ---- (5922, 'Leonardo Giles\n\n', (18, 34))
# (5937, 'Asmaa Elnahas', (0, 13)) ---- (5937, 'Asmaa Elnahas\n\nRubric', (0, 21))
# (5950, 'Kamal Jan', (0, 9))
# (5952, 'Yareli Thomas', (50, 63))
# (6020, 'Amanda Rose', (30, 41)) ---- (6020, 'Amanda Rose\n\nSelection', (30, 52))
# (6025, 'Omar Khan', (15, 24)) ---- (6025, 'Omar Khan\n\nDesign Thinking', (15, 41))
# (6027, 'Enrico Laterza', (16, 30))
# (6057, 'Lerato Salem', (4173, 4185))
# (6061, 'Justine Plascencia', (36, 54)) ---- (6061, 'Justine Plascencia\n\nChallenge', (36, 65))
# (6081, 'Giovanni', (0, 8)) ---- (6081, 'Giovanni 1', (0, 10))
# (6081, 'Giovanni', (3348, 3356))
# (6081, 'Giovanni', (5062, 5070))
# (6081, 'Giovanni', (1483, 1491))
# (6085, 'Siew Santamaria', (30, 45)) ---- (6085, 'Siew Santamaria      ', (30, 51))
# (6109, 'Lai Har Leung', (13, 26)) ---- (6109, 'Lai Har Leung  Date', (13, 32))
# (6121, 'Thai Tamang', (0, 11))
# (6125, 'Emanuele Biondi', (33, 48)) ---- (6125, 'Emanuele Biondi\n\nChallenge', (33, 59))
# (6133, 'Mahammad Khan', (109, 122)) ---- (6133, 'Mahammad Khan\n\nChallenge', (109, 133))
# (6135, 'Teresa Jimenez', (63, 77)) ---- (6135, 'Teresa Jimenez      Challenge', (63, 92))
# (6148, 'Christian', (104, 113))
# (6152, 'Manuel', (555, 561)) ---- (6152, 'Manuel  Age', (555, 566))
# (6152, 'Surendra Raj', (1481, 1493)) ---- (6152, 'Surendra Raj  Age', (1481, 1498))
# (6155, 'Khairul Rahman', (32, 46)) ---- (6155, 'Khairul Rahman\n\nChallenge', (32, 57))
# (6170, 'Md Mohamed', (0, 10)) ---- (6170, 'Md Mohamed  kwhite@yahoo.com\n\nWorkflow Optimization', (0, 51))
# (6172, 'Barbara Rolli', (0, 13)) ---- (6172, 'Barbara Rolli\n\nReflection', (0, 25))
# (6187, 'Gino Schiavo', (0, 12)) ---- (6187, 'Gino Schiavo  Design Thinking', (0, 29))
# (6261, 'Camila Parra', (2147, 2159)) ---- (6261, 'Camila Parra  Design Thinking for Innovation\n\nInsight & Approach', (2147, 2211))
# (6261, 'Camila Parra', (0, 12)) ---- (6261, 'Camila Parra  Design Thinking for Innovation', (0, 44))
# (6285, 'Yesenia Dube', (11, 23))
# (6310, 'Md Shahid', (39, 48)) ---- (6310, 'Md Shahid\n\nChallenge', (39, 59))
# (6339, 'Priya Jeet', (2762, 2772)) ---- (6339, 'Priya Jeet  Page 2', (2762, 2780))
# (6339, 'Priya Jeet', (0, 10)) ---- (6339, 'Priya Jeet  Page 1', (0, 18))
# (6361, 'Osman', (898, 903)) ---- (6361, 'Osman  Osman', (898, 910))
# (6361, 'Osman', (107, 112)) ---- (6361, 'Osman  Osman', (100, 112))
# (6361, 'Osman', (1433, 1438)) ---- (6361, 'Osman  Osman', (1426, 1438))
# (6361, 'Sushant Qureshi', (6, 21)) ---- (6361, 'Sushant Qureshi\n\nRoll', (6, 27))
# (6361, 'Osman', (100, 105)) ---- (6361, 'Osman  Osman', (100, 112))
# (6361, 'Osman', (543, 548)) ---- (6361, 'Osman  Osman', (536, 548))
# (6361, 'Osman', (905, 910)) ---- (6361, 'Osman  Osman', (898, 910))
# (6361, 'Osman', (1426, 1431)) ---- (6361, 'Osman  Osman', (1426, 1438))
# (6361, 'Osman', (536, 541)) ---- (6361, 'Osman  Osman', (536, 548))
# (6364, 'Irfan Khan', (32, 42)) ---- (6364, 'Irfan Khan\n\nReflection', (32, 54))
# (6376, 'Aitor Lopez', (6, 17))
# (6376, 'Aitor Lopez', (2459, 2470))
# (6379, 'Alaa Santos', (30, 41))
# (6393, 'Rania Mohammed', (14, 28)) ---- (6393, 'Rania Mohammed\n\nTool', (14, 34))
# (6416, 'Juan Velasquez', (18, 32)) ---- (6416, 'Juan Velasquez\n\nChallenge', (18, 43))
# (6432, 'Hiroshi Tamura', (57, 71)) ---- (6432, 'Hiroshi Tamura\n\n', (57, 73))
# (6457, 'Surya Mohamad', (56, 69)) ---- (6457, 'Surya Mohamad ©      ', (56, 77))
# (6460, 'Maria Luis', (85, 95))
# (6465, 'Tiago Borges', (11, 23)) ---- (6465, 'Reflection Tiago Borges', (0, 23))
# (6495, 'Shiva Kumar', (2999, 3010))
# (6497, 'Indhumathi Shaikh', (2522, 2539)) ---- (6497, 'Indhumathi Shaikh  Page', (2522, 2545))
# (6497, 'Indhumathi Shaikh', (32, 49)) ---- (6497, 'Indhumathi Shaikh  Page', (32, 55))
# (6497, 'Indhumathi Shaikh', (4772, 4789)) ---- (6497, 'Indhumathi Shaikh  Page', (4772, 4795))
# (6521, 'Danish Shaikh', (26, 39))
# (6582, 'Akshat Rajbhar', (50, 64)) ---- (6582, 'Akshat Rajbhar\n\nChallenge', (50, 75))
# (6593, 'Lily Grandon', (0, 12)) ---- (6593, 'Lily Grandon\n\nReflection', (0, 24))
# (6611, 'Cicero Carlos', (0, 13)) ---- (6611, 'Cicero Carlos  ', (0, 15))
# (6612, 'Na Rayan', (28, 36)) ---- (6612, 'Na Rayan\n\nChallenge', (28, 47))
# (6622, 'John Yates', (0, 10))
# (6624, 'Upendar Thakur', (43, 57))
# (6645, 'Stephanie Alaa', (27, 41)) ---- (6645, 'Stephanie Alaa  ', (27, 43))
# (6648, 'Redzuan Azifah', (32, 46)) ---- (6648, 'Redzuan Azifah\n\n', (32, 48))
# (6664, 'Sujith', (17, 23))
# (6693, 'Hugo Lambert', (2340, 2352))
# (6693, 'Hugo Lambert', (5135, 5147))
# (6694, 'Jose', (1461, 1465))
# (6694, 'Jose', (6610, 6614)) ---- (6694, 'Jose “Story', (6610, 6621))
# (6694, 'Jose', (6156, 6160))
# (6694, 'Jose', (3486, 3490))
# (6694, 'Jose', (2715, 2719))
# (6718, 'Lucas Medina', (4152, 4164)) ---- (6718, 'Lucas Medina\n\nDesign Thinking for Innovation', (4152, 4196))
# (6718, 'Lucas Medina', (45, 57)) ---- (6718, 'Lucas Medina\n\nDesign Thinking for Innovation\n\nChallenge\n\nSelection\n\nApplication', (45, 124))
# (6728, 'Jennifer Medina', (0, 15)) ---- (6728, 'Jennifer Medina\n\nReflection\n\nChallenge', (0, 38))
# (6739, 'Angelo Vallejos', (32, 47)) ---- (6739, 'Angelo Vallejos\n\nReflection.-', (32, 61))
# (6750, 'Katie Wakefield', (54, 69)) ---- (6750, 'Katie Wakefield\n\n', (54, 71))
# (6775, 'Gurwinder Singh', (6, 21)) ---- (6775, 'Gurwinder Singh\n\nChallenge', (6, 32))
# (6819, 'Malik Ali', (80, 89)) ---- (6819, 'Malik Ali\n\nChallenge', (80, 100))
# (6849, 'Madison Tate 034626995785', (69, 94)) ---- (6849, 'Madison Tate 034626995785\n\nLife', (69, 100))
# (6851, 'Idongesit Emeka', (43, 58)) ---- (6851, 'Idongesit Emeka\n\nChallenge', (43, 69))
# (6853, 'Mohinder Kumar', (4980, 4994))
# (6873, 'Rahmat Alshehri', (27, 42)) ---- (6873, 'Rahmat Alshehri\n\nChallenge', (27, 53))
# (6882, 'Mohamed Selim', (35, 48)) ---- (6882, 'Mohamed Selim\n\nChallange', (35, 59))
# (6888, 'Gonzalo Wong', (33, 45)) ---- (6888, 'Gonzalo Wong\n\nChallenge', (33, 56))
# (6897, 'Saeed Ahmad', (0, 11)) ---- (6897, 'Saeed Ahmad - Essay\n\nChallenge', (0, 30))
# (6898, 'Anna Russo', (2086, 2096)) ---- (6898, 'Anna Russo  ', (2086, 2098))
# (6898, 'Anna Russo', (78, 88)) ---- (6898, 'Anna Russo  ', (78, 90))
# (6898, 'Anna Russo', (125, 135)) ---- (6898, 'Anna Russo\n\nChallenge', (125, 146))
# (6903, 'Manar', (58, 63))
# (6921, 'Abdo Cortes', (32, 43))
# (6921, 'Abdo Cortes', (2879, 2890))
# (6946, 'Habibu George', (114, 127)) ---- (6946, 'Habibu George\n\nAbuja', (114, 134))
# (6948, 'Isidro Fernandez', (5556, 5572))
# (6976, 'Ifeoma Kings', (40, 52))
# (6976, 'Ifeoma Kings', (3819, 3831))
# (6999, 'Shubham Shubham', (3577, 3592)) ---- (6999, 'Shubham Shubham\n\nROLL', (3577, 3598))
# (7006, 'Angelik', (197, 204))
# (7022, 'Pablo Romero', (0, 12)) ---- (7022, 'Pablo Romero Example Reflection', (0, 31))
# (7032, 'Jesse Salazar', (0, 13)) ---- (7032, 'Jesse Salazar  Visualization Tool', (0, 33))
# (7037, 'Isabel Pardal', (27, 40)) ---- (7037, 'Isabel Pardal\n\nChallenge', (27, 51))
# (7065, 'Samar Mohamed', (25, 38)) ---- (7065, 'Samar Mohamed\n\nChallenge', (25, 49))
# (7067, 'Davi Dias', (33, 42)) ---- (7067, 'Davi Dias\n\nChallenge', (33, 53))
# (7075, 'Diego Campo', (34, 45))
# (7084, 'Jhonatan De Oliveira', (47, 67)) ---- (7084, 'Jhonatan De Oliveira\n\nChalenge & Selection', (47, 89))
# (7098, 'Eman Rahaman', (0, 12)) ---- (7098, 'Eman Rahaman Reflection', (0, 23))
# (7138, 'Mary Perez', (0, 10)) ---- (7138, 'Mary Perez\t\r \xa0\t\r \xa0 Reflection', (0, 29))
# (7156, 'Zhe Basmah', (6, 16)) ---- (7156, 'Zhe Basmah  ROLL', (6, 22))
# (7156, 'Zhe', (82, 85))
# (7156, 'Zhe Basmah', (151, 161)) ---- (7156, 'Zhe Basmah\n\n', (151, 163))
# (7202, 'Ragni Paru', (0, 10)) ---- (7202, 'Ragni Paru\n\nReflection', (0, 22))
# (7203, 'Juan Bakker', (0, 11))
# (7222, 'Dharmendra Shakya', (6, 23)) ---- (7222, 'Dharmendra Shakya  Date', (6, 29))
# (7231, 'Ana', (1389, 1392))
# (7256, 'Jose Brown', (36, 46))
# (7258, 'Michael Stewart', (3298, 3313)) ---- (7258, 'Michael Stewart\n\n\uf0a8', (3298, 3316))
# (7264, 'Sabita Pal', (27, 37))
# (7271, 'Rashid Kt', (107, 116)) ---- (7271, 'Rashid Kt\n\nChallenge', (107, 127))
# (7320, 'Minenhle Nucci', (29, 43))
# (7321, 'Ori Abrego', (43, 53))
# (7327, 'Paqui Martin', (12, 24))
# (7343, 'Priyanka Das', (2548, 2560))
# (7382, 'Aylin Osorio', (0, 12)) ---- (7382, 'Aylin Osorio\n\nReflection-Learning', (0, 33))
# (7389, 'Salimatou Reno', (49, 63))
# (7404, 'Jimena', (1530, 1536))
# (7428, 'Akash Brito', (91, 102)) ---- (7428, 'Akash Brito  Date', (91, 108))
# (7458, 'Yogi Yates', (109, 119)) ---- (7458, 'Yogi Yates\n\nChallenge', (109, 130))
# (7490, 'Abbas Hernandez', (21, 36)) ---- (7490, 'Abbas Hernandez\n\nChallenge', (21, 47))
# (7641, 'Imran Al', (5354, 5362)) ---- (7641, 'Imran Al  Date', (5354, 5368))
# (7663, 'Lalisa Cruz', (36, 47)) ---- (7663, 'Lalisa Cruz\n\nChallenge', (36, 58))
# (7668, 'Amira Ali', (70, 79)) ---- (7668, 'Amira Ali]\n\nChallenge', (70, 91))
# (7671, 'Barbara Sofia', (0, 13)) ---- (7671, 'Barbara Sofia Design-Thinking', (0, 29))
# (7676, 'Om Ahmed Teto', (145, 158)) ---- (7676, 'Om Ahmed Teto\n\nChallenge', (145, 169))
# (7680, 'Jonathan Vieira', (112, 127)) ---- (7680, 'Jonathan Vieira\xa0 \xa0 ', (112, 131))
# (7713, 'Miguel Caceres', (62, 76)) ---- (7713, 'Miguel Caceres\n\nChallenge', (62, 87))
# (7732, 'Ali Alawy', (0, 9)) ---- (7732, 'Ali Alawy\n\nInstructions', (0, 23))
# (7735, 'Abdul Khan', (29, 39)) ---- (7735, 'Abdul Khan\n\nChallenge & Selection', (29, 62))
# (7736, 'Md Sadam', (5415, 5423)) ---- (7736, 'Md Sadam  Course - Design', (5415, 5440))
# (7745, 'Luis Gonzales', (0, 13)) ---- (7745, 'Luis Gonzales  ', (0, 15))
# (7745, 'Luis Gonzales', (11991, 12004)) ---- (7745, 'Luis Gonzales  ', (11991, 12006))
# (7745, 'Luis Gonzales', (4441, 4454)) ---- (7745, 'Luis Gonzales  ', (4441, 4456))
# (7745, 'Luis Gonzales', (9077, 9090)) ---- (7745, 'Luis Gonzales  ', (9077, 9092))
# (7759, 'Mihaela Leal', (1215, 1227)) ---- (7759, 'Mihaela Leal  ', (1215, 1229))
# (7759, 'Mihaela Leal', (24, 36)) ---- (7759, 'Mihaela Leal  ', (24, 38))
# (7759, 'Mihaela Leal', (1402, 1414)) ---- (7759, 'Mihaela Leal  ', (1402, 1416))
# (7759, 'Mai Singh', (1179, 1188)) ---- (7759, 'Mai Singh:\n\nDesign', (1179, 1197))
# (7763, 'Nani Peroni', (0, 11)) ---- (7763, 'Nani Peroni  Design Thinking for Innovation Assignment', (0, 54))
# (7784, 'Shaun Tong', (79, 89)) ---- (7784, 'Shaun Tong\n\n1', (79, 92))
# (7793, 'Pallabi Amin', (63, 75))
# (7856, 'Ray Nguyen', (7749, 7759)) ---- (7856, 'Ray Nguyen\n\n', (7749, 7761))
# (7858, 'Mickael Richardson', (33, 51)) ---- (7858, 'Mickael Richardson\n\nChallenge', (33, 62))
# (7865, 'Tina Peralta', (0, 12)) ---- (7865, 'Tina Peralta - Reflection', (0, 25))
# (7867, 'Rabi Jain', (61, 70)) ---- (7867, 'Rabi Jain\n\nReflection', (61, 82))
# (7929, 'Muhammad Leonardo', (29, 46)) ---- (7929, 'Muhammad Leonardo\n\nChallenge', (29, 57))
# (7931, 'Rohan Magesh', (38, 50)) ---- (7931, 'Rohan Magesh\n\nChallenge', (38, 61))
# (7932, 'Ahmed Alaa', (3822, 3832)) ---- (7932, 'Ahmed Alaa\n\nDigitally', (3822, 3843))
# (7932, 'Ahmed Alaa', (3855, 3865)) ---- (7932, 'Ahmed Alaa  Date', (3855, 3871))
# (7932, 'Ahmed Carlos', (130, 142)) ---- (7932, 'Ahmed Carlos  Date', (130, 148))
# (7932, 'Ahmed Carlos', (2633, 2645)) ---- (7932, 'Ahmed Carlos  Date', (2633, 2651))
# (7948, 'Brajesh Husan', (34, 47)) ---- (7948, 'Brajesh Husan\n\nChallenge', (34, 58))
# (7959, 'Ravinder Pal', (6, 18)) ---- (7959, 'Ravinder Pal      Challenge', (6, 33))
# (7971, 'Palesa Palesa', (27, 40))
# (7974, 'Kojo Oteng', (8, 18)) ---- (7974, 'Kojo Oteng\n\nCourse', (8, 26))
# (7993, 'Quentin', (0, 7)) ---- (7993, 'Quentin 1', (0, 9))
# (7993, 'Quentin', (2969, 2976)) ---- (7993, 'Quentin 2', (2969, 2978))
# (8021, 'Caterina Mauro', (81, 95))
# (8025, 'Irving Gamez', (71, 83)) ---- (8025, 'Irving Gamez  Course', (71, 91))
# (8033, 'Shamsun Fawzy', (0, 13)) ---- (8033, 'Shamsun Fawzy\n\nReflection', (0, 25))
# (8102, 'Om Ahmed', (2037, 2045))
# (8102, 'Om Ahmed', (68, 76))
# (8108, 'Sameh', (861, 866))
# (8127, 'Filip', (38, 43))
# (8163, 'Abdi Bennett', (44, 56)) ---- (8163, 'Abdi Bennett\n\nChallenge', (44, 67))
# (8173, 'Graziella Ibrahim', (16, 33)) ---- (8173, 'Graziella Ibrahim  ', (16, 35))
# (8192, 'Roberto Hasan', (1904, 1917)) ---- (8192, 'Roberto Hasan Papers', (1904, 1924))
# (8192, 'Roberto Hasan', (10, 23)) ---- (8192, 'Roberto Hasan Papers', (10, 30))
# (8251, 'Kenichi Watanabe', (33, 49)) ---- (8251, 'Kenichi Watanabe\n\n', (33, 51))
# (8271, 'Paul Basha', (35, 45)) ---- (8271, 'Paul Basha\n\nChallenge', (35, 56))
# (8296, 'Feroz Saiful', (2963, 2975)) ---- (8296, 'Feroz Saiful\n\nDesign Thinking', (2963, 2992))
# (8296, 'Feroz Saiful', (0, 12)) ---- (8296, 'Feroz Saiful\n\nDesign Thinking', (0, 29))
# (8301, 'Jeff Fang', (44, 53)) ---- (8301, 'Jeff Fang  ', (44, 55))
# (8322, 'Adrian Trujillo', (5, 20)) ---- (8322, 'p.p. Adrian Trujillo', (0, 20))
# (8329, 'Uwe Bas', (113, 120)) ---- (8329, 'Uwe Bas\n\n21', (113, 124))
# (8337, 'Luiz Oliveira', (87, 100)) ---- (8337, 'Luiz Oliveira -', (87, 102))
# (8340, 'Giuseppe Petrosillo', (17, 36)) ---- (8340, 'Giuseppe Petrosillo -', (17, 38))
# (8340, 'El Petrosillo', (52, 65))
# (8364, 'Ali Zarei', (0, 9)) ---- (8364, 'Ali Zarei Reflection', (0, 20))
# (8371, 'Ismael Aguirre', (17, 31)) ---- (8371, 'Ismael Aguirre\n\nLife', (17, 37))
# (8372, 'Jaime Martinez', (66, 80))
# (8379, 'Iva Juric', (2944, 2953)) ---- (8379, 'Iva Juric\n\n', (2944, 2955))
# (8379, 'Iva Juric', (2278, 2287)) ---- (8379, 'Iva Juric\n\nInsight', (2278, 2296))
# (8412, 'Adriano Santos', (0, 14)) ---- (8412, 'Adriano Santos - Reflection\n\nChallenge', (0, 38))
# (8436, 'Farida Akpan', (9, 21)) ---- (8436, 'Farida Akpan\n\nDESIGN', (9, 29))
# (8468, 'Hernan Orozco', (6, 19)) ---- (8468, 'Hernan Orozco\n\nCHALLENGE', (6, 30))
# (8476, 'Ludis', (128, 133))
# (8483, 'Mario Belfiore', (30, 44))
# (8485, 'Ahmad Suryadi', (31, 44)) ---- (8485, 'Ahmad Suryadi      Challenge', (31, 59))
# (8496, 'Beatriz', (2647, 2654)) ---- (8496, 'Beatriz et al', (2647, 2660))
# (8505, 'Philippe Quesnel', (7582, 7598)) ---- (8505, 'Philippe Quesnel\n\nInnovation & R&D', (7582, 7616))
# (8535, 'Clash Royale', (2847, 2859))
# (8535, 'Clash Royale', (0, 12))
# (8545, 'Nweze Stanley', (0, 13)) ---- (8545, 'Nweze Stanley\n\nReflection', (0, 25))
# (8546, 'Sebastian Arenas', (0, 16)) ---- (8546, 'Sebastian Arenas\n\nFinal Reflection', (0, 34))
# (8550, 'Adigun Okoro', (45, 57))
# (8578, 'Javier Vega', (102, 113)) ---- (8578, 'Javier Vega  ', (102, 115))
# (8587, 'Nuno', (37, 41))
# (8593, 'Tony Flores', (0, 11)) ---- (8593, 'Tony Flores | Assignment', (0, 24))
# (8593, 'Tony Flores', (2942, 2953)) ---- (8593, 'Tony Flores | Assignment', (2942, 2966))
# (8597, 'Nomfundo Alkaabi', (14, 30)) ---- (8597, 'Nomfundo Alkaabi\n\nReflection', (14, 42))
# (8608, 'Sajid Jutt', (231, 241)) ---- (8608, 'Sajid Jutt\n\nDesign Thinking for Innovation    University of Virginia', (231, 299))
# (8610, 'Porch Zakwe', (107, 118))
# (8612, 'Ana Sofia Rayo', (36, 50)) ---- (8612, 'Ana Sofia Rayo\n\nSelection', (36, 61))
# (8621, 'Luz Marina Mora', (49, 64))
# (8650, 'Angelo Silva', (4120, 4132)) ---- (8650, 'Angelo Silva  ', (4120, 4134))
# (8650, 'Angelo Silva', (0, 12)) ---- (8650, 'Angelo Silva  ', (0, 14))
# (8670, 'Yoel', (0, 4))
# (8673, 'Farooq', (2307, 2313)) ---- (8673, 'Farooq  Page 2', (2307, 2321))
# (8673, 'Farooq', (0, 6)) ---- (8673, 'Farooq  Page 1', (0, 14))
# (8675, 'Pedro Ahmed', (4, 15)) ---- (8675, 'Pedro Ahmed\n\nChallenge', (4, 26))
# (8690, 'Diego', (22, 27))
# (8706, 'Lucy Guzman', (3328, 3339)) ---- (8706, 'Lucy Guzman           ', (3328, 3350))
# (8706, 'Lucy Guzman', (7109, 7120)) ---- (8706, 'Lucy Guzman           ', (7109, 7131))
# (8706, 'Lucy Guzman', (15, 26)) ---- (8706, 'Lucy Guzman           ', (15, 37))
# (8711, 'Blanca Becerra', (17, 31)) ---- (8711, 'Blanca Becerra\n\nChallenge & Selection', (17, 54))
# (8713, 'Benson Fung', (20, 31)) ---- (8713, 'Benson Fung\n\nChallenge', (20, 42))
# (8714, 'Jamshed', (33, 40))
# (8716, 'Smsm', (601, 605))
# (8718, 'Naser', (232, 237))
# (8731, 'Alexandra Schmid', (25, 41)) ---- (8731, 'Alexandra Schmid - Design', (25, 50))
# (8735, 'Ananya Agrawal', (1449, 1463)) ---- (8735, 'Ananya Agrawal Pin', (1449, 1467))
# (8751, 'Cesar Mahmood', (3165, 3178)) ---- (8751, 'Cesar Mahmood  Branch', (3165, 3186))
# (8760, 'Dmitriy Aliev', (0, 13)) ---- (8760, 'Dmitriy Aliev\n\nReflection', (0, 25))
# (8768, 'Asia Ibrahim', (31, 43))
# (8771, 'Manuel Alfaro', (2559, 2572)) ---- (8771, 'Manuel Alfaro - Design', (2559, 2581))
# (8771, 'Manuel Alfaro', (81, 94)) ---- (8771, 'Manuel Alfaro - Design', (81, 103))
# (8796, 'Md', (2071, 2073))
# (8796, 'Md', (4211, 4213))
# (8796, 'Md', (0, 2))
# (8844, 'Miriam Bianchi', (74, 88)) ---- (8844, 'Miriam Bianchi  ', (74, 90))
# (8846, 'Tatsuya Watanabe', (61, 77)) ---- (8846, 'Tatsuya Watanabe\n\nChallenge', (61, 88))
# (8858, 'Cleber', (114, 120))
# (8858, 'Ramesh Yadav Singh', (86, 104))
# (8858, 'Nurudeen', (122, 130))
# (8893, 'Emine Panagiotopoulos', (22, 43))
# (8919, 'Terry', (28, 33))
# (8950, 'Naga Raju', (31, 40))
# (8957, 'Sarah Walter', (43, 55)) ---- (8957, 'Sarah Walter\n\nChallenge', (43, 66))
# (8957, 'Sarah Walter', (2696, 2708)) ---- (8957, 'Sarah Walter\n\nChallenge', (2696, 2719))
# (8981, 'Daniel', (13, 19))
# (8983, 'Amr Abdelalem', (8, 21)) ---- (8983, 'Amr Abdelalem\n\nDate', (8, 27))
# (9018, 'Felice', (1039, 1045))
# (9028, 'Luz Young', (3121, 3130))
# (9044, 'Thabiso Mazibuko', (6240, 6256)) ---- (9044, 'Thabiso Mazibuko\n\nTeacher', (6240, 6265))
# (9107, 'Julian Ortiz', (3336, 3348)) ---- (9107, 'Julian Ortiz  Design Thinking', (3336, 3365))
# (9107, 'Julian Ortiz', (0, 12)) ---- (9107, 'Julian Ortiz  Design Thinking', (0, 29))
# (9124, 'Alvin Zainal', (0, 12)) ---- (9124, 'Alvin Zainal Reflection - Learning Launch\n\nChallenge', (0, 52))
# (9150, 'Ch Mackay', (4353, 4362))
# (9150, 'Ch Mackay', (6392, 6401))
# (9150, 'Ch Mackay', (3211, 3220))
# (9150, 'Ch Mackay', (0, 9))
# (9151, 'Corinna Bruns', (18, 31)) ---- (9151, 'Corinna Bruns      ', (18, 37))
# (9156, 'Ahmad Hussein', (82, 95)) ---- (9156, 'Ahmad Hussein\n\nChallenge', (82, 106))
# (9162, 'Dasha Baur', (16, 26)) ---- (9162, 'Dasha Baur\n\nChallenge', (16, 37))
# (9188, 'Alessandra Farrag', (54, 71)) ---- (9188, 'Alessandra Farrag\n\nDesign Thinking', (54, 88))
# (9206, 'Jan Waseem', (112, 122)) ---- (9206, 'Jan Waseem\n\nInstructions\n\nSelect', (112, 144))
# (9235, 'Sameer Sharma', (2596, 2609)) ---- (9235, 'Sameer Sharma      -  ', (2596, 2618))
# (9235, 'Richard Walker', (2522, 2536)) ---- (9235, 'Richard Walker       -', (2522, 2544))
# (9235, 'Luis', (2487, 2491))
# (9235, 'Maya Gupta', (2561, 2571))
# (9243, 'Bankole Ismail', (79, 93)) ---- (9243, 'Bankole Ismail\n\nChallenge', (79, 104))
# (9277, 'Abdulghaffar Abdulghaffar', (0, 25)) ---- (9277, 'Abdulghaffar Abdulghaffar  Elearning Instructional Design', (0, 57))
# (9286, 'Prakash', (2928, 2935))
# (9286, 'Prakash', (3556, 3563))
# (9289, 'Gabriele Khan', (0, 13)) ---- (9289, 'Gabriele Khan - Design', (0, 22))
# (9289, 'Gabriele Khan', (3155, 3168)) ---- (9289, 'Gabriele Khan - Design', (3155, 3177))
# (9291, 'Ahmed Zo', (14, 22)) ---- (9291, 'Ahmed Zo\n\nReflection - Mind', (14, 41))
# (9302, 'Wendy Romero', (2321, 2333))
# (9324, 'Menna', (2775, 2780))
# (9324, 'Menna', (2874, 2879))
# (9363, 'Castillo Valdez', (11, 26))
# (9396, 'Juan Rodriguez', (18, 32))
# (9405, 'Fabrizio', (1555, 1563))
# (9405, 'Fabrizio', (2187, 2195))
# (9442, 'Rajesh Tandel', (58, 71)) ---- (9442, 'Rajesh Tandel\n\nChallenge', (58, 82))
# (9460, 'Jose Luis', (77, 86))
# (9460, 'Lupe King', (55, 64)) ---- (9460, 'Anjali Rajput\n\nLupe King', (40, 64))
# (9460, 'Jose Luis', (66, 75)) ---- (9460, 'Jose Luis\n\nJose Luis                    ', (66, 106))
# (9460, 'Anjali Rajput', (40, 53)) ---- (9460, 'Anjali Rajput\n\nLupe King', (40, 64))
# (9473, 'Amparo Pimienta', (0, 15)) ---- (9473, 'Amparo Pimienta\n\nFINAL ASSIGNMENT', (0, 33))
# (9499, 'Sachin Khan', (39, 50)) ---- (9499, 'Sachin Khan  Design Thinking Course - Assignment\n\nChallenge', (39, 98))
# (9540, 'Jan Miah', (8354, 8362))
# (9546, 'Andru Orozco', (0, 12)) ---- (9546, 'Andru Orozco\n\nDESIGN', (0, 20))
# (9558, 'Alejandro Jerez', (76, 91))
# (9564, 'Giman Giman', (29, 40))
# (9585, 'Ajayi Azubuike', (0, 14)) ---- (9585, 'Ajayi Azubuike Reflection\n\nChallenge & Selection', (0, 48))
# (9628, 'Gianni Chiodini', (0, 15)) ---- (9628, 'Gianni Chiodini\n\n', (0, 17))
# (9629, 'Maria Amin', (9, 19)) ---- (9629, 'Maria Amin  ', (9, 21))
# (9635, 'Adriana Lopez', (1756, 1769)) ---- (9635, 'Adriana Lopez  https://www.brennan.com/taghome.htm', (1756, 1806))
# (9653, 'Man Man Kwok', (13, 25))
# (9661, 'Qis Sia', (8, 15)) ---- (9661, 'Qis Sia\n\nReflection on Visualization', (8, 44))
# (9665, 'Bastian Rubio', (9, 22)) ---- (9665, 'Bastian Rubio  ', (9, 24))
# (9674, 'Princess', (3797, 3805))
# (9674, 'Princess', (3829, 3837))
# (9674, 'Princess', (3811, 3819))
# (9760, 'Bk Bk', (6, 11)) ---- (9760, 'Bk Bk  Roll', (6, 17))
# (9760, 'Md', (1351, 1353))
# (9760, 'Sama', (1088, 1092))
# (9760, 'Bk Bk', (1009, 1014)) ---- (9760, 'Bk Bk  Roll', (1009, 1020))
# (9786, 'Jibon Low', (0, 9)) ---- (9786, 'Jibon Low  25', (0, 13))
# (9800, 'Douglas Holmes', (86, 100)) ---- (9800, 'Douglas Holmes\n\nChallenge', (86, 111))
# (9822, 'Luis Islas', (31, 41)) ---- (9822, 'Luis Islas\n\nChallenge', (31, 52))
# (9832, 'Willi Rohde', (43, 54)) ---- (9832, 'Willi Rohde      ', (43, 60))
# (9835, 'Florence James', (0, 14)) ---- (9835, 'Florence James\n\n', (0, 16))
# (9855, 'Laxmi Sachin Yadav', (33, 51))
# (9911, 'Cobus Mpanza', (1842, 1854))
# (9930, 'Busi Tarek', (23, 33))
# (9957, 'Rosnani Kiah', (6, 18))
# (9960, 'Javier Morales', (76, 90)) ---- (9960, 'Javier Morales  john14@hotmail.com\n\n', (76, 112))
# (9983, 'Soka', (44, 48))
# (9984, 'Abdiel Rios', (59, 70)) ---- (9984, 'Abdiel Rios\n\nChallenge', (59, 81))
# (9995, 'Loan Mendoza', (3713, 3725)) ---- (9995, 'Loan Mendoza\n\nINSIGHT &', (3713, 3736))
# (10057, 'Leidy Kabiri', (47, 59)) ---- (10057, 'Leidy Kabiri\n\n', (47, 61))
# (10065, 'Auni Nik', (31, 39)) ---- (10065, 'Auni Nik\n\nChallenge &', (31, 52))
# (10160, 'Abdul Thomas', (92, 104)) ---- (10160, 'Abdul Thomas\n\nChallenge', (92, 115))
# (10164, 'Rui Mendes', (27, 37)) ---- (10164, 'Rui Mendes\n\nDesign Thinking', (27, 54))
# (10165, 'Javier', (4110, 4116))
# (10196, 'Satish Kumar Zeeshan', (45, 65))
# (10239, 'Luis', (16, 20))
# (10246, 'Alessia Gentile', (40, 55)) ---- (10246, 'Alessia Gentile\n\nUNIVERSITY', (40, 67))
# (10252, 'Marcos Williams', (31, 46)) ---- (10252, 'Marcos Williams\n\nChallenge', (31, 57))
# (10269, 'Sergio Echavarria', (0, 17)) ---- (10269, 'Sergio Echavarria  Zuñiga', (0, 25))
# (10277, 'Claudia Perez', (54, 67)) ---- (10277, 'Claudia Perez\n\nChallenge', (54, 78))
# (10280, 'Martha Burton', (6651, 6664)) ---- (10280, 'Martha Burton  ', (6651, 6666))
# (10280, 'Martha Burton', (0, 13)) ---- (10280, 'Martha Burton  ', (0, 15))
# (10280, 'Martha Burton', (3218, 3231)) ---- (10280, 'Martha Burton  ', (3218, 3233))
# (10282, 'Harjinder Brar', (32, 46))
# (10307, 'Rania', (4673, 4678))
# (10307, 'Rania', (0, 5))
# (10345, 'Sk Rana', (29, 36))
# (10376, 'Eva Rivera', (0, 10)) ---- (10376, 'Eva Rivera  ', (0, 12))
# (10380, 'Chinyere Adam', (0, 13)) ---- (10380, 'Chinyere Adam\n\nPORTABLE WATER SUPPLY IN', (0, 39))
# (10421, 'Felix Shehu', (4077, 4088)) ---- (10421, 'Felix Shehu Dynamics\n\nProfessional Coaching and Consulting', (4077, 4135))
# (10421, 'Zaharaddeen Shehu', (8498, 8515)) ---- (10421, 'Zaharaddeen Shehu\n\n', (8498, 8517))
# (10429, 'Abdulrazzaq Aqeel', (64, 81))
# (10447, 'Jackie Lopez', (1944, 1956)) ---- (10447, 'Jackie Lopez  ', (1944, 1958))
# (10502, 'Philippe', (3243, 3251)) ---- (10502, 'VISUALIZATION Philippe', (3229, 3251))
# (10502, 'Philippe', (41, 49)) ---- (10502, 'VISUALIZATION Philippe', (27, 49))
# (10505, 'Caroline Parmar', (15, 30))
# (10506, 'Roberto', (0, 7)) ---- (10506, 'Roberto\n\nReflection', (0, 19))
# (10522, 'Jayanti Russo', (14, 27)) ---- (10522, 'Jayanti Russo\n\nSTORYTELLING\n\nChallenge', (14, 52))
# (10541, 'Joshua Marie', (0, 12)) ---- (10541, 'Joshua Marie\n\nDesign Thinking for Innovation   Reflection', (0, 57))
# (10606, 'Omar Martinez', (15, 28))
# (10672, 'Dip Ari', (0, 7))
# (10672, 'Dip Ari', (3062, 3069))
# (10675, 'Wilfredo Gonzales', (26, 43)) ---- (10675, 'Wilfredo Gonzales\n\nChallenge', (26, 54))
# (10682, 'Ahmed Mohammed', (1502, 1516)) ---- (10682, 'Ahmed Mohammed   Design', (1502, 1525))
# (10682, 'Ahmed Mohammed', (2724, 2738)) ---- (10682, 'Ahmed Mohammed   Design', (2724, 2747))
# (10682, 'Ahmed Mohammed', (0, 14)) ---- (10682, 'Ahmed Mohammed   Design', (0, 23))
# (10690, 'Yew Yew', (31, 38)) ---- (10690, 'Yew Yew\n\nChallenge', (31, 49))
# (10841, 'Marta Kowalski', (192, 206)) ---- (10841, 'Marta Kowalski  ��', (192, 210))
# (10880, 'Leslie Young', (32, 44)) ---- (10880, 'Leslie Young  ', (32, 46))
# (10880, 'Leslie Young', (3157, 3169)) ---- (10880, 'Leslie Young  ', (3157, 3171))
# (10880, 'Leslie Young', (1591, 1603)) ---- (10880, 'Leslie Young  ', (1591, 1605))
# (10888, 'Martin Ahmed', (49, 61)) ---- (10888, 'Martin Ahmed\n\nHello', (49, 68))
# (10934, 'Usman Sunday', (0, 12))
# (10944, 'Sneha Santu', (4133, 4144)) ---- (10944, 'Sneha Santu\n\n*', (4133, 4147))
# (10950, 'Matt Riley 201375864478', (1074, 1097))
# (10963, 'Pedro Paulo Brito', (26, 43))
# (10973, 'Aoife Farrelly', (2060, 2074))
# (10973, 'Aoife Farrelly', (34, 48))
# (10996, 'Fatima Guerrero', (78, 93))
# (11004, 'Joey Boonstra', (0, 13)) ---- (11004, 'Joey Boonstra Creative', (0, 22))
# (11012, 'Khalid Adil', (7, 18)) ---- (11012, 'Khalid Adil\n\nRoll', (7, 24))
# (11064, 'Vikas Ansari', (0, 12))
# (11073, 'Steffen', (8182, 8189))
# (11092, 'Bilal Khan', (44, 54)) ---- (11092, 'Bilal Khan\n\nChallenge & Selection', (44, 77))
# (11095, 'Mohamed', (47, 54))
# (11102, 'Fabio Mendez', (30, 42)) ---- (11102, 'Fabio Mendez\n\nChallenge', (30, 53))
# (11128, 'Pasquale Bergamo', (0, 16)) ---- (11128, 'Pasquale Bergamo\n\nVisualization\n\nChallenge & Seletion\n\nVisualization', (0, 68))
# (11141, 'Petra Schulz', (28, 40)) ---- (11141, 'Petra Schulz\t\r \xa0\t\r \xa0 Challenge', (28, 58))
# (11188, 'Roberto Conti', (0, 13)) ---- (11188, 'Roberto Conti Reflection - Visualization', (0, 40))
# (11192, 'Alessio Valentini', (43, 60)) ---- (11192, 'Alessio Valentini\n\nChallenge', (43, 71))
# (11236, 'David Femi', (0, 10)) ---- (11236, 'David Femi\n\nsherry76@hotmail.com', (0, 32))
# (11243, 'Asia Lemus', (48, 58))
# (11277, 'Anuska Sarkar', (29, 42))
# (11288, 'Juan', (1230, 1234))
# (11297, 'Nubia Parra', (21, 32))
# (11308, 'Flor', (55, 59))
# (11346, 'John Wang', (2494, 2503)) ---- (11346, 'John Wang  ', (2494, 2505))
# (11346, 'John Wang', (4394, 4403)) ---- (11346, 'John Wang  ', (4394, 4405))
# (11346, 'John Wang', (0, 9)) ---- (11346, 'John Wang  ', (0, 11))
# (11354, 'Rachel Karolis', (17, 31)) ---- (11354, 'Rachel Karolis  ', (17, 33))
# (11361, 'Agnese Massetti', (2019, 2034))
# (11361, 'Dawn Massetti', (82, 95))
# (11361, 'Agnese Massetti', (65, 80))
# (11373, 'Murugesan Fawzy', (0, 15)) ---- (11373, 'Murugesan Fawzy  ', (0, 17))
# (11376, 'Cesar Fowler', (15, 27))
# (11392, 'Farooq Tanbir', (73, 86)) ---- (11392, 'Farooq Tanbir\n\n', (73, 88))
# (11399, 'Om Islam', (32, 40))
# (11403, 'Josue Flores', (0, 12)) ---- (11403, 'Josue Flores\n\nChallenge', (0, 23))
# (11417, 'Gerrit De Boer', (8141, 8155)) ---- (11417, 'Gerrit De Boer  angela02', (8141, 8165))
# (11437, 'Javier Hernandez', (52, 68)) ---- (11437, 'Javier Hernandez\n\nChallenge', (52, 79))
# (11443, 'Paola Zagaria', (43, 56)) ---- (11443, 'Paola Zagaria\n\nChallenge & Selection', (43, 79))
# (11451, 'Margarita Bonilla', (111, 128)) ---- (11451, 'Margarita Bonilla      ', (111, 134))
# (11459, 'Alfonso Rodrigues', (0, 17)) ---- (11459, 'Alfonso Rodrigues\n\nDesign Thinking Course\n\nReflection', (0, 53))
# (11474, 'Elizabeth Jose', (0, 14)) ---- (11474, 'Elizabeth Jose\n\nDESIGN', (0, 22))
# (11487, 'Akram Akram', (0, 11)) ---- (11487, 'Akram Akram  Reflection', (0, 23))
# (11492, 'Catherine Donnelly', (52, 70)) ---- (11492, 'Catherine Donnelly  Date', (52, 76))
# (11507, 'Cesar Obando', (0, 12)) ---- (11507, 'Cesar Obando\n\nDesign Thinking', (0, 29))
# (11514, 'Luis Sotelo', (0, 11)) ---- (11514, 'Luis Sotelo\n\nReflection', (0, 23))
# (11521, 'Samantha Busatta', (1971, 1987)) ---- (11521, 'Samantha Busatta\n\n', (1971, 1989))
# (11529, 'Raph', (135, 139))
# (11564, 'Yara', (6647, 6651))
# (11565, 'Pina Varano', (1890, 1901))
# (11565, 'Pina Varano', (3323, 3334))
# (11565, 'Pina Varano', (36, 47))
# (11566, 'Emily', (417, 422)) ---- (11566, 'Emily  ', (417, 424))
# (11566, 'Emily', (2058, 2063)) ---- (11566, 'Emily  ', (2058, 2065))
# (11566, 'Emily', (2284, 2289)) ---- (11566, 'Emily  ', (2284, 2291))
# (11566, 'Emily', (4304, 4309))
# (11566, 'Emily', (22, 27)) ---- (11566, 'Emily,Giuseppe', (22, 36))
# (11566, 'Emily', (1587, 1592)) ---- (11566, 'Emily  ', (1587, 1594))
# (11566, 'Emily', (1542, 1547)) ---- (11566, 'Emily  ', (1542, 1549))
# (11566, 'Emily', (987, 992)) ---- (11566, 'Emily  ', (987, 994))
# (11566, 'Giuseppe', (28, 36)) ---- (11566, 'Emily,Giuseppe', (22, 36))
# (11566, 'Emily', (855, 860)) ---- (11566, 'Emily  ', (855, 862))
# (11569, 'Koky Fathy', (74, 84)) ---- (11569, 'Koky Fathy Challenge', (74, 94))
# (11598, 'Kuldeep Papadopoulos', (2426, 2446)) ---- (11598, 'Kuldeep Papadopoulos  sarah33@yahoo.com', (2426, 2465))
# (11674, 'Amy Malik', (40, 49)) ---- (11674, 'Amy Malik\n\n', (40, 51))
# (11694, 'Saeed Saeed', (29, 40)) ---- (11694, 'Saeed Saeed\n\nTool', (29, 46))
# (11780, 'Jesus Johnson', (0, 13)) ---- (11780, 'Jesus Johnson                                                                                                                                         04/06/2020\n\nReflection', (0, 172))
# (11793, 'Juber Millet', (54, 66))
# (11806, 'Majid Ali', (6723, 6732)) ---- (11806, 'Majid Ali  ', (6723, 6734))
# (11806, 'Majid Ali', (1881, 1890)) ---- (11806, 'Majid Ali  ', (1881, 1892))
# (11806, 'Majid Ali', (4356, 4365)) ---- (11806, 'Majid Ali  ', (4356, 4367))
# (11806, 'Majid Ali', (4288, 4297)) ---- (11806, 'Majid Ali  ', (4288, 4299))
# (11817, 'Karen', (0, 5))
# (11827, 'Sascha Gerber', (0, 13)) ---- (11827, 'Sascha Gerber Reflection', (0, 24))
# (11855, 'Daniel Almeida', (90, 104)) ---- (11855, 'Daniel Almeida  ', (90, 106))
# (11870, 'Rafaela Nasser', (34, 48)) ---- (11870, 'Rafaela Nasser\n\nChallenge', (34, 59))
# (11875, 'Carlos Ramirez', (0, 14)) ---- (11875, 'Carlos Ramirez\n\nReflection', (0, 26))
# (11878, 'Carolina Nieto', (54, 68))
# (11883, 'Karam Khan', (38, 48)) ---- (11883, 'Karam Khan\n\nDeveloping', (38, 60))
# (11886, 'Pipe Cuevas', (0, 11))
# ...
# (17883, 'Hena', (1126, 1130))
# (17886, 'Giulia Fanelli', (40, 54)) ---- (17886, 'Giulia Fanelli\n\nReflection', (40, 66))
# (17902, 'Santosh Kumar', (2368, 2381)) ---- (17902, 'Santosh Kumar  Page 2', (2368, 2389))
# (17902, 'Santosh Kumar', (89, 102)) ---- (17902, 'Santosh Kumar  Page 1', (89, 110))
# (17926, 'Victoria Rivera', (0, 15)) ---- (17926, 'Victoria Rivera |', (0, 17))
# (17928, 'Pinky Singh', (15, 26))
# (17938, 'Ben', (3881, 3884))
# (17938, 'Ben', (67, 70))
# (17965, 'Mahmoud Nasr', (0, 12)) ---- (17965, 'Mahmoud Nasr-Storytelling\n\nChallenge', (0, 36))
# (17975, 'Pilar Martin', (37, 49)) ---- (17975, 'Pilar Martin\n\nChallenge', (37, 60))
# (17999, 'Jonathan Morales', (54, 70)) ---- (17999, 'Jonathan Morales\n\nChallenge', (54, 81))
# (18024, 'Samukelisiwe', (1356, 1368))
# (18024, 'Samukelisiwe', (1372, 1384))
# (18043, 'Hamed Yusuf', (102, 113)) ---- (18043, 'Hamed Yusuf\n\nIntroduction', (102, 127))
# (18050, 'Gamal Ragab', (38, 49)) ---- (18050, 'Gamal Ragab\n\nChallenge', (38, 60))
# (18072, 'Alessandro Coco', (53, 68)) ---- (18072, 'Alessandro Coco |', (53, 70))
# (18072, 'Alessandro Coco', (1833, 1848)) ---- (18072, 'Alessandro Coco |', (1833, 1850))
# (18072, 'Alessandro Coco', (4485, 4500)) ---- (18072, 'Alessandro Coco |', (4485, 4502))
# (18081, 'Tawhidur', (2493, 2501))
# (18081, 'Tawhidur', (2260, 2268))
# (18099, 'Rosy Mondal', (0, 11))
# (18110, 'Denis Carpentier', (0, 16)) ---- (18110, 'Denis Carpentier\n\n', (0, 18))
# (18167, 'Patricio Lane', (28, 41)) ---- (18167, 'Patricio Lane\n\n', (28, 43))
# (18174, 'Anna Abbate', (29, 40)) ---- (18174, 'Anna Abbate\n\nChallenge', (29, 51))
# (18181, 'Md Lim', (24, 30)) ---- (18181, 'Md Lim\n\nChallenge', (24, 41))
# (18185, 'Ruben', (811, 816))
# (18206, 'Jose Grisales', (0, 13)) ---- (18206, 'Jose Grisales  ', (0, 15))
# (18222, 'Fateema Abdulrashid', (18, 37)) ---- (18222, 'Fateema Abdulrashid\n\nChallenge', (18, 48))
# (18225, 'Esteban Arenas', (84, 98)) ---- (18225, 'Esteban Arenas\n\nChallenge', (84, 109))
# (18246, 'Barbara Dinusha', (15, 30)) ---- (18246, 'Barbara Dinusha\n\nChallenge', (15, 41))
# (18251, 'Vivian Johnson', (83, 97)) ---- (18251, 'Vivian Johnson      ', (83, 103))
# (18284, 'Mercedes Baltazar', (69, 86))
# (18285, 'Sonia Ruiz', (39, 49)) ---- (18285, 'Sonia Ruiz\n\nChallenge', (39, 60))
# (18301, 'Geral Vergara', (1865, 1878)) ---- (18301, 'Geral Vergara �  de � 1', (1865, 1888))
# (18327, 'Abdelrhman Kanarya', (78, 96)) ---- (18327, 'Abdelrhman Kanarya\n\nChallenge', (78, 107))
# (18330, 'Naser Ali', (0, 9)) ---- (18330, 'Naser Ali\n\nChange', (0, 17))
# (18343, 'Ree Miller', (1086, 1096))
# (18343, 'Andrea Cammarata', (1048, 1064))
# (18361, 'Ximena Navarro', (0, 14)) ---- (18361, 'Ximena Navarro Reflection', (0, 25))
# (18365, 'Blanca Meyer', (43, 55))
# (18367, 'Priyanka Sah', (64, 76)) ---- (18367, 'Priyanka Sah\n\nReflection – Visualization\n\nChallenge & Selection    Visuals', (64, 138))
# (18391, 'Mohsin Shahrul', (0, 14)) ---- (18391, 'Mohsin Shahrul\n\nReflection', (0, 26))
# (18430, 'Cheong', (2897, 2903))
# (18430, 'Cheong', (11, 17))
# (18439, 'Jay Bernard', (3209, 3220)) ---- (18439, 'Jay Bernard\n\nApproach', (3209, 3230))
# (18475, 'Matteo Cascino', (25, 39)) ---- (18475, 'Matteo Cascino\n\nChallenge\t&', (25, 52))
# (18503, 'Danny Robinson', (0, 14)) ---- (18503, 'Danny Robinson | Design', (0, 23))
# (18516, 'Sumit Kumar', (242, 253))
# (18547, 'Renata', (22, 28))
# (18564, 'George Aguirre', (29, 43)) ---- (18564, 'George Aguirre\n\nChallenge', (29, 54))
# (18573, 'Nasrullah Perrone', (0, 17)) ---- (18573, 'Nasrullah Perrone  Design Thinking for Innovation', (0, 49))
# (18576, 'Jose Alves', (0, 10)) ---- (18576, 'Jose Alves - Learning Launch\n\nChallenge', (0, 39))
# (18588, 'Asia Faizan', (0, 11))
# (18596, 'Nona', (728, 732))
# (18612, 'Manik Joshi', (6, 17)) ---- (18612, 'Manik Joshi  Email', (6, 24))
# (18658, 'Francesco', (0, 9)) ---- (18658, 'Francesco 1', (0, 11))
# (18658, 'Maribel Navarrete', (13, 30))
# (18669, 'Vincent Lucas', (74, 87)) ---- (18669, 'Vincent Lucas\n\nChallenge', (74, 98))
# (18680, 'Alexander Guerra', (38, 54)) ---- (18680, 'Alexander Guerra\n\nChallenge', (38, 65))
# (18730, 'Romany Refaat', (59, 72))
# (18772, 'Scott', (25, 30))
# (18772, 'Scott', (2987, 2992))
# (18798, 'Nur Sumon', (45, 54)) ---- (18798, 'Nur Sumon\n\nChallenge & Selection', (45, 77))
# (18836, 'Indri Sah', (6726, 6735)) ---- (18836, 'Indri Sah  Date', (6726, 6741))
# (18849, 'Carmen Riveros', (0, 14)) ---- (18849, 'Carmen Riveros\n\nReflection', (0, 26))
# (18856, 'Jose Hany', (0, 9)) ---- (18856, 'Jose Hany  ', (0, 11))
# (18862, 'Hossam Khan', (77, 88)) ---- (18862, 'Hossam Khan\n\nRoadshow', (77, 98))
# (18891, 'Marie Lm', (61, 69)) ---- (18891, 'Marie Lm\n\nChallenge   &   Selection', (61, 96))
# (18912, 'Firoj', (8, 13))
# (18948, 'Concetta Delia', (0, 14)) ---- (18948, 'Concetta Delia\n\n09/15/2017\n\nReflection', (0, 38))
# (18954, 'Antonio Anderson', (25, 41)) ---- (18954, 'Antonio Anderson  ', (25, 43))
# (18957, 'Javier Ahmad', (37, 49)) ---- (18957, 'Javier Ahmad\n\n', (37, 51))
# (18962, 'Chayito Luna', (19, 31)) ---- (18962, 'Chayito Luna\n\nElements  Criteria', (19, 51))
# (18967, 'James King', (32, 42)) ---- (18967, 'James King\n\n1', (32, 45))
# (18980, 'Teresa Cano', (39, 50)) ---- (18980, 'Teresa Cano\n\nChallenge & Selection', (39, 73))
# (18992, 'Abdul', (93, 98)) ---- (18992, 'Abdul\n\nAbdul', (93, 105))
# (18992, 'Ana', (112, 115))
# (18992, 'Ana', (107, 110))
# (18992, 'Abdul', (100, 105)) ---- (18992, 'Abdul\n\nAbdul', (93, 105))
# (19011, 'Ilse Coppens', (11, 23))
# (19049, 'Na Nguyen', (43, 52))
# (19049, 'Na Nguyen', (4652, 4661))
# (19049, 'Na Nguyen', (2142, 2151))
# (19057, 'None Islam', (34, 44))
# (19064, 'Francisco Rinaldi', (0, 17)) ---- (19064, 'Francisco Rinaldi\n\n', (0, 19))
# (19066, 'Bukola Micheal', (13, 27)) ---- (19066, 'Bukola Micheal\n\nChallenge', (13, 38))
# (19084, 'Aya', (5675, 5678))
# (19099, 'Manuel Hernandez', (46, 62)) ---- (19099, 'Manuel Hernandez  11st', (46, 68))
# (19102, 'Md Imran', (138, 146)) ---- (19102, 'Md Imran                    ', (138, 166))
# (19125, 'Murjanatu Colombini', (0, 19)) ---- (19125, 'Murjanatu Colombini\n\nStorytelling\n\nChallenge & Selection\n\nStorytelling', (0, 70))
# (19136, 'Angel Lopez', (36, 47)) ---- (19136, 'Angel Lopez\n\nChallenge', (36, 58))
# (19149, 'Shabbir Ahmad', (27, 40)) ---- (19149, 'Shabbir Ahmad\n\nTitan Engineering & Automation Limited\n\n', (27, 82))
# (19179, 'Jose Mejia', (61, 71)) ---- (19179, 'Jose Mejia\n\nChallenge', (61, 82))
# (19188, 'Fabio Souza', (0, 11)) ---- (19188, 'Fabio Souza  |', (0, 14))
# (19220, 'Abdo Ali', (70, 78)) ---- (19220, 'Abdo Ali\n\nChallenge', (70, 89))
# (19223, 'Jake Lloyd', (0, 10)) ---- (19223, 'Jake Lloyd\n\nDirector', (0, 20))
# (19238, 'Diana Hernandez', (57, 72)) ---- (19238, 'Diana Hernandez\n\nChallenge', (57, 83))
# (19244, 'Kamal', (349, 354)) ---- (19244, 'Jesus  Kamal', (342, 354))
# (19244, 'Jesus', (342, 347)) ---- (19244, 'Jesus  Kamal', (342, 354))
# (19254, 'Jack', (0, 4)) ---- (19254, 'Jack Reflection', (0, 15))
# (19296, 'Joe Walker', (3696, 3706)) ---- (19296, 'Joe Walker\n\nWellness Wanderers', (3696, 3726))
# (19296, 'Joe Walker', (0, 10)) ---- (19296, 'Joe Walker  ', (0, 12))
# (19296, 'Joe Walker', (3515, 3525)) ---- (19296, 'Joe Walker  ', (3515, 3527))
# (19298, 'Ariel Granados', (43, 57)) ---- (19298, 'Ariel Granados\n\nChallenge', (43, 68))
# (19315, 'Giorgia Casazza', (0, 15))
# (19352, 'Jose Hernandez', (0, 14)) ---- (19352, 'Jose Hernandez\n\n', (0, 16))
# (19360, '\n\n', (0, 2))
# (19371, 'Grace Adeyemi', (66, 79)) ---- (19371, 'Grace Adeyemi\n\nChallenge', (66, 90))
# (19426, 'Siuwai Chan', (80, 91)) ---- (19426, 'Siuwai Chan\n\nChallenge', (80, 102))
# (19593, 'Jalen Gamez', (21, 32))
# (19600, 'Basma Ahmed', (0, 11)) ---- (19600, 'Basma Ahmed\n\nChallenge', (0, 22))
# (19602, 'Guadalupe Khan', (62, 76))
# (19623, 'Mostafa Darwish', (0, 15)) ---- (19623, 'Mostafa Darwish  X49465531', (0, 26))
# (19667, 'Gilbert Joseph', (52, 66)) ---- (19667, 'Gilbert Joseph\n\nChallenge', (52, 77))
# (19669, 'Victor Luis', (36, 47))
# (19670, 'Sure Ravishankar', (31, 47))
# (19697, 'Ever', (22, 26))
# (19748, 'Tiago Costa', (8077, 8088)) ---- (19748, 'Tiago Costa\n\n', (8077, 8090))
# (19771, 'Khalil Martinez', (837, 852)) ---- (19771, 'Khalil Martinez Pin', (837, 856))
# (19795, 'Md Monir Miah', (2810, 2823)) ---- (19795, 'Md Monir Miah\n\n', (2810, 2825))
# (19827, 'Hauwa Hassan', (28, 40)) ---- (19827, 'Hauwa Hassan  ', (28, 42))
# (19831, 'Ram Seema', (74, 83))
# (19876, 'Andrew Williams', (57, 72)) ---- (19876, 'Andrew Williams\n\nChallenge', (57, 83))
# (19965, 'Alejandro Raj', (72, 85)) ---- (19965, 'Alejandro Raj\n\n1', (72, 88))
# (19981, 'Jose Acevedo', (34, 46)) ---- (19981, 'Jose Acevedo\n\nReflection', (34, 58))
# (20003, 'Nasri', (20, 25))
# (20071, 'Harpreet Toor', (31, 44)) ---- (20071, 'Harpreet Toor  ', (31, 46))
# (20079, 'Ameen Wang', (2913, 2923)) ---- (20079, 'Ameen Wang\n\nDesign Thinking Process\n\nThe', (2913, 2953))
# (20126, 'Nokubongwa', (2506, 2516)) ---- (20126, 'Aunt Nokubongwa', (2501, 2516))
# (20126, 'Nokubongwa', (3962, 3972)) ---- (20126, 'Aunt Nokubongwa', (3957, 3972))
# (20126, 'Nokubongwa', (2141, 2151)) ---- (20126, 'Aunt Nokubongwa', (2136, 2151))
# (20126, 'Sebastian', (2183, 2192))
# (20126, 'Nokubongwa', (2431, 2441)) ---- (20126, 'Aunt Nokubongwa', (2426, 2441))
# (20133, 'Francisco Rojas', (14, 29)) ---- (20133, 'Francisco Rojas - keith35@hotmail.com', (14, 51))
# (20174, 'Zubair Khan', (678, 689))
# (20209, 'Aldo Bassi', (0, 10)) ---- (20209, 'Aldo Bassi - Mind Mapping Tool\n\nChallenge', (0, 41))
# (20211, 'Janet Chioma', (3403, 3415)) ---- (20211, 'Janet Chioma\n\nDopemu', (3403, 3423))
# (20229, 'Venkat', (5642, 5648))
# (20229, 'Venkat', (5867, 5873))
# (20229, 'Venkat', (6129, 6135))
# (20229, 'Venkat', (5168, 5174))
# (20245, 'Nena', (1025, 1029))
# (20250, 'Fran Cisco', (473, 483)) ---- (20250, "Fran Cisco's", (473, 485))
# (20253, 'Marcel De Haas', (4008, 4022)) ---- (20253, 'Marcel De Haas  Design Thinking for Business Innovation', (4008, 4063))
# (20258, 'Arun Khan', (116, 125))
# (20258, 'Arun Khan', (55, 64))
# (20264, 'Cristina Avila', (64, 78)) ---- (20264, 'Cristina Avila\n\nChallenge', (64, 89))
# (20301, 'Om Saleem', (120, 129))
# (20329, 'Ralf Haron', (0, 10)) ---- (20329, 'Ralf Haron - Mind', (0, 17))
# (20330, 'Tota', (2357, 2361))
# (20330, 'Tota', (1454, 1458))
# (20330, 'Tota', (2183, 2187))
# (20330, 'Tota', (1628, 1632))
# (20331, 'Thulisile Prinsloo', (0, 18))
# (20331, 'Thulisile Prinsloo', (1932, 1950))
# (20392, 'Rose Bo', (12, 19)) ---- (20392, 'Rose Bo\n\nChallenge', (12, 30))
# (20398, 'Loga', (63, 67))
# (20398, 'Loga', (69, 73))
# (20412, 'Anne Arena', (0, 10)) ---- (20412, 'Anne Arena\n\nDesign Thinking for Innovation\n\nMind Mapping for Staffing Struggles\n\nChallenge', (0, 90))
# (20423, 'Julien Adam', (8, 19)) ---- (20423, 'Julien Adam\n\nBuilding', (8, 29))
# (20430, 'Daniele Khan', (2366, 2378)) ---- (20430, 'Daniele Khan  Page', (2366, 2384))
# (20430, 'Daniele Khan', (11, 23)) ---- (20430, 'Daniele Khan  Page', (11, 29))
# (20430, 'Daniele Khan', (4317, 4329)) ---- (20430, 'Daniele Khan  Page', (4317, 4335))
# (20442, 'Man Yang', (0, 8))
# (20453, 'Efrain', (0, 6))
# (20472, 'Estrella Paredes', (3539, 3555)) ---- (20472, 'Estrella Paredes  Fecha', (3539, 3562))
# (20518, 'Ariful Morsy', (0, 12)) ---- (20518, 'Ariful Morsy  ', (0, 14))
# (20530, 'Roberto Christian', (0, 17)) ---- (20530, 'Roberto Christian\n\nIssue', (0, 24))
# (20622, 'Tammy Rivera', (0, 12)) ---- (20622, 'Tammy Rivera Design Thinking', (0, 28))
# (20637, 'Comfort Musah', (3981, 3994)) ---- (20637, 'Comfort Musah  ', (3981, 3996))
# (20637, 'Comfort Musah', (0, 13))
# (20648, 'Hyder Singh', (7279, 7290))
# (20667, 'Jahed', (3713, 3718)) ---- (20667, 'Jahed\n\n', (3713, 3720))
# (20667, 'Jahed', (2770, 2775)) ---- (20667, 'Jahed\n\nReflection', (2770, 2787))
# (20680, 'Ramon Solis', (0, 11)) ---- (20680, 'Ramon Solis 12/31/15', (0, 20))
# (20725, 'Sonia Frigo', (40, 51)) ---- (20725, 'Sonia Frigo  Design Thinking for Business Innovation\n\nChallenge', (40, 103))
# (20741, 'Mustapha Yusuf', (4274, 4288)) ---- (20741, 'Mustapha Yusuf  Design Thinking Assignment', (4274, 4316))
# (20741, 'Mustapha Yusuf', (0, 14)) ---- (20741, 'Mustapha Yusuf  Design Thinking Assignment', (0, 42))
# (20755, 'Aziz Khan', (51, 60)) ---- (20755, 'Aziz Khan\n\nVisualization\n\nChallenge & Selection', (51, 98))
# (20791, 'Wilfran Arbelaez', (18, 34)) ---- (20791, 'Wilfran Arbelaez\n\nCHALLENGE', (18, 45))
# (20799, 'Mariana Cruz', (11, 23)) ---- (20799, 'Mariana Cruz - Mind', (11, 30))
# (20910, 'Edwin', (6409, 6414))
# (20910, 'Edwin', (0, 5)) ---- (20910, 'Edwin | Confidential\n\nChallenge & Selection', (0, 43))
# (20910, 'Edwin', (3036, 3041)) ---- (20910, 'Edwin | Confidential', (3036, 3056))
# (20922, 'Precious Hill', (1664, 1677))
# (21023, 'Zaharaddeen Ashfaq', (22, 40)) ---- (21023, 'Zaharaddeen Ashfaq\n\nCHALLENGE', (22, 51))
# (21179, 'Ana Medina', (0, 10)) ---- (21179, 'Ana Medina\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0Design', (0, 136))
# (21179, 'Ana Medina', (5330, 5340)) ---- (21179, 'Ana Medina\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0Design', (5330, 5466))
# (21188, 'Angel Garcia', (0, 12)) ---- (21188, 'Angel Garcia\n\nCoursera', (0, 22))
# (21197, 'Md Shamim', (6, 15)) ---- (21197, 'Md Shamim\n\nReflection', (6, 27))
# (21226, 'Mona Ahmed', (107, 117))
# (21238, 'Edward Mohd Nor', (1767, 1782))
# (21242, 'Mohd Adham', (0, 10)) ---- (21242, 'Mohd Adham’ s', (0, 13))
# (21262, 'Andres Rodriguez', (94, 110)) ---- (21262, 'Andres Rodriguez\n\nChallenge', (94, 121))
# (21313, 'Mari Vaz', (2846, 2854)) ---- (21313, 'Mari Vaz\n\n05.02.2017', (2846, 2866))
# (21371, 'Marisela Godwin', (0, 15)) ---- (21371, 'Marisela Godwin       Reflection', (0, 32))
# (21381, 'Terry Marchal', (5010, 5023))
# (21469, 'Fatme Ismail', (1555, 1567))
# (21511, 'Elena', (25, 30))
# (21610, 'Diego Sofia', (33, 44)) ---- (21610, 'Diego Sofia\n\nChallenge & Selection', (33, 67))
# (21613, 'Siti', (33, 37))
# (21613, 'Abood', (58, 63))
# (21704, 'Kaline Pacheco', (30, 44))
# (21770, 'Cindy Ng', (1978, 1986)) ---- (21770, 'Cindy Ng  cs13  ', (1978, 1994))
# (21770, 'Cindy Ng', (14, 22)) ---- (21770, 'Cindy Ng  cs13', (14, 28))
# (21844, 'Mg Maurel', (0, 9))
# (21959, 'Jesus Alcala', (0, 12)) ---- (21959, 'Jesus Alcala  ', (0, 14))
# (21968, 'Jamie Dickinson', (28, 43)) ---- (21968, 'Jamie Dickinson      ', (28, 49))
# (21988, 'Anisa Hussain', (33, 46)) ---- (21988, 'Anisa Hussain - 8743214\n\nNon-Business Use\n\nVisualization\n\nChallenge & Selection', (33, 112))
# (21988, 'Anisa Hussain', (3130, 3143)) ---- (21988, 'Anisa Hussain - 8743214\n\nNon-Business Use\n\nInsight & Approach', (3130, 3191))
# (22068, 'Marine', (0, 6))
# (22156, 'Angel Polanco', (14, 27))
# (22166, 'Auwal De Maio', (38, 51)) ---- (22166, 'Turkey Auwal De Maio', (31, 51))
# (22180, 'Jenny', (0, 5)) ---- (22180, 'Jenny\n\nReflection\n\nChallenge & Selection', (0, 40))
# (22221, 'Jose Luis Gaudenzi', (0, 18)) ---- (22221, 'Jose Luis Gaudenzi  ', (0, 20))
# (22237, 'Rodolfo Jimenez', (78, 93)) ---- (22237, 'Rodolfo Jimenez\n\nChallenge', (78, 104))
# (22286, 'Juan Carlos Opazo', (0, 17)) ---- (22286, 'Juan Carlos Opazo - Design Learning Course', (0, 42))
# (22336, 'Meh Singh', (2007, 2016)) ---- (22336, 'Meh Singh\n\nParticipant', (2007, 2029))
# (22336, 'Meh Singh', (28, 37)) ---- (22336, 'Meh Singh\n\nMind', (28, 43))
# (22379, 'Raj', (169, 172))
# (22540, 'Jesus Rosado', (0, 12)) ---- (22540, 'Jesus Rosado Peer Graded Assignment', (0, 35))
# (22580, 'Maria Adam', (0, 10)) ---- (22580, 'Maria Adam Storytelling', (0, 23))
# (22635, 'Anthony Abubakar', (101, 117)) ---- (22635, 'Anthony Abubakar  Design Thinking Tool:', (101, 140))
# (22660, 'Amina Koko', (3697, 3707)) ---- (22660, 'Amina Koko Approach', (3697, 3716))

# %%
print_likely_successful_entities(url_set_true, url_set_detected, 'URL_PERSONAL')
# Out:
# Out of 58 FN entities for URL_PERSONAL category, 26 entities might have likely been successfully detected by Presidio.
# (1309, 'https://www.hall.biz/wp-contenthome.html', (2581, 2621))
# (3202, 'tps://www.facebook.com/bclark', (169, 198))
# (3202, 'https://www.youtube.com/channel/UC1ElAcppeuhfet nYZqnhEXw', (200, 257))
# (3515, 'https://www.youtube.com/watch?v=mYxoZaftuNN', (2166, 2209)) ---- (3515, 'https://www.youtube.com/watch?v=mYxoZaftuNN.', (2166, 2210))
# (3592, 'https://www.peterson.net/tag/app/listmain.php', (222, 267)) ---- (3592, 'https://www.peterson.net/tag/app/listmain.php.', (222, 268))
# (5358, 'https://schaefer.biz/posts/search/appsearch.php', (1543, 1590))
# (5861, 'https://www.stevens.biz/wp-contentindex.jsp', (3227, 3270))
# (6257, 'http://mcneil.org/list/taghomepage.htm', (721, 759)) ---- (6257, 'http://mcneil.org/list/taghomepage.htm.', (721, 760))
# (7183, 'http://bailey-perry.com/posts/tag/categoriesfaq.htm', (3411, 3462)) ---- (7183, 'http://bailey-perry.com/posts/tag/categoriesfaq.htm”', (3411, 3463))
# (7680, 'http://www.melendez.biz/postsabout.html', (1903, 1942))
# (8013, 'http://dunlap.com/explore/list/appmain.php', (1925, 1967)) ---- (8013, 'http://dunlap.com/explore/list/appmain.php,', (1925, 1968))
# (8088, 'https://www.cooper.com/blog/maincategory.htm', (2118, 2162)) ---- (8088, 'https://www.cooper.com/blog/maincategory.htm.', (2118, 2163))
# (8588, 'http://ramirez-burton.org/postsauthor.php', (3475, 3516)) ---- (8588, 'http://ramirez-burton.org/postsauthor.php.', (3475, 3517))
# (9297, 'https://www.youtube.com/watch?v=HePCiQaZo2X', (5332, 5375))
# (9297, 'https://www.youtube.com/watch?v=y1ZQmZmkaDD', (5286, 5329)) ---- (9297, 'https://www.youtube.com/watch?v=y1ZQmZmkaDD,  https://www.youtube.com/watch?v=HePCiQaZo2X,', (5286, 5376))
# (9470, 'http://perry-king.biz/main/exploreregister.jsp', (3899, 3945))
# (9534, 'https://www.fitzgerald.biz/categories/explorehomepage.php', (4334, 4391))
# (9881, 'https://roberts.biz/blog/postsprivacy.htm', (586, 627))
# (9982, 'http://www.jones.info/category/posts/categoryprivacy.html', (3033, 3090)) ---- (9982, 'http://www.jones.info/category/posts/categoryprivacy.html,', (3033, 3091))
# (10418, 'http://beck-calhoun.biz/bloghome.jsp', (578, 614))
# (10647, 'https://www.osborn.com/bloghomepage.htm', (1233, 1272)) ---- (10647, 'https://www.osborn.com/bloghomepage.htm.', (1233, 1273))
# (11428, 'http://camacho.biz/blog/main/appfaq.jsp', (3093, 3132))
# (11849, 'http://www.daniels.biz/tagssearch.php', (7283, 7320))
# (12043, 'http://thomas.biz/list/taghome.php', (1779, 1813))
# (12154, 'https://youtu.be/Kb-hqNGr5lJ', (2761, 2789)) ---- (12154, 'https://youtu.be/Kb-hqNGr5lJ,', (2761, 2790))
# (12267, 'https://www.johnson.biz/wp-content/appcategory.php', (3128, 3178))
# (12267, 'https://www.johnson.biz/wp-content/appcategory.php', (4709, 4759))
# (12509, 'http://caldwell.com/blog/exploresearch.php', (329, 371)) ---- (12509, 'http://caldwell.com/blog/exploresearch.php.', (329, 372))
# (12640, 'https://youtu.be/y1G4uZlMHO4', (2436, 2464)) ---- (12640, 'https://www.youtube.com/watch?v=jIVX30LMgZN&fprpjqt=wbqnceo  https://youtu.be/y1G4uZlMHO4', (2375, 2464))
# (12640, 'https://youtu.be/uDRN9IA2T5', (2467, 2494)) ---- (12640, 'https://youtu.be/uDRN9IA2T5g', (2467, 2495))
# (13103, 'https://hernandez.com/exploremain.html', (3335, 3373)) ---- (13103, 'https://hernandez.com/exploremain.html,', (3335, 3374))
# (13103, 'https://www.roman.info/list/appindex.html', (3375, 3416))
# (13103, 'https://www.roman.info/list/appindex.html', (856, 897)) ---- (13103, 'https://www.roman.info/list/appindex.html,', (856, 898))
# (13278, 'https://www.chambers.com/wp-content/tagshomepage.php', (3295, 3347)) ---- (13278, 'https://www.chambers.com/wp-content/tagshomepage.php.', (3295, 3348))
# (13473, 'https://www.norris.biz/listmain.asp', (5042, 5077))
# (13998, 'https://parrish.biz/listpost.html', (1284, 1317))
# (14186, 'https://jackson-phillips.com/main/tagauthor.html', (1698, 1746)) ---- (14186, 'https://jackson-phillips.com/main/tagauthor.html.', (1698, 1747))
# (14255, 'http://carpenter.com/mainfaq.asp', (496, 528)) ---- (14255, 'http://carpenter.com/mainfaq.asp.', (496, 529))
# (14255, 'https://www.murray.biz/searchhomepage.htm', (1594, 1635))
# (14315, 'http://schaefer.com/categorieshomepage.htm', (796, 838)) ---- (14315, 'http://schaefer.com/categorieshomepage.htm,', (796, 839))
# (14944, 'http://chang.biz/wp-content/categoriesauthor.htm', (2398, 2446))
# (15308, 'https://www.walsh-hudson.biz/categoryhomepage.asp', (4386, 4435))
# (15517, 'http://www.jackson-garcia.biz/main/app/maincategory.html', (1325, 1381))
# (15765, 'http://thomas.net/category/exploreabout.jsp', (5474, 5517)) ---- (15765, 'https://www.sanders.com/wp-contentindex.html  https://www.burton-jordan.com/category/mainlogin.php; http://thomas.net/category/exploreabout.jsp', (5374, 5517))
# (15765, 'https://www.burton-jordan.com/category/mainlogin.php', (5420, 5472))
# (15852, 'https://walters.biz/explore/categoriesregister.html', (3676, 3727))
# (15904, 'https://ramirez-white.com/posts/bloglogin.htm', (284, 329)) ---- (15904, 'https://ramirez-white.com/posts/bloglogin.htm.', (284, 330))
# (16435, 'madehttps://smith.org/main/list/tagsprivacy.htm', (3581, 3628))
# (16654, 'https://www.jones-baird.biz/categories/category/tagindex.html', (727, 788))
# (17221, 'http://kidd.com/tag/tagshomepage.php', (2446, 2482)) ---- (17221, 'http://kidd.com/tag/tagshomepage.php.', (2446, 2483))
# (17292, 'https://www.hudson.biz/tag/posts/listindex.htm', (5988, 6034))
# (18824, 'http://stevens.com/search/tagauthor.html', (60, 100)) ---- (18824, 'http://stevens.com/search/tagauthor.html.', (60, 101))
# (18995, 'https://www.garrett.biz/list/category/postslogin.html', (36, 89))
# (19277, 'https://www.ramirez.biz/listmain.html', (42, 79))
# (19609, 'https://jackson-manning.info/blog/appsearch.html', (2018, 2066)) ---- (19609, 'https://jackson-manning.info/blog/appsearch.html,', (2018, 2067))
# (19719, 'http://www.carpenter-davis.info/blog/mainabout.php', (4686, 4736)) ---- (19719, 'http://www.carpenter-davis.info/blog/mainabout.php,', (4686, 4737))
# (20216, 'https://www.sullivan-fisher.biz/main/app/postscategory.jsp', (2648, 2706))
# (20565, 'http://jensen-miller.biz/app/categories/blogregister.htm', (1091, 1147))

# %%
print_likely_successful_entities(email_set_true, email_set_detected, 'EMAIL')
# Out:
# Out of 1 FN entities for EMAIL category, 0 entities might have likely been successfully detected by Presidio.
# (11699, 'srpe…r@....kelsey21@gmail.com', (6157, 6186))

# %%
print_likely_successful_entities(phoneNum_set_true, phoneNum_set_detected, 'PHONE_NUM')
# Out:
# Out of 0 FN entities for PHONE_NUM category, 0 entities might have likely been successfully detected by Presidio.

# %%
import ast

def update_detected_entities(true_name_set, true_url_set, detected_file, output_file, indent=4):
    with open(detected_file, 'r') as file:
        detected_entities = file.readlines()

    updated_entities = []
    count_name_updates = 0
    count_url_updates = 0
    indent_space = ' ' * indent

    for line in detected_entities:
        entity = ast.literal_eval(line.strip())
        idx, entity_text, category, (start, end) = entity

        # Process 'PERSON' category
        if category == 'PERSON':
            match_found = False
            for entity_true in true_name_set:
                idx_true, entity_text_true, (start_true, end_true) = entity_true
                # Check for possible matches where detected entity is longer
                if idx == idx_true and ((start == start_true and end > end_true) or (end == end_true and start < start_true)):
                    updated_entities.append(f"{indent_space}({idx}, '{entity_text_true}', 'PERSON', ({start_true}, {end_true}))\n")
                    count_name_updates += 1
                    match_found = True
                    break
            if not match_found:
                updated_entities.append(line)

        # Process 'URL' category
        elif category == 'URL':
            match_found = False
            for entity_true in true_url_set:
                idx_true, entity_text_true, (start_true, end_true) = entity_true
                # Check for possible matches where detected entity is longer
                if idx == idx_true and ((start == start_true and end > end_true) or (end == end_true and start < start_true)):
                    updated_entities.append(f"{indent_space}({idx}, '{entity_text_true}', 'URL', ({start_true}, {end_true}))\n")
                    count_url_updates += 1
                    match_found = True
                    break
            if not match_found:
                updated_entities.append(line)
        else:
            updated_entities.append(line)

    # Save updated entities to the new file
    with open(output_file, 'w') as file:
        file.writelines(updated_entities)

    print(f"Out of {len(detected_entities)} entities, {count_name_updates} 'PERSON' and {count_url_updates} 'URL' were updated as likely successful detections.")
    print(f"Updated detected entities saved to {output_file}")

# Example Usage
update_detected_entities(name_set_true, url_set_true, 'output/pii_detected_lg.txt', 'others/pii_entities_detected_updated.txt')
# Out:
# Out of 23094 entities, 894 'PERSON' and 30 'URL' were updated as likely successful detections.
# Updated detected entities saved to output/pii_entities_detected_updated.txt

# %%
evaluate_detected_entities('others/pii_entities_detected_updated.txt')
# Out:
# All detected entites summary:
# PERSON: 18623
# URL: 4254
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.2102, Recall: 0.8908, F1 Score: 0.3401, F5 Score: 0.7921, TP: 3914, FP: 14707, FN: 480
# URL_PERSONAL    -- Precision: 0.0753, Recall: 0.9091, F1 Score: 0.1391, F5 Score: 0.6375, TP: 320, FP: 3930, FN: 32
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828, F5 Score: 0.8368, TP: 14, FP: 71, FN: 0

# %% [markdown]
# DDL: August 26, 2024 (Aiming at presentation towards Ken)
# 1. Post processing - AL
# 2. Other models - YW, JS
# 3. Random sampling (2000 cases) or stratified sampling for each category - JS
# 4. find mappings for ID_NUM, STREET_ADDRESS, USERNAME - JS

# %% [markdown]
# EDM paper, sequence labeling, we prompt GPT to do BIO, performance might not be good.
# Why we use GPT model? Other models?
# Let's do mini first.

# %%
import ast

def check_url_personal_starts_with_http(file_path: str):
    # Initialize a list to store any URLs that don't start with 'http'
    invalid_urls = []
    
    # Read the file line by line
    with open(file_path, 'r') as file:
        for line in file:
            entity = ast.literal_eval(line.strip())
            idx, entity_text, category, (start, end) = entity

            # Check if the category is 'URL_PERSONAL'
            if category == 'URL_PERSONAL' and not entity_text.startswith('http'):
                invalid_urls.append(entity)
    
    # Print the results
    if invalid_urls:
        print("URLs not starting with 'http':")
        for url in invalid_urls:
            print(url)
    else:
        print("All 'URL_PERSONAL' entities start with 'http'.")

# Example usage
check_url_personal_starts_with_http('data/pii_entities.txt')
# Out:
# URLs not starting with 'http':
# (3202, 'tps://www.facebook.com/bclark', 'URL_PERSONAL', (169, 198))
# (16435, 'madehttps://smith.org/main/list/tagsprivacy.htm', 'URL_PERSONAL', (3581, 3628))

# %%
import ast

def count_url_entities(file_path: str):
    # Initialize counters
    count_with_http = 0
    count_without_http = 0
    total_count_url = 0

    # Read the file line by line
    with open(file_path, 'r') as file:
        for line in file:
            entity = ast.literal_eval(line.strip())
            idx, entity_text, category, (start, end) = entity

            # Check if the category is 'URL'
            if category == 'URL':
                total_count_url += 1
                if 'http' in entity_text:
                    count_with_http += 1
                else:
                    count_without_http += 1

    # Print the results
    print(f"Total 'URL' entities: {total_count_url}")
    print(f"Total 'URL' entities containing 'http': {count_with_http}")
    print(f"Total 'URL' entities not containing 'http': {count_without_http}")

# Example usage
count_url_entities('others/pii_entities_detected_updated.txt')
# Out:
# Total 'URL' entities: 4254
# Total 'URL' entities containing 'http': 1094
# Total 'URL' entities not containing 'http': 3160

# %%
import ast

def remove_non_http_urls(input_file: str, output_file: str):
    # Initialize a list to store filtered entities
    filtered_entities = []

    # Read the file line by line
    with open(input_file, 'r') as file:
        for line in file:
            entity = ast.literal_eval(line.strip())
            idx, entity_text, category, (start, end) = entity

            # Keep the entity if it's not 'URL' or it contains 'http'
            if category != 'URL' or 'http' in entity_text:
                filtered_entities.append(line)

    # Save the filtered entities to a new file
    with open(output_file, 'w') as file:
        file.writelines(filtered_entities)

    print(f"Filtered entities saved to {output_file}")

# Example usage
remove_non_http_urls('others/pii_entities_detected_updated.txt', 'others/pii_entities_detected_updated2.txt')
# Out:
# Filtered entities saved to output/pii_entities_detected_updated2.txt

# %%
evaluate_detected_entities('others/pii_entities_detected_updated2.txt')
# Out:
# All detected entites summary:
# PERSON: 18623
# URL: 1094
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.2102, Recall: 0.8908, F1 Score: 0.3401, F5 Score: 0.7921, TP: 3914, FP: 14707, FN: 480
# URL_PERSONAL    -- Precision: 0.2936, Recall: 0.9091, F1 Score: 0.4438, F5 Score: 0.8413, TP: 320, FP: 770, FN: 32
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828, F5 Score: 0.8368, TP: 14, FP: 71, FN: 0

# %%
evaluate_detected_entities('output/pii_detected_trf.txt')
# Out:
# All detected entites summary:
# PERSON: 15330
# URL: 4254
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85
#
# Summary of Precision, Recall, F1 Score, and F5 Score
# NAME_STUDENT    -- Precision: 0.2367, Recall: 0.8257, F1 Score: 0.3679, F5 Score: 0.7535, TP: 3628, FP: 11702, FN: 766
# URL_PERSONAL    -- Precision: 0.0686, Recall: 0.8295, F1 Score: 0.1268, F5 Score: 0.5816, TP: 292, FP: 3962, FN: 60
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053, F5 Score: 0.9838, TP: 110, FP: 22, FN: 1
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828, F5 Score: 0.8368, TP: 14, FP: 71, FN: 0

# %%
# import ast

# def normalize_entity(entity_str):
#     """Helper function to normalize entities by stripping whitespace."""
#     entity = ast.literal_eval(entity_str.strip())
#     idx, entity_text, category, positions = entity
#     # Return a tuple with normalized text (no lowercase conversion)
#     return (idx, entity_text.strip(), category.strip(), positions)

# def compare_entities_limited(file1_path, file2_path):
#     # Read entities from the first file
#     entities1 = set()
#     with open(file1_path, 'r') as file1:
#         for line in file1:
#             entities1.add(normalize_entity(line))

#     # Read entities from the second file
#     entities2 = set()
#     with open(file2_path, 'r') as file2:
#         for line in file2:
#             entities2.add(normalize_entity(line))

#     # Compare the entities
#     only_in_file1 = entities1 - entities2
#     only_in_file2 = entities2 - entities1
#     common_entities = entities1 & entities2

#     # Display the comparison results
#     print(f"Entities only in {file1_path}: {len(only_in_file1)}")
#     for entity in sorted(only_in_file1):
#         print(entity)

#     print(f"\nEntities only in {file2_path}: {len(only_in_file2)}")
#     for entity in sorted(only_in_file2):
#         print(entity)

#     print(f"\nCommon entities in both files: {len(common_entities)}")
#     for entity in sorted(common_entities):
#         print(entity)

# # Example usage:
# compare_entities_limited('output/pii_detected_lg.txt', 'output/pii_detected_trf.txt')
# Out:
# Entities only in output/pii_detected_lg.txt: 8343
# (2, 'VISUALIZATION', 'PERSON', (0, 13))
# (4, 'Henry Acosta', 'PERSON', (36, 48))
# (5, 'https://www.greatplacetowork.com/resources/blog/why-is-diversity-inclusion-in-the-workplace-important', 'PERSON', (4150, 4251))
# (7, "Dessine-moi  l'intelligence", 'PERSON', (292, 319))
# (7, 'Nathalie Sylla', 'PERSON', (52, 68))
# (10, 'Diego Estrada', 'PERSON', (0, 13))
# (10, 'Diego Estrada', 'PERSON', (2386, 2399))
# (15, 'A. XYZ', 'PERSON', (2834, 2840))
# (15, 'A. XYZ', 'PERSON', (5861, 5867))
# (15, 'A. XYZ', 'PERSON', (8888, 8894))
# (15, 'A. XYZ', 'PERSON', (11925, 11931))
# (23, 'Cap', 'PERSON', (2158, 2161))
# (33, 'Learning Oﬃcer', 'PERSON', (2404, 2418))
# (37, 'Wann', 'PERSON', (895, 899))
# (37, 'wie', 'PERSON', (911, 914))
# (44, 'Centreno', 'PERSON', (376, 384))
# (46, 'INSIGHT', 'PERSON', (2034, 2041))
# (56, 'Nadine Born', 'PERSON', (53, 64))
# (59, 'MindMap', 'PERSON', (1248, 1255))
# (65, 'Cotton', 'PERSON', (486, 492))
# (66, 'd. Skills  e. Egos  f. Team', 'PERSON', (995, 1022))
# (66, 'g. Time  h. Money', 'PERSON', (1037, 1054))
# (71, 'Ali Kraft', 'PERSON', (2663, 2672))
# (77, 'Clifford', 'PERSON', (2160, 2168))
# (77, 'Pooh', 'PERSON', (2181, 2185))
# (79, 'Stop Procrastinating\n\n•', 'PERSON', (863, 886))
# (80, 'Karol Ferreira\n\nREFLECTION - VISUALIZATION\n\nChallenge\n\nWorking', 'PERSON', (2, 64))
# (83, 'Sathya Meva', 'PERSON', (1529, 1540))
# (83, 'trumps', 'PERSON', (1565, 1571))
# (83, 'ﬁnd', 'PERSON', (585, 588))
# (86, 'Delicatesen', 'PERSON', (681, 692))
# (88, 'Rakesh Singh\n\nChallenge', 'PERSON', (61, 84))
# (92, '3.INSIGHT', 'PERSON', (2388, 2397))
# (99, 'Francesco Boscolo\n\nChallenge', 'PERSON', (38, 66))
# (109, 'Michael  -', 'PERSON', (71, 81))
# (109, 'Michael  -', 'PERSON', (1300, 1310))
# (109, 'Michael  -', 'PERSON', (3336, 3346))
# (112, 'Capão das Antas', 'PERSON', (151, 166))
# (118, 'NOGO', 'PERSON', (2024, 2028))
# (123, 'A. Smith', 'PERSON', (1133, 1141))
# (123, 'Adam Smith', 'PERSON', (316, 326))
# (123, 'Andreoni J. Philanthropy', 'PERSON', (7864, 7888))
# (123, 'Fehr E.', 'PERSON', (8101, 8108))
# (123, "Gerashchenko I.G. A. Smith's", 'PERSON', (7298, 7326))
# (123, 'Kazantseva T.V.', 'PERSON', (7103, 7118))
# (123, 'Kazantseva T.V.', 'PERSON', (7676, 7691))
# (123, 'L.; N. Y.:', 'PERSON', (7987, 7997))
# (123, 'Schmidt K. M.', 'PERSON', (8110, 8123))
# (123, 'Shmakov', 'PERSON', (7524, 7531))
# (123, 'Stefano Lovato\n\nMDI-191', 'PERSON', (156, 179))
# (123, 'Terra Economicus', 'PERSON', (7602, 7618))
# (123, 'https://cyberleninka.ru/article/n/stremlenie-k-spravedlivomu-sotrudnichestvu-kak- motiv-ekonomicheskogo-povedeniya', 'PERSON', (7742, 7856))
# (123, 'optimally1', 'PERSON', (656, 666))
# (128, 'VISUALIZATION', 'PERSON', (0, 13))
# (137, 'Kirloskar', 'PERSON', (3043, 3052))
# (141, '2)Will', 'PERSON', (1506, 1512))
# (145, 'Belbin Characters', 'PERSON', (2899, 2916))
# (145, 'Walt', 'PERSON', (2757, 2761))
# (155, 'Alicia Diane Durand', 'PERSON', (3311, 3330))
# (161, 'Juan Farid', 'PERSON', (3758, 3770))
# (161, 'UAT', 'PERSON', (1250, 1253))
# (174, 'Maving', 'PERSON', (3884, 3890))
# (175, 'Item', 'PERSON', (407, 411))
# (193, 'Feelings', 'PERSON', (743, 751))
# (194, 'Overcomplicating', 'PERSON', (4899, 4915))
# (194, 'ﬁeld', 'PERSON', (4698, 4702))
# (198, 'Darden', 'PERSON', (1427, 1433))
# (202, 'Danny Long Reflection', 'PERSON', (0, 21))
# (202, 'difefrent', 'PERSON', (1045, 1054))
# (205, 'Azeez Olaide - Design Thinking for Innovation - 01.04.2020', 'PERSON', (0, 58))
# (205, 'Azeez Olaide - Design Thinking for Innovation - 01.04.2020', 'PERSON', (3225, 3283))
# (209, 'VISUALIZATION', 'PERSON', (1526, 1539))
# (212, 'Whit', 'PERSON', (1440, 1444))
# (214, 'Fareed Ponce\n\nChallenge', 'PERSON', (28, 51))
# (225, 'complex.\u200b \u200bTherefore,\u200b', 'PERSON', (1133, 1155))
# (225, 'complexity\u200b \u200bof\u200b', 'PERSON', (180, 196))
# (225, 'service\u200b', 'PERSON', (528, 536))
# (225, 'simpler\u200b \u200bway,\u200b', 'PERSON', (2573, 2588))
# (225, 'with\u200b \u200bnumber\u200b', 'PERSON', (2933, 2947))
# (225, '\u200ba\u200b', 'PERSON', (2829, 2832))
# (225, '\u200ba\u200b \u200bbig\u200b', 'PERSON', (4207, 4216))
# (225, '\u200ba\u200b \u200bcouple\u200b \u200bof\u200b', 'PERSON', (3129, 3146))
# (225, '\u200bbe\u200b', 'PERSON', (4908, 4912))
# (225, '\u200bdecided\u200b', 'PERSON', (1161, 1170))
# (225, '\u200beach', 'PERSON', (748, 755))
# (225, '\u200bideas\u200b \u200baround\u200b \u200ba\u200b', 'PERSON', (4404, 4424))
# (225, '\u200bor\u200b \u200bshown\u200b', 'PERSON', (824, 836))
# (225, '\u200bworking\u200b', 'PERSON', (387, 396))
# (230, 'Gujrati', 'PERSON', (2095, 2102))
# (237, 'VISUALIZATION', 'PERSON', (12, 25))
# (242, 'Rizan Rizvi', 'PERSON', (992, 1005))
# (250, 'Fig', 'PERSON', (2012, 2015))
# (250, 'Fig', 'PERSON', (4674, 4677))
# (251, 'Marketeer', 'PERSON', (127, 136))
# (253, 'foto safari', 'PERSON', (951, 962))
# (263, 'ANSYS Workbench', 'PERSON', (629, 644))
# (263, 'Abaqus', 'PERSON', (646, 652))
# (263, 'Hyperworks', 'PERSON', (657, 667))
# (269, 'Claudia Sarria', 'PERSON', (3805, 3819))
# (275, 'ﬁeld', 'PERSON', (2025, 2029))
# (278, 'Robel', 'PERSON', (1294, 1299))
# (278, 'Robel', 'PERSON', (2006, 2011))
# (285, 'timeboxed', 'PERSON', (2938, 2947))
# (286, 'Cobol', 'PERSON', (580, 585))
# (286, 'Kiuwan', 'PERSON', (2269, 2275))
# (288, 'A Raspberry Pi', 'PERSON', (1641, 1655))
# (308, 'Hunt', 'PERSON', (7887, 7891))
# (311, 'Dyad', 'PERSON', (1846, 1850))
# (314, 'Visio', 'PERSON', (1509, 1514))
# (318, 'David Grey’  Book', 'PERSON', (1472, 1489))
# (319, 'Jeanne', 'PERSON', (2362, 2368))
# (319, 'Ogilvie', 'PERSON', (2373, 2380))
# (319, 'Tim', 'PERSON', (2382, 2385))
# (320, 'Meritnation', 'PERSON', (2111, 2122))
# (320, 'd. Checking', 'PERSON', (4817, 4828))
# (324, 'URLLC', 'PERSON', (3185, 3190))
# (328, 'Carmine Mahmod', 'PERSON', (39, 53))
# (330, 'Marias Gamesa', 'PERSON', (122, 135))
# (330, 'Marias Gamesa', 'PERSON', (1577, 1590))
# (331, 'Yeimy Molina', 'PERSON', (0, 14))
# (334, 'Andres Diaz\n\nReflection', 'PERSON', (0, 23))
# (342, 'Anna\t\r \xa0Brown', 'PERSON', (108, 121))
# (347, 'Gantt', 'PERSON', (2802, 2807))
# (358, 'Barbers', 'PERSON', (633, 640))
# (359, 'MIRO-', 'PERSON', (4291, 4296))
# (361, 'Tony', 'PERSON', (129, 133))
# (368, 'VISUALIZATION', 'PERSON', (23, 36))
# (381, 'celluloses', 'PERSON', (1735, 1745))
# (390, 'Felix cat', 'PERSON', (891, 900))
# (391, 'Mentimeter', 'PERSON', (3280, 3290))
# (394, 'Learing  launch', 'PERSON', (4775, 4790))
# (399, 'Orthomosaic', 'PERSON', (1386, 1397))
# (407, 'Applica', 'PERSON', (1521, 1528))
# (407, 'Makeovermonday.co.uk', 'PERSON', (1497, 1517))
# (407, 'Tableau', 'PERSON', (2537, 2544))
# (407, 'Visualiza', 'PERSON', (7, 16))
# (407, 'ﬁeld', 'PERSON', (2609, 2613))
# (407, 'ﬁeld', 'PERSON', (4051, 4055))
# (409, 'TIMATIC', 'PERSON', (94, 101))
# (418, 'E. Young', 'PERSON', (815, 823))
# (426, 'Asterix', 'PERSON', (389, 396))
# (429, 'Sheen', 'PERSON', (157, 162))
# (431, 'INSIGHT', 'PERSON', (1419, 1426))
# (431, 'VISUALIZATION', 'PERSON', (6, 19))
# (445, 'MindMap', 'PERSON', (1394, 1401))
# (445, 'MindMap', 'PERSON', (1463, 1470))
# (445, 'MindMap', 'PERSON', (3014, 3021))
# (452, 'thé', 'PERSON', (1141, 1144))
# (454, 'conﬁrm', 'PERSON', (1021, 1027))
# (454, 'conﬁrm', 'PERSON', (4437, 4443))
# (454, 'conﬁrm', 'PERSON', (5575, 5581))
# (454, 'conﬁrm', 'PERSON', (6604, 6610))
# (454, 'disconﬁrm', 'PERSON', (1031, 1040))
# (457, 'Harappa', 'PERSON', (4356, 4363))
# (466, 'Jorney Maps', 'PERSON', (3784, 3795))
# (469, 'PRINCIPLES', 'PERSON', (4030, 4040))
# (469, 'xii', 'PERSON', (4348, 4351))
# (472, 'Résumés', 'PERSON', (904, 911))
# (472, 'Résumés', 'PERSON', (2333, 2340))
# (476, '-head', 'PERSON', (2715, 2720))
# (476, 'tabaco', 'PERSON', (1381, 1387))
# (476, '،', 'PERSON', (810, 811))
# (476, '،', 'PERSON', (926, 927))
# (480, 'Mentimeter', 'PERSON', (3374, 3384))
# (494, 'Bollywood', 'PERSON', (2018, 2027))
# (496, 'G.Christakos', 'PERSON', (3488, 3500))
# (500, 'bin idea', 'PERSON', (1893, 1901))
# (506, 'Tina', 'PERSON', (115, 119))
# (515, 'Lucas Martin  Zapata - Learning', 'PERSON', (18, 49))
# (540, 'Tony Buzan', 'PERSON', (1989, 1999))
# (541, 'ipccl2', 'PERSON', (2535, 2541))
# (542, '-----,-----,-----', 'PERSON', (3429, 3452))
# (542, '-----,-----,-----', 'PERSON', (3527, 3550))
# (542, '-----,-----,-----', 'PERSON', (3623, 3646))
# (543, 'Bora', 'PERSON', (1960, 1964))
# (543, 'Bora', 'PERSON', (2216, 2220))
# (543, 'Bora', 'PERSON', (2663, 2667))
# (543, 'Sacco', 'PERSON', (2230, 2235))
# (545, 'M. Jadhav', 'PERSON', (57, 66))
# (558, 'Marian   Moore', 'PERSON', (2488, 2502))
# (560, 'Cat Chow', 'PERSON', (218, 226))
# (568, 'Latly', 'PERSON', (1604, 1609))
# (571, 'Elizabeth & Alejandro', 'PERSON', (1630, 1651))
# (571, 'Monroy Ramírez\n\nReflection', 'PERSON', (0, 26))
# (572, 'Manit Patel', 'PERSON', (44, 55))
# (573, 'Visualizations', 'PERSON', (2730, 2744))
# (589, 'Osterwalder', 'PERSON', (1923, 1934))
# (589, 'VISUALIZATION', 'PERSON', (0, 13))
# (593, 'ideas concretizes', 'PERSON', (2605, 2622))
# (600, 'Joseph Campbell', 'PERSON', (2515, 2530))
# (600, 'artist', 'PERSON', (2405, 2411))
# (603, 'INSIGHT', 'PERSON', (956, 963))
# (607, 'Vlogers', 'PERSON', (610, 617))
# (608, 'Fishbone', 'PERSON', (961, 969))
# (609, 'Alex Swetha', 'PERSON', (409, 422))
# (609, 'Kasyap', 'PERSON', (324, 332))
# (609, 'Tino Swetha', 'PERSON', (290, 303))
# (610, 'Iftikhar Ansari', 'PERSON', (3641, 3656))
# (611, 'INSIGHT', 'PERSON', (2229, 2236))
# (616, 'David Kelley', 'PERSON', (1619, 1631))
# (621, 'INSIGHT', 'PERSON', (1143, 1150))
# (624, 'Al', 'PERSON', (1695, 1697))
# (624, 'Al', 'PERSON', (1809, 1811))
# (624, 'Al', 'PERSON', (2038, 2040))
# (624, 'Al', 'PERSON', (2403, 2405))
# (630, 'Miro', 'PERSON', (211, 215))
# (651, 'Wilson Syafinaz', 'PERSON', (3150, 3165))
# (653, 'Kaizen', 'PERSON', (1282, 1288))
# (653, 'VISUALIZATION', 'PERSON', (74, 87))
# (654, 'INSIGHT', 'PERSON', (2456, 2463))
# (656, 'Styrofoam', 'PERSON', (942, 951))
# (656, 'Styrofoam', 'PERSON', (1035, 1044))
# (658, 'Persona', 'PERSON', (2698, 2705))
# (659, 'Madina Eno', 'PERSON', (0, 10))
# (661, 'Mark', 'PERSON', (514, 518))
# (666, 'submaps', 'PERSON', (762, 769))
# (669, 'Miriam Durango\n\nDesign Thinking', 'PERSON', (0, 31))
# (674, '>\xa0 \xa0 Ryan', 'PERSON', (4299, 4308))
# (674, 'L.', 'PERSON', (4310, 4312))
# (674, 'Moseley', 'PERSON', (4113, 4120))
# (676, 'HIPPO', 'PERSON', (3795, 3800))
# (677, 'ﬁnd', 'PERSON', (3583, 3586))
# (689, 'Carlos Interviewee Name', 'PERSON', (53, 76))
# (689, 'Pin', 'PERSON', (158, 161))
# (689, 'Pin Rf.:327558943483', 'PERSON', (104, 124))
# (699, 'thougth', 'PERSON', (2583, 2590))
# (711, 'Mi Teleférico', 'PERSON', (174, 187))
# (713, 'ﬁle', 'PERSON', (1660, 1663))
# (714, 'Edgar Lara', 'PERSON', (18, 30))
# (724, 'Burra Katha', 'PERSON', (1306, 1317))
# (724, 'MILLET', 'PERSON', (4105, 4111))
# (724, 'RACHABANDA', 'PERSON', (1250, 1260))
# (724, 'VISUVALISATION', 'PERSON', (4246, 4260))
# (725, 'ton', 'PERSON', (1795, 1798))
# (730, 'Ahmed Saeed\n\nAhmed Saeed\n\nDESIGN', 'PERSON', (19, 51))
# (730, 'Vilmer', 'PERSON', (476, 482))
# (733, 'I´ve', 'PERSON', (4361, 4365))
# (733, 'Nestor Puerta\n\nReflection', 'PERSON', (0, 25))
# (735, 'Chosen', 'PERSON', (880, 886))
# (736, 'Joao Courtois\n\nElements', 'PERSON', (97, 120))
# (741, 'eCar', 'PERSON', (1469, 1473))
# (752, 'Bme', 'PERSON', (924, 927))
# (756, 'Bhagwat Gita', 'PERSON', (2832, 2844))
# (761, 'Jorge Mando', 'PERSON', (48, 59))
# (768, 'khats', 'PERSON', (1867, 1872))
# (769, 'VISUALIZATION', 'PERSON', (24, 37))
# (773, 'Insight(s', 'PERSON', (2731, 2740))
# (779, 't\u200bhe', 'PERSON', (925, 929))
# (783, 'Richa Arora\n\nLearning', 'PERSON', (13, 34))
# (786, 'PANATLON', 'PERSON', (17, 25))
# (786, 'Panatlon', 'PERSON', (695, 703))
# (786, 'Panatlon', 'PERSON', (924, 932))
# (786, 'Panatlon', 'PERSON', (4793, 4801))
# (786, 'pana', 'PERSON', (718, 722))
# (788, 'Javier Barragán', 'PERSON', (0, 17))
# (801, 'V. Guihan', 'PERSON', (42, 51))
# (802, 'VISUALIZATION', 'PERSON', (1086, 1099))
# (804, 'Fermín Torroba\n\nChallenge', 'PERSON', (67, 92))
# (805, 'variating', 'PERSON', (3657, 3666))
# (815, 'Melody', 'PERSON', (1833, 1839))
# (815, 'Rick', 'PERSON', (2697, 2701))
# (822, 'amloed', 'PERSON', (2509, 2515))
# (822, 'and”OR', 'PERSON', (1734, 1740))
# (822, 'exlain', 'PERSON', (2916, 2922))
# (822, 'informatom', 'PERSON', (884, 894))
# (822, 'learnig', 'PERSON', (3531, 3538))
# (822, 'zero.with', 'PERSON', (2381, 2390))
# (823, 'Goal Tree', 'PERSON', (2554, 2563))
# (827, 'trayed', 'PERSON', (4393, 4399))
# (829, 'Darton', 'PERSON', (1315, 1321))
# (830, 'Belkin', 'PERSON', (1478, 1484))
# (830, 'Dunne', 'PERSON', (1684, 1689))
# (830, 'Glen et al', 'PERSON', (1709, 1719))
# (830, 'Martin', 'PERSON', (1694, 1700))
# (834, 'João Miranda\n\nChallenge', 'PERSON', (42, 65))
# (844, 'Alexandra\tCherali', 'PERSON', (3818, 3835))
# (845, 'meter', 'PERSON', (2049, 2054))
# (845, 'meter', 'PERSON', (3332, 3337))
# (853, 'Medlink', 'PERSON', (1007, 1014))
# (869, 'Angelica Johnson', 'PERSON', (0, 18))
# (869, 'INSIGHT', 'PERSON', (2278, 2285))
# (880, 'Alma Matter', 'PERSON', (3932, 3943))
# (880, 'Employable', 'PERSON', (348, 358))
# (880, 'Max Salary', 'PERSON', (6449, 6459))
# (880, 'Min  Salary', 'PERSON', (6436, 6447))
# (885, 'designathon', 'PERSON', (212, 223))
# (888, 'Christos SIDIROPOULOS', 'PERSON', (2105, 2126))
# (891, 'D. G. Kulkarni-', 'PERSON', (1645, 1660))
# (891, 'Mins', 'PERSON', (769, 773))
# (891, 'VISUALIZATION', 'PERSON', (0, 13))
# (895, 'Harshvardhan Patil\n\nChallenge\n\nProblem', 'PERSON', (34, 72))
# (896, 'VISUALIZATION', 'PERSON', (0, 13))
# (906, 'wich', 'PERSON', (911, 915))
# (910, 'Gokulashtami', 'PERSON', (112, 124))
# (910, 'Mahabaratham', 'PERSON', (385, 397))
# (911, 'Agar Agar', 'PERSON', (2896, 2905))
# (911, 'Agar Agar', 'PERSON', (5181, 5190))
# (911, 'Gantt', 'PERSON', (3548, 3553))
# (911, 'Miro', 'PERSON', (1451, 1455))
# (914, 'Akhil karthik', 'PERSON', (43, 56))
# (917, 'Arnob Saha', 'PERSON', (3447, 3457))
# (918, 'Tableau', 'PERSON', (545, 552))
# (918, 'Tableau', 'PERSON', (1139, 1146))
# (918, 'Tableau', 'PERSON', (1348, 1355))
# (918, 'VISUALIZATION', 'PERSON', (0, 13))
# (920, 'Alp Mete Cetinkol', 'PERSON', (50, 67))
# (928, 'ﬁeld', 'PERSON', (1191, 1195))
# (928, 'ﬁeld', 'PERSON', (3315, 3319))
# (930, 'substeps', 'PERSON', (3558, 3566))
# (939, 'Matheus Baumgart', 'PERSON', (0, 18))
# (946, 'Arsalan', 'PERSON', (44, 51))
# (946, 'Waheed', 'PERSON', (55, 65))
# (971, 'Maxwell Colbert', 'PERSON', (32, 47))
# (973, 'cone tree', 'PERSON', (1679, 1688))
# (975, 'Tsvet', 'PERSON', (1466, 1471))
# (975, 'Vkus', 'PERSON', (1457, 1461))
# (987, '\u200b2  completely\u200b \u200bdifferent\u200b', 'PERSON', (413, 440))
# (987, '\u200b2\u200b \u200bcontrasting\u200b', 'PERSON', (1486, 1503))
# (987, '\u200bI\u200b \u200bwould\u200b \u200bdo\u200b \u200bdifferently.\u200b \u200bAllowing  the\u200b', 'PERSON', (4517, 4564))
# (987, '\u200ba\u200b', 'PERSON', (368, 371))
# (987, '\u200ba\u200b', 'PERSON', (835, 838))
# (987, '\u200bbuilding\u200b \u200bthe\u200b', 'PERSON', (1661, 1677))
# (987, '\u200bdecided\u200b', 'PERSON', (1775, 1784))
# (987, '\u200bideas\u200b \u200bdo\u200b \u200bnot\u200b \u200bhave\u200b', 'PERSON', (3677, 3702))
# (987, '\u200bmember\u200b \u200bof\u200b \u200bthe\u200b \u200bProduct\u200b', 'PERSON', (61, 90))
# (987, '\u200bor\u200b \u200beven  implement\u200b \u200bthe\u200b \u200bwebsite\u200b \u200bwould\u200b \u200bbe\u200b', 'PERSON', (4667, 4718))
# (987, '\u200bpeople.', 'PERSON', (521, 531))
# (987, '\u200btheir  proposed\u200b', 'PERSON', (2980, 2997))
# (994, 'revaluate', 'PERSON', (5141, 5154))
# (999, 'Lung', 'PERSON', (4451, 4455))
# (1005, 'Selection', 'PERSON', (606, 621))
# (1014, 'Matt', 'PERSON', (785, 789))
# (1023, 'Emapthy', 'PERSON', (2825, 2832))
# (1037, 'Jacqueline Novogratz', 'PERSON', (1890, 1910))
# (1040, 'Instagram  IGTV', 'PERSON', (913, 928))
# (1042, 'Dean', 'PERSON', (431, 435))
# (1042, 'Dean', 'PERSON', (2029, 2033))
# (1042, 'Dean', 'PERSON', (3485, 3489))
# (1045, 'MindMap', 'PERSON', (1896, 1903))
# (1049, 'Jeanne .M.', 'PERSON', (1925, 1935))
# (1049, 'ma lyf  or', 'PERSON', (2535, 2545))
# (1056, 'keeW', 'PERSON', (1571, 1575))
# (1057, 'Valentine´s Day', 'PERSON', (2152, 2167))
# (1060, 'Deﬁne Context Reﬁnement', 'PERSON', (3245, 3268))
# (1069, 'FALL -', 'PERSON', (58, 64))
# (1078, 'Se  selected', 'PERSON', (1270, 1282))
# (1080, 'Frist', 'PERSON', (2044, 2049))
# (1082, 'Nielsen', 'PERSON', (3385, 3392))
# (1083, 'Linkedin', 'PERSON', (1319, 1327))
# (1085, 'brigadeiro', 'PERSON', (2941, 2951))
# (1086, 'Copywriter', 'PERSON', (72, 82))
# (1086, 'INSIGHT', 'PERSON', (1154, 1161))
# (1094, 'Rich', 'PERSON', (623, 627))
# (1098, 'Wireframes', 'PERSON', (2679, 2689))
# (1099, 'Application\u200b', 'PERSON', (1327, 1339))
# (1102, 'Visio', 'PERSON', (1329, 1334))
# (1103, 'Michell', 'PERSON', (1934, 1941))
# (1106, '\u200ba', 'PERSON', (806, 808))
# (1112, 'INSIGHT', 'PERSON', (2606, 2613))
# (1113, 'INSIGHT', 'PERSON', (760, 767))
# (1119, 'Owen', 'PERSON', (526, 530))
# (1124, 'Serengeti', 'PERSON', (2543, 2552))
# (1124, 'Serengeti', 'PERSON', (3414, 3423))
# (1125, 'Schmidt', 'PERSON', (23, 30))
# (1125, 'Schmidt', 'PERSON', (3407, 3414))
# (1125, 'diﬃcult', 'PERSON', (2608, 2615))
# (1140, 'Billing', 'PERSON', (702, 709))
# (1140, 'Napkin Pitch', 'PERSON', (5936, 5948))
# (1143, 'M. Diga', 'PERSON', (0, 7))
# (1143, 'M. Diga', 'PERSON', (3391, 3398))
# (1152, 'Amtec', 'PERSON', (561, 566))
# (1153, 'MM', 'PERSON', (4205, 4207))
# (1153, 'ufff', 'PERSON', (4412, 4416))
# (1154, 'R&I', 'PERSON', (1854, 1857))
# (1161, 'VISUALIZATION', 'PERSON', (0, 13))
# (1163, 'ﬁeld', 'PERSON', (834, 838))
# (1166, 'Reach', 'PERSON', (1359, 1364))
# (1172, 'Rayan AlbinHassan', 'PERSON', (1987, 2006))
# (1173, 'Geoff', 'PERSON', (3587, 3592))
# (1174, 'An Schmidt', 'PERSON', (1130, 1140))
# (1174, 'Urb los Rincones', 'PERSON', (103, 119))
# (1180, 'uesd', 'PERSON', (1928, 1932))
# (1185, 'Florian Richter\n\nDate', 'PERSON', (36, 57))
# (1186, 'Design\u200b', 'PERSON', (0, 7))
# (1186, 'I\u200b', 'PERSON', (84, 86))
# (1186, 'Me\u200b \u200bbeing\u200b', 'PERSON', (1698, 1709))
# (1186, '\u200bProfessor\u200b \u200bMarian\u200b \u200bMoore\u200b \u200bsaid\u200b \u200bMind\u200b \u200bmapping\u200b \u200bis\u200b', 'PERSON', (1960, 2017))
# (1186, '\u200ba', 'PERSON', (2390, 2392))
# (1186, '\u200ba', 'PERSON', (4315, 4317))
# (1186, '\u200bas\u200b \u200bI\u200b', 'PERSON', (3587, 3595))
# (1186, '\u200ba\u200b', 'PERSON', (730, 733))
# (1186, '\u200ba\u200b', 'PERSON', (3290, 3293))
# (1186, '\u200bdecided\u200b', 'PERSON', (1911, 1920))
# (1186, '\u200bmember\u200b \u200bhas\u200b \u200bto\u200b \u200bsubmit\u200b \u200ba\u200b', 'PERSON', (1048, 1080))
# (1186, '\u200bof\u200b \u200bthe\u200b', 'PERSON', (3916, 3926))
# (1186, '\u200bof\u200b \u200bthe\u200b', 'PERSON', (5731, 5741))
# (1186, '\u200bof\u200b \u200btools\u200b', 'PERSON', (1830, 1842))
# (1186, '\u200bto  provide\u200b \u200bthe\u200b', 'PERSON', (758, 777))
# (1186, '\u200bto\u200b \u200bwhich,\u200b \u200band\u200b', 'PERSON', (3004, 3023))
# (1189, 'Kaizen', 'PERSON', (3116, 3122))
# (1195, 'Mindjet', 'PERSON', (4590, 4597))
# (1199, 'Joseph  with', 'PERSON', (1680, 1692))
# (1199, 'Joseph  with Jesus', 'PERSON', (1680, 1698))
# (1199, 'Nazareth', 'PERSON', (1106, 1114))
# (1199, 'Nazareth', 'PERSON', (1561, 1569))
# (1201, 'Hannah Ali\t\r \xa0\t\r \xa0 Brazilian', 'PERSON', (48, 76))
# (1209, 'VISUALIZATION', 'PERSON', (20, 33))
# (1210, 'Castro', 'PERSON', (514, 520))
# (1210, 'Castro', 'PERSON', (1435, 1441))
# (1210, 'Favela', 'PERSON', (249, 255))
# (1212, 'Alister', 'PERSON', (1302, 1309))
# (1212, 'Barbara Lopez', 'PERSON', (2150, 2163))
# (1212, 'CBien‐like', 'PERSON', (1008, 1018))
# (1212, 'David\xa0KELLEY', 'PERSON', (2194, 2206))
# (1212, 'Maria Melo', 'PERSON', (32, 42))
# (1212, 'MyEggBox', 'PERSON', (995, 1003))
# (1212, 'Trov', 'PERSON', (989, 993))
# (1226, 'Jose Suarez', 'PERSON', (40, 71))
# (1227, 'SELECTION-', 'PERSON', (331, 341))
# (1231, 'VISUALIZATION', 'PERSON', (0, 13))
# (1234, 'Miro', 'PERSON', (2657, 2661))
# (1239, 'Asim Sunar', 'PERSON', (55, 65))
# (1253, 'garifuna', 'PERSON', (1857, 1865))
# (1253, 'mennonite', 'PERSON', (1871, 1880))
# (1257, 'VISUALIZATION', 'PERSON', (566, 579))
# (1259, 'Mindmeister', 'PERSON', (1506, 1517))
# (1279, 'ﬁnd', 'PERSON', (402, 405))
# (1285, 'bake ragi', 'PERSON', (1850, 1859))
# (1287, 'Heriberto', 'PERSON', (559, 570))
# (1287, 'conﬁrm', 'PERSON', (2209, 2215))
# (1288, 'INSIGHT', 'PERSON', (1857, 1864))
# (1290, 'Bello', 'PERSON', (3257, 3262))
# (1290, 'Olivier Collet 2/2', 'PERSON', (3182, 3200))
# (1293, 'Mohd Javed\n\nChallenge', 'PERSON', (64, 85))
# (1296, 'Scrum Master', 'PERSON', (1057, 1069))
# (1304, 'Felt', 'PERSON', (3527, 3531))
# (1309, 'matrix1', 'PERSON', (320, 327))
# (1318, 'Garrety', 'PERSON', (2882, 2889))
# (1318, 'Morales', 'PERSON', (165, 172))
# (1318, 'Morales', 'PERSON', (259, 266))
# (1323, 'Appliyng', 'PERSON', (1193, 1201))
# (1326, 'Prezi', 'PERSON', (1320, 1325))
# (1350, 'techniques.[6][7', 'PERSON', (1537, 1553))
# (1353, 'Medo Uddin', 'PERSON', (47, 57))
# (1366, 'Scrum', 'PERSON', (2919, 2924))
# (1366, 'Scrum', 'PERSON', (3090, 3095))
# (1372, 'Andreas Spies', 'PERSON', (0, 15))
# (1372, 'Andreas Spies  Design Thinking', 'PERSON', (3573, 3603))
# (1376, 'Week2', 'PERSON', (2803, 2808))
# (1386, 'Isight', 'PERSON', (1324, 1330))
# (1387, 'Elderlies', 'PERSON', (1275, 1284))
# (1387, 'f.i.', 'PERSON', (2124, 2130))
# (1390, 'Samaa Abdelghany', 'PERSON', (42, 60))
# (1397, 'Pin No.:222010404057', 'PERSON', (156, 176))
# (1400, 'Tableau', 'PERSON', (576, 583))
# (1401, 'Eﬃciency', 'PERSON', (2383, 2391))
# (1412, 'GRADED', 'PERSON', (25, 31))
# (1413, 'David vs Goliath', 'PERSON', (1413, 1429))
# (1415, 'Khadi', 'PERSON', (182, 187))
# (1415, 'Khadi', 'PERSON', (262, 267))
# (1415, 'Khadi', 'PERSON', (395, 400))
# (1415, 'Khadi', 'PERSON', (411, 416))
# (1415, 'Khadi', 'PERSON', (686, 691))
# (1415, 'Khadi', 'PERSON', (857, 862))
# (1415, 'Khadi', 'PERSON', (1398, 1403))
# (1415, 'Khadi', 'PERSON', (1532, 1537))
# (1415, 'Khadi', 'PERSON', (1545, 1550))
# (1415, 'Khadi', 'PERSON', (1784, 1789))
# (1415, 'Khadi', 'PERSON', (1919, 1924))
# (1415, 'Khadi', 'PERSON', (2436, 2441))
# (1415, 'Khadi', 'PERSON', (2686, 2691))
# (1415, 'Mahatma Gandhi-the Father', 'PERSON', (497, 522))
# (1418, 'Visualitation', 'PERSON', (2906, 2919))
# (1418, 'kdneped', 'PERSON', (589, 596))
# (1425, 'Robert Sims’s', 'PERSON', (3918, 3931))
# (1425, '\u200bA', 'PERSON', (234, 236))
# (1425, '\u200bwe', 'PERSON', (2311, 2314))
# (1426, 'd. Enablement - Increase', 'PERSON', (5389, 5413))
# (1428, 'Mikhail  Bakhtin', 'PERSON', (5571, 5587))
# (1429, 'Tableau', 'PERSON', (836, 843))
# (1434, 'David Kelley', 'PERSON', (1163, 1175))
# (1437, 'LEARNING LAUNCH', 'PERSON', (0, 15))
# (1440, '\u200b“relevant', 'PERSON', (2055, 2065))
# (1443, 'HCD', 'PERSON', (1303, 1306))
# (1447, 'Scrum', 'PERSON', (772, 777))
# (1447, 'Scrum', 'PERSON', (788, 793))
# (1455, 'anda  running', 'PERSON', (2639, 2652))
# (1462, 'Don', 'PERSON', (1681, 1684))
# (1463, '\u200bA', 'PERSON', (1794, 1796))
# (1466, 'Bretherick', 'PERSON', (1804, 1814))
# (1477, 'Expert(SME', 'PERSON', (1379, 1389))
# (1477, 'Yvonne Schmidt', 'PERSON', (0, 14))
# (1478, 'Naan', 'PERSON', (597, 601))
# (1482, 'Tabling', 'PERSON', (2176, 2183))
# (1483, 'andy', 'PERSON', (284, 288))
# (1489, 'Continum Model', 'PERSON', (1330, 1344))
# (1492, 'VISUALIZATION', 'PERSON', (0, 13))
# (1526, 'groan', 'PERSON', (2512, 2521))
# (1546, 'Aline Lima\n\nAssignment Reflection –', 'PERSON', (40, 75))
# (1546, 'Aline Lima\n\nAssignment Reflection –', 'PERSON', (3338, 3373))
# (1546, 'Mein Pragati', 'PERSON', (462, 474))
# (1546, 'Mein Pragati', 'PERSON', (4589, 4601))
# (1546, 'Mein Pragati', 'PERSON', (5152, 5164))
# (1549, 'VISUALIZATION', 'PERSON', (87, 100))
# (1560, 'Addressal', 'PERSON', (1393, 1402))
# (1576, 'Aristotle', 'PERSON', (2092, 2101))
# (1576, 'Buechner', 'PERSON', (8503, 8511))
# (1576, 'Fisher', 'PERSON', (8570, 8576))
# (1576, 'Griffin', 'PERSON', (5894, 5901))
# (1576, 'Griffin', 'PERSON', (8910, 8917))
# (1576, 'R.', 'PERSON', (9000, 9002))
# (1584, 'FMVA', 'PERSON', (4991, 4995))
# (1587, 'hypothesis\u200b', 'PERSON', (3644, 3655))
# (1589, 'keeper/ minute', 'PERSON', (2270, 2284))
# (1600, 'Aguilar', 'PERSON', (1045, 1052))
# (1606, 'INSIGHT', 'PERSON', (6233, 6240))
# (1613, 'Jacqueline Stuurman', 'PERSON', (40, 59))
# (1620, 'Aspen Hysys', 'PERSON', (963, 974))
# (1622, 'wan', 'PERSON', (51, 54))
# (1626, 'Principally', 'PERSON', (996, 1007))
# (1628, 'CHALLEGES', 'PERSON', (0, 9))
# (1628, 'INSIGHT', 'PERSON', (1096, 1103))
# (1631, 'Natalia', 'PERSON', (13, 20))
# (1637, 'Andre  Martin', 'PERSON', (1575, 1588))
# (1649, 'Leaverging Virtualization Tool For Design  Thinking -Real Life Case Study\n\n- Sumit Kumar', 'PERSON', (0, 88))
# (1650, 'Kudos', 'PERSON', (2776, 2781))
# (1658, 'Dev', 'PERSON', (348, 351))
# (1658, 'Rakesh Rajput\n\nChallenge', 'PERSON', (65, 89))
# (1663, 'ﬁnd', 'PERSON', (3982, 3985))
# (1663, 'ﬁnd meaningh', 'PERSON', (696, 708))
# (1680, 'I\u200b', 'PERSON', (3551, 3553))
# (1680, 'kind\u200b', 'PERSON', (1712, 1717))
# (1680, '\u200bIn', 'PERSON', (2343, 2348))
# (1680, '\u200ba\u200b', 'PERSON', (2124, 2127))
# (1680, '\u200bof\u200b \u200bthe\u200b', 'PERSON', (2322, 2332))
# (1680, '\u200bor\u200b \u200bsituation  among\u200b \u200ba\u200b', 'PERSON', (715, 742))
# (1680, '\u200bsketch\u200b \u200bout\u200b \u200ba  digital\u200b', 'PERSON', (835, 862))
# (1680, '\u200btool\u200b', 'PERSON', (525, 531))
# (1683, 'VISUALIZATION', 'PERSON', (53, 66))
# (1688, 'Cinderella', 'PERSON', (1879, 1889))
# (1689, 'Lot', 'PERSON', (566, 569))
# (1689, 'VISUALIZATION', 'PERSON', (24, 37))
# (1695, 'A. Lowering', 'PERSON', (837, 848))
# (1718, 'Marcelo Eduardo', 'PERSON', (12, 27))
# (1718, 'Marcelo Eduardo', 'PERSON', (3916, 3931))
# (1725, 'Scrum', 'PERSON', (2551, 2556))
# (1726, 'Siat', 'PERSON', (0, 4))
# (1730, 'Visme', 'PERSON', (997, 1002))
# (1730, 'Visme', 'PERSON', (1380, 1385))
# (1732, 'Mand', 'PERSON', (2527, 2531))
# (1732, 'Winding', 'PERSON', (2548, 2555))
# (1735, 'Edward  Hess', 'PERSON', (391, 403))
# (1740, '-Insight', 'PERSON', (1374, 1382))
# (1742, 'NPLs', 'PERSON', (429, 433))
# (1742, 'NPLs', 'PERSON', (1111, 1115))
# (1744, 'INSIGHT', 'PERSON', (1275, 1282))
# (1747, 'QA QC', 'PERSON', (347, 352))
# (1749, 'INSIGHT', 'PERSON', (3701, 3708))
# (1749, 'PERSONALIZATION', 'PERSON', (2953, 2968))
# (1749, 'PERSONALIZATION', 'PERSON', (3441, 3456))
# (1752, 'Steve Denning\n\nChallenge', 'PERSON', (247, 271))
# (1758, 'VISUALIZATION', 'PERSON', (0, 13))
# (1762, '.One', 'PERSON', (1007, 1011))
# (1762, 'meena', 'PERSON', (2002, 2009))
# (1763, 'Imtiyaz', 'PERSON', (82, 89))
# (1767, 'ﬁeld', 'PERSON', (1430, 1434))
# (1775, 'baklava', 'PERSON', (3795, 3802))
# (1775, 'baklava', 'PERSON', (3830, 3837))
# (1779, 'Head Manajemen\n\nMarketer\n\nAdmin Finance', 'PERSON', (2520, 2559))
# (1779, 'Tranparant Acrylic', 'PERSON', (1606, 1624))
# (1790, 'Shirley Medina\n\nCompany', 'PERSON', (51, 74))
# (1795, 'Craig Gonzalez', 'PERSON', (4372, 4386))
# (1797, 'Hellen Keller  Institute', 'PERSON', (59, 83))
# (1798, 'Neha Sharma', 'PERSON', (332, 343))
# (1802, 'Ilir Ahmed  Profesor de Lengua', 'PERSON', (0, 30))
# (1802, 'Ilir Ahmed  Profesor de Lengua', 'PERSON', (3698, 3728))
# (1802, 'Ilir Ahmed  Profesor de Lengua', 'PERSON', (6371, 6401))
# (1802, 'Instagram', 'PERSON', (5839, 5848))
# (1802, 'Radicality', 'PERSON', (7318, 7328))
# (1802, 'mōris', 'PERSON', (1918, 1923))
# (1803, 'A.Y.', 'PERSON', (0, 4))
# (1803, 'Maxim', 'PERSON', (764, 769))
# (1803, 'Trias', 'PERSON', (170, 175))
# (1803, 'Trias', 'PERSON', (272, 277))
# (1805, 'Innova', 'PERSON', (1553, 1559))
# (1805, 'MINCETUR', 'PERSON', (25, 33))
# (1805, 'MINCETUR', 'PERSON', (175, 183))
# (1805, 'MINCETUR', 'PERSON', (328, 336))
# (1805, 'MINCETUR', 'PERSON', (1561, 1569))
# (1805, 'MINCETUR', 'PERSON', (1639, 1647))
# (1805, 'MINCETUR', 'PERSON', (1852, 1860))
# (1805, 'MINCETUR', 'PERSON', (4541, 4549))
# (1805, 'Mostafa', 'PERSON', (4863, 4870))
# (1807, 'Ferienlenk', 'PERSON', (207, 217))
# (1807, 'Melody', 'PERSON', (1321, 1327))
# (1810, 'Shailesh Jain\n\n1', 'PERSON', (73, 89))
# (1832, 'Cathal Elder', 'PERSON', (6, 20))
# (1834, 'a mudboard', 'PERSON', (2425, 2435))
# (1834, 'a mudboard', 'PERSON', (2455, 2465))
# (1838, 'manager\u200b', 'PERSON', (608, 616))
# (1844, 'DVO', 'PERSON', (824, 827))
# (1844, 'DVO', 'PERSON', (1208, 1211))
# (1844, 'RM', 'PERSON', (523, 525))
# (1847, 'Tableau', 'PERSON', (843, 850))
# (1847, 'Tableau', 'PERSON', (1619, 1626))
# (1849, 'Rice', 'PERSON', (1546, 1550))
# (1853, 'Anthony R. West', 'PERSON', (918, 933))
# (1856, 'Tulsi', 'PERSON', (1271, 1276))
# (1857, 'Graph', 'PERSON', (3074, 3079))
# (1858, 'Yellow', 'PERSON', (2261, 2267))
# (1861, 'managers\u200b', 'PERSON', (77, 86))
# (1861, 'vision\u200b', 'PERSON', (734, 741))
# (1871, 'Carlos Angelo D. Aguilar  cdaguilar@ust.edu.ph\n\nStorytelling\n\nChallenge', 'PERSON', (0, 71))
# (1871, 'N.B.', 'PERSON', (2677, 2681))
# (1893, 'Bollywood', 'PERSON', (1859, 1868))
# (1893, 'Dubsmash', 'PERSON', (1596, 1604))
# (1893, 'ﬁnd', 'PERSON', (1943, 1946))
# (1897, 'VISUALIZATION  1.Challenge and', 'PERSON', (14, 44))
# (1897, 'absorbe', 'PERSON', (1132, 1139))
# (1898, 'Elizabeth Timmins Reﬂection - Learning', 'PERSON', (0, 38))
# (1899, 'storytelling1', 'PERSON', (372, 385))
# (1902, 'VISUALIZATION', 'PERSON', (0, 13))
# (1907, 'IOT', 'PERSON', (631, 634))
# (1907, 'Paula Eckhardt', 'PERSON', (72, 88))
# (1907, 'Paula Eckhardt', 'PERSON', (2144, 2160))
# (1907, 'Paula Eckhardt', 'PERSON', (3496, 3512))
# (1911, 'Pradheepa R.', 'PERSON', (4969, 4983))
# (1912, 'https://warren2lynch.medium.com/mind-map-a-practical-tutorial-with-30-examples- b248d543ca8a\n\nProject', 'PERSON', (3, 104))
# (1918, 'bush', 'PERSON', (2715, 2719))
# (1919, 'FLORENCE GAKUI', 'PERSON', (0, 14))
# (1925, 'Darton', 'PERSON', (2476, 2482))
# (1935, 'Graham Process', 'PERSON', (1760, 1774))
# (1936, 'JOHAN GUSTAVO', 'PERSON', (15, 28))
# (1941, 'Caio Ledesma\n\nTool', 'PERSON', (38, 56))
# (1942, 'Rhino', 'PERSON', (555, 560))
# (1942, 'Whit', 'PERSON', (2822, 2826))
# (1945, 'Mark', 'PERSON', (1938, 1942))
# (1949, 'wisemapping', 'PERSON', (2865, 2876))
# (1952, 'Ito', 'PERSON', (1076, 1079))
# (1958, 'Speciﬁcally', 'PERSON', (831, 842))
# (1961, 'Viessmann', 'PERSON', (1729, 1738))
# (1961, 'Viessmann', 'PERSON', (1824, 1833))
# (1961, 'Viessmann', 'PERSON', (2117, 2126))
# (1961, 'Viessmann', 'PERSON', (2332, 2341))
# (1961, 'Viessmann', 'PERSON', (2771, 2780))
# (1961, 'Viessmann', 'PERSON', (3332, 3341))
# (1962, 'Chatbot', 'PERSON', (6187, 6194))
# (1962, 'Chatbot', 'PERSON', (6615, 6622))
# (1965, 'appls', 'PERSON', (1928, 1933))
# (1970, 'Idris Mootee', 'PERSON', (2020, 2032))
# (1970, 'Rodrigo Correa\n\nChallenge', 'PERSON', (173, 198))
# (1971, 'Balsamiq', 'PERSON', (2281, 2289))
# (1971, 'Balsamiq Mockups', 'PERSON', (1435, 1451))
# (1971, 'Mockup', 'PERSON', (2710, 2716))
# (1973, 'Meghavi Pasumarti', 'PERSON', (56, 92))
# (1976, 'Ramayana', 'PERSON', (772, 780))
# (1976, 'Shivaji Maharaj', 'PERSON', (803, 818))
# (1982, 'xar-1874547', 'PERSON', (2929, 2940))
# (1984, 'Bora  fa', 'PERSON', (1659, 1667))
# (1984, 'lica', 'PERSON', (3804, 3808))
# (1986, 'Said', 'PERSON', (2702, 2706))
# (1989, 'Jorneys', 'PERSON', (1625, 1632))
# (1990, 'hasn´t', 'PERSON', (2668, 2674))
# (2004, 'Karabo Thokwane', 'PERSON', (0, 17))
# (2004, 'wat', 'PERSON', (2376, 2379))
# (2005, 'VISUALIZATION', 'PERSON', (2452, 2465))
# (2013, 'Traduttore', 'PERSON', (16, 26))
# (2014, 'Anwesha Mukherjee', 'PERSON', (14, 31))
# (2017, 'ASSIGNMENT-', 'PERSON', (0, 11))
# (2020, 'Maria Florencia', 'PERSON', (2702, 2717))
# (2021, 'Ed Hess', 'PERSON', (982, 989))
# (2023, 'staﬀ', 'PERSON', (6286, 6290))
# (2023, 'ﬁeld', 'PERSON', (5290, 5294))
# (2023, 'ﬁeld', 'PERSON', (6677, 6681))
# (2027, 'Juan Manuel Giraldo Rios\n\nChallenge', 'PERSON', (42, 77))
# (2032, 'goood', 'PERSON', (663, 668))
# (2034, 'Angela \xa0Myer', 'PERSON', (1581, 1593))
# (2034, 'Angela \xa0Myer', 'PERSON', (2982, 2994))
# (2034, 'Angela \xa0Myer \xa0  \xa0 Weapon', 'PERSON', (815, 839))
# (2040, 'Dissonance', 'PERSON', (8411, 8421))
# (2042, 'spidergrams', 'PERSON', (452, 463))
# (2052, 'Bob', 'PERSON', (2701, 2704))
# (2056, 'Bellow', 'PERSON', (2058, 2064))
# (2058, 'Morale', 'PERSON', (4353, 4359))
# (2058, 'Ravneet Williams', 'PERSON', (60, 78))
# (2063, 'ben diagrams', 'PERSON', (2020, 2032))
# (2070, 'Mary Elizabeth Smith', 'PERSON', (2339, 2359))
# (2070, 'Mary Elizabeth Smith\n\nVisualization - Reflection\n\nCreating Value for Online Students', 'PERSON', (0, 84))
# (2071, 'Catalina O’Ryan', 'PERSON', (2987, 3004))
# (2082, 'WeSing', 'PERSON', (2870, 2876))
# (2082, 'Wesing', 'PERSON', (331, 337))
# (2091, 'd. Re-group', 'PERSON', (4274, 4285))
# (2106, 'Shrek', 'PERSON', (1611, 1616))
# (2107, 'Baijiu', 'PERSON', (689, 695))
# (2107, 'Wei Wang', 'PERSON', (70, 80))
# (2109, 'Application\u200b', 'PERSON', (3601, 3613))
# (2115, 'JAY AR  SANDOVAL', 'PERSON', (86, 104))
# (2117, 'Irfan Aulia', 'PERSON', (12, 23))
# (2121, 'Miro', 'PERSON', (1097, 1101))
# (2121, 'Miro', 'PERSON', (1242, 1246))
# (2130, 'throe', 'PERSON', (2327, 2332))
# (2132, 'Challengue', 'PERSON', (0, 10))
# (2133, 'INSIGHT', 'PERSON', (1878, 1885))
# (2137, 'key´s', 'PERSON', (519, 524))
# (2145, 'Julien Tartaglia -', 'PERSON', (62, 80))
# (2154, 'Tim', 'PERSON', (873, 876))
# (2155, 'max', 'PERSON', (561, 564))
# (2160, '+400', 'PERSON', (720, 724))
# (2174, 'Moreother', 'PERSON', (4556, 4565))
# (2185, 'George', 'PERSON', (1016, 1024))
# (2185, 'George  considers', 'PERSON', (670, 687))
# (2186, 'Andrews', 'PERSON', (5513, 5520))
# (2186, 'J. Joel Hulett\n\nChallenge', 'PERSON', (66, 91))
# (2187, 'Rob Fontenot', 'PERSON', (67, 79))
# (2188, 'Joseph', 'PERSON', (3485, 3493))
# (2189, 'Sherril Moana', 'PERSON', (12, 25))
# (2191, 'Adonis', 'PERSON', (1903, 1909))
# (2194, 'okhaha', 'PERSON', (1408, 1414))
# (2196, 'recommendation2', 'PERSON', (2378, 2393))
# (2200, 'Andre Martin', 'PERSON', (830, 842))
# (2208, 'Hernan Guerra\n\nChallenge', 'PERSON', (0, 24))
# (2222, 'Myjob', 'PERSON', (605, 610))
# (2222, 'discuesd', 'PERSON', (2453, 2461))
# (2222, 'myfriends', 'PERSON', (1720, 1729))
# (2222, 'myfriends', 'PERSON', (3868, 3877))
# (2222, 'myfriends', 'PERSON', (4107, 4116))
# (2222, 'myother', 'PERSON', (5119, 5126))
# (2226, 'Bigs', 'PERSON', (1461, 1465))
# (2226, 'Bigs', 'PERSON', (2950, 2954))
# (2226, 'Bigs', 'PERSON', (5357, 5361))
# (2226, 'Bigs  and', 'PERSON', (2402, 2411))
# (2226, 'Dad', 'PERSON', (4172, 4175))
# (2226, 'Rachel - a', 'PERSON', (4650, 4660))
# (2228, 'Sanjit Rao', 'PERSON', (4615, 4625))
# (2229, 'wor k', 'PERSON', (1642, 1647))
# (2230, 'BiP Translate', 'PERSON', (0, 13))
# (2231, 'Feelings', 'PERSON', (1623, 1631))
# (2231, 'Graph', 'PERSON', (2049, 2054))
# (2233, 'NFPs', 'PERSON', (2544, 2548))
# (2236, 'visualiza4on', 'PERSON', (3298, 3310))
# (2246, 'Ed  Hesse', 'PERSON', (1145, 1154))
# (2256, 'Marian  Moore', 'PERSON', (1278, 1291))
# (2256, 'Mark Brewer', 'PERSON', (3104, 3115))
# (2256, 'Mark Brewer\n\nDesign Thinking', 'PERSON', (39, 67))
# (2256, 'Thomas Gilbert’s', 'PERSON', (2299, 2315))
# (2257, 'i. e.\n\n1-Can', 'PERSON', (2706, 2718))
# (2258, 'Sherif Attia  Storytelling', 'PERSON', (0, 26))
# (2270, 'Dampfschifffahrtskapitänsfrau', 'PERSON', (1162, 1191))
# (2271, 'Miro', 'PERSON', (2353, 2357))
# (2271, 'Miro', 'PERSON', (2952, 2956))
# (2271, 'Miro', 'PERSON', (3562, 3566))
# (2271, 'Miro', 'PERSON', (4084, 4088))
# (2271, 'Miro', 'PERSON', (4230, 4234))
# (2281, 'INSIGHT', 'PERSON', (1979, 1986))
# (2281, 'Sabantuy', 'PERSON', (151, 159))
# (2281, 'Sabantuy', 'PERSON', (258, 266))
# (2288, 'PJ Camp Malik\n\nDesign Visualisation Workshop\n\nChallenge  Working', 'PERSON', (0, 64))
# (2292, 'E. g.', 'PERSON', (4499, 4504))
# (2292, 'e. g.', 'PERSON', (2578, 2583))
# (2293, 'GenX', 'PERSON', (3671, 3675))
# (2296, 'Lucia Latorre', 'PERSON', (15, 34))
# (2307, 'VISUALIZATION', 'PERSON', (1297, 1310))
# (2308, '10:11', 'PERSON', (2914, 2919))
# (2309, 'Harry Hostel', 'PERSON', (31, 43))
# (2309, 'Louis I am', 'PERSON', (402, 412))
# (2316, 'Erin Brockovich', 'PERSON', (1556, 1571))
# (2317, 'Ilka Dominguez', 'PERSON', (32, 117))
# (2320, 'Caroline', 'PERSON', (1616, 1624))
# (2320, 'Caroline', 'PERSON', (3010, 3018))
# (2322, 'Darton', 'PERSON', (1666, 1672))
# (2322, 'Farieda Gordon', 'PERSON', (29, 43))
# (2322, 'Farieda Gordon', 'PERSON', (2430, 2444))
# (2327, 'decriped', 'PERSON', (1963, 1971))
# (2333, 'Tim Hortons', 'PERSON', (1014, 1025))
# (2337, 'Mahmoud Callejas', 'PERSON', (3362, 3380))
# (2343, 'Moses', 'PERSON', (4273, 4278))
# (2349, 'added\u200b', 'PERSON', (2224, 2230))
# (2357, 'Meera Chita', 'PERSON', (72, 83))
# (2361, 'Dhoker Jhara', 'PERSON', (219, 231))
# (2363, 'terriﬁed', 'PERSON', (3978, 3986))
# (2365, 'Jerome Cariño', 'PERSON', (65, 78))
# (2366, 'enthalpy', 'PERSON', (2507, 2515))
# (2367, 'MORAL', 'PERSON', (2612, 2617))
# (2370, 'VISUALIZATION', 'PERSON', (1669, 1682))
# (2374, 'ketp', 'PERSON', (2070, 2074))
# (2375, 'Eileen Fisher', 'PERSON', (830, 843))
# (2375, 'Eileen Fisher', 'PERSON', (873, 886))
# (2375, 'Eileen Fisher', 'PERSON', (1964, 1977))
# (2380, 'Salespersons', 'PERSON', (1093, 1105))
# (2380, 'VISUALIZATION', 'PERSON', (2556, 2569))
# (2392, 'Charles  Cavalier', 'PERSON', (1492, 1509))
# (2392, 'Yorkie', 'PERSON', (2571, 2577))
# (2395, 'Saudi Armco', 'PERSON', (141, 152))
# (2397, 'Salesman', 'PERSON', (4285, 4293))
# (2398, 'Sydwell Tshabalala', 'PERSON', (0, 18))
# (2400, 'https://www.coursera.org/learn/design-thinking-', 'PERSON', (1373, 1420))
# (2404, 'Bitmoji', 'PERSON', (3227, 3234))
# (2404, 'Mustafeez', 'PERSON', (2926, 2935))
# (2404, 'Snapchat', 'PERSON', (3270, 3278))
# (2404, 'Zahra', 'PERSON', (3120, 3125))
# (2404, 'Zohair  Mustafeez', 'PERSON', (2990, 3007))
# (2405, 'bin lorry', 'PERSON', (3146, 3155))
# (2405, 'bin overnight', 'PERSON', (3089, 3102))
# (2405, 'storytelling1', 'PERSON', (1170, 1183))
# (2409, 'James', 'PERSON', (2455, 2462))
# (2413, 'Maite Garza\n\nReflection', 'PERSON', (0, 23))
# (2414, 'Ahn', 'PERSON', (51, 54))
# (2415, 'Assignment- Reflection\n\nChallenge', 'PERSON', (16, 49))
# (2416, 'Scrum Model', 'PERSON', (2450, 2461))
# (2419, 'Cerner', 'PERSON', (146, 152))
# (2419, 'Cerner', 'PERSON', (3091, 3097))
# (2419, 'EMR', 'PERSON', (240, 243))
# (2419, 'EMR', 'PERSON', (1305, 1308))
# (2419, 'EMR', 'PERSON', (2357, 2360))
# (2419, 'EMR', 'PERSON', (2620, 2623))
# (2422, 'William B. Crane  Reflection: Visualization     Our Challenge and Tool Selection', 'PERSON', (0, 80))
# (2440, 'Cesar Viteri Zorondo', 'PERSON', (4283, 4305))
# (2442, 'INSIGHT', 'PERSON', (1810, 1817))
# (2445, 'Manus Mokarakul', 'PERSON', (2839, 2854))
# (2455, 'INSIGHT', 'PERSON', (1987, 1994))
# (2455, 'VISUALIZATION', 'PERSON', (0, 13))
# (2456, 'Jon Koh', 'PERSON', (1896, 1903))
# (2456, 'Jon Koh\n\nReflection', 'PERSON', (0, 19))
# (2458, 'Jessica Hernández Cadó\n\nChallenge & Selection', 'PERSON', (29, 74))
# (2466, 'Terri Trespicio |', 'PERSON', (435, 452))
# (2468, 'KRA', 'PERSON', (4352, 4355))
# (2468, 'Vison', 'PERSON', (156, 161))
# (2472, 'Wendy', 'PERSON', (2896, 2901))
# (2479, 'Jody Snodgrass\n\nChallenge', 'PERSON', (33, 58))
# (2479, 'Tableau', 'PERSON', (1102, 1109))
# (2479, 'Tableau', 'PERSON', (2909, 2916))
# (2480, 'Nasser Mohd Salah', 'PERSON', (1910, 1929))
# (2481, 'difﬁculties', 'PERSON', (947, 958))
# (2483, 'ﬁeld', 'PERSON', (170, 174))
# (2489, 'kpi', 'PERSON', (984, 987))
# (2491, 'aslo', 'PERSON', (3266, 3270))
# (2496, 'Miro', 'PERSON', (1339, 1343))
# (2496, 'Miro', 'PERSON', (2099, 2103))
# (2496, 'Miro', 'PERSON', (3174, 3178))
# (2498, 'Debbie', 'PERSON', (2305, 2315))
# (2498, 'Debbie', 'PERSON', (4348, 4354))
# (2498, 'Debbie', 'PERSON', (7297, 7303))
# (2498, 'Marian\t\r \xa0Moore', 'PERSON', (1697, 1712))
# (2498, 'Mind-\xad‐Mapping', 'PERSON', (1633, 1647))
# (2500, 'Meister', 'PERSON', (1065, 1072))
# (2500, 'Meister', 'PERSON', (1533, 1540))
# (2500, 'Meister Task', 'PERSON', (1667, 1679))
# (2504, 'Sebastian Menendez  Design Thinking', 'PERSON', (0, 35))
# (2505, 'Kaizen', 'PERSON', (1782, 1788))
# (2511, 'Marian  Moore', 'PERSON', (1739, 1752))
# (2521, 'Desai', 'PERSON', (34, 39))
# (2523, 'Alﬁe', 'PERSON', (2947, 2951))
# (2523, 'Duc Do  Design Thinking for Innovation', 'PERSON', (0, 38))
# (2523, 'Harry Potter', 'PERSON', (1232, 1244))
# (2523, 'Harry Potter ﬁlm', 'PERSON', (1716, 1732))
# (2529, 'Superman', 'PERSON', (190, 198))
# (2538, 'Che', 'PERSON', (3583, 3586))
# (2538, 'Smokey Mo', 'PERSON', (1688, 1697))
# (2538, 'Smokey Mo', 'PERSON', (2804, 2813))
# (2541, 'Mario', 'PERSON', (1500, 1505))
# (2544, 'Ed Hesse', 'PERSON', (1270, 1278))
# (2545, 'Amelia Crabtree', 'PERSON', (28, 43))
# (2548, 'al  least 10', 'PERSON', (2650, 2662))
# (2552, 'Franken', 'PERSON', (1131, 1138))
# (2555, 'Tim', 'PERSON', (6273, 6276))
# (2557, 'Calvin Klein', 'PERSON', (380, 392))
# (2557, 'Spencers', 'PERSON', (366, 374))
# (2558, 'INSIGHT', 'PERSON', (2664, 2671))
# (2560, 'I´m', 'PERSON', (249, 252))
# (2569, 'Mindmap', 'PERSON', (1787, 1794))
# (2572, 'Lena\tHartikainen', 'PERSON', (5133, 5149))
# (2577, 'Fig', 'PERSON', (1014, 1017))
# (2586, 'Selection.\u200b', 'PERSON', (1050, 1061))
# (2587, 'improven', 'PERSON', (2289, 2297))
# (2591, 'ANDREA ROMANO', 'PERSON', (76, 89))
# (2592, 'VISUALIZATION', 'PERSON', (0, 13))
# (2592, 'Vega', 'PERSON', (877, 881))
# (2592, 'Vega', 'PERSON', (1667, 1671))
# (2592, 'ggplot2', 'PERSON', (671, 678))
# (2594, 'Law', 'PERSON', (228, 231))
# (2594, 'Law', 'PERSON', (2951, 2954))
# (2601, 'INSIGHT', 'PERSON', (1455, 1462))
# (2603, 'staﬀ', 'PERSON', (614, 618))
# (2612, 'Navghare', 'PERSON', (3343, 3351))
# (2612, 'Navghare', 'PERSON', (5478, 5486))
# (2627, 'cipants', 'PERSON', (2708, 2715))
# (2628, 'Ferrary', 'PERSON', (4709, 4716))
# (2628, 'afford\u200b', 'PERSON', (4948, 4955))
# (2631, 'Dergilik', 'PERSON', (316, 324))
# (2631, 'Dergilik', 'PERSON', (326, 334))
# (2631, 'Dergilik', 'PERSON', (1563, 1571))
# (2631, 'skecthed', 'PERSON', (829, 837))
# (2634, 'Learning Questionnarie', 'PERSON', (977, 999))
# (2638, 'VISUALIZATION', 'PERSON', (1, 14))
# (2639, 'VISUALIZATION', 'PERSON', (1711, 1724))
# (2640, 'KAUST', 'PERSON', (175, 180))
# (2648, 'Alessandro', 'PERSON', (322, 332))
# (2648, 'Alessandro', 'PERSON', (2029, 2039))
# (2648, 'VISUALIZATION', 'PERSON', (0, 13))
# (2650, 'breaktime', 'PERSON', (2343, 2352))
# (2654, 'Insigth', 'PERSON', (1566, 1573))
# (2654, 'ampathy', 'PERSON', (2432, 2439))
# (2657, 'Raj Raj', 'PERSON', (27, 34))
# (2661, 'Capgemeni', 'PERSON', (1290, 1299))
# (2662, 'Deep', 'PERSON', (1451, 1455))
# (2662, 'Mindmap', 'PERSON', (1681, 1688))
# (2666, 'VISUALIZATION', 'PERSON', (885, 898))
# (2668, 'Feith', 'PERSON', (1121, 1126))
# (2668, 'Feith', 'PERSON', (1129, 1134))
# (2668, 'Feith', 'PERSON', (1476, 1481))
# (2672, 'Asif Khan\n\nDesign Thinking', 'PERSON', (50, 76))
# (2676, '.My', 'PERSON', (178, 181))
# (2690, 'Saraj Chavda', 'PERSON', (0, 12))
# (2692, 'King Arthur', 'PERSON', (4818, 4829))
# (2693, 'Hindi', 'PERSON', (1430, 1435))
# (2693, 'Imanni', 'PERSON', (756, 762))
# (2693, 'Oversimplified', 'PERSON', (3785, 3799))
# (2695, 'organigrams', 'PERSON', (801, 812))
# (2696, 'GPJ', 'PERSON', (5250, 5253))
# (2699, 'help(i.e', 'PERSON', (542, 550))
# (2700, 'Pricy', 'PERSON', (1680, 1685))
# (2700, 'Surfed', 'PERSON', (3013, 3019))
# (2702, 'Sankey', 'PERSON', (4581, 4587))
# (2705, 'Coincidentaly,\u200b', 'PERSON', (3910, 3925))
# (2705, 'Design\u200b \u200bthinking\u200b \u200bhas\u200b \u200bshown\u200b', 'PERSON', (4527, 4559))
# (2705, 'I\u200b \u200bwould\u200b \u200blike\u200b', 'PERSON', (4817, 4834))
# (2705, 'Lastly,\u200b \u200bI\u200b \u200bpicked\u200b \u200bout\u200b', 'PERSON', (3006, 3033))
# (2705, 'Maria', 'PERSON', (5227, 5232))
# (2705, 'Maria Rodriguez \u200bshares\u200b', 'PERSON', (1397, 1421))
# (2705, '\u200bI\u200b', 'PERSON', (1312, 1315))
# (2705, '\u200bI\u200b \u200bnoticed\u200b', 'PERSON', (4924, 4937))
# (2705, '\u200ba', 'PERSON', (5429, 5433))
# (2705, '\u200bas\u200b', 'PERSON', (5001, 5005))
# (2705, '\u200ba\xa0 lot\u200b \u200bof\u200b', 'PERSON', (4283, 4296))
# (2705, '\u200ba\u200b', 'PERSON', (658, 661))
# (2705, '\u200ba\u200b', 'PERSON', (4040, 4043))
# (2705, '\u200bdescribe\xa0 three\u200b \u200bdifferent\u200b', 'PERSON', (2304, 2333))
# (2705, '\u200bduring\u200b \u200binterviews,\u200b \u200band\u200b \u200btheir\u200b', 'PERSON', (2203, 2239))
# (2705, '\u200bhas\u200b \u200bbeen\u200b \u200brunning\u200b', 'PERSON', (451, 473))
# (2705, '\u200bimmediately\u200b \u200bafter\u200b \u200btheir\u200b \u200bone\u200b', 'PERSON', (944, 979))
# (2705, '\u200bof\u200b \u200bneed', 'PERSON', (551, 561))
# (2705, '\u200btakes\u200b', 'PERSON', (3858, 3865))
# (2705, '\u200btraining.\u200b \u200bTherefore,\u200b', 'PERSON', (988, 1012))
# (2705, '\u200btrust\u200b \u200bbetween\u200b \u200bus\u200b', 'PERSON', (590, 612))
# (2705, '\u200bwe', 'PERSON', (4022, 4025))
# (2705, '\u200bworking\u200b \u200bexperience', 'PERSON', (1706, 1727))
# (2705, '\u200bwould', 'PERSON', (5542, 5548))
# (2707, '•JOB', 'PERSON', (0, 4))
# (2711, 'Loredana Abidin', 'PERSON', (25, 40))
# (2714, 'Edgar Munoz\n\nChallenge & Selection', 'PERSON', (28, 62))
# (2718, 'coursea', 'PERSON', (2260, 2267))
# (2722, 'Adam Filip  Project', 'PERSON', (38, 57))
# (2722, 'Adam Filip  Project', 'PERSON', (3510, 3529))
# (2722, 'Saman', 'PERSON', (2779, 2784))
# (2722, 'Saman', 'PERSON', (3691, 3696))
# (2722, 'Saman', 'PERSON', (3860, 3865))
# (2722, 'Saman', 'PERSON', (4581, 4586))
# (2722, 'Saman', 'PERSON', (4735, 4740))
# (2725, 'CAUTIONS', 'PERSON', (1187, 1195))
# (2726, 'comittment', 'PERSON', (2198, 2208))
# (2727, 'Carter Garcia am', 'PERSON', (11, 27))
# (2734, 'Claro', 'PERSON', (382, 387))
# (2746, 'Agile Scrum  Framework', 'PERSON', (1525, 1547))
# (2746, 'Agile Scrum Framework', 'PERSON', (1627, 1648))
# (2755, 'Hats', 'PERSON', (2681, 2685))
# (2756, 'Eliud  Kipchoge', 'PERSON', (1688, 1703))
# (2763, 'FOUO', 'PERSON', (23, 27))
# (2769, 'Daniela Sangineto\n\nStudent', 'PERSON', (72, 98))
# (2769, 'Ruben Soria  matthew72@hotmail.com\n\nCourse Assignment - Mind', 'PERSON', (101, 161))
# (2771, 'Law', 'PERSON', (722, 725))
# (2771, 'Law', 'PERSON', (877, 880))
# (2773, 'al least 1.5 meter', 'PERSON', (2340, 2358))
# (2774, 'Daan', 'PERSON', (2472, 2476))
# (2774, 'LKG', 'PERSON', (831, 834))
# (2774, 'Sevai Shanthi  Matriculation', 'PERSON', (689, 717))
# (2774, 'Sevai Shanthi Matriculation', 'PERSON', (754, 781))
# (2776, '\u200bWill customers\u200b', 'PERSON', (1688, 1704))
# (2790, 'architecture5', 'PERSON', (2132, 2145))
# (2790, 'assumptions8', 'PERSON', (2748, 2760))
# (2791, 'Mari Ahmad', 'PERSON', (12, 22))
# (2793, 'Md Aktar | DESIGN THINKING', 'PERSON', (0, 26))
# (2794, 'Ourense', 'PERSON', (1434, 1441))
# (2799, 'card adminstrator', 'PERSON', (1733, 1750))
# (2800, 'kamrup', 'PERSON', (992, 998))
# (2804, 'Maicol Toro', 'PERSON', (0, 11))
# (2807, 'Luciano Rodrigues', 'PERSON', (2386, 2403))
# (2808, 'Mindmap', 'PERSON', (2341, 2348))
# (2808, 'Mindmap', 'PERSON', (2798, 2805))
# (2814, 'Ricardo Brito\n\nChallenge', 'PERSON', (16, 40))
# (2815, 'Kala karivelan', 'PERSON', (658, 672))
# (2818, 'Valentine', 'PERSON', (2502, 2511))
# (2821, 'Bloodline', 'PERSON', (32, 41))
# (2824, 'Longread Longread', 'PERSON', (3957, 3974))
# (2825, 'azimuthal', 'PERSON', (604, 613))
# (2828, 'James Gray', 'PERSON', (3267, 3277))
# (2830, 'Jorge Oliva\n\nDesign', 'PERSON', (33, 52))
# (2832, 'create2', 'PERSON', (2338, 2345))
# (2837, '1.00ct', 'PERSON', (297, 303))
# (2842, 'Md Hamid', 'PERSON', (2857, 2867))
# (2845, 'VISUALIZATION', 'PERSON', (0, 13))
# (2861, 'Nayarit', 'PERSON', (138, 145))
# (2871, 'Bora', 'PERSON', (1813, 1817))
# (2879, 'learnig', 'PERSON', (3760, 3767))
# (2879, 'learnig', 'PERSON', (4595, 4602))
# (2888, 'Dave Gray', 'PERSON', (905, 914))
# (2889, 'Insigth', 'PERSON', (903, 910))
# (2896, 'Project DIM', 'PERSON', (2339, 2350))
# (2897, 'Minginui', 'PERSON', (122, 130))
# (2897, 'Minginui', 'PERSON', (316, 324))
# (2897, 'Minginui', 'PERSON', (4953, 4961))
# (2897, 'Minginui  Village', 'PERSON', (3989, 4006))
# (2897, 'Minginui Village', 'PERSON', (642, 658))
# (2897, 'Minginui Village', 'PERSON', (981, 997))
# (2897, 'Minginui Village', 'PERSON', (4266, 4282))
# (2897, 'Minginui Village', 'PERSON', (7735, 7751))
# (2897, 'Minginui Village', 'PERSON', (9625, 9641))
# (2897, 'Ngati Whare', 'PERSON', (694, 705))
# (2897, 'Ngāputahi', 'PERSON', (146, 155))
# (2897, 'Ngāputahi', 'PERSON', (340, 349))
# (2910, 'Larry Leifer', 'PERSON', (374, 386))
# (2910, 'Michael Lewrick', 'PERSON', (345, 360))
# (2913, 'David Stevenson', 'PERSON', (28, 43))
# (2934, 'Leancorner', 'PERSON', (3650, 3660))
# (2939, 'bigin', 'PERSON', (1048, 1053))
# (2939, 'somthig', 'PERSON', (957, 964))
# (2939, 'talck', 'PERSON', (589, 594))
# (2939, 'trasforme', 'PERSON', (622, 631))
# (2947, 'Gve ondt', 'PERSON', (1211, 1219))
# (2947, 'almady', 'PERSON', (715, 721))
# (2947, 'ldeas', 'PERSON', (937, 942))
# (2947, 'mprow', 'PERSON', (666, 673))
# (2947, 'tooh lke', 'PERSON', (1328, 1336))
# (2947, 'wah simpie', 'PERSON', (1314, 1324))
# (2954, 'VISUALIZATION      Visualization', 'PERSON', (0, 32))
# (2956, 'Product Construct  o', 'PERSON', (1154, 1174))
# (2960, 'tha', 'PERSON', (1534, 1537))
# (2968, 'My challange', 'PERSON', (313, 325))
# (2972, 'Scrum Master', 'PERSON', (3125, 3137))
# (2972, 'Sysmtem', 'PERSON', (2294, 2301))
# (2977, 'Rice', 'PERSON', (1791, 1795))
# ...
# (21987, 'it.an', 'URL', (184, 189))
# (21988, 'David Gray’s', 'PERSON', (1356, 1368))
# (21989, 'Jairo Chavez', 'PERSON', (38, 50))
# (21994, '..et', 'URL', (823, 827))
# (21999, 'Buddha', 'PERSON', (1943, 1949))
# (21999, 'Napoleon Hill', 'PERSON', (2332, 2345))
# (22002, 'Maria S. Zvezdkina', 'PERSON', (2783, 2801))
# (22005, 'Angela\t\r \xa0Mayer', 'PERSON', (3882, 3897))
# (22005, 'http://www.danroam.com/assets/pdf/tools/TBOTN_6x6.pdf.', 'URL', (5732, 5786))
# (22007, 'twofour54.com', 'URL', (164, 177))
# (22007, 'yusuf.buti@twofour54.com', 'EMAIL_ADDRESS', (153, 177))
# (22021, 'Chad Knipschild', 'PERSON', (34, 49))
# (22022, 'Fernanda Fierro', 'PERSON', (0, 15))
# (22024, 'Moses', 'PERSON', (822, 827))
# (22027, 'michael01@yahoo.com', 'EMAIL_ADDRESS', (12, 31))
# (22027, 'vs.de', 'URL', (6845, 6850))
# (22027, 'yahoo.com', 'URL', (22, 31))
# (22035, 'more.fi', 'URL', (1793, 1800))
# (22037, 'Gebbia', 'PERSON', (526, 532))
# (22037, 'Gebbia', 'PERSON', (718, 724))
# (22037, 'Gebbia', 'PERSON', (993, 999))
# (22037, 'Graham', 'PERSON', (707, 713))
# (22037, 'Graham', 'PERSON', (982, 988))
# (22037, 'Joe Gebbia', 'PERSON', (303, 313))
# (22037, 'Paul Graham', 'PERSON', (318, 329))
# (22038, 'Darwin', 'PERSON', (2570, 2576))
# (22042, 'Diego Moreno', 'PERSON', (1525, 1537))
# (22042, 'Grandma', 'PERSON', (2056, 2063))
# (22054, 'https://www.mural.co/', 'URL', (132, 153))
# (22054, 'https://www.mural.co/templates/storyboarding-2', 'URL', (662, 708))
# (22060, 'Angela Myer', 'PERSON', (971, 982))
# (22063, 'Monalisa', 'PERSON', (1206, 1214))
# (22068, 'question.An', 'URL', (2399, 2410))
# (22071, 'Terry Pratchett', 'PERSON', (139, 154))
# (22076, 'not.Th', 'URL', (101, 107))
# (22076, 'others.Th', 'URL', (73, 82))
# (22078, 'JOHN LEWIS', 'PERSON', (0, 10))
# (22088, 'María José Reyes', 'PERSON', (93, 109))
# (22089, 'Angela Myer', 'PERSON', (804, 815))
# (22092, 'Christian Hoffmeister', 'PERSON', (1261, 1282))
# (22095, 'Benjamin Banneker', 'PERSON', (4212, 4229))
# (22096, 'https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/lsFRa/mind-', 'URL', (2054, 2142))
# (22097, 'Geoff', 'PERSON', (900, 905))
# (22101, 'Geoff', 'PERSON', (831, 836))
# (22107, 'Andre Martin', 'PERSON', (3821, 3833))
# (22122, 'Angela Myer', 'PERSON', (1490, 1501))
# (22124, 'Luke', 'PERSON', (1430, 1434))
# (22124, 'Luke', 'PERSON', (1436, 1440))
# (22125, 'Vikram', 'PERSON', (3622, 3628))
# (22126, 'Angela Myer', 'PERSON', (1043, 1054))
# (22126, 'Myer', 'PERSON', (1130, 1134))
# (22127, 'Ryan Johnson', 'PERSON', (32, 44))
# (22127, 'Ryan Johnson', 'PERSON', (3318, 3330))
# (22127, 'Ryan Johnson', 'PERSON', (4455, 4467))
# (22130, 'Shankaracharya', 'PERSON', (2600, 2614))
# (22130, 'Shankaracharya', 'PERSON', (2860, 2874))
# (22130, 'Vidyottama', 'PERSON', (3301, 3311))
# (22138, 'Deepak Thakur', 'PERSON', (144, 157))
# (22140, 'https://www.designthinkingformobility.org/wp-', 'URL', (679, 724))
# (22146, 'B.Sc', 'URL', (975, 979))
# (22147, '1348869811', 'PHONE_NUMBER', (5002, 5012))
# (22147, 'Francesca Hussain’s', 'PERSON', (1572, 1591))
# (22147, 'LifeHacker.com', 'URL', (4729, 4743))
# (22147, 'Melanie \xa0 Pinola', 'PERSON', (4710, 4726))
# (22147, 'MindTools.com', 'URL', (4850, 4863))
# (22147, 'http://lifehacker.com/how-to-use-mind-maps-to-unleash-your-', 'URL', (4924, 4983))
# (22147, 'iMindMap.com', 'URL', (4772, 4784))
# (22149, '1.Th', 'URL', (30, 34))
# (22149, '2.Int', 'URL', (5300, 5305))
# (22149, '2.Th', 'URL', (1737, 1741))
# (22149, '3.App', 'URL', (3292, 3297))
# (22149, '4.In', 'URL', (3994, 3998))
# (22154, 'manner.Al', 'URL', (962, 971))
# (22154, 'manner.It', 'URL', (1468, 1477))
# (22154, 'plan.In', 'URL', (230, 237))
# (22154, 'wordings.Si', 'URL', (618, 629))
# (22166, 'Giovanni De Maio', 'PERSON', (12, 28))
# (22176, 'Geoff', 'PERSON', (3300, 3305))
# (22176, 'George', 'PERSON', (3289, 3295))
# (22177, 'Odysseus', 'PERSON', (739, 747))
# (22181, 'Natalie   Portman', 'PERSON', (2786, 2803))
# (22181, 'Portman', 'PERSON', (2540, 2547))
# (22181, 'that.St', 'URL', (1985, 1992))
# (22185, 'workplace.Th', 'URL', (2218, 2230))
# (22188, 'perform.Th', 'URL', (539, 549))
# (22200, 'attractive.Fo', 'URL', (1465, 1478))
# (22200, 'others.Th', 'URL', (1209, 1218))
# (22200, 'relate.You', 'URL', (582, 592))
# (22202, '1.Ch', 'URL', (15, 19))
# (22202, '2.Se', 'URL', (859, 863))
# (22202, '3.App', 'URL', (1105, 1110))
# (22202, '4.In', 'URL', (1499, 1503))
# (22202, '5.App', 'URL', (1647, 1652))
# (22202, 'in.An', 'URL', (793, 798))
# (22202, 'organization.An', 'URL', (429, 444))
# (22203, 'Jody', 'PERSON', (1469, 1473))
# (22203, 'Jody', 'PERSON', (1475, 1479))
# (22203, 'Jody', 'PERSON', (1868, 1872))
# (22203, 'Jody', 'PERSON', (2011, 2015))
# (22203, 'Jody', 'PERSON', (2244, 2248))
# (22203, 'Jody', 'PERSON', (2558, 2562))
# (22203, 'Jody', 'PERSON', (2653, 2657))
# (22203, 'Jody', 'PERSON', (3129, 3133))
# (22203, 'Jody', 'PERSON', (3349, 3353))
# (22203, 'Jody', 'PERSON', (3405, 3409))
# (22204, 'Max Sea', 'PERSON', (1594, 1601))
# (22206, 'Madelon', 'PERSON', (506, 513))
# (22206, 'Madelon', 'PERSON', (1420, 1427))
# (22206, 'Madelon', 'PERSON', (2388, 2395))
# (22206, 'Madelon', 'PERSON', (4425, 4432))
# (22206, 'René', 'PERSON', (552, 556))
# (22206, 'René', 'PERSON', (4536, 4540))
# (22207, 'https://www.nngroup.com/articles/storyboards-visualize-ideas/', 'URL', (1483, 1544))
# (22208, 'Stephen Chan', 'PERSON', (6181, 6193))
# (22210, 'Amelia Earhart', 'PERSON', (2024, 2038))
# (22210, 'JK Rowling', 'PERSON', (1477, 1487))
# (22210, 'JK Rowling', 'PERSON', (2012, 2022))
# (22210, 'opportunity.Th', 'URL', (214, 228))
# (22210, 'time.It', 'URL', (491, 498))
# (22215, 'David Kelley', 'PERSON', (966, 978))
# (22217, '1.CH', 'URL', (0, 4))
# (22226, 'Arvind Vikash Kumar', 'PERSON', (3320, 3339))
# (22226, 'gmail.com', 'URL', (3357, 3366))
# (22226, 'katherinebrady@gmail.com', 'EMAIL_ADDRESS', (3342, 3366))
# (22235, 'David Gray’s', 'PERSON', (1546, 1558))
# (22235, 'solutions.App', 'URL', (908, 921))
# (22239, 'Tony Busan', 'PERSON', (132, 142))
# (22240, 'Norma Alvarado', 'PERSON', (61, 75))
# (22242, 'David Kelley', 'PERSON', (1114, 1126))
# (22245, 'handle.Th', 'URL', (3069, 3078))
# (22245, 'handle.Th', 'URL', (3434, 3443))
# (22245, 'look.St', 'URL', (3533, 3540))
# (22246, 'Ted', 'PERSON', (2162, 2165))
# (22250, 'Alice', 'PERSON', (1911, 1916))
# (22250, 'Alice', 'PERSON', (2083, 2088))
# (22250, 'Alice', 'PERSON', (2120, 2125))
# (22250, 'http://www.silverdialogue.co.uk/word_clouds.html', 'URL', (2508, 2556))
# (22250, 'www.quora.com/Did-Peter-Drucker-actually-say-culture-eats-strategy-for-breakfast-and-if-so-where-when', 'URL', (2403, 2504))
# (22250, 'www.wordclouds.com/', 'URL', (4351, 4370))
# (22255, '1.Ch', 'URL', (0, 4))
# (22255, '2.Tech', 'URL', (264, 270))
# (22255, '4.In', 'URL', (774, 778))
# (22255, '5.App', 'URL', (951, 956))
# (22256, 'Student.Th', 'URL', (41, 51))
# (22256, 'studies.Fi', 'URL', (209, 219))
# (22259, 'Jimmy', 'PERSON', (1666, 1671))
# (22259, 'Jimmy', 'PERSON', (1775, 1780))
# (22259, 'Jimmy', 'PERSON', (2343, 2348))
# (22262, 'Gretel', 'PERSON', (1204, 1210))
# (22262, 'Messi', 'PERSON', (958, 963))
# (22262, 'Steve', 'PERSON', (1532, 1537))
# (22264, 'John Ortiz', 'PERSON', (115, 125))
# (22271, 'Jeanne', 'PERSON', (1194, 1200))
# (22281, 'Andre Martin', 'PERSON', (3049, 3061))
# (22281, 'Ed Hess', 'PERSON', (7167, 7174))
# (22282, 'ort.It', 'URL', (4007, 4013))
# (22288, "Leonardo da Vinci's", 'PERSON', (489, 508))
# (22291, 'etc.In', 'URL', (988, 994))
# (22292, 'back.Sh', 'URL', (1839, 1846))
# (22292, 'hometown.Th', 'URL', (2908, 2919))
# (22294, 'a.Ge', 'URL', (1043, 1047))
# (22294, 'b.As', 'URL', (1122, 1126))
# (22294, 'c.Pr', 'URL', (1207, 1211))
# (22294, 'd.Pro', 'URL', (1264, 1269))
# (22294, 'details.Ma', 'URL', (413, 423))
# (22294, 'details.Ma', 'URL', (1609, 1619))
# (22301, 'Shultz', 'PERSON', (884, 890))
# (22301, 'Shultz', 'PERSON', (3445, 3451))
# (22303, 'Geoff', 'PERSON', (3638, 3643))
# (22320, 'Ana Melton', 'PERSON', (2891, 2901))
# (22326, 'research.Th', 'URL', (1546, 1557))
# (22328, 'problem.Th', 'URL', (3623, 3633))
# (22328, 'solved.Th', 'URL', (4151, 4160))
# (22329, 'Ed Hess', 'PERSON', (4180, 4187))
# (22332, 'https://www.mindmeister.com', 'URL', (1460, 1487))
# (22333, 'Akash Pandit', 'PERSON', (4971, 4983))
# (22333, 'catch.Th', 'URL', (2042, 2050))
# (22333, 'had.Now', 'URL', (807, 814))
# (22333, 'idea.So', 'URL', (466, 473))
# (22333, 'request.Now', 'URL', (2428, 2439))
# (22333, 'shade.So', 'URL', (2676, 2684))
# (22333, 'themselves.So', 'URL', (1650, 1663))
# (22339, 'David Gray’s', 'PERSON', (1498, 1510))
# (22345, 'Angela Myer', 'PERSON', (1187, 1198))
# (22360, 'seriously.Es', 'URL', (4276, 4288))
# (22364, 'Luis', 'PERSON', (1931, 1935))
# (22364, 'Luis', 'PERSON', (2085, 2089))
# (22364, 'him.Th', 'URL', (1998, 2004))
# (22371, 'http://www.designkit.org/methods', 'URL', (1506, 1538))
# (22375, 'Roger Martin', 'PERSON', (1009, 1021))
# (22384, '..Th', 'URL', (2858, 2862))
# (22384, '1.Cl', 'URL', (339, 343))
# (22386, 'Awang Chai', 'PERSON', (44, 54))
# (22386, 'Awang Chai', 'PERSON', (5824, 5834))
# (22391, 'Chris Carter', 'PERSON', (7412, 7424))
# (22391, 'Marion Moore', 'PERSON', (1226, 1238))
# (22401, 'Bryant', 'PERSON', (401, 407))
# (22401, 'Gianna', 'PERSON', (1079, 1085))
# (22401, 'James Harden', 'PERSON', (1329, 1341))
# (22401, 'Kobe Bryant', 'PERSON', (1050, 1061))
# (22401, 'Kobe Bryant’s', 'PERSON', (293, 306))
# (22401, 'Michael Jordan', 'PERSON', (1346, 1360))
# (22404, 'Justin George', 'PERSON', (1439, 1452))
# (22404, 'https://www.coursera.org/learn/uva-darden-design-thinking-', 'URL', (1501, 1559))
# (22404, 'https://www.coursera.org/learn/uva-darden-design-thinking-', 'URL', (2101, 2159))
# (22404, 'https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/xju53/visualization-', 'URL', (3386, 3483))
# (22406, 'Rita Saha', 'PERSON', (973, 982))
# (22409, 'https://www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/', 'URL', (1874, 1951))
# (22409, 'www.coursera.org/learn/uva-darden-design-thinking-innovation/lecture/W6tTs/the-meyouhealth-story-part-i-what-is', 'URL', (1557, 1668))
# (22414, 'Andreas Schmitz', 'PERSON', (1384, 1399))
# (22415, 'Ernest Shackleton', 'PERSON', (817, 834))
# (22419, 'Carlo Serra', 'PERSON', (0, 11))
# (22420, 'Taboo', 'PERSON', (2685, 2690))
# (22422, 'Ed \xa0Hess', 'PERSON', (4112, 4120))
# (22425, 'http://designresearchtechniques.com/casestudies/storytelling/', 'URL', (2539, 2600))
# (22425, 'https://www.coursera.org/learn/design-thinking-', 'URL', (1749, 1796))
# (22432, 'tools.Pe', 'URL', (533, 541))
# (22435, 'Angela Meyer', 'PERSON', (3496, 3508))
# (22439, 'Ed Hesse', 'PERSON', (1339, 1347))
# (22440, 'draw.io', 'URL', (2396, 2403))
# (22440, 'https://trello.com/', 'URL', (2013, 2032))
# (22440, 'https://www.draw.io', 'URL', (2424, 2443))
# (22443, '1.Com', 'URL', (1371, 1376))
# (22443, '3.Su', 'URL', (1412, 1416))
# (22443, '4.Solutions', 'URL', (1427, 1438))
# (22446, 'Andy Wilson', 'PERSON', (5068, 5079))
# (22447, 'i.e.by', 'URL', (2482, 2488))
# (22450, 'Pat Lopez', 'PERSON', (3738, 3747))
# (22450, "Pat Lopez's", 'PERSON', (1777, 1788))
# (22450, 'Pat Lopez’s', 'PERSON', (1085, 1096))
# (22450, 'Pat Lopez’s', 'PERSON', (5539, 5550))
# (22452, 'itself..so', 'URL', (1010, 1020))
# (22452, 'studies...in', 'URL', (844, 856))
# (22452, 'that...fo', 'URL', (253, 262))
# (22452, 'too..as', 'URL', (1684, 1691))
# (22453, 'come.in', 'URL', (4002, 4009))
# (22453, 'market.th', 'URL', (292, 301))
# (22453, 'possible.Th', 'URL', (4284, 4295))
# (22453, 'visualization.it', 'URL', (3694, 3710))
# (22456, 'bush', 'PERSON', (1529, 1533))
# (22459, 'Jacques Diouf', 'PERSON', (36, 49))
# (22471, 'Angela Mayer', 'PERSON', (821, 833))
# (22473, 'Tim  O’Brien', 'PERSON', (805, 817))
# (22479, 'Gerth', 'PERSON', (1458, 1463))
# (22479, 'Gerth', 'PERSON', (2116, 2121))
# (22479, 'themselves.As', 'URL', (3868, 3881))
# (22481, 'Beatriz Bron', 'PERSON', (532, 544))
# (22488, 'Aesop', 'PERSON', (1197, 1202))
# (22488, 'Justin Sotelo', 'PERSON', (2470, 2483))
# (22492, 'Omprakash Maurya', 'PERSON', (963, 979))
# (22492, 'https://www.youtube.com/watch?v=DCUcrfBKyeL', 'URL', (746, 789))
# (22495, 'Ghandy', 'PERSON', (2452, 2458))
# (22495, 'Kublai Khaidir', 'PERSON', (14, 28))
# (22495, 'life.Al', 'URL', (1236, 1243))
# (22496, 'Fabio Roman', 'PERSON', (0, 11))
# (22501, 'simplicity.In', 'URL', (311, 324))
# (22513, 'David Gray’s', 'PERSON', (1563, 1575))
# (22520, '1.It', 'URL', (992, 996))
# (22520, '2.It', 'URL', (1108, 1112))
# (22520, '4.It', 'URL', (1202, 1206))
# (22522, 'Furthur', 'PERSON', (223, 230))
# (22523, 'Maria Martinez', 'PERSON', (1645, 1659))
# (22526, 'Ogilvie', 'PERSON', (1372, 1379))
# (22539, 'David Kelley', 'PERSON', (772, 784))
# (22543, 'Sankey', 'PERSON', (951, 957))
# (22551, 'Andre Martin', 'PERSON', (954, 966))
# (22552, 'children.App', 'URL', (3265, 3277))
# (22553, 'Goldie Locks', 'PERSON', (2998, 3010))
# (22553, 'Goldie Locks', 'PERSON', (3210, 3222))
# (22560, "Leonardo da Vinci's", 'PERSON', (376, 395))
# (22566, 'David Gray’s', 'PERSON', (2039, 2051))
# (22571, 'Ed Hesse', 'PERSON', (1271, 1279))
# (22578, 'Md Abdulla', 'PERSON', (50, 60))
# (22579, 'Manuel Lima', 'PERSON', (1724, 1735))
# (22579, 'http://www.ted.com/talks/manuel_lima_a_visual_history_of_human_knowledge/transcript?language=', 'URL', (1901, 1994))
# (22582, 'agreement.Th', 'URL', (2826, 2838))
# (22582, 'available.Th', 'URL', (817, 829))
# (22582, 'depth.Al', 'URL', (3892, 3900))
# (22582, 'depth.So', 'URL', (518, 526))
# (22582, 'emojis.Th', 'URL', (1030, 1039))
# (22582, 'field.So', 'URL', (3727, 3735))
# (22582, 'make.So', 'URL', (1789, 1796))
# (22582, 'make.So', 'URL', (3362, 3369))
# (22582, 'members.Us', 'URL', (433, 443))
# (22582, 'need.Vi', 'URL', (2286, 2293))
# (22582, 'process.Th', 'URL', (2984, 2994))
# (22582, 'shown.Now', 'URL', (2090, 2099))
# (22582, 'target.Af', 'URL', (1604, 1613))
# (22582, 'them.Th', 'URL', (1404, 1411))
# (22582, 'thinking.It', 'URL', (154, 165))
# (22582, 'thinking.So', 'URL', (3242, 3253))
# (22582, 'topic.So', 'URL', (368, 376))
# (22582, 'way.So', 'URL', (3179, 3185))
# (22582, 'work.By', 'URL', (3661, 3668))
# (22585, 'Daniela Mora', 'PERSON', (3649, 3661))
# (22586, '2.cu', 'URL', (1048, 1052))
# (22586, '3.help', 'URL', (1282, 1288))
# (22586, '5.Im', 'URL', (1777, 1781))
# (22586, '7.fi', 'URL', (2138, 2142))
# (22587, 'Angela Myer', 'PERSON', (1323, 1334))
# (22587, 'Miguel Torres', 'PERSON', (40, 53))
# (22593, 'Bob', 'PERSON', (1872, 1875))
# (22595, 'invention.Th', 'URL', (206, 218))
# (22596, 'Cadabra.com', 'URL', (508, 519))
# (22596, 'Jeff Bezos', 'PERSON', (122, 132))
# (22596, 'Tom Walton', 'PERSON', (830, 840))
# (22599, 'it.Vi', 'URL', (2055, 2060))
# (22606, 'Michael Schumacher', 'PERSON', (2900, 2918))
# (22612, 'Wolf', 'PERSON', (2536, 2540))
# (22612, 'Wolf', 'PERSON', (4627, 4631))
# (22612, 'Woodsman', 'PERSON', (2670, 2678))
# (22616, 'Dean', 'PERSON', (2854, 2858))
# (22616, 'Ghemawat', 'PERSON', (2863, 2871))
# (22616, 'Jeff Dean', 'PERSON', (2625, 2634))
# (22616, 'Sanjay Ghemawat', 'PERSON', (2639, 2654))
# (22620, 'David Gray’s', 'PERSON', (3695, 3707))
# (22620, 'Kohlhammer', 'PERSON', (1104, 1114))
# (22627, 'Theodore Levitt', 'PERSON', (4157, 4172))
# (22628, 'https://www.nngroup.com/articles/ideation-in-practice/', 'URL', (1137, 1191))
# (22629, 'Dave', 'PERSON', (846, 850))
# (22629, 'Dave', 'PERSON', (1285, 1289))
# (22629, 'Jim', 'PERSON', (855, 858))
# (22629, 'Jim', 'PERSON', (1293, 1296))
# (22638, 'Gaudi', 'PERSON', (4534, 4539))
# (22638, 'Jeanne', 'PERSON', (4515, 4521))
# (22638, 'Marilyn Garzon', 'PERSON', (1072, 1086))
# (22648, '..Al', 'URL', (3256, 3260))
# (22649, 'eatery.By', 'URL', (1172, 1181))
# (22654, '29.An', 'URL', (1232, 1237))
# (22657, 'people.it', 'URL', (1750, 1759))
# (22660, 'Amina Koko', 'PERSON', (32, 42))
# (22660, 'Amina Koko', 'PERSON', (2442, 2452))
# (22661, 'Jake Knapp', 'PERSON', (501, 511))
# (22664, 'Andre Martin', 'PERSON', (1539, 1551))
# (22670, 'Carmen Garcia', 'PERSON', (781, 794))
# (22676, 'Buddha', 'PERSON', (1222, 1228))
# (22676, 'https://www.coursera.org/lecture/uva-darden-design-thinking-innovation/storytelling-', 'URL', (1353, 1437))
# (22677, '1.Ch', 'URL', (19, 23))
# (22677, '2.Se', 'URL', (298, 302))
# (22677, '3.In', 'URL', (665, 669))
# (22682, '635.Th', 'URL', (202, 208))
# (22682, 'challenge.Am', 'URL', (335, 347))
# (22682, 'ideas.An', 'URL', (419, 427))
# (22682, 'problem.Ad', 'URL', (661, 671))
# (22682, 'selected.Th', 'URL', (574, 585))
