# %%
import ast
from collections import Counter

name_set_true = set()
url_set_true = set()
email_set_true = set()
phoneNum_set_true = set()
location_set_true = set()

# processing true categories
true_categories = Counter()
with open('pii_entities.txt', 'r') as file:
    for line in file:
        line = line.strip()
        
        # convert the string to a tuple
        tup = ast.literal_eval(line)
        
        # Only process the first 500 docs
        doc_idx = tup[0]
        # if doc_idx < 15000:
        # increment this category's count in dictionary
        category = tup[2]
        true_categories[category] += 1
        
        new_tup = (tup[0],tup[1],tup[3])
        if category == 'NAME_STUDENT':
            name_set_true.add(new_tup)
        elif category == 'URL_PERSONAL':
            url_set_true.add(new_tup)
        elif category == 'EMAIL':
            email_set_true.add(new_tup)
        elif category == 'PHONE_NUM':
            phoneNum_set_true.add(new_tup)
        elif category == 'STREET_ADDRESS':
            location_set_true.add(new_tup)
        
# print categories
print("All true entites summary:")
for key, count in true_categories.items():
    print(f"{key}: {count}")
# Out:
# All true entites summary:
# NAME_STUDENT: 4394
# URL_PERSONAL: 352
# EMAIL: 111
# ID_NUM: 218
# USERNAME: 19
# PHONE_NUM: 14
# STREET_ADDRESS: 9

# %%
name_set_detected = set()
url_set_detected = set()
email_set_detected = set()
phoneNum_set_detected = set()
location_set_detected = set()

# processing detected categories
detected_categories = Counter()
with open('pii_entities_detected.txt', 'r') as file:
    for line in file:
        line = line.strip()
        
        # convert the string to a tuple
        tup = ast.literal_eval(line)
        
        # increment this category's count in dictionary
        category = tup[2]
        detected_categories[category] += 1
        
        new_tup = (tup[0],tup[1],tup[3])
        if category == 'PERSON':
            name_set_detected.add(new_tup)
        elif category == 'URL':
            url_set_detected.add(new_tup)
        elif category == 'EMAIL_ADDRESS':
            email_set_detected.add(new_tup)
        elif category == 'PHONE_NUMBER':
            phoneNum_set_detected.add(new_tup)
        elif category == 'LOCATION':
            location_set_detected.add(new_tup)

print("All detected entites summary:")
# print categories
for key, count in detected_categories.items():
    print(f"{key}: {count}")
# Out:
# All detected entites summary:
# PERSON: 18623
# URL: 4254
# LOCATION: 14227
# EMAIL_ADDRESS: 132
# PHONE_NUMBER: 85

# %%
# true categories: ID_NUM and USERNAME have no mapping
# Don't know whether STREET_ADDRESS (true) maps to LOCATION (detected)

# only calculating metrics for NAME_STUDENT/PERSON, URL_PERSONAL/URL, EMAIL/EMAIL_ADDRESS, PHONE_NUM/PHONE_NUMBER mappings
# STREET_ADDRESS/LOCATION is also tested below

# %%
def calculate_metrics(synthetic_set, analyzed_set):
    tp = 0
    fp = 0
    fn = 0
    
    for analyzed in analyzed_set:
        if analyzed in synthetic_set:
            tp += 1 # true PII, detected by presidio
            # print(f"TP: {analyzed}")
        else: # false PII, detected by presidio
            fp += 1
            # print(f"FP: {analyzed}")
    
    for synthetic in synthetic_set:
        if synthetic not in analyzed_set:
            fn += 1
            # print(f"FN: {synthetic}") 
    
    return tp, fp, fn

def calculate_metrics_set_method(synthetic_set, analyzed_set):
    # Exclude the entity type from the comparison
    true_set = set((i, start, end) for i, _, (start, end) in synthetic_set)
    detected_set = set((i, start, end) for i, _, (start, end) in analyzed_set)

    tp = true_set & detected_set
    fp = detected_set - true_set
    fn = true_set - detected_set

    tp_count = len(tp)
    fp_count = len(fp)
    fn_count = len(fn)
    
    return tp_count, fp_count, fn_count

def compute_precision_recall_f1(tp, fp, fn):
    precision = tp / (tp + fp) if tp + fp > 0 else 0
    recall = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0
    return precision, recall, f1

# %%
# Calculate TP, FP, FN, TN
# tp_n, fp_n, fn_n = calculate_metrics(name_set_true, name_set_detected)
# tp_u, fp_u, fn_u = calculate_metrics(url_set_true, url_set_detected)
# tp_e, fp_e, fn_e = calculate_metrics(email_set_true, email_set_detected)
# tp_p, fp_p, fn_p = calculate_metrics(phoneNum_set_true, phoneNum_set_detected)
# tp_l, fp_l, fn_l = calculate_metrics(location_set_true, location_set_detected)

tp_n, fp_n, fn_n = calculate_metrics_set_method(name_set_true, name_set_detected)
tp_u, fp_u, fn_u = calculate_metrics_set_method(url_set_true, url_set_detected)
tp_e, fp_e, fn_e = calculate_metrics_set_method(email_set_true, email_set_detected)
tp_p, fp_p, fn_p = calculate_metrics_set_method(phoneNum_set_true, phoneNum_set_detected)
tp_l, fp_l, fn_l = calculate_metrics_set_method(location_set_true, location_set_detected)

# Compute Precision, Recall, and F1 Score
precision_n, recall_n, f1_n = compute_precision_recall_f1(tp_n, fp_n, fn_n)
precision_u, recall_u, f1_u = compute_precision_recall_f1(tp_u, fp_u, fn_u)
precision_e, recall_e, f1_e = compute_precision_recall_f1(tp_e, fp_e, fn_e)
precision_p, recall_p, f1_p = compute_precision_recall_f1(tp_p, fp_p, fn_p)
precision_l, recall_l, f1_l = compute_precision_recall_f1(tp_l, fp_l, fn_l)

print("Summary of Precision, Recall, and F1 Score")
print(f"NAME_STUDENT    -- Precision: {precision_n:.4f}, Recall: {recall_n:.4f}, F1 Score: {f1_n:.4f}")
print(f"URL_PERSONAL    -- Precision: {precision_u:.4f}, Recall: {recall_u:.4f}, F1 Score: {f1_u:.4f}")
print(f"EMAIL           -- Precision: {precision_e:.4f}, Recall: {recall_e:.4f}, F1 Score: {f1_e:.4f}")
print(f"PHONE_NUM       -- Precision: {precision_p:.4f}, Recall: {recall_p:.4f}, F1 Score: {f1_p:.4f}")
print(f"STREET_ADDRESS  -- Precision: {precision_l:.4f}, Recall: {recall_l:.4f}, F1 Score: {f1_l:.4f}")
# Out:
# Summary of Precision, Recall, and F1 Score
# NAME_STUDENT    -- Precision: 0.1623, Recall: 0.6878, F1 Score: 0.2626
# URL_PERSONAL    -- Precision: 0.0691, Recall: 0.8352, F1 Score: 0.1277
# EMAIL           -- Precision: 0.8333, Recall: 0.9910, F1 Score: 0.9053
# PHONE_NUM       -- Precision: 0.1647, Recall: 1.0000, F1 Score: 0.2828
# STREET_ADDRESS  -- Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000

# %%
def print_likely_successful_entities(true_set, detected_set):
    output_list = []
    count = 0

    for entity_true in true_set:
        if entity_true not in detected_set:
            idx, entity_text, (start, end) = entity_true
            match_found = False  # Initialize a flag to track if a match is found

            for entity_detected in detected_set:
                idx_d, entity_text_d, (start_d, end_d) = entity_detected
                if idx == idx_d and (start == start_d or end == end_d):
                    count += 1
                    output_list.append(f"{entity_true} ---- {entity_detected}")
                    match_found = True  # Set the flag to True when a match is found
                    break  # No need to check further once a match is found

            if not match_found:  # Only add the original entity if no match was found
                output_list.append(str(entity_true))
    
    # Sort the output list by document index (idx)
    sorted_output = sorted(output_list, key=lambda x: int(x.split(",")[0][1:]))

    # Print the sorted output
    print(f"Out of {len(sorted_output)} entities for NAME category, {count} entities might have likely been successfully detected by Presidio.")
    for line in sorted_output:
        print(line)

# %%
print_likely_successful_entities(name_set_true, name_set_detected)
# Out:
# Out of 1372 entities for NAME category, 939 entities might have likely been successfully detected by Presidio.
# (7, 'Nathalie Sylla', (52, 66)) ---- (7, 'Nathalie Sylla\n\n', (52, 68))
# (80, 'Karol Ferreira', (2, 16)) ---- (80, 'Karol Ferreira\n\nREFLECTION - VISUALIZATION\n\nChallenge\n\nWorking', (2, 64))
# (88, 'Rakesh Singh', (61, 73)) ---- (88, 'Rakesh Singh\n\nChallenge', (61, 84))
# (99, 'Francesco Boscolo', (38, 55)) ---- (99, 'Francesco Boscolo\n\nChallenge', (38, 66))
# (109, 'Michael', (3336, 3343)) ---- (109, 'Michael  -', (3336, 3346))
# (109, 'Michael', (1300, 1307)) ---- (109, 'Michael  -', (1300, 1310))
# (109, 'Michael', (71, 78)) ---- (109, 'Michael  -', (71, 81))
# (112, 'Francisco Ferreira', (30, 48))
# (113, 'Rita', (0, 4))
# (123, 'Stefano Lovato', (156, 170)) ---- (123, 'Stefano Lovato\n\nMDI-191', (156, 179))
# (161, 'Juan Farid', (3758, 3768)) ---- (161, 'Juan Farid  ', (3758, 3770))
# (202, 'Danny Long', (0, 10)) ---- (202, 'Danny Long Reflection', (0, 21))
# (204, 'Deiby', (29, 34))
# (205, 'Azeez Olaide', (3225, 3237)) ---- (205, 'Azeez Olaide - Design Thinking for Innovation - 01.04.2020', (3225, 3283))
# (205, 'Azeez Olaide', (0, 12)) ---- (205, 'Azeez Olaide - Design Thinking for Innovation - 01.04.2020', (0, 58))
# (214, 'Fareed Ponce', (28, 40)) ---- (214, 'Fareed Ponce\n\nChallenge', (28, 51))
# (288, 'Rajinder Santos', (0, 15))
# (324, 'Zia', (79, 82))
# (331, 'Yeimy Molina', (0, 12)) ---- (331, 'Yeimy Molina  ', (0, 14))
# (334, 'Andres Diaz', (0, 11)) ---- (334, 'Andres Diaz\n\nReflection', (0, 23))
# (377, 'Juan Hernandez', (17, 31))
# (470, 'Daniel', (0, 6))
# (609, 'Alex Swetha', (409, 420)) ---- (609, 'Alex Swetha  ', (409, 422))
# (609, 'Alex Bravo', (438, 448))
# (609, 'Tino Swetha', (290, 301)) ---- (609, 'Tino Swetha  ', (290, 303))
# (609, 'Gabriel Bravo', (112, 125))
# (669, 'Miriam Durango', (0, 14)) ---- (669, 'Miriam Durango\n\nDesign Thinking', (0, 31))
# (671, 'Amparo', (65, 71))
# (689, 'Carlos', (53, 59)) ---- (689, 'Carlos Interviewee Name', (53, 76))
# (714, 'Edgar Lara', (18, 28)) ---- (714, 'Edgar Lara\n\n', (18, 30))
# (730, 'Ahmed Saeed', (19, 30)) ---- (730, 'Ahmed Saeed\n\nAhmed Saeed\n\nDESIGN', (19, 51))
# (730, 'Ahmed Saeed', (32, 43))
# (733, 'Nestor Puerta', (0, 13)) ---- (733, 'Nestor Puerta\n\nReflection', (0, 25))
# (736, 'Joao Courtois', (97, 110)) ---- (736, 'Joao Courtois\n\nElements', (97, 120))
# (1125, 'Christian Schmidt', (3397, 3414)) ---- (1125, 'Schmidt', (3407, 3414))
# (1125, 'Christian Schmidt', (13, 30)) ---- (1125, 'Schmidt', (23, 30))
# (1185, 'Florian Richter', (36, 51)) ---- (1185, 'Florian Richter\n\nDate', (36, 57))
# (1201, 'Hannah Ali', (48, 58)) ---- (1201, 'Hannah Ali\t\r \xa0\t\r \xa0 Brazilian', (48, 76))
# (1226, 'Jose Suarez', (40, 51)) ---- (1226, 'Jose Suarez                    ', (40, 71))
# (1290, 'Olivier Collet', (3182, 3196)) ---- (1290, 'Olivier Collet 2/2', (3182, 3200))
# (1293, 'Mohd Javed', (64, 74)) ---- (1293, 'Mohd Javed\n\nChallenge', (64, 85))
# (1352, 'Katy Rivera', (31, 42))
# (1445, 'Doaa', (937, 941))
# (1445, 'Doaa', (0, 4))
# (1445, 'Doaa', (323, 327))
# (1445, 'Doaa', (2530, 2534))
# (1546, 'Aline Lima', (40, 50)) ---- (1546, 'Aline Lima\n\nAssignment Reflection –', (40, 75))
# (1546, 'Aline Lima', (3338, 3348)) ---- (1546, 'Aline Lima\n\nAssignment Reflection –', (3338, 3373))
# (1551, 'Puja', (0, 4))
# (1607, 'German Franco', (35, 48))
# (1658, 'Rakesh Rajput', (65, 78)) ---- (1658, 'Rakesh Rajput\n\nChallenge', (65, 89))
# (1764, 'Anrudh Clifton', (19, 33))
# (1790, 'Shirley Medina', (51, 65)) ---- (1790, 'Shirley Medina\n\nCompany', (51, 74))
# (1792, 'Jan Moradi', (49, 59))
# (1802, 'Ilir Ahmed', (6371, 6381)) ---- (1802, 'Ilir Ahmed  Profesor de Lengua', (6371, 6401))
# (1802, 'Ilir Ahmed', (3698, 3708)) ---- (1802, 'Ilir Ahmed  Profesor de Lengua', (3698, 3728))
# (1802, 'Ilir Ahmed', (0, 10)) ---- (1802, 'Ilir Ahmed  Profesor de Lengua', (0, 30))
# (1810, 'Shailesh Jain', (73, 86)) ---- (1810, 'Shailesh Jain\n\n1', (73, 89))
# (1814, 'Waliur Aslam', (35, 47))
# (2058, 'Ravneet Williams', (60, 76)) ---- (2058, 'Ravneet Williams  ', (60, 78))
# (2061, 'Pushpalatha Bisht', (52, 69))
# (2337, 'Mahmoud Callejas', (3362, 3378)) ---- (2337, 'Mahmoud Callejas  ', (3362, 3380))
# (2672, 'Asif Khan', (50, 59)) ---- (2672, 'Asif Khan\n\nDesign Thinking', (50, 76))
# (2707, 'Muhammed', (12, 20))
# (2714, 'Edgar Munoz', (28, 39)) ---- (2714, 'Edgar Munoz\n\nChallenge & Selection', (28, 62))
# (2722, 'Saman', (1111, 1116)) ---- (2722, 'Saman Jaramillo', (1111, 1126))
# (2722, 'Adam Filip', (38, 48)) ---- (2722, 'Adam Filip  Project', (38, 57))
# (2722, 'Adam Filip', (3510, 3520)) ---- (2722, 'Adam Filip  Project', (3510, 3529))
# (2727, 'Carter Garcia', (11, 24)) ---- (2727, 'Carter Garcia am', (11, 27))
# (2734, 'Junior Diaz', (30, 41))
# (2769, 'Ruben Soria', (101, 112)) ---- (2769, 'Ruben Soria  matthew72@hotmail.com\n\nCourse Assignment - Mind', (101, 161))
# (2793, 'Md Aktar', (0, 8)) ---- (2793, 'Md Aktar | DESIGN THINKING', (0, 26))
# (2814, 'Ricardo Brito', (16, 29)) ---- (2814, 'Ricardo Brito\n\nChallenge', (16, 40))
# (2830, 'Jorge Oliva', (33, 44)) ---- (2830, 'Jorge Oliva\n\nDesign', (33, 52))
# (2842, 'Md Hamid', (2857, 2865)) ---- (2842, 'Md Hamid\n\n', (2857, 2867))
# (2915, 'Carolina Finetti', (154, 170))
# (3003, 'Guddu Singh', (0, 11)) ---- (3003, 'Guddu Singh Reflection of Design Tool Application\n\nChallenge', (0, 60))
# (3202, 'Ahmed Salem', (259, 270))
# (3211, 'Fabio Sameh', (56, 67)) ---- (3211, 'Fabio Sameh\n\nChallenge', (56, 78))
# (3214, 'Ashley', (1756, 1762))
# (3214, 'Ashley', (1524, 1530))
# (3236, 'Carmen Falchi', (0, 13)) ---- (3236, 'Carmen Falchi\n\nChallenge & Selection\n\nDescription', (0, 49))
# (3285, 'Francisca Rojas', (0, 15)) ---- (3285, 'Francisca Rojas’s', (0, 17))
# (3328, 'Karim Elnazer', (33, 46)) ---- (3328, 'Karim Elnazer\n\nChallenge', (33, 57))
# (3411, 'Mduduzi Dladla', (0, 14)) ---- (3411, 'Mduduzi Dladla\n\nMy Reflection – Visualisation\n\nIntroduction', (0, 59))
# (3427, 'Rhiannon Karim', (129, 143)) ---- (3427, 'Rhiannon Karim\n\nChallenge', (129, 154))
# (3427, 'Rhiannon Karim', (37, 51)) ---- (3427, 'Rhiannon Karim\n\nKatia Rania\n\nDesign Thinking', (37, 81))
# (3446, 'Shivam Giri', (42, 53)) ---- (3446, 'Shivam Giri\n\nChallenge', (42, 64))
# (3518, 'Enrique Olaya', (47, 60)) ---- (3518, 'Enrique Olaya\n\nID', (47, 64))
# (3559, 'Esteban Sanhueza', (2394, 2410)) ---- (3559, 'Esteban Sanhueza - Scrum', (2394, 2418))
# (3559, 'Esteban Sanhueza', (0, 16)) ---- (3559, 'Esteban Sanhueza - Scrum', (0, 24))
# (3572, 'Guillaume', (0, 9)) ---- (3572, 'Guillaume -Visualization\n\n', (0, 26))
# (3579, 'Desiree Mazza', (19, 32)) ---- (3579, 'Desiree Mazza Newtown', (19, 40))
# (3585, 'Angel Paternostro', (4276, 4293))
# (3585, 'Angel Paternostro', (0, 17))
# (3589, 'Maria Ferreira', (19, 33)) ---- (3589, 'Maria Ferreira\n\nLearning Launch Tool\n\nChallenge', (19, 66))
# (3603, 'Esraa Han', (40, 49))
# (3652, 'Bekim Campanelli', (13, 29)) ---- (3652, 'Bekim Campanelli - Mind Mapping\n\nChallenge & Selection', (13, 67))
# (3664, 'Blanca Villa', (37, 49))
# (3686, 'Hussain Mohammed', (7741, 7757)) ---- (3686, 'Hussain Mohammed\n\n', (7741, 7759))
# (3701, 'Newton', (24, 30))
# (3701, 'Newton', (2536, 2542))
# (3736, 'Firoz Khan Pandey', (0, 17)) ---- (3736, 'Firoz Khan Pandey Reflection', (0, 28))
# (3742, 'Hector Prada', (0, 12)) ---- (3742, 'Prada', (7, 12))
# (3745, 'Jessica', (86, 93))
# (3760, 'Muhmmad Sher', (67, 79)) ---- (3760, 'Muhmmad Sher  ', (67, 81))
# (3786, 'Jakeline Lunardi', (0, 16)) ---- (3786, 'Jakeline Lunardi\n\nDESIGN', (0, 24))
# (3885, 'Luca', (1816, 1820))
# (3896, 'Hector Lopez', (0, 12))
# (3900, 'Carmen Perez', (42, 54)) ---- (3900, 'Carmen Perez\n\nChallenge', (42, 65))
# (3911, 'Ganesh Kumar', (3612, 3624)) ---- (3911, 'Kumar', (3619, 3624))
# (3911, 'Ganesh Kumar', (2447, 2459)) ---- (3911, 'Kumar', (2454, 2459))
# (3911, 'Ganesh Kumar', (0, 12)) ---- (3911, 'Kumar', (7, 12))
# (3915, 'Maria Laitinen', (6041, 6055)) ---- (3915, 'Maria Laitinen  Design', (6041, 6063))
# (3915, 'Maria Laitinen', (0, 14)) ---- (3915, 'Maria Laitinen  ', (0, 16))
# (3915, 'Maria Laitinen', (2815, 2829)) ---- (3915, 'Maria Laitinen  Design', (2815, 2837))
# (3915, 'Maria Laitinen', (5982, 5996)) ---- (3915, 'Maria Laitinen  Design', (5982, 6004))
# (3917, 'Jose Rocha', (0, 10)) ---- (3917, 'Jose Rocha\n\n', (0, 12))
# (3921, 'Juan Flores', (47, 58)) ---- (3921, 'Juan Flores\n\nChallenge', (47, 69))
# (3935, 'Ismael Garcia', (95, 108)) ---- (3935, 'Ismael Garcia\n\nReflection', (95, 120))
# (3938, 'Ghala Alzhrani', (60, 74)) ---- (3938, 'Ghala Alzhrani\n\n', (60, 76))
# (3964, 'Thabani Ayo', (3569, 3580)) ---- (3964, 'Thabani Ayo  Design Thinking', (3569, 3597))
# (3964, 'Thabani Ayo', (0, 11)) ---- (3964, 'Thabani Ayo  Design Thinking', (0, 28))
# (3968, 'Mohammed Salah', (16, 30)) ---- (3968, 'Mohammed Salah\n\nChallenge &', (16, 43))
# (3987, 'Tara Limbu', (5917, 5927)) ---- (3987, 'Tara Limbu\n\nPros', (5917, 5933))
# (4003, 'Ruma Ali', (37, 45)) ---- (4003, 'Ruma Ali\n\nChallenge', (37, 56))
# (4004, 'Robin Duffy', (2463, 2474)) ---- (4004, 'Robin Duffy Reﬂection', (2463, 2484))
# (4004, 'Robin Duffy', (0, 11)) ---- (4004, 'Robin Duffy Reﬂection', (0, 21))
# (4026, 'Naty Fernandez', (0, 14)) ---- (4026, 'Naty Fernandez - Homework', (0, 25))
# (4040, 'Manuela Lucas', (0, 13)) ---- (4040, 'Manuela Lucas\n\nReflection', (0, 25))
# (4050, 'Aurore Parmentier', (97, 114))
# (4061, 'Vero Reyes', (67, 77)) ---- (4061, 'Vero Reyes\n\nChallenge', (67, 88))
# (4090, 'Aakash Kumar Aakash Kumar', (0, 25)) ---- (4090, 'Aakash Kumar', (13, 25))
# (4091, 'Ahmed Goda', (81, 91))
# (4109, 'Taty', (53, 57))
# (4123, 'Federica', (30, 38))
# (4161, 'Ashley', (1412, 1418))
# (4165, 'Aries Wee', (17, 26))
# (4179, 'Avi Rachel', (15, 25)) ---- (4179, 'Avi Rachel\n\nChallenge', (15, 36))
# (4185, 'Anne Marie Sanquer', (3025, 3043)) ---- (4185, 'Anne Marie Sanquer   Final Assignment  ', (3025, 3064))
# (4185, 'Anne Marie Sanquer', (0, 18)) ---- (4185, 'Anne Marie Sanquer   Final Assignment  ', (0, 39))
# (4191, 'Francesco Rizzi', (41, 56)) ---- (4191, 'Francesco Rizzi      ', (41, 62))
# (4212, 'Carmen Martinez', (0, 15)) ---- (4212, 'Carmen Martinez\n\nTool', (0, 21))
# (4214, 'Alvaro Moreno', (0, 13)) ---- (4214, 'Alvaro Moreno  ', (0, 15))
# (4218, 'Kevin Chai', (59, 69)) ---- (4218, 'Kevin Chai\n\nReflection', (59, 81))
# (4220, 'Ali Costa', (80, 89))
# (4241, 'Richard Young', (0, 13)) ---- (4241, 'Richard Young\n\nExample Reflection – Visualization\n\nChallenge & Selection', (0, 72))
# (4263, 'Zakir', (44, 49))
# (4276, 'Jean Pierre Jouanne', (35, 54)) ---- (4276, 'Jean Pierre Jouanne\n\n', (35, 56))
# (4291, 'Cristian Tapia', (82, 96)) ---- (4291, 'Cristian Tapia\n\nChallenge\n\nReaching', (82, 117))
# (4296, 'Everardo Ayala', (0, 14)) ---- (4296, 'Everardo Ayala  Reflection', (0, 26))
# (4328, 'Ajay Preet', (0, 10))
# (4336, 'Michael Kl', (0, 10)) ---- (4336, 'Michael Kl Reflection:', (0, 22))
# (4339, 'Joe Rana', (0, 8)) ---- (4339, 'Joe Rana\n\nReflection', (0, 20))
# (4351, 'Ivan Marta', (290, 300)) ---- (4351, 'Ivan Marta-Conceptual Artist', (290, 318))
# (4351, 'Tyler Okey', (35, 45))
# (4351, 'Liz Okey', (359, 367)) ---- (4351, 'Liz Okey Visual Artist', (359, 381))
# (4394, 'Manuel Medina', (39, 52)) ---- (4394, 'Manuel Medina\n\nChallenge', (39, 63))
# (4400, 'Esteban Ojeda', (4417, 4430)) ---- (4400, 'Esteban Ojeda -', (4417, 4432))
# (4403, 'Zakaria Hassan', (0, 14)) ---- (4403, 'Zakaria Hassan\n\nChallenge', (0, 25))
# (4443, 'Thyago Miguel', (70, 83)) ---- (4443, 'Thyago Miguel\n\nChallenge', (70, 94))
# (4465, 'Mithilesh Gupta', (4496, 4511))
# (4469, 'Sarah Matthew', (0, 13)) ---- (4469, 'Sarah Matthew\n\nReflection', (0, 25))
# (4495, 'Nicolas Charles', (41, 56)) ---- (4495, 'Nicolas Charles\n\nChallenge', (41, 67))
# (4501, 'Aman Baloch', (256, 267)) ---- (4501, 'Aman Baloch\n\n', (256, 269))
# (4506, 'Wesley Rodrigues', (16, 32)) ---- (4506, 'Wesley Rodrigues\n\n', (16, 34))
# (4521, 'Gabriel Lara', (0, 12)) ---- (4521, 'Gabriel Lara\n\nReflection', (0, 24))
# (4547, 'Mohammad Rayan', (0, 14)) ---- (4547, 'Mohammad Rayan  Final Assignment:', (0, 33))
# (4547, 'Mohammad Rayan', (3090, 3104)) ---- (4547, 'Mohammad Rayan  Final Assignment:', (3090, 3123))
# (4553, 'Jessie Belal https://www.kramer.info/wp-content/category/bloghome.php', (119, 188)) ---- (4553, 'Jessie Belal', (119, 131))
# (4569, 'Carmen Taylor', (19, 32)) ---- (4569, 'Carmen Taylor\n\n', (19, 34))
# (4579, 'Samshad Dercole', (2810, 2825)) ---- (4579, 'Samshad Dercole - 12/22/2016 - Sao Paulo', (2810, 2850))
# (4600, 'Isabel Yomna', (30, 42)) ---- (4600, 'Isabel Yomna I  ', (30, 46))
# (4623, 'Stella Sk', (10, 19)) ---- (4623, 'Stella Sk  Assignment:\u200b', (10, 33))
# (4634, 'Md Rashid', (99, 108)) ---- (4634, 'Md Rashid\n\nChallenge', (99, 119))
# (4650, 'Reshma', (1016, 1022))
# (4698, 'Willian Sanches', (0, 15)) ---- (4698, 'Willian Sanches V', (0, 17))
# (4698, 'Willian Sanches', (3848, 3863)) ---- (4698, 'Willian Sanches V', (3848, 3865))
# (4698, 'Willian Sanches', (2010, 2025)) ---- (4698, 'Willian Sanches V', (2010, 2027))
# (4717, 'Qais', (46, 50))
# (4744, 'Busisiwe Msimanga', (6452, 6469))
# (4749, 'Andrew Hawkins', (32, 46)) ---- (4749, 'Andrew Hawkins  ', (32, 48))
# (4765, 'Joy Cooper', (128, 138)) ---- (4765, 'Joy Cooper\n\nSabah', (128, 145))
# (4777, 'Eslam Abo Fatma', (2168, 2183)) ---- (4777, 'Eslam Abo Fatma\n\nRwanda-', (2168, 2192))
# (4796, 'Samuel Luna', (16, 27)) ---- (4796, 'Samuel Luna\n\nChallenge', (16, 38))
# (4808, 'Rasha', (525, 530))
# (4808, 'Rasha', (35, 40))
# (4808, 'Rasha', (1511, 1516))
# (4811, 'Christian Fuentes', (89, 106))
# (4820, 'Moin Ch', (2024, 2031))
# (4842, 'Jan Peters', (29, 39))
# (4878, 'Juan Jose Diaz', (22, 36)) ---- (4878, 'Juan Jose Diaz - 8/12/2020', (22, 48))
# (4913, 'Nizam Ahmed', (39, 50)) ---- (4913, 'Nizam Ahmed                             Pin', (39, 82))
# (4933, 'Blanca Torres', (48, 61))
# (4948, 'Ganesh Mankar', (65, 78))
# (4954, 'Brian Ho', (82, 90)) ---- (4954, 'Brian Ho\n\nChallenge', (82, 101))
# (4957, 'Mia Villanueva', (73, 87)) ---- (4957, 'Mia Villanueva      ', (73, 93))
# (4968, 'Mdjakir Puerta', (45, 59))
# (4971, 'Sajid Khan', (2780, 2790)) ---- (4971, 'Sajid Khan  167695383458', (2780, 2804))
# (4971, 'Sajid Khan', (2556, 2566)) ---- (4971, 'Sajid Khan  792389774673', (2556, 2580))
# (4972, 'Noor Noor', (14, 23)) ---- (4972, 'Noor Noor\n\nReflection', (14, 35))
# (4998, 'Ernesto Young', (33, 46)) ---- (4998, 'Ernesto Young                    ', (33, 66))
# (5013, 'Santosh Kumar Prajapati', (3420, 3443)) ---- (5013, 'Kumar Prajapati', (3428, 3443))
# (5042, 'Hasan Rostami', (1298, 1311)) ---- (5042, 'Hasan Rostami\n\nApplication', (1298, 1324))
# (5060, 'Nor Fitri', (38, 47)) ---- (5060, 'Fitri', (42, 47))
# (5085, 'Kashi Papa', (0, 10)) ---- (5085, 'Kashi Papa\n\nExample Reflection', (0, 30))
# (5155, 'Daniel Mohamed', (3225, 3239)) ---- (5155, 'Daniel Mohamed Group - Confidential\n\n', (3225, 3262))
# (5155, 'Daniel Mohamed', (0, 14)) ---- (5155, 'Daniel Mohamed Group - Confidential\n\nExample Reflection', (0, 55))
# (5167, 'Cherry Dantas', (27, 40))
# (5171, 'Azad Ali', (6, 14)) ---- (5171, 'Azad Ali\n\nTitle: Using', (6, 28))
# (5192, 'Isabelle Laurent', (0, 16)) ---- (5192, 'Isabelle Laurent\n\nDesign Thinking', (0, 33))
# (5203, 'Xavier Xuan', (20, 31)) ---- (5203, 'Xavier Xuan\n\nDesign Thinking for Innovation', (20, 63))
# (5203, 'Xavier Xuan', (3029, 3040)) ---- (5203, 'Xavier Xuan\n\nDesign Thinking for Innovation', (3029, 3072))
# (5212, 'Fernando Aguirre', (3921, 3937)) ---- (5212, 'Fernando Aguirre\n\n', (3921, 3939))
# (5215, 'Matheus Kumari', (1200, 1214)) ---- (5215, "Matheus Kumari's", (1200, 1216))
# (5215, 'Matheus Kumari', (2212, 2226)) ---- (5215, "Matheus Kumari's", (2212, 2228))
# (5225, 'Al Kain', (30, 37)) ---- (5225, 'Al Kain\n\nDesign Thinking Tools', (30, 60))
# (5257, 'Sherif Mackie', (45, 58))
# (5290, 'Thomas Meyer', (0, 12)) ---- (5290, 'Thomas Meyer Reflection', (0, 23))
# (5372, 'Aline Ferreira', (28, 42)) ---- (5372, 'Aline Ferreira\n\nChallenge', (28, 53))
# (5452, 'Daniel Chen', (0, 11)) ---- (5452, 'Daniel Chen  Design Thinking', (0, 28))
# (5471, 'Francisco Brown', (0, 15)) ---- (5471, 'Francisco Brown\n\nDesign Thinking', (0, 32))
# (5480, 'Mustafa Majid', (0, 13)) ---- (5480, 'Mustafa Majid  Design Thinking - Assignment  Learning', (0, 53))
# (5526, 'Andrea Rios', (1183, 1194)) ---- (5526, 'Andrea Rios\n\n', (1183, 1196))
# (5529, 'Raffaella Perillo', (73, 90)) ---- (5529, 'Raffaella Perillo\n\nChallenge', (73, 101))
# (5549, 'Moustapha Santi', (0, 15)) ---- (5549, 'Moustapha Santi\t\r \xa0 \t\r \xa0 Challenge', (0, 34))
# (5554, 'Daniele Ameh', (0, 12)) ---- (5554, 'Daniele Ameh Reflection', (0, 23))
# (5588, 'Janet Rios', (0, 10)) ---- (5588, 'Janet Rios  July 10', (0, 19))
# (5588, 'Janet Rios', (3088, 3098)) ---- (5588, 'Janet Rios  July 10', (3088, 3107))
# (5593, 'Jairo Khan', (3102, 3112)) ---- (5593, 'Jairo Khan  Design Thinking', (3102, 3129))
# (5593, 'Jairo Khan', (0, 10)) ---- (5593, 'Jairo Khan  Design Thinking', (0, 27))
# (5608, 'Nirmal Hossain', (31, 45)) ---- (5608, 'Nirmal Hossain\n\nChallenge', (31, 56))
# (5620, 'Edgar Martinez', (0, 14)) ---- (5620, 'Edgar Martinez  -', (0, 17))
# (5634, 'Talaat Mohmmed', (28, 42))
# (5662, 'Philippe Elle', (60, 73)) ---- (5662, 'Philippe Elle OUSSOU', (60, 80))
# (5670, 'Altaf Manish Kumar', (33, 51)) ---- (5670, 'Kumar', (46, 51))
# (5736, 'Pietro Gabrielli', (27, 43)) ---- (5736, 'Pietro Gabrielli\n\n', (27, 45))
# (5737, 'Crystal Campbell', (35, 51))
# (5742, 'Angel Roy', (0, 9)) ---- (5742, 'Angel Roy      ', (0, 15))
# (5742, 'Angel Roy', (2738, 2747)) ---- (5742, 'Angel Roy\n\n', (2738, 2749))
# (5748, 'Mohamed Kamal', (2858, 2871)) ---- (5748, 'Mohamed Kamal  ', (2858, 2873))
# (5748, 'Mohamed Kamal', (0, 13)) ---- (5748, 'Mohamed Kamal  ', (0, 15))
# (5776, 'Ayman', (14, 19))
# (5813, 'Luz', (1896, 1899))
# (5813, 'Luz', (1751, 1754))
# (5825, 'Ricardo Hernandez', (34, 51))
# (5840, 'Yaser Mostafa', (33, 46)) ---- (5840, 'Yaser Mostafa      Challenge', (33, 61))
# (5855, 'May Sutton', (83, 93))
# (5861, 'Masahiro Takahashi', (54, 72)) ---- (5861, 'Masahiro Takahashi      ', (54, 78))
# (5896, 'Donya Donya', (38, 49)) ---- (5896, 'Donya Donya\n\nChallenge', (38, 60))
# (5902, 'Karen', (10, 15)) ---- (5902, 'Karen - Reflection on Mind Mapping Tool\n\nChallenge & Selection', (10, 72))
# (5905, 'Gianpaolo Poli', (3170, 3184))
# (5905, 'Gianpaolo Poli', (0, 14))
# (5907, 'Anna Pirrotta', (0, 13)) ---- (5907, 'Anna Pirrotta\n\nReflection', (0, 25))
# (5910, 'Sara Garcia', (15, 26)) ---- (5910, 'Sara Garcia\n\nChallenge', (15, 37))
# (5922, 'Leonardo Giles', (18, 32)) ---- (5922, 'Leonardo Giles\n\n', (18, 34))
# (5937, 'Asmaa Elnahas', (0, 13)) ---- (5937, 'Asmaa Elnahas\n\nRubric', (0, 21))
# (5950, 'Kamal Jan', (0, 9)) ---- (5950, 'Kamal', (0, 5))
# (5952, 'Yareli Thomas', (50, 63))
# (6020, 'Amanda Rose', (30, 41)) ---- (6020, 'Amanda Rose\n\nSelection', (30, 52))
# (6025, 'Omar Khan', (15, 24)) ---- (6025, 'Omar Khan\n\nDesign Thinking', (15, 41))
# (6027, 'Enrico Laterza', (16, 30))
# (6057, 'Lerato Salem', (4173, 4185))
# (6061, 'Justine Plascencia', (36, 54)) ---- (6061, 'Justine Plascencia\n\nChallenge', (36, 65))
# (6081, 'Giovanni', (1483, 1491))
# (6081, 'Giovanni', (3348, 3356))
# (6081, 'Giovanni', (5062, 5070))
# (6081, 'Giovanni', (0, 8)) ---- (6081, 'Giovanni 1', (0, 10))
# (6085, 'Siew Santamaria', (30, 45)) ---- (6085, 'Siew Santamaria      ', (30, 51))
# (6109, 'Lai Har Leung', (13, 26)) ---- (6109, 'Lai Har Leung  Date', (13, 32))
# (6121, 'Thai Tamang', (0, 11)) ---- (6121, 'Tamang', (5, 11))
# (6125, 'Emanuele Biondi', (33, 48)) ---- (6125, 'Emanuele Biondi\n\nChallenge', (33, 59))
# (6133, 'Mahammad Khan', (109, 122)) ---- (6133, 'Mahammad Khan\n\nChallenge', (109, 133))
# (6135, 'Teresa Jimenez', (63, 77)) ---- (6135, 'Teresa Jimenez      Challenge', (63, 92))
# (6148, 'Christian', (104, 113))
# (6152, 'Manuel', (555, 561)) ---- (6152, 'Manuel  Age', (555, 566))
# (6152, 'Surendra Raj', (1481, 1493)) ---- (6152, 'Surendra Raj  Age', (1481, 1498))
# (6155, 'Khairul Rahman', (32, 46)) ---- (6155, 'Khairul Rahman\n\nChallenge', (32, 57))
# (6170, 'Md Mohamed', (0, 10)) ---- (6170, 'Md Mohamed  kwhite@yahoo.com\n\nWorkflow Optimization', (0, 51))
# (6172, 'Barbara Rolli', (0, 13)) ---- (6172, 'Barbara Rolli\n\nReflection', (0, 25))
# (6187, 'Gino Schiavo', (0, 12)) ---- (6187, 'Gino Schiavo  Design Thinking', (0, 29))
# (6261, 'Camila Parra', (2147, 2159)) ---- (6261, 'Camila Parra  Design Thinking for Innovation\n\nInsight & Approach', (2147, 2211))
# (6261, 'Camila Parra', (0, 12)) ---- (6261, 'Camila Parra  Design Thinking for Innovation', (0, 44))
# (6285, 'Yesenia Dube', (11, 23))
# (6310, 'Md Shahid', (39, 48)) ---- (6310, 'Md Shahid\n\nChallenge', (39, 59))
# (6339, 'Priya Jeet', (0, 10)) ---- (6339, 'Priya Jeet  Page 1', (0, 18))
# (6339, 'Priya Jeet', (2762, 2772)) ---- (6339, 'Priya Jeet  Page 2', (2762, 2780))
# (6361, 'Osman', (898, 903)) ---- (6361, 'Osman  Osman', (898, 910))
# (6361, 'Osman', (107, 112)) ---- (6361, 'Osman  Osman', (100, 112))
# (6361, 'Osman', (1433, 1438)) ---- (6361, 'Osman  Osman', (1426, 1438))
# (6361, 'Osman', (100, 105)) ---- (6361, 'Osman  Osman', (100, 112))
# (6361, 'Osman', (543, 548)) ---- (6361, 'Osman  Osman', (536, 548))
# (6361, 'Osman', (905, 910)) ---- (6361, 'Osman  Osman', (898, 910))
# (6361, 'Osman', (1426, 1431)) ---- (6361, 'Osman  Osman', (1426, 1438))
# (6361, 'Osman', (536, 541)) ---- (6361, 'Osman  Osman', (536, 548))
# (6361, 'Sushant Qureshi', (6, 21)) ---- (6361, 'Sushant Qureshi\n\nRoll', (6, 27))
# (6364, 'Irfan Khan', (32, 42)) ---- (6364, 'Irfan Khan\n\nReflection', (32, 54))
# (6376, 'Aitor Lopez', (6, 17))
# (6376, 'Aitor Lopez', (2459, 2470))
# (6379, 'Alaa Santos', (30, 41))
# (6393, 'Rania Mohammed', (14, 28)) ---- (6393, 'Rania Mohammed\n\nTool', (14, 34))
# (6416, 'Juan Velasquez', (18, 32)) ---- (6416, 'Juan Velasquez\n\nChallenge', (18, 43))
# (6432, 'Hiroshi Tamura', (57, 71)) ---- (6432, 'Hiroshi Tamura\n\n', (57, 73))
# (6457, 'Surya Mohamad', (56, 69)) ---- (6457, 'Surya Mohamad ©      ', (56, 77))
# (6460, 'Maria Luis', (85, 95))
# (6465, 'Tiago Borges', (11, 23)) ---- (6465, 'Reflection Tiago Borges', (0, 23))
# (6495, 'Shiva Kumar', (2999, 3010)) ---- (6495, 'Kumar', (3005, 3010))
# (6497, 'Indhumathi Shaikh', (2522, 2539)) ---- (6497, 'Indhumathi Shaikh  Page', (2522, 2545))
# (6497, 'Indhumathi Shaikh', (32, 49)) ---- (6497, 'Indhumathi Shaikh  Page', (32, 55))
# (6497, 'Indhumathi Shaikh', (4772, 4789)) ---- (6497, 'Indhumathi Shaikh  Page', (4772, 4795))
# (6521, 'Danish Shaikh', (26, 39))
# (6582, 'Akshat Rajbhar', (50, 64)) ---- (6582, 'Akshat Rajbhar\n\nChallenge', (50, 75))
# (6593, 'Lily Grandon', (0, 12)) ---- (6593, 'Lily Grandon\n\nReflection', (0, 24))
# (6611, 'Cicero Carlos', (0, 13)) ---- (6611, 'Cicero Carlos  ', (0, 15))
# (6612, 'Na Rayan', (28, 36)) ---- (6612, 'Na Rayan\n\nChallenge', (28, 47))
# (6622, 'John Yates', (0, 10))
# (6624, 'Upendar Thakur', (43, 57))
# (6645, 'Stephanie Alaa', (27, 41)) ---- (6645, 'Stephanie Alaa  ', (27, 43))
# (6648, 'Redzuan Azifah', (32, 46)) ---- (6648, 'Redzuan Azifah\n\n', (32, 48))
# (6664, 'Sujith', (17, 23))
# (6693, 'Hugo Lambert', (2340, 2352))
# (6693, 'Hugo Lambert', (5135, 5147))
# (6694, 'Jose', (2715, 2719))
# (6694, 'Jose', (6610, 6614)) ---- (6694, 'Jose “Story', (6610, 6621))
# (6694, 'Jose', (6156, 6160))
# (6694, 'Jose', (1461, 1465))
# (6694, 'Jose', (3486, 3490))
# (6718, 'Lucas Medina', (4152, 4164)) ---- (6718, 'Lucas Medina\n\nDesign Thinking for Innovation', (4152, 4196))
# (6718, 'Lucas Medina', (45, 57)) ---- (6718, 'Lucas Medina\n\nDesign Thinking for Innovation\n\nChallenge\n\nSelection\n\nApplication', (45, 124))
# (6728, 'Jennifer Medina', (0, 15)) ---- (6728, 'Jennifer Medina\n\nReflection\n\nChallenge', (0, 38))
# (6739, 'Angelo Vallejos', (32, 47)) ---- (6739, 'Angelo Vallejos\n\nReflection.-', (32, 61))
# (6750, 'Katie Wakefield', (54, 69)) ---- (6750, 'Katie Wakefield\n\n', (54, 71))
# (6775, 'Gurwinder Singh', (6, 21)) ---- (6775, 'Gurwinder Singh\n\nChallenge', (6, 32))
# (6819, 'Malik Ali', (80, 89)) ---- (6819, 'Malik Ali\n\nChallenge', (80, 100))
# (6849, 'Madison Tate 034626995785', (69, 94)) ---- (6849, 'Madison Tate 034626995785\n\nLife', (69, 100))
# (6851, 'Idongesit Emeka', (43, 58)) ---- (6851, 'Idongesit Emeka\n\nChallenge', (43, 69))
# (6853, 'Mohinder Kumar', (4980, 4994))
# (6873, 'Rahmat Alshehri', (27, 42)) ---- (6873, 'Rahmat Alshehri\n\nChallenge', (27, 53))
# (6882, 'Mohamed Selim', (35, 48)) ---- (6882, 'Mohamed Selim\n\nChallange', (35, 59))
# (6888, 'Gonzalo Wong', (33, 45)) ---- (6888, 'Gonzalo Wong\n\nChallenge', (33, 56))
# (6897, 'Saeed Ahmad', (0, 11)) ---- (6897, 'Saeed Ahmad - Essay\n\nChallenge', (0, 30))
# (6898, 'Anna Russo', (125, 135)) ---- (6898, 'Anna Russo\n\nChallenge', (125, 146))
# (6898, 'Anna Russo', (2086, 2096)) ---- (6898, 'Anna Russo  ', (2086, 2098))
# (6898, 'Anna Russo', (78, 88)) ---- (6898, 'Anna Russo  ', (78, 90))
# (6903, 'Manar', (58, 63))
# (6921, 'Abdo Cortes', (2879, 2890))
# (6921, 'Abdo Cortes', (32, 43))
# (6946, 'Habibu George', (114, 127)) ---- (6946, 'Habibu George\n\nAbuja', (114, 134))
# (6948, 'Isidro Fernandez', (5556, 5572))
# (6976, 'Ifeoma Kings', (40, 52))
# (6976, 'Ifeoma Kings', (3819, 3831))
# (6999, 'Shubham Shubham', (3577, 3592)) ---- (6999, 'Shubham Shubham\n\nROLL', (3577, 3598))
# (7006, 'Angelik', (197, 204))
# (7022, 'Pablo Romero', (0, 12)) ---- (7022, 'Pablo Romero Example Reflection', (0, 31))
# (7032, 'Jesse Salazar', (0, 13)) ---- (7032, 'Jesse Salazar  Visualization Tool', (0, 33))
# (7037, 'Isabel Pardal', (27, 40)) ---- (7037, 'Isabel Pardal\n\nChallenge', (27, 51))
# (7065, 'Samar Mohamed', (25, 38)) ---- (7065, 'Samar Mohamed\n\nChallenge', (25, 49))
# (7067, 'Davi Dias', (33, 42)) ---- (7067, 'Davi Dias\n\nChallenge', (33, 53))
# (7075, 'Diego Campo', (34, 45))
# (7084, 'Jhonatan De Oliveira', (47, 67)) ---- (7084, 'Jhonatan De Oliveira\n\nChalenge & Selection', (47, 89))
# (7098, 'Eman Rahaman', (0, 12)) ---- (7098, 'Eman Rahaman Reflection', (0, 23))
# (7138, 'Mary Perez', (0, 10)) ---- (7138, 'Mary Perez\t\r \xa0\t\r \xa0 Reflection', (0, 29))
# (7156, 'Zhe Basmah', (151, 161)) ---- (7156, 'Zhe Basmah\n\n', (151, 163))
# (7156, 'Zhe Basmah', (6, 16)) ---- (7156, 'Zhe Basmah  ROLL', (6, 22))
# (7156, 'Zhe', (82, 85))
# (7202, 'Ragni Paru', (0, 10)) ---- (7202, 'Ragni Paru\n\nReflection', (0, 22))
# (7203, 'Juan Bakker', (0, 11))
# (7222, 'Dharmendra Shakya', (6, 23)) ---- (7222, 'Dharmendra Shakya  Date', (6, 29))
# (7231, 'Ana', (1389, 1392))
# (7256, 'Jose Brown', (36, 46))
# (7258, 'Michael Stewart', (3298, 3313)) ---- (7258, 'Michael Stewart\n\n\uf0a8', (3298, 3316))
# (7264, 'Sabita Pal', (27, 37))
# (7271, 'Rashid Kt', (107, 116)) ---- (7271, 'Rashid Kt\n\nChallenge', (107, 127))
# (7320, 'Minenhle Nucci', (29, 43))
# (7321, 'Ori Abrego', (43, 53))
# (7327, 'Paqui Martin', (12, 24))
# (7343, 'Priyanka Das', (2548, 2560))
# (7382, 'Aylin Osorio', (0, 12)) ---- (7382, 'Aylin Osorio\n\nReflection-Learning', (0, 33))
# (7389, 'Salimatou Reno', (49, 63))
# (7404, 'Jimena', (1530, 1536))
# (7428, 'Akash Brito', (91, 102)) ---- (7428, 'Akash Brito  Date', (91, 108))
# (7458, 'Yogi Yates', (109, 119)) ---- (7458, 'Yogi Yates\n\nChallenge', (109, 130))
# (7490, 'Abbas Hernandez', (21, 36)) ---- (7490, 'Abbas Hernandez\n\nChallenge', (21, 47))
# (7641, 'Imran Al', (5354, 5362)) ---- (7641, 'Imran Al  Date', (5354, 5368))
# (7663, 'Lalisa Cruz', (36, 47)) ---- (7663, 'Lalisa Cruz\n\nChallenge', (36, 58))
# (7668, 'Amira Ali', (70, 79)) ---- (7668, 'Amira Ali]\n\nChallenge', (70, 91))
# (7671, 'Barbara Sofia', (0, 13)) ---- (7671, 'Barbara Sofia Design-Thinking', (0, 29))
# (7676, 'Om Ahmed Teto', (145, 158)) ---- (7676, 'Om Ahmed Teto\n\nChallenge', (145, 169))
# (7680, 'Jonathan Vieira', (112, 127)) ---- (7680, 'Jonathan Vieira\xa0 \xa0 ', (112, 131))
# (7713, 'Miguel Caceres', (62, 76)) ---- (7713, 'Miguel Caceres\n\nChallenge', (62, 87))
# (7732, 'Ali Alawy', (0, 9)) ---- (7732, 'Ali Alawy\n\nInstructions', (0, 23))
# (7735, 'Abdul Khan', (29, 39)) ---- (7735, 'Abdul Khan\n\nChallenge & Selection', (29, 62))
# (7736, 'Md Sadam', (5415, 5423)) ---- (7736, 'Md Sadam  Course - Design', (5415, 5440))
# (7745, 'Luis Gonzales', (11991, 12004)) ---- (7745, 'Luis Gonzales  ', (11991, 12006))
# (7745, 'Luis Gonzales', (4441, 4454)) ---- (7745, 'Luis Gonzales  ', (4441, 4456))
# (7745, 'Luis Gonzales', (9077, 9090)) ---- (7745, 'Luis Gonzales  ', (9077, 9092))
# (7745, 'Luis Gonzales', (0, 13)) ---- (7745, 'Luis Gonzales  ', (0, 15))
# (7759, 'Mai Singh', (1179, 1188)) ---- (7759, 'Mai Singh:\n\nDesign', (1179, 1197))
# (7759, 'Mihaela Leal', (24, 36)) ---- (7759, 'Mihaela Leal  ', (24, 38))
# (7759, 'Mihaela Leal', (1402, 1414)) ---- (7759, 'Mihaela Leal  ', (1402, 1416))
# (7759, 'Mihaela Leal', (1215, 1227)) ---- (7759, 'Mihaela Leal  ', (1215, 1229))
# (7763, 'Nani Peroni', (0, 11)) ---- (7763, 'Nani Peroni  Design Thinking for Innovation Assignment', (0, 54))
# (7784, 'Shaun Tong', (79, 89)) ---- (7784, 'Shaun Tong\n\n1', (79, 92))
# (7793, 'Pallabi Amin', (63, 75))
# (7856, 'Ray Nguyen', (7749, 7759)) ---- (7856, 'Ray Nguyen\n\n', (7749, 7761))
# (7858, 'Mickael Richardson', (33, 51)) ---- (7858, 'Mickael Richardson\n\nChallenge', (33, 62))
# (7865, 'Tina Peralta', (0, 12)) ---- (7865, 'Tina Peralta - Reflection', (0, 25))
# (7867, 'Rabi Jain', (61, 70)) ---- (7867, 'Rabi Jain\n\nReflection', (61, 82))
# (7929, 'Muhammad Leonardo', (29, 46)) ---- (7929, 'Muhammad Leonardo\n\nChallenge', (29, 57))
# (7931, 'Rohan Magesh', (38, 50)) ---- (7931, 'Rohan Magesh\n\nChallenge', (38, 61))
# (7932, 'Ahmed Alaa', (3855, 3865)) ---- (7932, 'Ahmed Alaa  Date', (3855, 3871))
# (7932, 'Ahmed Alaa', (3822, 3832)) ---- (7932, 'Ahmed Alaa\n\nDigitally', (3822, 3843))
# (7932, 'Ahmed Carlos', (2633, 2645)) ---- (7932, 'Ahmed Carlos  Date', (2633, 2651))
# (7932, 'Ahmed Carlos', (130, 142)) ---- (7932, 'Ahmed Carlos  Date', (130, 148))
# (7948, 'Brajesh Husan', (34, 47)) ---- (7948, 'Brajesh Husan\n\nChallenge', (34, 58))
# (7959, 'Ravinder Pal', (6, 18)) ---- (7959, 'Ravinder Pal      Challenge', (6, 33))
# (7971, 'Palesa Palesa', (27, 40))
# (7974, 'Kojo Oteng', (8, 18)) ---- (7974, 'Kojo Oteng\n\nCourse', (8, 26))
# (7993, 'Quentin', (0, 7)) ---- (7993, 'Quentin 1', (0, 9))
# (7993, 'Quentin', (2969, 2976)) ---- (7993, 'Quentin 2', (2969, 2978))
# (8021, 'Caterina Mauro', (81, 95))
# (8025, 'Irving Gamez', (71, 83)) ---- (8025, 'Irving Gamez  Course', (71, 91))
# (8033, 'Shamsun Fawzy', (0, 13)) ---- (8033, 'Shamsun Fawzy\n\nReflection', (0, 25))
# (8102, 'Om Ahmed', (68, 76))
# (8102, 'Om Ahmed', (2037, 2045))
# (8108, 'Sameh', (861, 866))
# (8127, 'Filip', (38, 43))
# (8163, 'Abdi Bennett', (44, 56)) ---- (8163, 'Abdi Bennett\n\nChallenge', (44, 67))
# (8173, 'Graziella Ibrahim', (16, 33)) ---- (8173, 'Graziella Ibrahim  ', (16, 35))
# (8192, 'Roberto Hasan', (10, 23)) ---- (8192, 'Roberto Hasan Papers', (10, 30))
# (8192, 'Roberto Hasan', (1904, 1917)) ---- (8192, 'Roberto Hasan Papers', (1904, 1924))
# (8251, 'Kenichi Watanabe', (33, 49)) ---- (8251, 'Kenichi Watanabe\n\n', (33, 51))
# (8271, 'Paul Basha', (35, 45)) ---- (8271, 'Paul Basha\n\nChallenge', (35, 56))
# (8296, 'Feroz Saiful', (2963, 2975)) ---- (8296, 'Feroz Saiful\n\nDesign Thinking', (2963, 2992))
# (8296, 'Feroz Saiful', (0, 12)) ---- (8296, 'Feroz Saiful\n\nDesign Thinking', (0, 29))
# (8301, 'Jeff Fang', (44, 53)) ---- (8301, 'Jeff Fang  ', (44, 55))
# (8322, 'Adrian Trujillo', (5, 20)) ---- (8322, 'p.p. Adrian Trujillo', (0, 20))
# (8329, 'Uwe Bas', (113, 120)) ---- (8329, 'Uwe Bas\n\n21', (113, 124))
# (8337, 'Luiz Oliveira', (87, 100)) ---- (8337, 'Luiz Oliveira -', (87, 102))
# (8340, 'Giuseppe Petrosillo', (17, 36)) ---- (8340, 'Giuseppe Petrosillo -', (17, 38))
# (8340, 'El Petrosillo', (52, 65))
# (8364, 'Ali Zarei', (0, 9)) ---- (8364, 'Ali Zarei Reflection', (0, 20))
# (8371, 'Ismael Aguirre', (17, 31)) ---- (8371, 'Ismael Aguirre\n\nLife', (17, 37))
# (8372, 'Jaime Martinez', (66, 80))
# (8379, 'Iva Juric', (2944, 2953)) ---- (8379, 'Iva Juric\n\n', (2944, 2955))
# (8379, 'Iva Juric', (2278, 2287)) ---- (8379, 'Iva Juric\n\nInsight', (2278, 2296))
# (8412, 'Adriano Santos', (0, 14)) ---- (8412, 'Adriano Santos - Reflection\n\nChallenge', (0, 38))
# (8436, 'Farida Akpan', (9, 21)) ---- (8436, 'Farida Akpan\n\nDESIGN', (9, 29))
# (8468, 'Hernan Orozco', (6, 19)) ---- (8468, 'Hernan Orozco\n\nCHALLENGE', (6, 30))
# (8476, 'Ludis', (128, 133))
# (8483, 'Mario Belfiore', (30, 44))
# (8485, 'Ahmad Suryadi', (31, 44)) ---- (8485, 'Ahmad Suryadi      Challenge', (31, 59))
# (8496, 'Beatriz', (2647, 2654)) ---- (8496, 'Beatriz et al', (2647, 2660))
# (8505, 'Philippe Quesnel', (7582, 7598)) ---- (8505, 'Philippe Quesnel\n\nInnovation & R&D', (7582, 7616))
# (8535, 'Clash Royale', (2847, 2859))
# (8535, 'Clash Royale', (0, 12))
# (8545, 'Nweze Stanley', (0, 13)) ---- (8545, 'Nweze Stanley\n\nReflection', (0, 25))
# (8546, 'Sebastian Arenas', (0, 16)) ---- (8546, 'Sebastian Arenas\n\nFinal Reflection', (0, 34))
# (8550, 'Adigun Okoro', (45, 57))
# (8578, 'Javier Vega', (102, 113)) ---- (8578, 'Javier Vega  ', (102, 115))
# (8587, 'Nuno', (37, 41))
# (8593, 'Tony Flores', (0, 11)) ---- (8593, 'Tony Flores | Assignment', (0, 24))
# (8593, 'Tony Flores', (2942, 2953)) ---- (8593, 'Tony Flores | Assignment', (2942, 2966))
# (8597, 'Nomfundo Alkaabi', (14, 30)) ---- (8597, 'Nomfundo Alkaabi\n\nReflection', (14, 42))
# (8608, 'Sajid Jutt', (231, 241)) ---- (8608, 'Sajid Jutt\n\nDesign Thinking for Innovation    University of Virginia', (231, 299))
# (8610, 'Porch Zakwe', (107, 118))
# (8612, 'Ana Sofia Rayo', (36, 50)) ---- (8612, 'Ana Sofia Rayo\n\nSelection', (36, 61))
# (8621, 'Luz Marina Mora', (49, 64))
# (8650, 'Angelo Silva', (0, 12)) ---- (8650, 'Angelo Silva  ', (0, 14))
# (8650, 'Angelo Silva', (4120, 4132)) ---- (8650, 'Angelo Silva  ', (4120, 4134))
# (8670, 'Yoel', (0, 4))
# (8673, 'Farooq', (0, 6)) ---- (8673, 'Farooq  Page 1', (0, 14))
# (8673, 'Farooq', (2307, 2313)) ---- (8673, 'Farooq  Page 2', (2307, 2321))
# (8675, 'Pedro Ahmed', (4, 15)) ---- (8675, 'Pedro Ahmed\n\nChallenge', (4, 26))
# (8690, 'Diego', (22, 27))
# (8706, 'Lucy Guzman', (15, 26)) ---- (8706, 'Lucy Guzman           ', (15, 37))
# (8706, 'Lucy Guzman', (3328, 3339)) ---- (8706, 'Lucy Guzman           ', (3328, 3350))
# (8706, 'Lucy Guzman', (7109, 7120)) ---- (8706, 'Lucy Guzman           ', (7109, 7131))
# (8711, 'Blanca Becerra', (17, 31)) ---- (8711, 'Blanca Becerra\n\nChallenge & Selection', (17, 54))
# (8713, 'Benson Fung', (20, 31)) ---- (8713, 'Benson Fung\n\nChallenge', (20, 42))
# (8714, 'Jamshed', (33, 40))
# (8716, 'Smsm', (601, 605))
# (8718, 'Naser', (232, 237))
# (8731, 'Alexandra Schmid', (25, 41)) ---- (8731, 'Alexandra Schmid - Design', (25, 50))
# (8735, 'Ananya Agrawal', (1449, 1463)) ---- (8735, 'Ananya Agrawal Pin', (1449, 1467))
# (8751, 'Cesar Mahmood', (3165, 3178)) ---- (8751, 'Cesar Mahmood  Branch', (3165, 3186))
# (8760, 'Dmitriy Aliev', (0, 13)) ---- (8760, 'Dmitriy Aliev\n\nReflection', (0, 25))
# (8768, 'Asia Ibrahim', (31, 43))
# (8771, 'Manuel Alfaro', (2559, 2572)) ---- (8771, 'Manuel Alfaro - Design', (2559, 2581))
# (8771, 'Manuel Alfaro', (81, 94)) ---- (8771, 'Manuel Alfaro - Design', (81, 103))
# (8796, 'Md', (2071, 2073))
# (8796, 'Md', (4211, 4213))
# (8796, 'Md', (0, 2))
# (8844, 'Miriam Bianchi', (74, 88)) ---- (8844, 'Miriam Bianchi  ', (74, 90))
# (8846, 'Tatsuya Watanabe', (61, 77)) ---- (8846, 'Tatsuya Watanabe\n\nChallenge', (61, 88))
# (8858, 'Ramesh Yadav Singh', (86, 104)) ---- (8858, 'Singh', (99, 104))
# (8858, 'Cleber', (114, 120))
# (8858, 'Nurudeen', (122, 130))
# (8893, 'Emine Panagiotopoulos', (22, 43))
# (8919, 'Terry', (28, 33))
# (8950, 'Naga Raju', (31, 40))
# (8957, 'Sarah Walter', (43, 55)) ---- (8957, 'Sarah Walter\n\nChallenge', (43, 66))
# (8957, 'Sarah Walter', (2696, 2708)) ---- (8957, 'Sarah Walter\n\nChallenge', (2696, 2719))
# (8981, 'Daniel', (13, 19))
# (8983, 'Amr Abdelalem', (8, 21)) ---- (8983, 'Amr Abdelalem\n\nDate', (8, 27))
# (9018, 'Felice', (1039, 1045))
# (9028, 'Luz Young', (3121, 3130))
# (9044, 'Thabiso Mazibuko', (6240, 6256)) ---- (9044, 'Thabiso Mazibuko\n\nTeacher', (6240, 6265))
# (9107, 'Julian Ortiz', (0, 12)) ---- (9107, 'Julian Ortiz  Design Thinking', (0, 29))
# (9107, 'Julian Ortiz', (3336, 3348)) ---- (9107, 'Julian Ortiz  Design Thinking', (3336, 3365))
# (9124, 'Alvin Zainal', (0, 12)) ---- (9124, 'Alvin Zainal Reflection - Learning Launch\n\nChallenge', (0, 52))
# (9150, 'Ch Mackay', (4353, 4362))
# (9150, 'Ch Mackay', (6392, 6401))
# (9150, 'Ch Mackay', (3211, 3220))
# (9150, 'Ch Mackay', (0, 9))
# (9151, 'Corinna Bruns', (18, 31)) ---- (9151, 'Corinna Bruns      ', (18, 37))
# (9156, 'Ahmad Hussein', (82, 95)) ---- (9156, 'Ahmad Hussein\n\nChallenge', (82, 106))
# (9162, 'Dasha Baur', (16, 26)) ---- (9162, 'Dasha Baur\n\nChallenge', (16, 37))
# (9188, 'Alessandra Farrag', (54, 71)) ---- (9188, 'Alessandra Farrag\n\nDesign Thinking', (54, 88))
# (9206, 'Jan Waseem', (112, 122)) ---- (9206, 'Jan Waseem\n\nInstructions\n\nSelect', (112, 144))
# (9235, 'Sameer Sharma', (2596, 2609)) ---- (9235, 'Sameer Sharma      -  ', (2596, 2618))
# (9235, 'Maya Gupta', (2561, 2571))
# (9235, 'Luis', (2487, 2491))
# (9235, 'Richard Walker', (2522, 2536)) ---- (9235, 'Richard Walker       -', (2522, 2544))
# (9243, 'Bankole Ismail', (79, 93)) ---- (9243, 'Bankole Ismail\n\nChallenge', (79, 104))
# (9277, 'Abdulghaffar Abdulghaffar', (0, 25)) ---- (9277, 'Abdulghaffar Abdulghaffar  Elearning Instructional Design', (0, 57))
# (9286, 'Prakash', (3556, 3563))
# (9286, 'Prakash', (2928, 2935))
# (9289, 'Gabriele Khan', (3155, 3168)) ---- (9289, 'Gabriele Khan - Design', (3155, 3177))
# (9289, 'Gabriele Khan', (0, 13)) ---- (9289, 'Gabriele Khan - Design', (0, 22))
# (9291, 'Ahmed Zo', (14, 22)) ---- (9291, 'Ahmed Zo\n\nReflection - Mind', (14, 41))
# (9302, 'Wendy Romero', (2321, 2333))
# (9324, 'Menna', (2775, 2780))
# (9324, 'Menna', (2874, 2879))
# (9363, 'Castillo Valdez', (11, 26))
# (9396, 'Juan Rodriguez', (18, 32))
# (9405, 'Fabrizio', (1555, 1563))
# (9405, 'Fabrizio', (2187, 2195))
# (9442, 'Rajesh Tandel', (58, 71)) ---- (9442, 'Rajesh Tandel\n\nChallenge', (58, 82))
# (9460, 'Jose Luis', (66, 75)) ---- (9460, 'Jose Luis\n\nJose Luis                    ', (66, 106))
# (9460, 'Lupe King', (55, 64)) ---- (9460, 'Anjali Rajput\n\nLupe King', (40, 64))
# (9460, 'Anjali Rajput', (40, 53)) ---- (9460, 'Anjali Rajput\n\nLupe King', (40, 64))
# (9460, 'Jose Luis', (77, 86))
# (9473, 'Amparo Pimienta', (0, 15)) ---- (9473, 'Amparo Pimienta\n\nFINAL ASSIGNMENT', (0, 33))
# (9499, 'Sachin Khan', (39, 50)) ---- (9499, 'Sachin Khan  Design Thinking Course - Assignment\n\nChallenge', (39, 98))
# (9540, 'Jan Miah', (8354, 8362))
# (9546, 'Andru Orozco', (0, 12)) ---- (9546, 'Andru Orozco\n\nDESIGN', (0, 20))
# (9558, 'Alejandro Jerez', (76, 91))
# (9564, 'Giman Giman', (29, 40))
# (9585, 'Ajayi Azubuike', (0, 14)) ---- (9585, 'Ajayi Azubuike Reflection\n\nChallenge & Selection', (0, 48))
# (9628, 'Gianni Chiodini', (0, 15)) ---- (9628, 'Gianni Chiodini\n\n', (0, 17))
# (9629, 'Maria Amin', (9, 19)) ---- (9629, 'Maria Amin  ', (9, 21))
# (9635, 'Adriana Lopez', (1756, 1769)) ---- (9635, 'Adriana Lopez  https://www.brennan.com/taghome.htm', (1756, 1806))
# (9653, 'Man Man Kwok', (13, 25))
# (9661, 'Qis Sia', (8, 15)) ---- (9661, 'Qis Sia\n\nReflection on Visualization', (8, 44))
# (9665, 'Bastian Rubio', (9, 22)) ---- (9665, 'Bastian Rubio  ', (9, 24))
# (9674, 'Princess', (3811, 3819))
# (9674, 'Princess', (3797, 3805))
# (9674, 'Princess', (3829, 3837))
# (9760, 'Md', (1351, 1353))
# (9760, 'Sama', (1088, 1092))
# (9760, 'Bk Bk', (6, 11)) ---- (9760, 'Bk Bk  Roll', (6, 17))
# (9760, 'Bk Bk', (1009, 1014)) ---- (9760, 'Bk Bk  Roll', (1009, 1020))
# (9786, 'Jibon Low', (0, 9)) ---- (9786, 'Jibon Low  25', (0, 13))
# (9800, 'Douglas Holmes', (86, 100)) ---- (9800, 'Douglas Holmes\n\nChallenge', (86, 111))
# (9822, 'Luis Islas', (31, 41)) ---- (9822, 'Luis Islas\n\nChallenge', (31, 52))
# (9832, 'Willi Rohde', (43, 54)) ---- (9832, 'Willi Rohde      ', (43, 60))
# (9835, 'Florence James', (0, 14)) ---- (9835, 'Florence James\n\n', (0, 16))
# (9855, 'Laxmi Sachin Yadav', (33, 51)) ---- (9855, 'Sachin Yadav', (39, 51))
# (9911, 'Cobus Mpanza', (1842, 1854))
# (9930, 'Busi Tarek', (23, 33))
# (9957, 'Rosnani Kiah', (6, 18))
# (9960, 'Javier Morales', (76, 90)) ---- (9960, 'Javier Morales  john14@hotmail.com\n\n', (76, 112))
# (9983, 'Soka', (44, 48))
# (9984, 'Abdiel Rios', (59, 70)) ---- (9984, 'Abdiel Rios\n\nChallenge', (59, 81))
# (9995, 'Loan Mendoza', (3713, 3725)) ---- (9995, 'Loan Mendoza\n\nINSIGHT &', (3713, 3736))
# (10057, 'Leidy Kabiri', (47, 59)) ---- (10057, 'Leidy Kabiri\n\n', (47, 61))
# (10065, 'Auni Nik', (31, 39)) ---- (10065, 'Auni Nik\n\nChallenge &', (31, 52))
# (10160, 'Abdul Thomas', (92, 104)) ---- (10160, 'Abdul Thomas\n\nChallenge', (92, 115))
# (10164, 'Rui Mendes', (27, 37)) ---- (10164, 'Rui Mendes\n\nDesign Thinking', (27, 54))
# (10165, 'Javier', (4110, 4116))
# (10196, 'Satish Kumar Zeeshan', (45, 65)) ---- (10196, 'Kumar Zeeshan', (52, 65))
# (10239, 'Luis', (16, 20))
# (10246, 'Alessia Gentile', (40, 55)) ---- (10246, 'Alessia Gentile\n\nUNIVERSITY', (40, 67))
# (10252, 'Marcos Williams', (31, 46)) ---- (10252, 'Marcos Williams\n\nChallenge', (31, 57))
# (10269, 'Sergio Echavarria', (0, 17)) ---- (10269, 'Sergio Echavarria  Zuñiga', (0, 25))
# (10277, 'Claudia Perez', (54, 67)) ---- (10277, 'Claudia Perez\n\nChallenge', (54, 78))
# (10280, 'Martha Burton', (6651, 6664)) ---- (10280, 'Martha Burton  ', (6651, 6666))
# (10280, 'Martha Burton', (0, 13)) ---- (10280, 'Martha Burton  ', (0, 15))
# (10280, 'Martha Burton', (3218, 3231)) ---- (10280, 'Martha Burton  ', (3218, 3233))
# (10282, 'Harjinder Brar', (32, 46))
# (10307, 'Rania', (4673, 4678))
# (10307, 'Rania', (0, 5))
# (10345, 'Sk Rana', (29, 36))
# (10376, 'Eva Rivera', (0, 10)) ---- (10376, 'Eva Rivera  ', (0, 12))
# (10380, 'Chinyere Adam', (0, 13)) ---- (10380, 'Chinyere Adam\n\nPORTABLE WATER SUPPLY IN', (0, 39))
# (10421, 'Felix Shehu', (4077, 4088)) ---- (10421, 'Felix Shehu Dynamics\n\nProfessional Coaching and Consulting', (4077, 4135))
# (10421, 'Zaharaddeen Shehu', (8498, 8515)) ---- (10421, 'Zaharaddeen Shehu\n\n', (8498, 8517))
# (10429, 'Abdulrazzaq Aqeel', (64, 81))
# (10447, 'Jackie Lopez', (1944, 1956)) ---- (10447, 'Jackie Lopez  ', (1944, 1958))
# (10502, 'Philippe', (41, 49)) ---- (10502, 'VISUALIZATION Philippe', (27, 49))
# (10502, 'Philippe', (3243, 3251)) ---- (10502, 'VISUALIZATION Philippe', (3229, 3251))
# (10505, 'Caroline Parmar', (15, 30))
# (10506, 'Roberto', (0, 7)) ---- (10506, 'Roberto\n\nReflection', (0, 19))
# (10522, 'Jayanti Russo', (14, 27)) ---- (10522, 'Jayanti Russo\n\nSTORYTELLING\n\nChallenge', (14, 52))
# (10541, 'Joshua Marie', (0, 12)) ---- (10541, 'Joshua Marie\n\nDesign Thinking for Innovation   Reflection', (0, 57))
# (10606, 'Omar Martinez', (15, 28))
# (10672, 'Dip Ari', (3062, 3069))
# (10672, 'Dip Ari', (0, 7))
# (10675, 'Wilfredo Gonzales', (26, 43)) ---- (10675, 'Wilfredo Gonzales\n\nChallenge', (26, 54))
# (10682, 'Ahmed Mohammed', (1502, 1516)) ---- (10682, 'Ahmed Mohammed   Design', (1502, 1525))
# (10682, 'Ahmed Mohammed', (2724, 2738)) ---- (10682, 'Ahmed Mohammed   Design', (2724, 2747))
# (10682, 'Ahmed Mohammed', (0, 14)) ---- (10682, 'Ahmed Mohammed   Design', (0, 23))
# (10690, 'Yew Yew', (31, 38)) ---- (10690, 'Yew Yew\n\nChallenge', (31, 49))
# (10841, 'Marta Kowalski', (192, 206)) ---- (10841, 'Marta Kowalski  ��', (192, 210))
# (10880, 'Leslie Young', (1591, 1603)) ---- (10880, 'Leslie Young  ', (1591, 1605))
# (10880, 'Leslie Young', (32, 44)) ---- (10880, 'Leslie Young  ', (32, 46))
# (10880, 'Leslie Young', (3157, 3169)) ---- (10880, 'Leslie Young  ', (3157, 3171))
# (10888, 'Martin Ahmed', (49, 61)) ---- (10888, 'Martin Ahmed\n\nHello', (49, 68))
# (10934, 'Usman Sunday', (0, 12))
# (10944, 'Sneha Santu', (4133, 4144)) ---- (10944, 'Sneha Santu\n\n*', (4133, 4147))
# (10950, 'Matt Riley 201375864478', (1074, 1097)) ---- (10950, 'Matt Riley', (1074, 1084))
# (10963, 'Pedro Paulo Brito', (26, 43))
# (10973, 'Aoife Farrelly', (2060, 2074))
# (10973, 'Aoife Farrelly', (34, 48))
# (10996, 'Fatima Guerrero', (78, 93))
# (11004, 'Joey Boonstra', (0, 13)) ---- (11004, 'Joey Boonstra Creative', (0, 22))
# (11012, 'Khalid Adil', (7, 18)) ---- (11012, 'Khalid Adil\n\nRoll', (7, 24))
# (11064, 'Vikas Ansari', (0, 12))
# (11073, 'Steffen', (8182, 8189))
# (11092, 'Bilal Khan', (44, 54)) ---- (11092, 'Bilal Khan\n\nChallenge & Selection', (44, 77))
# (11095, 'Mohamed', (47, 54))
# (11102, 'Fabio Mendez', (30, 42)) ---- (11102, 'Fabio Mendez\n\nChallenge', (30, 53))
# (11128, 'Pasquale Bergamo', (0, 16)) ---- (11128, 'Pasquale Bergamo\n\nVisualization\n\nChallenge & Seletion\n\nVisualization', (0, 68))
# (11141, 'Petra Schulz', (28, 40)) ---- (11141, 'Petra Schulz\t\r \xa0\t\r \xa0 Challenge', (28, 58))
# (11188, 'Roberto Conti', (0, 13)) ---- (11188, 'Roberto Conti Reflection - Visualization', (0, 40))
# (11192, 'Alessio Valentini', (43, 60)) ---- (11192, 'Alessio Valentini\n\nChallenge', (43, 71))
# (11236, 'David Femi', (0, 10)) ---- (11236, 'David Femi\n\nsherry76@hotmail.com', (0, 32))
# (11243, 'Asia Lemus', (48, 58)) ---- (11243, 'Lemus', (53, 58))
# (11277, 'Anuska Sarkar', (29, 42))
# (11288, 'Juan', (1230, 1234))
# (11297, 'Nubia Parra', (21, 32))
# (11308, 'Flor', (55, 59))
# (11346, 'John Wang', (2494, 2503)) ---- (11346, 'John Wang  ', (2494, 2505))
# (11346, 'John Wang', (4394, 4403)) ---- (11346, 'John Wang  ', (4394, 4405))
# (11346, 'John Wang', (0, 9)) ---- (11346, 'John Wang  ', (0, 11))
# (11354, 'Rachel Karolis', (17, 31)) ---- (11354, 'Rachel Karolis  ', (17, 33))
# (11361, 'Dawn Massetti', (82, 95))
# (11361, 'Agnese Massetti', (2019, 2034))
# (11361, 'Agnese Massetti', (65, 80))
# (11373, 'Murugesan Fawzy', (0, 15)) ---- (11373, 'Murugesan Fawzy  ', (0, 17))
# (11376, 'Cesar Fowler', (15, 27))
# (11392, 'Farooq Tanbir', (73, 86)) ---- (11392, 'Farooq Tanbir\n\n', (73, 88))
# (11399, 'Om Islam', (32, 40))
# (11403, 'Josue Flores', (0, 12)) ---- (11403, 'Josue Flores\n\nChallenge', (0, 23))
# (11417, 'Gerrit De Boer', (8141, 8155)) ---- (11417, 'Gerrit De Boer  angela02', (8141, 8165))
# (11437, 'Javier Hernandez', (52, 68)) ---- (11437, 'Javier Hernandez\n\nChallenge', (52, 79))
# (11443, 'Paola Zagaria', (43, 56)) ---- (11443, 'Paola Zagaria\n\nChallenge & Selection', (43, 79))
# (11451, 'Margarita Bonilla', (111, 128)) ---- (11451, 'Margarita Bonilla      ', (111, 134))
# (11459, 'Alfonso Rodrigues', (0, 17)) ---- (11459, 'Alfonso Rodrigues\n\nDesign Thinking Course\n\nReflection', (0, 53))
# (11474, 'Elizabeth Jose', (0, 14)) ---- (11474, 'Elizabeth Jose\n\nDESIGN', (0, 22))
# (11487, 'Akram Akram', (0, 11)) ---- (11487, 'Akram Akram  Reflection', (0, 23))
# (11492, 'Catherine Donnelly', (52, 70)) ---- (11492, 'Catherine Donnelly  Date', (52, 76))
# (11507, 'Cesar Obando', (0, 12)) ---- (11507, 'Cesar Obando\n\nDesign Thinking', (0, 29))
# (11514, 'Luis Sotelo', (0, 11)) ---- (11514, 'Luis Sotelo\n\nReflection', (0, 23))
# (11521, 'Samantha Busatta', (1971, 1987)) ---- (11521, 'Samantha Busatta\n\n', (1971, 1989))
# (11529, 'Raph', (135, 139))
# (11564, 'Yara', (6647, 6651))
# (11565, 'Pina Varano', (1890, 1901))
# (11565, 'Pina Varano', (36, 47))
# (11565, 'Pina Varano', (3323, 3334))
# (11566, 'Emily', (22, 27)) ---- (11566, 'Emily,Giuseppe', (22, 36))
# (11566, 'Emily', (1587, 1592)) ---- (11566, 'Emily  ', (1587, 1594))
# (11566, 'Emily', (1542, 1547)) ---- (11566, 'Emily  ', (1542, 1549))
# (11566, 'Emily', (987, 992)) ---- (11566, 'Emily  ', (987, 994))
# (11566, 'Giuseppe', (28, 36)) ---- (11566, 'Emily,Giuseppe', (22, 36))
# (11566, 'Emily', (855, 860)) ---- (11566, 'Emily  ', (855, 862))
# (11566, 'Emily', (4304, 4309))
# (11566, 'Emily', (417, 422)) ---- (11566, 'Emily  ', (417, 424))
# (11566, 'Emily', (2058, 2063)) ---- (11566, 'Emily  ', (2058, 2065))
# (11566, 'Emily', (2284, 2289)) ---- (11566, 'Emily  ', (2284, 2291))
# (11569, 'Koky Fathy', (74, 84)) ---- (11569, 'Koky Fathy Challenge', (74, 94))
# (11598, 'Kuldeep Papadopoulos', (2426, 2446)) ---- (11598, 'Kuldeep Papadopoulos  sarah33@yahoo.com', (2426, 2465))
# (11674, 'Amy Malik', (40, 49)) ---- (11674, 'Amy Malik\n\n', (40, 51))
# (11694, 'Saeed Saeed', (29, 40)) ---- (11694, 'Saeed Saeed\n\nTool', (29, 46))
# (11780, 'Jesus Johnson', (0, 13)) ---- (11780, 'Jesus Johnson                                                                                                                                         04/06/2020\n\nReflection', (0, 172))
# (11793, 'Juber Millet', (54, 66))
# (11806, 'Majid Ali', (6723, 6732)) ---- (11806, 'Majid Ali  ', (6723, 6734))
# (11806, 'Majid Ali', (1881, 1890)) ---- (11806, 'Majid Ali  ', (1881, 1892))
# ...
# (17902, 'Santosh Kumar', (89, 102)) ---- (17902, 'Santosh Kumar  Page 1', (89, 110))
# (17926, 'Victoria Rivera', (0, 15)) ---- (17926, 'Victoria Rivera |', (0, 17))
# (17928, 'Pinky Singh', (15, 26))
# (17938, 'Ben', (3881, 3884))
# (17938, 'Ben', (67, 70))
# (17965, 'Mahmoud Nasr', (0, 12)) ---- (17965, 'Mahmoud Nasr-Storytelling\n\nChallenge', (0, 36))
# (17975, 'Pilar Martin', (37, 49)) ---- (17975, 'Pilar Martin\n\nChallenge', (37, 60))
# (17999, 'Jonathan Morales', (54, 70)) ---- (17999, 'Jonathan Morales\n\nChallenge', (54, 81))
# (18024, 'Samukelisiwe', (1372, 1384))
# (18024, 'Samukelisiwe', (1356, 1368))
# (18043, 'Hamed Yusuf', (102, 113)) ---- (18043, 'Hamed Yusuf\n\nIntroduction', (102, 127))
# (18050, 'Gamal Ragab', (38, 49)) ---- (18050, 'Gamal Ragab\n\nChallenge', (38, 60))
# (18072, 'Alessandro Coco', (53, 68)) ---- (18072, 'Alessandro Coco |', (53, 70))
# (18072, 'Alessandro Coco', (4485, 4500)) ---- (18072, 'Alessandro Coco |', (4485, 4502))
# (18072, 'Alessandro Coco', (1833, 1848)) ---- (18072, 'Alessandro Coco |', (1833, 1850))
# (18081, 'Tawhidur', (2260, 2268))
# (18081, 'Tawhidur', (2493, 2501))
# (18099, 'Rosy Mondal', (0, 11))
# (18110, 'Denis Carpentier', (0, 16)) ---- (18110, 'Denis Carpentier\n\n', (0, 18))
# (18167, 'Patricio Lane', (28, 41)) ---- (18167, 'Patricio Lane\n\n', (28, 43))
# (18174, 'Anna Abbate', (29, 40)) ---- (18174, 'Anna Abbate\n\nChallenge', (29, 51))
# (18181, 'Md Lim', (24, 30)) ---- (18181, 'Md Lim\n\nChallenge', (24, 41))
# (18185, 'Ruben', (811, 816))
# (18206, 'Jose Grisales', (0, 13)) ---- (18206, 'Jose Grisales  ', (0, 15))
# (18222, 'Fateema Abdulrashid', (18, 37)) ---- (18222, 'Fateema Abdulrashid\n\nChallenge', (18, 48))
# (18225, 'Esteban Arenas', (84, 98)) ---- (18225, 'Esteban Arenas\n\nChallenge', (84, 109))
# (18246, 'Barbara Dinusha', (15, 30)) ---- (18246, 'Barbara Dinusha\n\nChallenge', (15, 41))
# (18251, 'Vivian Johnson', (83, 97)) ---- (18251, 'Vivian Johnson      ', (83, 103))
# (18284, 'Mercedes Baltazar', (69, 86))
# (18285, 'Sonia Ruiz', (39, 49)) ---- (18285, 'Sonia Ruiz\n\nChallenge', (39, 60))
# (18301, 'Geral Vergara', (1865, 1878)) ---- (18301, 'Geral Vergara �  de � 1', (1865, 1888))
# (18327, 'Abdelrhman Kanarya', (78, 96)) ---- (18327, 'Abdelrhman Kanarya\n\nChallenge', (78, 107))
# (18330, 'Naser Ali', (0, 9)) ---- (18330, 'Naser Ali\n\nChange', (0, 17))
# (18343, 'Andrea Cammarata', (1048, 1064))
# (18343, 'Ree Miller', (1086, 1096))
# (18361, 'Ximena Navarro', (0, 14)) ---- (18361, 'Ximena Navarro Reflection', (0, 25))
# (18365, 'Blanca Meyer', (43, 55))
# (18367, 'Priyanka Sah', (64, 76)) ---- (18367, 'Priyanka Sah\n\nReflection – Visualization\n\nChallenge & Selection    Visuals', (64, 138))
# (18391, 'Mohsin Shahrul', (0, 14)) ---- (18391, 'Mohsin Shahrul\n\nReflection', (0, 26))
# (18430, 'Cheong', (11, 17))
# (18430, 'Cheong', (2897, 2903))
# (18439, 'Jay Bernard', (3209, 3220)) ---- (18439, 'Jay Bernard\n\nApproach', (3209, 3230))
# (18475, 'Matteo Cascino', (25, 39)) ---- (18475, 'Matteo Cascino\n\nChallenge\t&', (25, 52))
# (18503, 'Danny Robinson', (0, 14)) ---- (18503, 'Danny Robinson | Design', (0, 23))
# (18516, 'Sumit Kumar', (242, 253))
# (18547, 'Renata', (22, 28))
# (18564, 'George Aguirre', (29, 43)) ---- (18564, 'George Aguirre\n\nChallenge', (29, 54))
# (18573, 'Nasrullah Perrone', (0, 17)) ---- (18573, 'Nasrullah Perrone  Design Thinking for Innovation', (0, 49))
# (18576, 'Jose Alves', (0, 10)) ---- (18576, 'Jose Alves - Learning Launch\n\nChallenge', (0, 39))
# (18588, 'Asia Faizan', (0, 11)) ---- (18588, 'Faizan', (5, 11))
# (18596, 'Nona', (728, 732))
# (18612, 'Manik Joshi', (6, 17)) ---- (18612, 'Manik Joshi  Email', (6, 24))
# (18658, 'Francesco', (0, 9)) ---- (18658, 'Francesco 1', (0, 11))
# (18658, 'Maribel Navarrete', (13, 30))
# (18669, 'Vincent Lucas', (74, 87)) ---- (18669, 'Vincent Lucas\n\nChallenge', (74, 98))
# (18680, 'Alexander Guerra', (38, 54)) ---- (18680, 'Alexander Guerra\n\nChallenge', (38, 65))
# (18730, 'Romany Refaat', (59, 72))
# (18772, 'Scott', (25, 30))
# (18772, 'Scott', (2987, 2992))
# (18798, 'Nur Sumon', (45, 54)) ---- (18798, 'Nur Sumon\n\nChallenge & Selection', (45, 77))
# (18836, 'Indri Sah', (6726, 6735)) ---- (18836, 'Indri Sah  Date', (6726, 6741))
# (18849, 'Carmen Riveros', (0, 14)) ---- (18849, 'Carmen Riveros\n\nReflection', (0, 26))
# (18856, 'Jose Hany', (0, 9)) ---- (18856, 'Jose Hany  ', (0, 11))
# (18862, 'Hossam Khan', (77, 88)) ---- (18862, 'Hossam Khan\n\nRoadshow', (77, 98))
# (18891, 'Marie Lm', (61, 69)) ---- (18891, 'Marie Lm\n\nChallenge   &   Selection', (61, 96))
# (18912, 'Firoj', (8, 13))
# (18948, 'Concetta Delia', (0, 14)) ---- (18948, 'Concetta Delia\n\n09/15/2017\n\nReflection', (0, 38))
# (18954, 'Antonio Anderson', (25, 41)) ---- (18954, 'Antonio Anderson  ', (25, 43))
# (18957, 'Javier Ahmad', (37, 49)) ---- (18957, 'Javier Ahmad\n\n', (37, 51))
# (18962, 'Chayito Luna', (19, 31)) ---- (18962, 'Chayito Luna\n\nElements  Criteria', (19, 51))
# (18967, 'James King', (32, 42)) ---- (18967, 'James King\n\n1', (32, 45))
# (18980, 'Teresa Cano', (39, 50)) ---- (18980, 'Teresa Cano\n\nChallenge & Selection', (39, 73))
# (18992, 'Abdul', (100, 105)) ---- (18992, 'Abdul\n\nAbdul', (93, 105))
# (18992, 'Ana', (112, 115))
# (18992, 'Abdul', (93, 98)) ---- (18992, 'Abdul\n\nAbdul', (93, 105))
# (18992, 'Ana', (107, 110))
# (19011, 'Ilse Coppens', (11, 23))
# (19049, 'Na Nguyen', (2142, 2151))
# (19049, 'Na Nguyen', (43, 52))
# (19049, 'Na Nguyen', (4652, 4661))
# (19057, 'None Islam', (34, 44))
# (19064, 'Francisco Rinaldi', (0, 17)) ---- (19064, 'Francisco Rinaldi\n\n', (0, 19))
# (19066, 'Bukola Micheal', (13, 27)) ---- (19066, 'Bukola Micheal\n\nChallenge', (13, 38))
# (19084, 'Aya', (5675, 5678))
# (19099, 'Manuel Hernandez', (46, 62)) ---- (19099, 'Manuel Hernandez  11st', (46, 68))
# (19102, 'Md Imran', (138, 146)) ---- (19102, 'Md Imran                    ', (138, 166))
# (19125, 'Murjanatu Colombini', (0, 19)) ---- (19125, 'Murjanatu Colombini\n\nStorytelling\n\nChallenge & Selection\n\nStorytelling', (0, 70))
# (19136, 'Angel Lopez', (36, 47)) ---- (19136, 'Angel Lopez\n\nChallenge', (36, 58))
# (19149, 'Shabbir Ahmad', (27, 40)) ---- (19149, 'Shabbir Ahmad\n\nTitan Engineering & Automation Limited\n\n', (27, 82))
# (19179, 'Jose Mejia', (61, 71)) ---- (19179, 'Jose Mejia\n\nChallenge', (61, 82))
# (19188, 'Fabio Souza', (0, 11)) ---- (19188, 'Fabio Souza  |', (0, 14))
# (19220, 'Abdo Ali', (70, 78)) ---- (19220, 'Abdo Ali\n\nChallenge', (70, 89))
# (19223, 'Jake Lloyd', (0, 10)) ---- (19223, 'Jake Lloyd\n\nDirector', (0, 20))
# (19238, 'Diana Hernandez', (57, 72)) ---- (19238, 'Diana Hernandez\n\nChallenge', (57, 83))
# (19244, 'Jesus', (342, 347)) ---- (19244, 'Jesus  Kamal', (342, 354))
# (19244, 'Kamal', (349, 354)) ---- (19244, 'Jesus  Kamal', (342, 354))
# (19254, 'Jack', (0, 4)) ---- (19254, 'Jack Reflection', (0, 15))
# (19296, 'Joe Walker', (3515, 3525)) ---- (19296, 'Joe Walker  ', (3515, 3527))
# (19296, 'Joe Walker', (3696, 3706)) ---- (19296, 'Joe Walker\n\nWellness Wanderers', (3696, 3726))
# (19296, 'Joe Walker', (0, 10)) ---- (19296, 'Joe Walker  ', (0, 12))
# (19298, 'Ariel Granados', (43, 57)) ---- (19298, 'Ariel Granados\n\nChallenge', (43, 68))
# (19315, 'Giorgia Casazza', (0, 15))
# (19352, 'Jose Hernandez', (0, 14)) ---- (19352, 'Jose Hernandez\n\n', (0, 16))
# (19360, '\n\n', (0, 2))
# (19371, 'Grace Adeyemi', (66, 79)) ---- (19371, 'Grace Adeyemi\n\nChallenge', (66, 90))
# (19426, 'Siuwai Chan', (80, 91)) ---- (19426, 'Siuwai Chan\n\nChallenge', (80, 102))
# (19593, 'Jalen Gamez', (21, 32))
# (19600, 'Basma Ahmed', (0, 11)) ---- (19600, 'Basma Ahmed\n\nChallenge', (0, 22))
# (19602, 'Guadalupe Khan', (62, 76))
# (19623, 'Mostafa Darwish', (0, 15)) ---- (19623, 'Mostafa Darwish  X49465531', (0, 26))
# (19667, 'Gilbert Joseph', (52, 66)) ---- (19667, 'Gilbert Joseph\n\nChallenge', (52, 77))
# (19669, 'Victor Luis', (36, 47))
# (19670, 'Sure Ravishankar', (31, 47)) ---- (19670, 'Ravishankar', (36, 47))
# (19697, 'Ever', (22, 26))
# (19748, 'Tiago Costa', (8077, 8088)) ---- (19748, 'Tiago Costa\n\n', (8077, 8090))
# (19771, 'Khalil Martinez', (837, 852)) ---- (19771, 'Khalil Martinez Pin', (837, 856))
# (19795, 'Md Monir Miah', (2810, 2823)) ---- (19795, 'Md Monir Miah\n\n', (2810, 2825))
# (19827, 'Hauwa Hassan', (28, 40)) ---- (19827, 'Hauwa Hassan  ', (28, 42))
# (19831, 'Ram Seema', (74, 83))
# (19876, 'Andrew Williams', (57, 72)) ---- (19876, 'Andrew Williams\n\nChallenge', (57, 83))
# (19965, 'Alejandro Raj', (72, 85)) ---- (19965, 'Alejandro Raj\n\n1', (72, 88))
# (19981, 'Jose Acevedo', (34, 46)) ---- (19981, 'Jose Acevedo\n\nReflection', (34, 58))
# (20003, 'Nasri', (20, 25))
# (20071, 'Harpreet Toor', (31, 44)) ---- (20071, 'Harpreet Toor  ', (31, 46))
# (20079, 'Ameen Wang', (2913, 2923)) ---- (20079, 'Ameen Wang\n\nDesign Thinking Process\n\nThe', (2913, 2953))
# (20126, 'Nokubongwa', (2431, 2441)) ---- (20126, 'Aunt Nokubongwa', (2426, 2441))
# (20126, 'Nokubongwa', (2506, 2516)) ---- (20126, 'Aunt Nokubongwa', (2501, 2516))
# (20126, 'Nokubongwa', (3962, 3972)) ---- (20126, 'Aunt Nokubongwa', (3957, 3972))
# (20126, 'Nokubongwa', (2141, 2151)) ---- (20126, 'Aunt Nokubongwa', (2136, 2151))
# (20126, 'Sebastian', (2183, 2192))
# (20133, 'Francisco Rojas', (14, 29)) ---- (20133, 'Francisco Rojas - keith35@hotmail.com', (14, 51))
# (20174, 'Zubair Khan', (678, 689))
# (20209, 'Aldo Bassi', (0, 10)) ---- (20209, 'Aldo Bassi - Mind Mapping Tool\n\nChallenge', (0, 41))
# (20211, 'Janet Chioma', (3403, 3415)) ---- (20211, 'Janet Chioma\n\nDopemu', (3403, 3423))
# (20229, 'Venkat', (5168, 5174))
# (20229, 'Venkat', (5642, 5648))
# (20229, 'Venkat', (5867, 5873))
# (20229, 'Venkat', (6129, 6135))
# (20245, 'Nena', (1025, 1029))
# (20250, 'Fran Cisco', (473, 483)) ---- (20250, "Fran Cisco's", (473, 485))
# (20253, 'Marcel De Haas', (4008, 4022)) ---- (20253, 'Marcel De Haas  Design Thinking for Business Innovation', (4008, 4063))
# (20258, 'Arun Khan', (55, 64)) ---- (20258, 'Khan', (60, 64))
# (20258, 'Arun Khan', (116, 125)) ---- (20258, 'Khan', (121, 125))
# (20264, 'Cristina Avila', (64, 78)) ---- (20264, 'Cristina Avila\n\nChallenge', (64, 89))
# (20301, 'Om Saleem', (120, 129))
# (20329, 'Ralf Haron', (0, 10)) ---- (20329, 'Ralf Haron - Mind', (0, 17))
# (20330, 'Tota', (2183, 2187))
# (20330, 'Tota', (1628, 1632))
# (20330, 'Tota', (1454, 1458))
# (20330, 'Tota', (2357, 2361))
# (20331, 'Thulisile Prinsloo', (1932, 1950))
# (20331, 'Thulisile Prinsloo', (0, 18))
# (20392, 'Rose Bo', (12, 19)) ---- (20392, 'Rose Bo\n\nChallenge', (12, 30))
# (20398, 'Loga', (69, 73))
# (20398, 'Loga', (63, 67))
# (20412, 'Anne Arena', (0, 10)) ---- (20412, 'Anne Arena\n\nDesign Thinking for Innovation\n\nMind Mapping for Staffing Struggles\n\nChallenge', (0, 90))
# (20423, 'Julien Adam', (8, 19)) ---- (20423, 'Julien Adam\n\nBuilding', (8, 29))
# (20430, 'Daniele Khan', (11, 23)) ---- (20430, 'Daniele Khan  Page', (11, 29))
# (20430, 'Daniele Khan', (2366, 2378)) ---- (20430, 'Daniele Khan  Page', (2366, 2384))
# (20430, 'Daniele Khan', (4317, 4329)) ---- (20430, 'Daniele Khan  Page', (4317, 4335))
# (20442, 'Man Yang', (0, 8))
# (20453, 'Efrain', (0, 6))
# (20472, 'Estrella Paredes', (3539, 3555)) ---- (20472, 'Estrella Paredes  Fecha', (3539, 3562))
# (20518, 'Ariful Morsy', (0, 12)) ---- (20518, 'Ariful Morsy  ', (0, 14))
# (20530, 'Roberto Christian', (0, 17)) ---- (20530, 'Roberto Christian\n\nIssue', (0, 24))
# (20622, 'Tammy Rivera', (0, 12)) ---- (20622, 'Tammy Rivera Design Thinking', (0, 28))
# (20637, 'Comfort Musah', (3981, 3994)) ---- (20637, 'Comfort Musah  ', (3981, 3996))
# (20637, 'Comfort Musah', (0, 13))
# (20648, 'Hyder Singh', (7279, 7290))
# (20667, 'Jahed', (3713, 3718)) ---- (20667, 'Jahed\n\n', (3713, 3720))
# (20667, 'Jahed', (2770, 2775)) ---- (20667, 'Jahed\n\nReflection', (2770, 2787))
# (20680, 'Ramon Solis', (0, 11)) ---- (20680, 'Ramon Solis 12/31/15', (0, 20))
# (20725, 'Sonia Frigo', (40, 51)) ---- (20725, 'Sonia Frigo  Design Thinking for Business Innovation\n\nChallenge', (40, 103))
# (20741, 'Mustapha Yusuf', (0, 14)) ---- (20741, 'Mustapha Yusuf  Design Thinking Assignment', (0, 42))
# (20741, 'Mustapha Yusuf', (4274, 4288)) ---- (20741, 'Mustapha Yusuf  Design Thinking Assignment', (4274, 4316))
# (20755, 'Aziz Khan', (51, 60)) ---- (20755, 'Aziz Khan\n\nVisualization\n\nChallenge & Selection', (51, 98))
# (20791, 'Wilfran Arbelaez', (18, 34)) ---- (20791, 'Wilfran Arbelaez\n\nCHALLENGE', (18, 45))
# (20799, 'Mariana Cruz', (11, 23)) ---- (20799, 'Mariana Cruz - Mind', (11, 30))
# (20910, 'Edwin', (6409, 6414))
# (20910, 'Edwin', (0, 5)) ---- (20910, 'Edwin | Confidential\n\nChallenge & Selection', (0, 43))
# (20910, 'Edwin', (3036, 3041)) ---- (20910, 'Edwin | Confidential', (3036, 3056))
# (20922, 'Precious Hill', (1664, 1677)) ---- (20922, 'Hill', (1673, 1677))
# (21023, 'Zaharaddeen Ashfaq', (22, 40)) ---- (21023, 'Zaharaddeen Ashfaq\n\nCHALLENGE', (22, 51))
# (21179, 'Ana Medina', (0, 10)) ---- (21179, 'Ana Medina\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0Design', (0, 136))
# (21179, 'Ana Medina', (5330, 5340)) ---- (21179, 'Ana Medina\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0Design', (5330, 5466))
# (21188, 'Angel Garcia', (0, 12)) ---- (21188, 'Angel Garcia\n\nCoursera', (0, 22))
# (21197, 'Md Shamim', (6, 15)) ---- (21197, 'Md Shamim\n\nReflection', (6, 27))
# (21226, 'Mona Ahmed', (107, 117))
# (21238, 'Edward Mohd Nor', (1767, 1782)) ---- (21238, 'Edward Mohd', (1767, 1778))
# (21242, 'Mohd Adham', (0, 10)) ---- (21242, 'Mohd Adham’ s', (0, 13))
# (21262, 'Andres Rodriguez', (94, 110)) ---- (21262, 'Andres Rodriguez\n\nChallenge', (94, 121))
# (21313, 'Mari Vaz', (2846, 2854)) ---- (21313, 'Mari Vaz\n\n05.02.2017', (2846, 2866))
# (21371, 'Marisela Godwin', (0, 15)) ---- (21371, 'Marisela Godwin       Reflection', (0, 32))
# (21381, 'Terry Marchal', (5010, 5023))
# (21469, 'Fatme Ismail', (1555, 1567))
# (21511, 'Elena', (25, 30))
# (21610, 'Diego Sofia', (33, 44)) ---- (21610, 'Diego Sofia\n\nChallenge & Selection', (33, 67))
# (21613, 'Siti', (33, 37))
# (21613, 'Abood', (58, 63))
# (21704, 'Kaline Pacheco', (30, 44))
# (21770, 'Cindy Ng', (14, 22)) ---- (21770, 'Cindy Ng  cs13', (14, 28))
# (21770, 'Cindy Ng', (1978, 1986)) ---- (21770, 'Cindy Ng  cs13  ', (1978, 1994))
# (21844, 'Mg Maurel', (0, 9))
# (21959, 'Jesus Alcala', (0, 12)) ---- (21959, 'Jesus Alcala  ', (0, 14))
# (21968, 'Jamie Dickinson', (28, 43)) ---- (21968, 'Jamie Dickinson      ', (28, 49))
# (21988, 'Anisa Hussain', (33, 46)) ---- (21988, 'Anisa Hussain - 8743214\n\nNon-Business Use\n\nVisualization\n\nChallenge & Selection', (33, 112))
# (21988, 'Anisa Hussain', (3130, 3143)) ---- (21988, 'Anisa Hussain - 8743214\n\nNon-Business Use\n\nInsight & Approach', (3130, 3191))
# (22068, 'Marine', (0, 6))
# (22156, 'Angel Polanco', (14, 27))
# (22166, 'Auwal De Maio', (38, 51)) ---- (22166, 'Turkey Auwal De Maio', (31, 51))
# (22180, 'Jenny', (0, 5)) ---- (22180, 'Jenny\n\nReflection\n\nChallenge & Selection', (0, 40))
# (22221, 'Jose Luis Gaudenzi', (0, 18)) ---- (22221, 'Jose Luis Gaudenzi  ', (0, 20))
# (22237, 'Rodolfo Jimenez', (78, 93)) ---- (22237, 'Rodolfo Jimenez\n\nChallenge', (78, 104))
# (22286, 'Juan Carlos Opazo', (0, 17)) ---- (22286, 'Juan Carlos Opazo - Design Learning Course', (0, 42))
# (22336, 'Meh Singh', (28, 37)) ---- (22336, 'Meh Singh\n\nMind', (28, 43))
# (22336, 'Meh Singh', (2007, 2016)) ---- (22336, 'Meh Singh\n\nParticipant', (2007, 2029))
# (22379, 'Raj', (169, 172))
# (22540, 'Jesus Rosado', (0, 12)) ---- (22540, 'Jesus Rosado Peer Graded Assignment', (0, 35))
# (22580, 'Maria Adam', (0, 10)) ---- (22580, 'Maria Adam Storytelling', (0, 23))
# (22635, 'Anthony Abubakar', (101, 117)) ---- (22635, 'Anthony Abubakar  Design Thinking Tool:', (101, 140))
# (22660, 'Amina Koko', (3697, 3707)) ---- (22660, 'Amina Koko Approach', (3697, 3716))

# %%
print_likely_successful_entities(url_set_true, url_set_detected)
# Out:
# Out of 58 entities for NAME category, 55 entities might have likely been successfully detected by Presidio.
# (1309, 'https://www.hall.biz/wp-contenthome.html', (2581, 2621)) ---- (1309, 'https://www.hall.bi', (2581, 2600))
# (3202, 'https://www.youtube.com/channel/UC1ElAcppeuhfet nYZqnhEXw', (200, 257)) ---- (3202, 'https://www.youtube.com/channel/UC1ElAcppeuhfet', (200, 247))
# (3202, 'tps://www.facebook.com/bclark', (169, 198)) ---- (3202, 'www.facebook.com/bclark', (175, 198))
# (3515, 'https://www.youtube.com/watch?v=mYxoZaftuNN', (2166, 2209)) ---- (3515, 'https://www.youtube.com/watch?v=mYxoZaftuNN.', (2166, 2210))
# (3592, 'https://www.peterson.net/tag/app/listmain.php', (222, 267)) ---- (3592, 'https://www.peterson.net/tag/app/listmain.php.', (222, 268))
# (5358, 'https://schaefer.biz/posts/search/appsearch.php', (1543, 1590)) ---- (5358, 'https://schaefer.bi', (1543, 1562))
# (5861, 'https://www.stevens.biz/wp-contentindex.jsp', (3227, 3270)) ---- (5861, 'https://www.stevens.bi', (3227, 3249))
# (6257, 'http://mcneil.org/list/taghomepage.htm', (721, 759)) ---- (6257, 'http://mcneil.org/list/taghomepage.htm.', (721, 760))
# (7183, 'http://bailey-perry.com/posts/tag/categoriesfaq.htm', (3411, 3462)) ---- (7183, 'http://bailey-perry.com/posts/tag/categoriesfaq.htm”', (3411, 3463))
# (7680, 'http://www.melendez.biz/postsabout.html', (1903, 1942)) ---- (7680, 'http://www.melendez.bi', (1903, 1925))
# (8013, 'http://dunlap.com/explore/list/appmain.php', (1925, 1967)) ---- (8013, 'http://dunlap.com/explore/list/appmain.php,', (1925, 1968))
# (8088, 'https://www.cooper.com/blog/maincategory.htm', (2118, 2162)) ---- (8088, 'https://www.cooper.com/blog/maincategory.htm.', (2118, 2163))
# (8588, 'http://ramirez-burton.org/postsauthor.php', (3475, 3516)) ---- (8588, 'http://ramirez-burton.org/postsauthor.php.', (3475, 3517))
# (9297, 'https://www.youtube.com/watch?v=y1ZQmZmkaDD', (5286, 5329)) ---- (9297, 'https://www.youtube.com/watch?v=y1ZQmZmkaDD,', (5286, 5330))
# (9297, 'https://www.youtube.com/watch?v=HePCiQaZo2X', (5332, 5375))
# (9470, 'http://perry-king.biz/main/exploreregister.jsp', (3899, 3945)) ---- (9470, 'http://perry-king.bi', (3899, 3919))
# (9534, 'https://www.fitzgerald.biz/categories/explorehomepage.php', (4334, 4391)) ---- (9534, 'https://www.fitzgerald.bi', (4334, 4359))
# (9881, 'https://roberts.biz/blog/postsprivacy.htm', (586, 627)) ---- (9881, 'https://roberts.bi', (586, 604))
# (9982, 'http://www.jones.info/category/posts/categoryprivacy.html', (3033, 3090)) ---- (9982, 'http://www.jones.info/category/posts/categoryprivacy.html,   https://www.forbes.com/', (3033, 3117))
# (10418, 'http://beck-calhoun.biz/bloghome.jsp', (578, 614)) ---- (10418, 'http://beck-calhoun.bi', (578, 600))
# (10647, 'https://www.osborn.com/bloghomepage.htm', (1233, 1272)) ---- (10647, 'https://www.osborn.com/bloghomepage.htm.', (1233, 1273))
# (11428, 'http://camacho.biz/blog/main/appfaq.jsp', (3093, 3132)) ---- (11428, 'http://camacho.bi', (3093, 3110))
# (11849, 'http://www.daniels.biz/tagssearch.php', (7283, 7320)) ---- (11849, 'http://www.daniels.bi', (7283, 7304))
# (12043, 'http://thomas.biz/list/taghome.php', (1779, 1813)) ---- (12043, 'http://thomas.bi', (1779, 1795))
# (12154, 'https://youtu.be/Kb-hqNGr5lJ', (2761, 2789)) ---- (12154, 'https://youtu.be/Kb-hqNGr5lJ,', (2761, 2790))
# (12267, 'https://www.johnson.biz/wp-content/appcategory.php', (4709, 4759)) ---- (12267, 'https://www.johnson.bi', (4709, 4731))
# (12267, 'https://www.johnson.biz/wp-content/appcategory.php', (3128, 3178)) ---- (12267, 'https://www.johnson.bi', (3128, 3150))
# (12509, 'http://caldwell.com/blog/exploresearch.php', (329, 371)) ---- (12509, 'http://caldwell.com/blog/exploresearch.php.', (329, 372))
# (12640, 'https://youtu.be/y1G4uZlMHO4', (2436, 2464)) ---- (12640, 'https://www.youtube.com/watch?v=jIVX30LMgZN&fprpjqt=wbqnceo  https://youtu.be/y1G4uZlMHO4', (2375, 2464))
# (12640, 'https://youtu.be/uDRN9IA2T5', (2467, 2494)) ---- (12640, 'https://youtu.be/uDRN9IA2T5g', (2467, 2495))
# (13103, 'https://www.roman.info/list/appindex.html', (3375, 3416))
# (13103, 'https://www.roman.info/list/appindex.html', (856, 897)) ---- (13103, 'https://www.roman.info/list/appindex.html,', (856, 898))
# (13103, 'https://hernandez.com/exploremain.html', (3335, 3373)) ---- (13103, 'https://hernandez.com/exploremain.html,', (3335, 3374))
# (13278, 'https://www.chambers.com/wp-content/tagshomepage.php', (3295, 3347)) ---- (13278, 'https://www.chambers.com/wp-content/tagshomepage.php.', (3295, 3348))
# (13473, 'https://www.norris.biz/listmain.asp', (5042, 5077)) ---- (13473, 'https://www.norris.bi', (5042, 5063))
# (13998, 'https://parrish.biz/listpost.html', (1284, 1317)) ---- (13998, 'https://parrish.bi', (1284, 1302))
# (14186, 'https://jackson-phillips.com/main/tagauthor.html', (1698, 1746)) ---- (14186, 'https://jackson-phillips.com/main/tagauthor.html.', (1698, 1747))
# (14255, 'https://www.murray.biz/searchhomepage.htm', (1594, 1635)) ---- (14255, 'https://www.murray.bi', (1594, 1615))
# (14255, 'http://carpenter.com/mainfaq.asp', (496, 528)) ---- (14255, 'http://carpenter.com/mainfaq.asp.', (496, 529))
# (14315, 'http://schaefer.com/categorieshomepage.htm', (796, 838)) ---- (14315, 'http://schaefer.com/categorieshomepage.htm,', (796, 839))
# (14944, 'http://chang.biz/wp-content/categoriesauthor.htm', (2398, 2446)) ---- (14944, 'http://chang.bi', (2398, 2413))
# (15308, 'https://www.walsh-hudson.biz/categoryhomepage.asp', (4386, 4435)) ---- (15308, 'https://www.walsh-hudson.bi', (4386, 4413))
# (15517, 'http://www.jackson-garcia.biz/main/app/maincategory.html', (1325, 1381)) ---- (15517, 'http://www.jackson-garcia.bi', (1325, 1353))
# (15765, 'http://thomas.net/category/exploreabout.jsp', (5474, 5517)) ---- (15765, 'https://www.sanders.com/wp-contentindex.html  https://www.burton-jordan.com/category/mainlogin.php; http://thomas.net/category/exploreabout.jsp', (5374, 5517))
# (15765, 'https://www.burton-jordan.com/category/mainlogin.php', (5420, 5472))
# (15852, 'https://walters.biz/explore/categoriesregister.html', (3676, 3727)) ---- (15852, 'https://walters.bi', (3676, 3694))
# (15904, 'https://ramirez-white.com/posts/bloglogin.htm', (284, 329)) ---- (15904, 'https://ramirez-white.com/posts/bloglogin.htm.', (284, 330))
# (16435, 'madehttps://smith.org/main/list/tagsprivacy.htm', (3581, 3628)) ---- (16435, 'https://smith.org/main/list/tagsprivacy.htm', (3585, 3628))
# (16654, 'https://www.jones-baird.biz/categories/category/tagindex.html', (727, 788)) ---- (16654, 'https://www.jones-baird.bi', (727, 753))
# (17221, 'http://kidd.com/tag/tagshomepage.php', (2446, 2482)) ---- (17221, 'http://kidd.com/tag/tagshomepage.php.', (2446, 2483))
# (17292, 'https://www.hudson.biz/tag/posts/listindex.htm', (5988, 6034)) ---- (17292, 'https://www.hudson.bi', (5988, 6009))
# (18824, 'http://stevens.com/search/tagauthor.html', (60, 100)) ---- (18824, 'http://stevens.com/search/tagauthor.html.', (60, 101))
# (18995, 'https://www.garrett.biz/list/category/postslogin.html', (36, 89)) ---- (18995, 'https://www.garrett.bi', (36, 58))
# (19277, 'https://www.ramirez.biz/listmain.html', (42, 79)) ---- (19277, 'https://www.ramirez.bi', (42, 64))
# (19609, 'https://jackson-manning.info/blog/appsearch.html', (2018, 2066)) ---- (19609, 'https://jackson-manning.info/blog/appsearch.html,', (2018, 2067))
# (19719, 'http://www.carpenter-davis.info/blog/mainabout.php', (4686, 4736)) ---- (19719, 'http://www.carpenter-davis.info/blog/mainabout.php,', (4686, 4737))
# (20216, 'https://www.sullivan-fisher.biz/main/app/postscategory.jsp', (2648, 2706)) ---- (20216, 'https://www.sullivan-fisher.bi', (2648, 2678))
# (20565, 'http://jensen-miller.biz/app/categories/blogregister.htm', (1091, 1147)) ---- (20565, 'http://jensen-miller.bi', (1091, 1114))

# %%
print_likely_successful_entities(email_set_true, email_set_detected)
# Out:
# Out of 1 entities for NAME category, 1 entities might have likely been successfully detected by Presidio.
# (11699, 'srpe…r@....kelsey21@gmail.com', (6157, 6186)) ---- (11699, 'kelsey21@gmail.com', (6168, 6186))

# %%
print_likely_successful_entities(phoneNum_set_true, phoneNum_set_detected)
# Out:
# Out of 0 entities for NAME category, 0 entities might have likely been successfully detected by Presidio.

# %%
print_likely_successful_entities(location_set_true, location_set_detected)
# Out:
# Out of 9 entities for NAME category, 4 entities might have likely been successfully detected by Presidio.
# (9854, '591 Smith Centers Apt. 656\nJoshuamouth, RI 95963', (16, 64))
# (10447, '6828 Harris Squares Suite 829\nChristinatown, SD 16180', (1958, 2011)) ---- (10447, 'SD 16180', (2003, 2011))
# (10447, '6828 Harris Squares Suite 829\nChristinatown, SD 16180', (14, 67)) ---- (10447, 'SD 16180', (59, 67))
# (10447, '6828 Harris Squares Suite 829\nChristinatown, SD 16180', (5883, 5936)) ---- (10447, 'SD 16180', (5928, 5936))
# (11442, '743 Erika Bypass Apt. 419\nAndreahaven, IL 54207', (714, 761))
# (13733, '61955 Kelly Ford\nAndretown, MH 48154', (108, 144)) ---- (13733, 'MH 48154', (136, 144))
# (13733, '0475 Mclean Flats\nSouth Sara, NY 27576', (1013, 1051))
# (14025, '5468 Keith Islands Suite 664\nLake John, VI 73879', (4703, 4751))
# (18745, '2828 Kristy Pass Suite 749\nThompsonbury, VI 21802', (306, 355))

# %% [markdown]
# DDL: August 26, 2024 (Aiming at presentation towards Ken)
# 1. Post processing - AL
# 2. Other models - YW, JS
# 3. Random sampling (2000 cases) or stratified sampling for each category - JS
# 4. find mappings for ID_NUM, STREET_ADDRESS, USERNAME - JS

# %% [markdown]
# EDM paper, sequence labeling, we prompt GPT to do BIO, performance might not be good
# Why we use GPT model? Other models?
# Let's do mini first.
